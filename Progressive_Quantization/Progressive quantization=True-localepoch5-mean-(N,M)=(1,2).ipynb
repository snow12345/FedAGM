# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="2"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users,class_per_user=1):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=class_per_user
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
def Quantize(input):
    result=torch.sign(input)
    return result

# %% [markdown]
# 아직 이름만 signSGD이지 일반적인 SGD와 같을 때

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        #self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = (F.relu(self.conv3(x)))
        x = x.view(-1, 64*4*4)
        x = F.relu(self.fc1(x))
        x = (self.fc2(x))
        
        return x

# %%
def get_from_absmomentum(momentum,func):
    save=0
    if func==max:
        save=-float('inf')
    if func==min:
        save=float('inf')
    numel=0
    for el in momentum:
        el=abs(el)
        if func=='mean':
            save+=el.sum()
            numel+=el.numel()
        if func==max:
            save=save if save>el.max() else el.max()
        if func==min:
            save=save if save<el.min() else el.min()

    if func=='mean':
        save/=numel
    
    
    return save

# %% [markdown]
# signSGD Federated learning

# %%
def error_send(momentum,p_t,cut):
    boundary_low=cut*0.7
    boundary_high=cut*1.3
    abs_moment=abs(momentum)
    result=p_t*((abs_moment<boundary_low)|(abs_moment>boundary_high))
    return result

# %%
import torch
from torch.optim import Optimizer#, required


class signSGD(Optimizer):
    r"""Implements stochastic gradient descent (optionally with momentum).

    Nesterov momentum is based on the formula from
    `On the importance of initialization and momentum in deep learning`__.

    Args:
        params (iterable): iterable of parameters to optimize or dicts defining
            parameter groups
        lr (float): learning rate
        momentum (float, optional): momentum factor (default: 0)
        weight_decay (float, optional): weight decay (L2 penalty) (default: 0)
        dampening (float, optional): dampening for momentum (default: 0)
        nesterov (bool, optional): enables Nesterov momentum (default: False)

    Example:
        >>> optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
        >>> optimizer.zero_grad()
        >>> loss_fn(model(input), target).backward()
        >>> optimizer.step()

    __ http://www.cs.toronto.edu/%7Ehinton/absps/momentum.pdf

    .. note::
        The implementation of SGD with Momentum/Nesterov subtly differs from
        Sutskever et. al. and implementations in some other frameworks.

        Considering the specific case of Momentum, the update can be written as

        .. math::
            \begin{aligned}
                v_{t+1} & = \mu * v_{t} + g_{t+1}, \\
                p_{t+1} & = p_{t} - \text{lr} * v_{t+1},
            \end{aligned}

        where :math:`p`, :math:`g`, :math:`v` and :math:`\mu` denote the 
        parameters, gradient, velocity, and momentum respectively.

        This is in contrast to Sutskever et. al. and
        other frameworks which employ an update of the form

        .. math::
            \begin{aligned}
                v_{t+1} & = \mu * v_{t} + \text{lr} * g_{t+1}, \\
                p_{t+1} & = p_{t} - v_{t+1}.
            \end{aligned}

        The Nesterov version is analogously modified.
    """

    def __init__(self, params, lr=-1, momentum=0, dampening=0,
                 weight_decay=0, nesterov=False,error=[]):
        #if lr is not required and lr < 0.0:
        if lr < 0.0:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if momentum < 0.0:
            raise ValueError("Invalid momentum value: {}".format(momentum))
        if weight_decay < 0.0:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))

        defaults = dict(lr=lr, momentum=momentum, dampening=dampening,
                        weight_decay=weight_decay, nesterov=nesterov)
        if nesterov and (momentum <= 0 or dampening != 0):
            raise ValueError("Nesterov momentum requires a momentum and zero dampening")
        super(signSGD, self).__init__(params, defaults)
        self.error=error
        self.num_of_step=0

    def __setstate__(self, state):
        super(signSGD, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('nesterov', False)

    @torch.no_grad()
    def step(self,On=True,cut=0.0007, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()
        #print(self.param_groups)
        gradient=[]
        first=1
        
        for group in self.param_groups:
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            dampening = group['dampening']
            nesterov = group['nesterov']

            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad
                
                if weight_decay != 0:
                    d_p = d_p.add(p, alpha=weight_decay)
                if momentum != 0:
                    param_state = self.state[p]
                    if 'momentum_buffer' not in param_state:
                        buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
                    else:
                        buf = param_state['momentum_buffer']
                        if On==True:
                            d_p=error_send(momentum=buf,p_t=d_p,cut=cut)
                        
                            
                        buf.mul_(momentum).add_(d_p, alpha=1 - dampening)
                    '''if nesterov:
                        d_p = d_p.add(buf, alpha=momentum)
                    else:
                        d_p = buf'''

                p.add_(d_p, alpha=-group['lr'])

        return loss
    @torch.no_grad()
    def get_momentum(self, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()
        #print(self.param_groups)
        momentum=[]
        for group in self.param_groups:

            

            for p in group['params']:
                param_state = self.state[p]
                momentum.append(param_state['momentum_buffer'])
        return (momentum)
    
    @torch.no_grad()
    def get_quantized_momentum(self, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()
        #print(self.param_groups)
        momentum=[]
        for group in self.param_groups:

            

            for p in group['params']:
                param_state = self.state[p]
                momentum.append(torch.sign(param_state['momentum_buffer']))
        return (momentum)

# %%
def get_quantizationLoss(gradient,lr):
    total=0
    for layer_grad in gradient:
        
        quantized_layer_grad=torch.sign(layer_grad)*lr
        layer_quantize_loss=(abs(layer_grad-quantized_layer_grad)).sum()
        total+=layer_quantize_loss
    return total

# %%
class LocalUpdate(object):
    def __init__(self,lr,local_epoch,device,batch_size, dataset=None, idxs=None):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.iterate=0
        self.error=[]
        self.cut_epoch=int(0.6*self.local_epoch)

    def train(self,net,On=True):
        net.train()
        # train and update
        optimizer=signSGD(net.parameters(), lr=0.1,error=self.error,momentum=1)
        #print(f"On:{On}")
        epoch_loss = []
        for iter in range(self.local_epoch):
            if iter<self.cut_epoch:
                this_on=False
                cut=self.lr
            if iter==self.cut_epoch:
                this_on=On
                this_momentum=optimizer.get_momentum()
                cut=get_from_absmomentum(this_momentum,'mean')
                
                
            batch_loss = []
            
            
            #print(this_on,cut)
            
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs = net(images)
                loss = self.loss_func(log_probs, labels)
                loss.backward()
                optimizer.step(On=this_on,cut=cut)
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        momentum=optimizer.get_quantized_momentum()
        return momentum, sum(epoch_loss) / len(epoch_loss),cut

# %%
def list_add(a,b,c):
    result=[]
    for i in range(len(a)):
        result.append(a[i]+b[i]*c)
    return result

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.1
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %% [markdown]
# 맨 처음에 local gradient sign이 0인 경우가 있는 것 같다(진짜로 0이어서 그것의 sign도 0이 나오는 경우...)

# %%
#low boundary 안에 있는 녀석들만 update했을 때
learning_rate=0.0007
for epoch in range(global_epoch):

    #m=max(int(C*num_clients),1)
    m=5
    print(f"This is global {epoch} epoch")
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    first=1
    local_setting=[]
    for repeat in range(1):
        local_gradient=[]
        local_loss=[]
        local_cut=[]
        
        for idx,user in enumerate(selected_user):
            #print(f"client :{idx}")
            if first==1:
                #local_setting.append(LocalUpdate(lr=0.0007,local_epoch=50,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user]))
                local_setting.append(LocalUpdate(lr=learning_rate,local_epoch=3,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user]))
                this_local_setting=local_setting[-1]
            else:
                this_local_setting=local_setting[idx]
            gradient,loss,cut=this_local_setting.train(net=copy.deepcopy(FedAvg_model).to(device),On=True)

            local_gradient.append(copy.deepcopy(gradient))
            #print(local_weight[0].keys())
            local_loss.append(copy.deepcopy(loss))
            local_cut.append(copy.deepcopy(cut))
        #print("Local_gradient")
        #print(local_gradient)
        first=0
        FedAvg_gradient=copy.deepcopy(local_gradient[0])
        for i in range(len(FedAvg_gradient)):
            FedAvg_gradient[i]*=local_cut[0]
        #print(local_gradient)
        #for key in FedAvg_weight.keys():
        for i in range(1,len(local_gradient)):
            FedAvg_gradient=list_add(FedAvg_gradient,local_gradient[i],local_cut[i])
            #print(i)
            #print(FedAvg_gradient[0])
        #print("FedAvg_gradient")
        #print(FedAvg_gradient)
        temp=FedAvg_model.state_dict()
        for idx,key in enumerate(temp.keys()):
            #print(key)
            #print(temp[key].size())
            #print(FedAvg_gradient[idx].size())
            #print(torch.sign(FedAvg_gradient[idx]))
            #print(torch.sign(FedAvg_gradient[idx])*learning_rate)
            temp[key]+=-learning_rate*torch.sign(FedAvg_gradient[idx])
            #print(temp[key])
        FedAvg_model.load_state_dict(temp)
    first=1
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.295
# Accuracy of the network on the 10000 test images: 12.280000 %
# This is global 1 epoch
#  Average loss 2.276
# Accuracy of the network on the 10000 test images: 13.700000 %
# This is global 2 epoch
#  Average loss 2.240
# Accuracy of the network on the 10000 test images: 12.550000 %
# This is global 3 epoch
#  Average loss 2.196
# Accuracy of the network on the 10000 test images: 16.730000 %
# This is global 4 epoch
#  Average loss 2.160
# Accuracy of the network on the 10000 test images: 17.110000 %
# This is global 5 epoch
#  Average loss 2.135
# Accuracy of the network on the 10000 test images: 17.380000 %
# This is global 6 epoch
#  Average loss 2.101
# Accuracy of the network on the 10000 test images: 18.110000 %
# This is global 7 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 18.500000 %
# This is global 8 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 19.660000 %
# This is global 9 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 20.920000 %
# This is global 10 epoch
#  Average loss 2.046
# Accuracy of the network on the 10000 test images: 23.240000 %
# This is global 11 epoch
#  Average loss 2.000
# Accuracy of the network on the 10000 test images: 27.100000 %
# This is global 12 epoch
#  Average loss 2.010
# Accuracy of the network on the 10000 test images: 27.750000 %
# This is global 13 epoch
#  Average loss 1.976
# Accuracy of the network on the 10000 test images: 29.010000 %
# This is global 14 epoch
#  Average loss 1.967
# Accuracy of the network on the 10000 test images: 29.760000 %
# This is global 15 epoch
#  Average loss 1.955
# Accuracy of the network on the 10000 test images: 30.540000 %
# This is global 16 epoch
#  Average loss 1.942
# Accuracy of the network on the 10000 test images: 31.470000 %
# This is global 17 epoch
#  Average loss 1.917
# Accuracy of the network on the 10000 test images: 31.880000 %
# This is global 18 epoch
#  Average loss 1.924
# Accuracy of the network on the 10000 test images: 32.630000 %
# This is global 19 epoch
#  Average loss 1.908
# Accuracy of the network on the 10000 test images: 32.690000 %
# This is global 20 epoch
#  Average loss 1.872
# Accuracy of the network on the 10000 test images: 33.490000 %
# This is global 21 epoch
#  Average loss 1.870
# Accuracy of the network on the 10000 test images: 34.050000 %
# This is global 22 epoch
#  Average loss 1.819
# Accuracy of the network on the 10000 test images: 34.690000 %
# This is global 23 epoch
#  Average loss 1.817
# Accuracy of the network on the 10000 test images: 34.510000 %
# This is global 24 epoch
#  Average loss 1.840
# Accuracy of the network on the 10000 test images: 34.730000 %
# This is global 25 epoch
#  Average loss 1.789
# Accuracy of the network on the 10000 test images: 35.470000 %
# This is global 26 epoch
#  Average loss 1.789
# Accuracy of the network on the 10000 test images: 35.600000 %
# This is global 27 epoch
#  Average loss 1.795
# Accuracy of the network on the 10000 test images: 36.720000 %
# This is global 28 epoch
#  Average loss 1.761
# Accuracy of the network on the 10000 test images: 36.630000 %
# This is global 29 epoch
#  Average loss 1.727
# Accuracy of the network on the 10000 test images: 37.010000 %
# This is global 30 epoch
#  Average loss 1.755
# Accuracy of the network on the 10000 test images: 37.400000 %
# This is global 31 epoch
#  Average loss 1.752
# Accuracy of the network on the 10000 test images: 37.770000 %
# This is global 32 epoch
#  Average loss 1.716
# Accuracy of the network on the 10000 test images: 37.900000 %
# This is global 33 epoch
#  Average loss 1.679
# Accuracy of the network on the 10000 test images: 38.380000 %
# This is global 34 epoch
#  Average loss 1.692
# Accuracy of the network on the 10000 test images: 38.490000 %
# This is global 35 epoch
#  Average loss 1.693
# Accuracy of the network on the 10000 test images: 38.800000 %
# This is global 36 epoch
#  Average loss 1.702
# Accuracy of the network on the 10000 test images: 39.320000 %
# This is global 37 epoch
#  Average loss 1.683
# Accuracy of the network on the 10000 test images: 39.940000 %
# This is global 38 epoch
#  Average loss 1.643
# Accuracy of the network on the 10000 test images: 39.870000 %
# This is global 39 epoch
#  Average loss 1.661
# Accuracy of the network on the 10000 test images: 40.590000 %
# This is global 40 epoch
#  Average loss 1.632
# Accuracy of the network on the 10000 test images: 40.630000 %
# This is global 41 epoch
#  Average loss 1.645
# Accuracy of the network on the 10000 test images: 41.500000 %
# This is global 42 epoch
#  Average loss 1.684
# Accuracy of the network on the 10000 test images: 41.970000 %
# This is global 43 epoch
#  Average loss 1.597
# Accuracy of the network on the 10000 test images: 42.230000 %
# This is global 44 epoch
#  Average loss 1.635
# Accuracy of the network on the 10000 test images: 42.620000 %
# This is global 45 epoch
#  Average loss 1.590
# Accuracy of the network on the 10000 test images: 43.080000 %
# This is global 46 epoch
#  Average loss 1.584
# Accuracy of the network on the 10000 test images: 43.060000 %
# This is global 47 epoch
#  Average loss 1.567
# Accuracy of the network on the 10000 test images: 43.390000 %
# This is global 48 epoch
#  Average loss 1.584
# Accuracy of the network on the 10000 test images: 43.380000 %
# This is global 49 epoch
#  Average loss 1.543
# Accuracy of the network on the 10000 test images: 43.690000 %
# This is global 50 epoch
#  Average loss 1.547
# Accuracy of the network on the 10000 test images: 44.090000 %
# This is global 51 epoch
#  Average loss 1.551
# Accuracy of the network on the 10000 test images: 44.670000 %
# This is global 52 epoch
#  Average loss 1.541
# Accuracy of the network on the 10000 test images: 44.830000 %
# This is global 53 epoch
#  Average loss 1.574
# Accuracy of the network on the 10000 test images: 44.940000 %
# This is global 54 epoch
#  Average loss 1.517
# Accuracy of the network on the 10000 test images: 45.040000 %
# This is global 55 epoch
#  Average loss 1.515
# Accuracy of the network on the 10000 test images: 45.330000 %
# This is global 56 epoch
#  Average loss 1.582
# Accuracy of the network on the 10000 test images: 45.670000 %
# This is global 57 epoch
#  Average loss 1.546
# Accuracy of the network on the 10000 test images: 45.850000 %
# This is global 58 epoch
#  Average loss 1.496
# Accuracy of the network on the 10000 test images: 45.600000 %
# This is global 59 epoch
#  Average loss 1.482
# Accuracy of the network on the 10000 test images: 45.690000 %
# This is global 60 epoch
#  Average loss 1.480
# Accuracy of the network on the 10000 test images: 45.930000 %
# This is global 61 epoch
#  Average loss 1.507
# Accuracy of the network on the 10000 test images: 46.140000 %
# This is global 62 epoch
#  Average loss 1.496
# Accuracy of the network on the 10000 test images: 46.220000 %
# This is global 63 epoch
#  Average loss 1.462
# Accuracy of the network on the 10000 test images: 46.640000 %
# This is global 64 epoch
#  Average loss 1.454
# Accuracy of the network on the 10000 test images: 47.000000 %
# This is global 65 epoch
#  Average loss 1.445
# Accuracy of the network on the 10000 test images: 47.010000 %
# This is global 66 epoch
#  Average loss 1.462
# Accuracy of the network on the 10000 test images: 47.310000 %
# This is global 67 epoch
#  Average loss 1.456
# Accuracy of the network on the 10000 test images: 47.450000 %
# This is global 68 epoch
#  Average loss 1.462
# Accuracy of the network on the 10000 test images: 47.550000 %
# This is global 69 epoch
#  Average loss 1.430
# Accuracy of the network on the 10000 test images: 47.710000 %
# This is global 70 epoch
#  Average loss 1.417
# Accuracy of the network on the 10000 test images: 48.070000 %
# This is global 71 epoch
#  Average loss 1.437
# Accuracy of the network on the 10000 test images: 47.900000 %
# This is global 72 epoch
#  Average loss 1.427
# Accuracy of the network on the 10000 test images: 48.100000 %
# This is global 73 epoch
#  Average loss 1.386
# Accuracy of the network on the 10000 test images: 48.470000 %
# This is global 74 epoch
#  Average loss 1.408
# Accuracy of the network on the 10000 test images: 48.480000 %
# This is global 75 epoch
#  Average loss 1.432
# Accuracy of the network on the 10000 test images: 48.840000 %
# This is global 76 epoch
#  Average loss 1.402
# Accuracy of the network on the 10000 test images: 48.860000 %
# This is global 77 epoch
#  Average loss 1.390
# Accuracy of the network on the 10000 test images: 48.980000 %
# This is global 78 epoch
#  Average loss 1.392
# Accuracy of the network on the 10000 test images: 49.310000 %
# This is global 79 epoch
#  Average loss 1.409
# Accuracy of the network on the 10000 test images: 49.270000 %
# This is global 80 epoch
#  Average loss 1.351
# Accuracy of the network on the 10000 test images: 49.390000 %
# This is global 81 epoch
#  Average loss 1.352
# Accuracy of the network on the 10000 test images: 49.570000 %
# This is global 82 epoch
#  Average loss 1.410
# Accuracy of the network on the 10000 test images: 49.720000 %
# This is global 83 epoch
#  Average loss 1.353
# Accuracy of the network on the 10000 test images: 50.000000 %
# This is global 84 epoch
#  Average loss 1.370
# Accuracy of the network on the 10000 test images: 49.840000 %
# This is global 85 epoch
#  Average loss 1.374
# Accuracy of the network on the 10000 test images: 50.340000 %
# This is global 86 epoch
#  Average loss 1.320
# Accuracy of the network on the 10000 test images: 50.400000 %
# This is global 87 epoch
#  Average loss 1.379
# Accuracy of the network on the 10000 test images: 50.480000 %
# This is global 88 epoch
#  Average loss 1.328
# Accuracy of the network on the 10000 test images: 50.670000 %
# This is global 89 epoch
#  Average loss 1.319
# Accuracy of the network on the 10000 test images: 50.700000 %
# This is global 90 epoch
#  Average loss 1.389
# Accuracy of the network on the 10000 test images: 50.770000 %
# This is global 91 epoch
#  Average loss 1.330
# Accuracy of the network on the 10000 test images: 51.140000 %
# This is global 92 epoch
#  Average loss 1.344
# Accuracy of the network on the 10000 test images: 51.390000 %
# This is global 93 epoch
#  Average loss 1.352
# Accuracy of the network on the 10000 test images: 51.590000 %
# This is global 94 epoch
#  Average loss 1.324
# Accuracy of the network on the 10000 test images: 51.610000 %
# This is global 95 epoch
#  Average loss 1.292
# Accuracy of the network on the 10000 test images: 51.740000 %
# This is global 96 epoch
#  Average loss 1.330
# Accuracy of the network on the 10000 test images: 51.830000 %
# This is global 97 epoch
#  Average loss 1.313
# Accuracy of the network on the 10000 test images: 52.000000 %
# This is global 98 epoch
#  Average loss 1.350
# Accuracy of the network on the 10000 test images: 52.060000 %
# This is global 99 epoch
#  Average loss 1.306
# Accuracy of the network on the 10000 test images: 52.120000 %
# This is global 100 epoch
#  Average loss 1.261
# Accuracy of the network on the 10000 test images: 52.630000 %
# This is global 101 epoch
#  Average loss 1.351
# Accuracy of the network on the 10000 test images: 52.990000 %
# This is global 102 epoch
#  Average loss 1.240
# Accuracy of the network on the 10000 test images: 52.640000 %
# This is global 103 epoch
#  Average loss 1.312
# Accuracy of the network on the 10000 test images: 52.690000 %
# This is global 104 epoch
#  Average loss 1.317
# Accuracy of the network on the 10000 test images: 52.720000 %
# This is global 105 epoch
#  Average loss 1.298
# Accuracy of the network on the 10000 test images: 52.830000 %
# This is global 106 epoch
#  Average loss 1.227
# Accuracy of the network on the 10000 test images: 53.050000 %
# This is global 107 epoch
#  Average loss 1.298
# Accuracy of the network on the 10000 test images: 53.160000 %
# This is global 108 epoch
#  Average loss 1.228
# Accuracy of the network on the 10000 test images: 53.300000 %
# This is global 109 epoch
#  Average loss 1.284
# Accuracy of the network on the 10000 test images: 53.760000 %
# This is global 110 epoch
#  Average loss 1.293
# Accuracy of the network on the 10000 test images: 53.430000 %
# This is global 111 epoch
#  Average loss 1.259
# Accuracy of the network on the 10000 test images: 53.570000 %
# This is global 112 epoch
#  Average loss 1.257
# Accuracy of the network on the 10000 test images: 53.420000 %
# This is global 113 epoch
#  Average loss 1.251
# Accuracy of the network on the 10000 test images: 53.770000 %
# This is global 114 epoch
#  Average loss 1.251
# Accuracy of the network on the 10000 test images: 54.170000 %
# This is global 115 epoch
#  Average loss 1.219
# Accuracy of the network on the 10000 test images: 54.070000 %
# This is global 116 epoch
#  Average loss 1.234
# Accuracy of the network on the 10000 test images: 54.040000 %
# This is global 117 epoch
#  Average loss 1.281
# Accuracy of the network on the 10000 test images: 54.440000 %
# This is global 118 epoch
#  Average loss 1.245
# Accuracy of the network on the 10000 test images: 54.220000 %
# This is global 119 epoch
#  Average loss 1.210
# Accuracy of the network on the 10000 test images: 54.210000 %
# This is global 120 epoch
#  Average loss 1.192
# Accuracy of the network on the 10000 test images: 54.190000 %
# This is global 121 epoch
#  Average loss 1.248
# Accuracy of the network on the 10000 test images: 54.700000 %
# This is global 122 epoch
#  Average loss 1.216
# Accuracy of the network on the 10000 test images: 54.560000 %
# This is global 123 epoch
#  Average loss 1.245
# Accuracy of the network on the 10000 test images: 54.840000 %
# This is global 124 epoch
#  Average loss 1.224
# Accuracy of the network on the 10000 test images: 54.620000 %
# This is global 125 epoch
#  Average loss 1.198
# Accuracy of the network on the 10000 test images: 54.660000 %
# This is global 126 epoch
#  Average loss 1.200
# Accuracy of the network on the 10000 test images: 54.730000 %
# This is global 127 epoch
#  Average loss 1.187
# Accuracy of the network on the 10000 test images: 54.940000 %
# This is global 128 epoch
#  Average loss 1.230
# Accuracy of the network on the 10000 test images: 54.980000 %
# This is global 129 epoch
#  Average loss 1.168
# Accuracy of the network on the 10000 test images: 55.000000 %
# This is global 130 epoch
#  Average loss 1.196
# Accuracy of the network on the 10000 test images: 55.150000 %
# This is global 131 epoch
#  Average loss 1.186
# Accuracy of the network on the 10000 test images: 55.340000 %
# This is global 132 epoch
#  Average loss 1.173
# Accuracy of the network on the 10000 test images: 55.150000 %
# This is global 133 epoch
#  Average loss 1.184
# Accuracy of the network on the 10000 test images: 55.350000 %
# This is global 134 epoch
#  Average loss 1.153
# Accuracy of the network on the 10000 test images: 55.520000 %
# This is global 135 epoch
#  Average loss 1.158
# Accuracy of the network on the 10000 test images: 55.720000 %
# This is global 136 epoch
#  Average loss 1.155
# Accuracy of the network on the 10000 test images: 55.590000 %
# This is global 137 epoch
#  Average loss 1.169
# Accuracy of the network on the 10000 test images: 56.000000 %
# This is global 138 epoch
#  Average loss 1.168
# Accuracy of the network on the 10000 test images: 56.000000 %
# This is global 139 epoch
#  Average loss 1.165
# Accuracy of the network on the 10000 test images: 55.940000 %
# This is global 140 epoch
#  Average loss 1.167
# Accuracy of the network on the 10000 test images: 56.220000 %
# This is global 141 epoch
#  Average loss 1.177
# Accuracy of the network on the 10000 test images: 56.140000 %
# This is global 142 epoch
#  Average loss 1.179
# Accuracy of the network on the 10000 test images: 56.300000 %
# This is global 143 epoch
#  Average loss 1.155
# Accuracy of the network on the 10000 test images: 56.320000 %
# This is global 144 epoch
#  Average loss 1.130
# Accuracy of the network on the 10000 test images: 56.190000 %
# This is global 145 epoch
#  Average loss 1.116
# Accuracy of the network on the 10000 test images: 56.450000 %
# This is global 146 epoch
#  Average loss 1.112
# Accuracy of the network on the 10000 test images: 56.290000 %
# This is global 147 epoch
#  Average loss 1.167
# Accuracy of the network on the 10000 test images: 56.510000 %
# This is global 148 epoch
#  Average loss 1.105
# Accuracy of the network on the 10000 test images: 56.630000 %
# This is global 149 epoch
#  Average loss 1.130
# Accuracy of the network on the 10000 test images: 56.750000 %
# This is global 150 epoch
#  Average loss 1.160
# Accuracy of the network on the 10000 test images: 56.720000 %
# This is global 151 epoch
#  Average loss 1.134
# Accuracy of the network on the 10000 test images: 56.720000 %
# This is global 152 epoch
#  Average loss 1.142
# Accuracy of the network on the 10000 test images: 57.060000 %
# This is global 153 epoch
#  Average loss 1.125
# Accuracy of the network on the 10000 test images: 57.020000 %
# This is global 154 epoch
#  Average loss 1.101
# Accuracy of the network on the 10000 test images: 57.200000 %
# This is global 155 epoch
#  Average loss 1.107
# Accuracy of the network on the 10000 test images: 57.090000 %
# This is global 156 epoch
#  Average loss 1.074
# Accuracy of the network on the 10000 test images: 56.940000 %
# This is global 157 epoch
#  Average loss 1.115
# Accuracy of the network on the 10000 test images: 57.230000 %
# This is global 158 epoch
#  Average loss 1.087
# Accuracy of the network on the 10000 test images: 57.170000 %
# This is global 159 epoch
#  Average loss 1.096
# Accuracy of the network on the 10000 test images: 57.300000 %
# This is global 160 epoch
#  Average loss 1.108
# Accuracy of the network on the 10000 test images: 57.200000 %
# This is global 161 epoch
#  Average loss 1.094
# Accuracy of the network on the 10000 test images: 57.230000 %
# This is global 162 epoch
#  Average loss 1.061
# Accuracy of the network on the 10000 test images: 57.130000 %
# This is global 163 epoch
#  Average loss 1.084
# Accuracy of the network on the 10000 test images: 57.360000 %
# This is global 164 epoch
#  Average loss 1.090
# Accuracy of the network on the 10000 test images: 57.480000 %
# This is global 165 epoch
#  Average loss 1.090
# Accuracy of the network on the 10000 test images: 57.680000 %
# This is global 166 epoch
#  Average loss 1.073
# Accuracy of the network on the 10000 test images: 57.710000 %
# This is global 167 epoch
#  Average loss 1.074
# Accuracy of the network on the 10000 test images: 57.820000 %
# This is global 168 epoch
#  Average loss 1.076
# Accuracy of the network on the 10000 test images: 57.950000 %
# This is global 169 epoch
#  Average loss 1.093
# Accuracy of the network on the 10000 test images: 57.960000 %
# This is global 170 epoch
#  Average loss 1.077
# Accuracy of the network on the 10000 test images: 58.140000 %
# This is global 171 epoch
#  Average loss 1.011
# Accuracy of the network on the 10000 test images: 58.220000 %
# This is global 172 epoch
#  Average loss 1.050
# Accuracy of the network on the 10000 test images: 58.190000 %
# This is global 173 epoch
#  Average loss 1.044
# Accuracy of the network on the 10000 test images: 58.110000 %
# This is global 174 epoch
#  Average loss 1.056
# Accuracy of the network on the 10000 test images: 58.370000 %
# This is global 175 epoch
#  Average loss 1.052
# Accuracy of the network on the 10000 test images: 58.330000 %
# This is global 176 epoch
#  Average loss 1.032
# Accuracy of the network on the 10000 test images: 58.650000 %
# This is global 177 epoch
#  Average loss 1.031
# Accuracy of the network on the 10000 test images: 58.560000 %
# This is global 178 epoch
#  Average loss 1.075
# Accuracy of the network on the 10000 test images: 58.670000 %
# This is global 179 epoch
#  Average loss 1.076
# Accuracy of the network on the 10000 test images: 58.670000 %
# This is global 180 epoch
#  Average loss 1.060
# Accuracy of the network on the 10000 test images: 58.600000 %
# This is global 181 epoch
#  Average loss 1.045
# Accuracy of the network on the 10000 test images: 58.750000 %
# This is global 182 epoch
#  Average loss 1.005
# Accuracy of the network on the 10000 test images: 58.880000 %
# This is global 183 epoch
#  Average loss 1.049
# Accuracy of the network on the 10000 test images: 58.940000 %
# This is global 184 epoch
#  Average loss 0.992
# Accuracy of the network on the 10000 test images: 58.870000 %
# This is global 185 epoch
#  Average loss 1.009
# Accuracy of the network on the 10000 test images: 58.920000 %
# This is global 186 epoch
#  Average loss 1.050
# Accuracy of the network on the 10000 test images: 59.130000 %
# This is global 187 epoch
#  Average loss 1.020
# Accuracy of the network on the 10000 test images: 59.160000 %
# This is global 188 epoch
#  Average loss 1.032
# Accuracy of the network on the 10000 test images: 59.190000 %
# This is global 189 epoch
#  Average loss 1.044
# Accuracy of the network on the 10000 test images: 59.210000 %
# This is global 190 epoch
#  Average loss 1.027
# Accuracy of the network on the 10000 test images: 58.970000 %
# This is global 191 epoch
#  Average loss 1.020
# Accuracy of the network on the 10000 test images: 59.090000 %
# This is global 192 epoch
#  Average loss 1.020
# Accuracy of the network on the 10000 test images: 59.100000 %
# This is global 193 epoch
#  Average loss 1.028
# Accuracy of the network on the 10000 test images: 59.360000 %
# This is global 194 epoch
#  Average loss 1.035
# Accuracy of the network on the 10000 test images: 59.250000 %
# This is global 195 epoch
#  Average loss 0.981
# Accuracy of the network on the 10000 test images: 59.430000 %
# This is global 196 epoch
#  Average loss 0.997
# Accuracy of the network on the 10000 test images: 59.440000 %
# This is global 197 epoch
#  Average loss 1.027
# Accuracy of the network on the 10000 test images: 59.450000 %
# This is global 198 epoch
#  Average loss 1.016
# Accuracy of the network on the 10000 test images: 59.450000 %
# This is global 199 epoch
#  Average loss 0.998
# Accuracy of the network on the 10000 test images: 59.550000 %
# This is global 200 epoch
#  Average loss 0.988
# Accuracy of the network on the 10000 test images: 59.580000 %
# This is global 201 epoch
#  Average loss 0.990
# Accuracy of the network on the 10000 test images: 59.460000 %
# This is global 202 epoch
#  Average loss 0.992
# Accuracy of the network on the 10000 test images: 59.590000 %
# This is global 203 epoch
#  Average loss 0.986
# Accuracy of the network on the 10000 test images: 59.760000 %
# This is global 204 epoch
#  Average loss 0.985
# Accuracy of the network on the 10000 test images: 59.730000 %
# This is global 205 epoch
#  Average loss 1.009
# Accuracy of the network on the 10000 test images: 59.740000 %
# This is global 206 epoch
#  Average loss 0.985
# Accuracy of the network on the 10000 test images: 59.790000 %
# This is global 207 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 59.850000 %
# This is global 208 epoch
#  Average loss 0.953
# Accuracy of the network on the 10000 test images: 60.080000 %
# This is global 209 epoch
#  Average loss 0.930
# Accuracy of the network on the 10000 test images: 60.110000 %
# This is global 210 epoch
#  Average loss 0.964
# Accuracy of the network on the 10000 test images: 60.240000 %
# This is global 211 epoch
#  Average loss 0.961
# Accuracy of the network on the 10000 test images: 60.160000 %
# This is global 212 epoch
#  Average loss 0.962
# Accuracy of the network on the 10000 test images: 60.150000 %
# This is global 213 epoch
#  Average loss 0.988
# Accuracy of the network on the 10000 test images: 59.970000 %
# This is global 214 epoch
#  Average loss 0.930
# Accuracy of the network on the 10000 test images: 60.260000 %
# This is global 215 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 60.340000 %
# This is global 216 epoch
#  Average loss 0.950
# Accuracy of the network on the 10000 test images: 60.600000 %
# This is global 217 epoch
#  Average loss 0.927
# Accuracy of the network on the 10000 test images: 60.570000 %
# This is global 218 epoch
#  Average loss 0.963
# Accuracy of the network on the 10000 test images: 60.410000 %
# This is global 219 epoch
#  Average loss 0.937
# Accuracy of the network on the 10000 test images: 60.640000 %
# This is global 220 epoch
#  Average loss 0.945
# Accuracy of the network on the 10000 test images: 60.680000 %
# This is global 221 epoch
#  Average loss 0.945
# Accuracy of the network on the 10000 test images: 60.620000 %
# This is global 222 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 60.740000 %
# This is global 223 epoch
#  Average loss 0.938
# Accuracy of the network on the 10000 test images: 60.510000 %
# This is global 224 epoch
#  Average loss 0.902
# Accuracy of the network on the 10000 test images: 60.790000 %
# This is global 225 epoch
#  Average loss 0.895
# Accuracy of the network on the 10000 test images: 60.800000 %
# This is global 226 epoch
#  Average loss 0.935
# Accuracy of the network on the 10000 test images: 61.030000 %
# This is global 227 epoch
#  Average loss 0.929
# Accuracy of the network on the 10000 test images: 60.900000 %
# This is global 228 epoch
#  Average loss 0.957
# Accuracy of the network on the 10000 test images: 61.140000 %
# This is global 229 epoch
#  Average loss 0.974
# Accuracy of the network on the 10000 test images: 61.270000 %
# This is global 230 epoch
#  Average loss 0.901
# Accuracy of the network on the 10000 test images: 61.250000 %
# This is global 231 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 61.240000 %
# This is global 232 epoch
#  Average loss 0.918
# Accuracy of the network on the 10000 test images: 61.090000 %
# This is global 233 epoch
#  Average loss 0.886
# Accuracy of the network on the 10000 test images: 61.040000 %
# This is global 234 epoch
#  Average loss 0.892
# Accuracy of the network on the 10000 test images: 61.360000 %
# This is global 235 epoch
#  Average loss 0.916
# Accuracy of the network on the 10000 test images: 61.400000 %
# This is global 236 epoch
#  Average loss 0.948
# Accuracy of the network on the 10000 test images: 61.330000 %
# This is global 237 epoch
#  Average loss 0.911
# Accuracy of the network on the 10000 test images: 61.370000 %
# This is global 238 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 61.410000 %
# This is global 239 epoch
#  Average loss 0.888
# Accuracy of the network on the 10000 test images: 61.460000 %
# This is global 240 epoch
#  Average loss 0.891
# Accuracy of the network on the 10000 test images: 61.420000 %
# This is global 241 epoch
#  Average loss 0.903
# Accuracy of the network on the 10000 test images: 61.690000 %
# This is global 242 epoch
#  Average loss 0.862
# Accuracy of the network on the 10000 test images: 61.680000 %
# This is global 243 epoch
#  Average loss 0.912
# Accuracy of the network on the 10000 test images: 61.550000 %
# This is global 244 epoch
#  Average loss 0.816
# Accuracy of the network on the 10000 test images: 61.780000 %
# This is global 245 epoch
#  Average loss 0.883
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 246 epoch
#  Average loss 0.881
# Accuracy of the network on the 10000 test images: 61.960000 %
# This is global 247 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 61.960000 %
# This is global 248 epoch
#  Average loss 0.872
# Accuracy of the network on the 10000 test images: 61.960000 %
# This is global 249 epoch
#  Average loss 0.899
# Accuracy of the network on the 10000 test images: 61.980000 %
# This is global 250 epoch
#  Average loss 0.920
# Accuracy of the network on the 10000 test images: 62.090000 %
# This is global 251 epoch
#  Average loss 0.875
# Accuracy of the network on the 10000 test images: 62.160000 %
# This is global 252 epoch
#  Average loss 0.828
# Accuracy of the network on the 10000 test images: 62.190000 %
# This is global 253 epoch
#  Average loss 0.841
# Accuracy of the network on the 10000 test images: 62.100000 %
# This is global 254 epoch
#  Average loss 0.855
# Accuracy of the network on the 10000 test images: 62.180000 %
# This is global 255 epoch
#  Average loss 0.891
# Accuracy of the network on the 10000 test images: 62.140000 %
# This is global 256 epoch
#  Average loss 0.843
# Accuracy of the network on the 10000 test images: 62.160000 %
# This is global 257 epoch
#  Average loss 0.921
# Accuracy of the network on the 10000 test images: 62.100000 %
# This is global 258 epoch
#  Average loss 0.855
# Accuracy of the network on the 10000 test images: 62.290000 %
# This is global 259 epoch
#  Average loss 0.899
# Accuracy of the network on the 10000 test images: 62.070000 %
# This is global 260 epoch
#  Average loss 0.850
# Accuracy of the network on the 10000 test images: 62.310000 %
# This is global 261 epoch
#  Average loss 0.832
# Accuracy of the network on the 10000 test images: 62.470000 %
# This is global 262 epoch
#  Average loss 0.820
# Accuracy of the network on the 10000 test images: 62.280000 %
# This is global 263 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 62.540000 %
# This is global 264 epoch
#  Average loss 0.854
# Accuracy of the network on the 10000 test images: 62.320000 %
# This is global 265 epoch
#  Average loss 0.814
# Accuracy of the network on the 10000 test images: 62.480000 %
# This is global 266 epoch
#  Average loss 0.840
# Accuracy of the network on the 10000 test images: 62.670000 %
# This is global 267 epoch
#  Average loss 0.821
# Accuracy of the network on the 10000 test images: 62.640000 %
# This is global 268 epoch
#  Average loss 0.859
# Accuracy of the network on the 10000 test images: 62.550000 %
# This is global 269 epoch
#  Average loss 0.838
# Accuracy of the network on the 10000 test images: 62.990000 %
# This is global 270 epoch
#  Average loss 0.855
# Accuracy of the network on the 10000 test images: 62.880000 %
# This is global 271 epoch
#  Average loss 0.817
# Accuracy of the network on the 10000 test images: 62.750000 %
# This is global 272 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 63.010000 %
# This is global 273 epoch
#  Average loss 0.859
# Accuracy of the network on the 10000 test images: 63.110000 %
# This is global 274 epoch
#  Average loss 0.837
# Accuracy of the network on the 10000 test images: 63.220000 %
# This is global 275 epoch
#  Average loss 0.810
# Accuracy of the network on the 10000 test images: 63.390000 %
# This is global 276 epoch
#  Average loss 0.827
# Accuracy of the network on the 10000 test images: 63.250000 %
# This is global 277 epoch
#  Average loss 0.792
# Accuracy of the network on the 10000 test images: 63.220000 %
# This is global 278 epoch
#  Average loss 0.836
# Accuracy of the network on the 10000 test images: 63.230000 %
# This is global 279 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 63.310000 %
# This is global 280 epoch
#  Average loss 0.823
# Accuracy of the network on the 10000 test images: 63.370000 %
# This is global 281 epoch
#  Average loss 0.815
# Accuracy of the network on the 10000 test images: 63.370000 %
# This is global 282 epoch
#  Average loss 0.812
# Accuracy of the network on the 10000 test images: 63.420000 %
# This is global 283 epoch
#  Average loss 0.810
# Accuracy of the network on the 10000 test images: 63.560000 %
# This is global 284 epoch
#  Average loss 0.855
# Accuracy of the network on the 10000 test images: 63.450000 %
# This is global 285 epoch
#  Average loss 0.796
# Accuracy of the network on the 10000 test images: 63.570000 %
# This is global 286 epoch
#  Average loss 0.791
# Accuracy of the network on the 10000 test images: 63.370000 %
# This is global 287 epoch
#  Average loss 0.766
# Accuracy of the network on the 10000 test images: 63.680000 %
# This is global 288 epoch
#  Average loss 0.820
# Accuracy of the network on the 10000 test images: 63.540000 %
# This is global 289 epoch
#  Average loss 0.797
# Accuracy of the network on the 10000 test images: 63.450000 %
# This is global 290 epoch
#  Average loss 0.808
# Accuracy of the network on the 10000 test images: 63.670000 %
# This is global 291 epoch
#  Average loss 0.815
# Accuracy of the network on the 10000 test images: 63.820000 %
# This is global 292 epoch
#  Average loss 0.783
# Accuracy of the network on the 10000 test images: 63.640000 %
# This is global 293 epoch
#  Average loss 0.841
# Accuracy of the network on the 10000 test images: 63.920000 %
# This is global 294 epoch
#  Average loss 0.819
# Accuracy of the network on the 10000 test images: 63.920000 %
# This is global 295 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 63.870000 %
# This is global 296 epoch
#  Average loss 0.821
# Accuracy of the network on the 10000 test images: 63.800000 %
# This is global 297 epoch
#  Average loss 0.743
# Accuracy of the network on the 10000 test images: 63.970000 %
# This is global 298 epoch
#  Average loss 0.800
# Accuracy of the network on the 10000 test images: 63.750000 %
# This is global 299 epoch
#  Average loss 0.803
# Accuracy of the network on the 10000 test images: 63.780000 %
# This is global 300 epoch
#  Average loss 0.798
# Accuracy of the network on the 10000 test images: 64.020000 %
# This is global 301 epoch
#  Average loss 0.760
# Accuracy of the network on the 10000 test images: 63.960000 %
# This is global 302 epoch
#  Average loss 0.794
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 303 epoch
#  Average loss 0.835
# Accuracy of the network on the 10000 test images: 63.860000 %
# This is global 304 epoch
#  Average loss 0.762
# Accuracy of the network on the 10000 test images: 63.920000 %
# This is global 305 epoch
#  Average loss 0.799
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 306 epoch
#  Average loss 0.763
# Accuracy of the network on the 10000 test images: 64.270000 %
# This is global 307 epoch
#  Average loss 0.766
# Accuracy of the network on the 10000 test images: 64.270000 %
# This is global 308 epoch
#  Average loss 0.751
# Accuracy of the network on the 10000 test images: 64.400000 %
# This is global 309 epoch
#  Average loss 0.772
# Accuracy of the network on the 10000 test images: 64.280000 %
# This is global 310 epoch
#  Average loss 0.776
# Accuracy of the network on the 10000 test images: 64.340000 %
# This is global 311 epoch
#  Average loss 0.778
# Accuracy of the network on the 10000 test images: 64.370000 %
# This is global 312 epoch
#  Average loss 0.752
# Accuracy of the network on the 10000 test images: 64.300000 %
# This is global 313 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 64.440000 %
# This is global 314 epoch
#  Average loss 0.725
# Accuracy of the network on the 10000 test images: 64.650000 %
# This is global 315 epoch
#  Average loss 0.794
# Accuracy of the network on the 10000 test images: 64.720000 %
# This is global 316 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 64.830000 %
# This is global 317 epoch
#  Average loss 0.761
# Accuracy of the network on the 10000 test images: 64.690000 %
# This is global 318 epoch
#  Average loss 0.761
# Accuracy of the network on the 10000 test images: 64.700000 %
# This is global 319 epoch
#  Average loss 0.745
# Accuracy of the network on the 10000 test images: 64.800000 %
# This is global 320 epoch
#  Average loss 0.727
# Accuracy of the network on the 10000 test images: 64.930000 %
# This is global 321 epoch
#  Average loss 0.763
# Accuracy of the network on the 10000 test images: 64.760000 %
# This is global 322 epoch
#  Average loss 0.742
# Accuracy of the network on the 10000 test images: 64.800000 %
# This is global 323 epoch
#  Average loss 0.770
# Accuracy of the network on the 10000 test images: 64.810000 %
# This is global 324 epoch
#  Average loss 0.778
# Accuracy of the network on the 10000 test images: 64.950000 %
# This is global 325 epoch
#  Average loss 0.740
# Accuracy of the network on the 10000 test images: 64.940000 %
# This is global 326 epoch
#  Average loss 0.695
# Accuracy of the network on the 10000 test images: 65.010000 %
# This is global 327 epoch
#  Average loss 0.712
# Accuracy of the network on the 10000 test images: 65.160000 %
# This is global 328 epoch
#  Average loss 0.703
# Accuracy of the network on the 10000 test images: 65.310000 %
# This is global 329 epoch
#  Average loss 0.728
# Accuracy of the network on the 10000 test images: 65.260000 %
# This is global 330 epoch
#  Average loss 0.744
# Accuracy of the network on the 10000 test images: 65.270000 %
# This is global 331 epoch
#  Average loss 0.741
# Accuracy of the network on the 10000 test images: 65.330000 %
# This is global 332 epoch
#  Average loss 0.713
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 333 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 65.350000 %
# This is global 334 epoch
#  Average loss 0.762
# Accuracy of the network on the 10000 test images: 65.320000 %
# This is global 335 epoch
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 65.280000 %
# This is global 336 epoch
#  Average loss 0.761
# Accuracy of the network on the 10000 test images: 65.500000 %
# This is global 337 epoch
#  Average loss 0.709
# Accuracy of the network on the 10000 test images: 65.330000 %
# This is global 338 epoch
#  Average loss 0.733
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 339 epoch
#  Average loss 0.746
# Accuracy of the network on the 10000 test images: 65.150000 %
# This is global 340 epoch
#  Average loss 0.726
# Accuracy of the network on the 10000 test images: 65.270000 %
# This is global 341 epoch
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 65.400000 %
# This is global 342 epoch
#  Average loss 0.712
# Accuracy of the network on the 10000 test images: 65.330000 %
# This is global 343 epoch
#  Average loss 0.740
# Accuracy of the network on the 10000 test images: 65.350000 %
# This is global 344 epoch
#  Average loss 0.706
# Accuracy of the network on the 10000 test images: 65.660000 %
# This is global 345 epoch
#  Average loss 0.701
# Accuracy of the network on the 10000 test images: 65.460000 %
# This is global 346 epoch
#  Average loss 0.694
# Accuracy of the network on the 10000 test images: 65.450000 %
# This is global 347 epoch
#  Average loss 0.695
# Accuracy of the network on the 10000 test images: 65.360000 %
# This is global 348 epoch
#  Average loss 0.697
# Accuracy of the network on the 10000 test images: 65.190000 %
# This is global 349 epoch
#  Average loss 0.733
# Accuracy of the network on the 10000 test images: 65.420000 %
# This is global 350 epoch
#  Average loss 0.708
# Accuracy of the network on the 10000 test images: 65.350000 %
# This is global 351 epoch
#  Average loss 0.679
# Accuracy of the network on the 10000 test images: 65.480000 %
# This is global 352 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 65.390000 %
# This is global 353 epoch
#  Average loss 0.692
# Accuracy of the network on the 10000 test images: 65.440000 %
# This is global 354 epoch
#  Average loss 0.720
# Accuracy of the network on the 10000 test images: 65.510000 %
# This is global 355 epoch
#  Average loss 0.660
# Accuracy of the network on the 10000 test images: 65.510000 %
# This is global 356 epoch
#  Average loss 0.667
# Accuracy of the network on the 10000 test images: 65.830000 %
# This is global 357 epoch
#  Average loss 0.715
# Accuracy of the network on the 10000 test images: 65.600000 %
# This is global 358 epoch
#  Average loss 0.653
# Accuracy of the network on the 10000 test images: 65.780000 %
# This is global 359 epoch
#  Average loss 0.717
# Accuracy of the network on the 10000 test images: 65.560000 %
# This is global 360 epoch
#  Average loss 0.686
# Accuracy of the network on the 10000 test images: 65.690000 %
# This is global 361 epoch
#  Average loss 0.674
# Accuracy of the network on the 10000 test images: 65.790000 %
# This is global 362 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 65.810000 %
# This is global 363 epoch
#  Average loss 0.687
# Accuracy of the network on the 10000 test images: 66.020000 %
# This is global 364 epoch
#  Average loss 0.680
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 365 epoch
#  Average loss 0.706
# Accuracy of the network on the 10000 test images: 66.040000 %
# This is global 366 epoch
#  Average loss 0.642
# Accuracy of the network on the 10000 test images: 66.170000 %
# This is global 367 epoch
#  Average loss 0.722
# Accuracy of the network on the 10000 test images: 66.200000 %
# This is global 368 epoch
#  Average loss 0.689
# Accuracy of the network on the 10000 test images: 66.030000 %
# This is global 369 epoch
#  Average loss 0.701
# Accuracy of the network on the 10000 test images: 66.270000 %
# This is global 370 epoch
#  Average loss 0.702
# Accuracy of the network on the 10000 test images: 66.520000 %
# This is global 371 epoch
#  Average loss 0.682
# Accuracy of the network on the 10000 test images: 66.270000 %
# This is global 372 epoch
#  Average loss 0.664
# Accuracy of the network on the 10000 test images: 66.230000 %
# This is global 373 epoch
#  Average loss 0.691
# Accuracy of the network on the 10000 test images: 66.180000 %
# This is global 374 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 66.250000 %
# This is global 375 epoch
#  Average loss 0.690
# Accuracy of the network on the 10000 test images: 66.170000 %
# This is global 376 epoch
#  Average loss 0.636
# Accuracy of the network on the 10000 test images: 66.230000 %
# This is global 377 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 66.290000 %
# This is global 378 epoch
#  Average loss 0.691
# Accuracy of the network on the 10000 test images: 66.240000 %
# This is global 379 epoch
#  Average loss 0.677
# Accuracy of the network on the 10000 test images: 66.290000 %
# This is global 380 epoch
#  Average loss 0.633
# Accuracy of the network on the 10000 test images: 66.210000 %
# This is global 381 epoch
#  Average loss 0.642
# Accuracy of the network on the 10000 test images: 66.210000 %
# This is global 382 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 66.190000 %
# This is global 383 epoch
#  Average loss 0.672
# Accuracy of the network on the 10000 test images: 66.550000 %
# This is global 384 epoch
#  Average loss 0.633
# Accuracy of the network on the 10000 test images: 66.370000 %
# This is global 385 epoch
#  Average loss 0.658
# Accuracy of the network on the 10000 test images: 66.380000 %
# This is global 386 epoch
#  Average loss 0.643
# Accuracy of the network on the 10000 test images: 66.360000 %
# This is global 387 epoch
#  Average loss 0.668
# Accuracy of the network on the 10000 test images: 66.460000 %
# This is global 388 epoch
#  Average loss 0.635
# Accuracy of the network on the 10000 test images: 66.610000 %
# This is global 389 epoch
#  Average loss 0.665
# Accuracy of the network on the 10000 test images: 66.390000 %
# This is global 390 epoch
#  Average loss 0.688
# Accuracy of the network on the 10000 test images: 66.490000 %
# This is global 391 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 66.490000 %
# This is global 392 epoch
#  Average loss 0.635
# Accuracy of the network on the 10000 test images: 66.650000 %
# This is global 393 epoch
#  Average loss 0.627
# Accuracy of the network on the 10000 test images: 66.690000 %
# This is global 394 epoch
#  Average loss 0.626
# Accuracy of the network on the 10000 test images: 66.790000 %
# This is global 395 epoch
#  Average loss 0.647
# Accuracy of the network on the 10000 test images: 66.890000 %
# This is global 396 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 66.910000 %
# This is global 397 epoch
#  Average loss 0.621
# Accuracy of the network on the 10000 test images: 66.770000 %
# This is global 398 epoch
#  Average loss 0.677
# Accuracy of the network on the 10000 test images: 66.940000 %
# This is global 399 epoch
#  Average loss 0.602
# Accuracy of the network on the 10000 test images: 66.920000 %
# This is global 400 epoch
#  Average loss 0.637
# Accuracy of the network on the 10000 test images: 67.010000 %
# This is global 401 epoch
#  Average loss 0.615
# Accuracy of the network on the 10000 test images: 66.760000 %
# This is global 402 epoch
#  Average loss 0.656
# Accuracy of the network on the 10000 test images: 66.770000 %
# This is global 403 epoch
#  Average loss 0.638
# Accuracy of the network on the 10000 test images: 66.630000 %
# This is global 404 epoch
#  Average loss 0.618
# Accuracy of the network on the 10000 test images: 66.820000 %
# This is global 405 epoch
#  Average loss 0.612
# Accuracy of the network on the 10000 test images: 66.790000 %
# This is global 406 epoch
#  Average loss 0.655
# Accuracy of the network on the 10000 test images: 66.660000 %
# This is global 407 epoch
#  Average loss 0.660
# Accuracy of the network on the 10000 test images: 66.740000 %
# This is global 408 epoch
#  Average loss 0.628
# Accuracy of the network on the 10000 test images: 66.660000 %
# This is global 409 epoch
#  Average loss 0.647
# Accuracy of the network on the 10000 test images: 66.970000 %
# This is global 410 epoch
#  Average loss 0.616
# Accuracy of the network on the 10000 test images: 66.930000 %
# This is global 411 epoch
#  Average loss 0.574
# Accuracy of the network on the 10000 test images: 66.860000 %
# This is global 412 epoch
#  Average loss 0.638
# Accuracy of the network on the 10000 test images: 66.940000 %
# This is global 413 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 67.030000 %
# This is global 414 epoch
#  Average loss 0.592
# Accuracy of the network on the 10000 test images: 67.040000 %
# This is global 415 epoch
#  Average loss 0.637
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 416 epoch
#  Average loss 0.653
# Accuracy of the network on the 10000 test images: 67.090000 %
# This is global 417 epoch
#  Average loss 0.610
# Accuracy of the network on the 10000 test images: 67.120000 %
# This is global 418 epoch
#  Average loss 0.607
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 419 epoch
#  Average loss 0.587
# Accuracy of the network on the 10000 test images: 67.090000 %
# This is global 420 epoch
#  Average loss 0.618
# Accuracy of the network on the 10000 test images: 67.150000 %
# This is global 421 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 67.040000 %
# This is global 422 epoch
#  Average loss 0.587
# Accuracy of the network on the 10000 test images: 67.090000 %
# This is global 423 epoch
#  Average loss 0.680
# Accuracy of the network on the 10000 test images: 66.980000 %
# This is global 424 epoch
#  Average loss 0.662
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 425 epoch
#  Average loss 0.620
# Accuracy of the network on the 10000 test images: 67.050000 %
# This is global 426 epoch
#  Average loss 0.599
# Accuracy of the network on the 10000 test images: 66.950000 %
# This is global 427 epoch
#  Average loss 0.621
# Accuracy of the network on the 10000 test images: 67.030000 %
# This is global 428 epoch
#  Average loss 0.616
# Accuracy of the network on the 10000 test images: 67.040000 %
# This is global 429 epoch
#  Average loss 0.609
# Accuracy of the network on the 10000 test images: 67.000000 %
# This is global 430 epoch
#  Average loss 0.616
# Accuracy of the network on the 10000 test images: 66.930000 %
# This is global 431 epoch
#  Average loss 0.578
# Accuracy of the network on the 10000 test images: 67.100000 %
# This is global 432 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 66.900000 %
# This is global 433 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 67.000000 %
# This is global 434 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 435 epoch
#  Average loss 0.575
# Accuracy of the network on the 10000 test images: 67.230000 %
# This is global 436 epoch
#  Average loss 0.612
# Accuracy of the network on the 10000 test images: 67.370000 %
# This is global 437 epoch
#  Average loss 0.578
# Accuracy of the network on the 10000 test images: 67.310000 %
# This is global 438 epoch
#  Average loss 0.602
# Accuracy of the network on the 10000 test images: 67.500000 %
# This is global 439 epoch
#  Average loss 0.611
# Accuracy of the network on the 10000 test images: 67.480000 %
# This is global 440 epoch
#  Average loss 0.625
# Accuracy of the network on the 10000 test images: 67.670000 %
# This is global 441 epoch
#  Average loss 0.600
# Accuracy of the network on the 10000 test images: 67.510000 %
# This is global 442 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 67.660000 %
# This is global 443 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 67.680000 %
# This is global 444 epoch
#  Average loss 0.597
# Accuracy of the network on the 10000 test images: 67.750000 %
# This is global 445 epoch
#  Average loss 0.574
# Accuracy of the network on the 10000 test images: 67.890000 %
# This is global 446 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 67.890000 %
# ...
# This is global 4853 epoch
#  Average loss 0.158
# Accuracy of the network on the 10000 test images: 67.780000 %
# This is global 4854 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4855 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4856 epoch
#  Average loss 0.006
# Accuracy of the network on the 10000 test images: 68.260000 %
# This is global 4857 epoch
#  Average loss 0.006
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4858 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4859 epoch
#  Average loss 0.006
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4860 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 68.290000 %
# This is global 4861 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4862 epoch
#  Average loss 0.017
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4863 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4864 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 68.020000 %
# This is global 4865 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.330000 %
# This is global 4866 epoch
#  Average loss 0.005
# Accuracy of the network on the 10000 test images: 68.460000 %
# This is global 4867 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 68.340000 %
# This is global 4868 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 68.330000 %
# This is global 4869 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.500000 %
# This is global 4870 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4871 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.470000 %
# This is global 4872 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 68.500000 %
# This is global 4873 epoch
#  Average loss 0.103
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4874 epoch
#  Average loss 0.125
# Accuracy of the network on the 10000 test images: 68.040000 %
# This is global 4875 epoch
#  Average loss 0.017
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4876 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.290000 %
# This is global 4877 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 68.340000 %
# This is global 4878 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4879 epoch
#  Average loss 0.016
# Accuracy of the network on the 10000 test images: 68.270000 %
# This is global 4880 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 67.930000 %
# This is global 4881 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 67.760000 %
# This is global 4882 epoch
#  Average loss 0.156
# Accuracy of the network on the 10000 test images: 67.560000 %
# This is global 4883 epoch
#  Average loss 0.172
# Accuracy of the network on the 10000 test images: 67.220000 %
# This is global 4884 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 67.060000 %
# This is global 4885 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 67.260000 %
# This is global 4886 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 4887 epoch
#  Average loss 0.005
# Accuracy of the network on the 10000 test images: 67.740000 %
# This is global 4888 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4889 epoch
#  Average loss 0.143
# Accuracy of the network on the 10000 test images: 67.950000 %
# This is global 4890 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 67.940000 %
# This is global 4891 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 67.870000 %
# This is global 4892 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 67.560000 %
# This is global 4893 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 67.470000 %
# This is global 4894 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 67.930000 %
# This is global 4895 epoch
#  Average loss 0.008
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4896 epoch
#  Average loss 0.161
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 4897 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4898 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 68.030000 %
# This is global 4899 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4900 epoch
#  Average loss 0.137
# Accuracy of the network on the 10000 test images: 67.990000 %
# This is global 4901 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4902 epoch
#  Average loss 0.011
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4903 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.470000 %
# This is global 4904 epoch
#  Average loss 0.007
# Accuracy of the network on the 10000 test images: 68.410000 %
# This is global 4905 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 68.300000 %
# This is global 4906 epoch
#  Average loss 0.016
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4907 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4908 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 67.900000 %
# This is global 4909 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4910 epoch
#  Average loss 0.009
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4911 epoch
#  Average loss 0.429
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4912 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4913 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4914 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 67.710000 %
# This is global 4915 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4916 epoch
#  Average loss 0.181
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4917 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4918 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4919 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 67.970000 %
# This is global 4920 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 67.700000 %
# This is global 4921 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.010000 %
# This is global 4922 epoch
#  Average loss 0.012
# Accuracy of the network on the 10000 test images: 68.080000 %
# This is global 4923 epoch
#  Average loss 0.019
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4924 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 67.820000 %
# This is global 4925 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 67.930000 %
# This is global 4926 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4927 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 67.970000 %
# This is global 4928 epoch
#  Average loss 0.007
# Accuracy of the network on the 10000 test images: 68.020000 %
# This is global 4929 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.350000 %
# This is global 4930 epoch
#  Average loss 0.009
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4931 epoch
#  Average loss 0.283
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4932 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4933 epoch
#  Average loss 0.014
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4934 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4935 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.400000 %
# This is global 4936 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4937 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 68.390000 %
# This is global 4938 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 68.340000 %
# This is global 4939 epoch
#  Average loss 0.124
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4940 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 68.300000 %
# This is global 4941 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.380000 %
# This is global 4942 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 4943 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4944 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 67.940000 %
# This is global 4945 epoch
#  Average loss 0.130
# Accuracy of the network on the 10000 test images: 67.840000 %
# This is global 4946 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 67.630000 %
# This is global 4947 epoch
#  Average loss 0.007
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4948 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 67.730000 %
# This is global 4949 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 67.880000 %
# This is global 4950 epoch
#  Average loss 0.005
# Accuracy of the network on the 10000 test images: 68.030000 %
# This is global 4951 epoch
#  Average loss 0.015
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4952 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4953 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4954 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.370000 %
# This is global 4955 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.450000 %
# This is global 4956 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.490000 %
# This is global 4957 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.360000 %
# This is global 4958 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.290000 %
# This is global 4959 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4960 epoch
#  Average loss 0.961
# Accuracy of the network on the 10000 test images: 67.900000 %
# This is global 4961 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4962 epoch
#  Average loss 0.136
# Accuracy of the network on the 10000 test images: 67.910000 %
# This is global 4963 epoch
#  Average loss 0.708
# Accuracy of the network on the 10000 test images: 66.880000 %
# This is global 4964 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 66.850000 %
# This is global 4965 epoch
#  Average loss 0.022
# Accuracy of the network on the 10000 test images: 66.930000 %
# This is global 4966 epoch
#  Average loss 0.005
# Accuracy of the network on the 10000 test images: 67.440000 %
# This is global 4967 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.300000 %
# This is global 4968 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.250000 %
# This is global 4969 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 67.800000 %
# This is global 4970 epoch
#  Average loss 0.162
# Accuracy of the network on the 10000 test images: 67.640000 %
# This is global 4971 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 67.790000 %
# This is global 4972 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 67.620000 %
# This is global 4973 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 67.630000 %
# This is global 4974 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4975 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 67.970000 %
# This is global 4976 epoch
#  Average loss 0.007
# Accuracy of the network on the 10000 test images: 68.000000 %
# This is global 4977 epoch
#  Average loss 0.022
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4978 epoch
#  Average loss 0.502
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 4979 epoch
#  Average loss 0.006
# Accuracy of the network on the 10000 test images: 67.500000 %
# This is global 4980 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4981 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4982 epoch
#  Average loss 0.010
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4983 epoch
#  Average loss 0.318
# Accuracy of the network on the 10000 test images: 67.910000 %
# This is global 4984 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 67.910000 %
# This is global 4985 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 67.900000 %
# This is global 4986 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 4987 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 67.990000 %
# This is global 4988 epoch
#  Average loss 0.003
# Accuracy of the network on the 10000 test images: 68.280000 %
# This is global 4989 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 68.000000 %
# This is global 4990 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 4991 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4992 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4993 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 4994 epoch
#  Average loss 0.145
# Accuracy of the network on the 10000 test images: 67.720000 %
# This is global 4995 epoch
#  Average loss 0.142
# Accuracy of the network on the 10000 test images: 67.510000 %
# This is global 4996 epoch
#  Average loss 0.148
# Accuracy of the network on the 10000 test images: 67.260000 %
# This is global 4997 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 67.160000 %
# This is global 4998 epoch
#  Average loss 0.004
# Accuracy of the network on the 10000 test images: 67.700000 %
# This is global 4999 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 67.410000 %
# This is global 5000 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 67.340000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=2001

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.1
num_clients=100
CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients,class_per_user=2)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
#low boundary 안에 있는 녀석들만 update했을 때
learning_rate=0.0007
for epoch in range(global_epoch):

    #m=max(int(C*num_clients),1)
    m=5
    print(f"This is global {epoch} epoch")
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    first=1
    local_setting=[]
    for repeat in range(10):
        local_gradient=[]
        local_loss=[]
        local_cut=[]
        
        for idx,user in enumerate(selected_user):
            #print(f"client :{idx}")
            if first==1:
                #local_setting.append(LocalUpdate(lr=0.0007,local_epoch=50,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user]))
                local_setting.append(LocalUpdate(lr=learning_rate,local_epoch=3,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user]))
                this_local_setting=local_setting[-1]
            else:
                this_local_setting=local_setting[idx]
            gradient,loss,cut=this_local_setting.train(net=copy.deepcopy(FedAvg_model).to(device),On=True)

            local_gradient.append(copy.deepcopy(gradient))
            #print(local_weight[0].keys())
            local_loss.append(copy.deepcopy(loss))
            local_cut.append(copy.deepcopy(cut))
        #print("Local_gradient")
        #print(local_gradient)
        first=0
        FedAvg_gradient=copy.deepcopy(local_gradient[0])
        for i in range(len(FedAvg_gradient)):
            FedAvg_gradient[i]*=local_cut[0]
        #print(local_gradient)
        #for key in FedAvg_weight.keys():
        for i in range(1,len(local_gradient)):
            FedAvg_gradient=list_add(FedAvg_gradient,local_gradient[i],local_cut[i])
            #print(i)
            #print(FedAvg_gradient[0])
        #print("FedAvg_gradient")
        #print(FedAvg_gradient)
        temp=FedAvg_model.state_dict()
        for idx,key in enumerate(temp.keys()):
            #print(key)
            #print(temp[key].size())
            #print(FedAvg_gradient[idx].size())
            #print(torch.sign(FedAvg_gradient[idx]))
            #print(torch.sign(FedAvg_gradient[idx])*learning_rate)
            temp[key]+=-learning_rate*torch.sign(FedAvg_gradient[idx])
            #print(temp[key])
        FedAvg_model.load_state_dict(temp)
    first=1
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 0.737
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 0.814
# Accuracy of the network on the 10000 test images: 11.760000 %
# This is global 2 epoch
#  Average loss 0.743
# Accuracy of the network on the 10000 test images: 12.480000 %
# This is global 3 epoch
#  Average loss 0.562
# Accuracy of the network on the 10000 test images: 18.570000 %
# This is global 4 epoch
#  Average loss 0.796
# Accuracy of the network on the 10000 test images: 15.010000 %
# This is global 5 epoch
#  Average loss 0.628
# Accuracy of the network on the 10000 test images: 10.780000 %
# This is global 6 epoch
#  Average loss 0.419
# Accuracy of the network on the 10000 test images: 20.030000 %
# This is global 7 epoch
#  Average loss 0.419
# Accuracy of the network on the 10000 test images: 12.910000 %
# This is global 8 epoch
#  Average loss 0.401
# Accuracy of the network on the 10000 test images: 15.050000 %
# This is global 9 epoch
#  Average loss 0.535
# Accuracy of the network on the 10000 test images: 14.600000 %
# This is global 10 epoch
#  Average loss 0.517
# Accuracy of the network on the 10000 test images: 16.450000 %
# This is global 11 epoch
#  Average loss 0.392
# Accuracy of the network on the 10000 test images: 15.610000 %
# This is global 12 epoch
#  Average loss 0.451
# Accuracy of the network on the 10000 test images: 21.980000 %
# This is global 13 epoch
#  Average loss 0.544
# Accuracy of the network on the 10000 test images: 17.060000 %
# This is global 14 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 15.580000 %
# This is global 15 epoch
#  Average loss 0.548
# Accuracy of the network on the 10000 test images: 21.680000 %
# This is global 16 epoch
#  Average loss 0.584
# Accuracy of the network on the 10000 test images: 22.980000 %
# This is global 17 epoch
#  Average loss 0.479
# Accuracy of the network on the 10000 test images: 22.930000 %
# This is global 18 epoch
#  Average loss 0.390
# Accuracy of the network on the 10000 test images: 20.320000 %
# This is global 19 epoch
#  Average loss 0.371
# Accuracy of the network on the 10000 test images: 19.010000 %
# This is global 20 epoch
#  Average loss 0.321
# Accuracy of the network on the 10000 test images: 24.890000 %
# This is global 21 epoch
#  Average loss 0.390
# Accuracy of the network on the 10000 test images: 25.060000 %
# This is global 22 epoch
#  Average loss 0.427
# Accuracy of the network on the 10000 test images: 29.550000 %
# This is global 23 epoch
#  Average loss 0.445
# Accuracy of the network on the 10000 test images: 29.500000 %
# This is global 24 epoch
#  Average loss 0.466
# Accuracy of the network on the 10000 test images: 26.140000 %
# This is global 25 epoch
#  Average loss 0.394
# Accuracy of the network on the 10000 test images: 29.290000 %
# This is global 26 epoch
#  Average loss 0.274
# Accuracy of the network on the 10000 test images: 21.220000 %
# This is global 27 epoch
#  Average loss 0.260
# Accuracy of the network on the 10000 test images: 27.750000 %
# This is global 28 epoch
#  Average loss 0.399
# Accuracy of the network on the 10000 test images: 23.340000 %
# This is global 29 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 29.480000 %
# This is global 30 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 35.820000 %
# This is global 31 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 26.370000 %
# This is global 32 epoch
#  Average loss 0.369
# Accuracy of the network on the 10000 test images: 32.140000 %
# This is global 33 epoch
#  Average loss 0.330
# Accuracy of the network on the 10000 test images: 28.530000 %
# This is global 34 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 22.860000 %
# This is global 35 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 29.950000 %
# This is global 36 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 31.340000 %
# This is global 37 epoch
#  Average loss 0.299
# Accuracy of the network on the 10000 test images: 29.470000 %
# This is global 38 epoch
#  Average loss 0.404
# Accuracy of the network on the 10000 test images: 29.960000 %
# This is global 39 epoch
#  Average loss 0.337
# Accuracy of the network on the 10000 test images: 31.900000 %
# This is global 40 epoch
#  Average loss 0.245
# Accuracy of the network on the 10000 test images: 33.910000 %
# This is global 41 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 32.050000 %
# This is global 42 epoch
#  Average loss 0.385
# Accuracy of the network on the 10000 test images: 33.030000 %
# This is global 43 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 26.790000 %
# This is global 44 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 28.250000 %
# This is global 45 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 24.510000 %
# This is global 46 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 27.850000 %
# This is global 47 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 29.580000 %
# This is global 48 epoch
#  Average loss 0.160
# Accuracy of the network on the 10000 test images: 26.900000 %
# This is global 49 epoch
#  Average loss 0.385
# Accuracy of the network on the 10000 test images: 33.170000 %
# This is global 50 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 33.310000 %
# This is global 51 epoch
#  Average loss 0.135
# Accuracy of the network on the 10000 test images: 27.660000 %
# This is global 52 epoch
#  Average loss 0.324
# Accuracy of the network on the 10000 test images: 35.470000 %
# This is global 53 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 36.200000 %
# This is global 54 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 40.310000 %
# This is global 55 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 27.640000 %
# This is global 56 epoch
#  Average loss 0.294
# Accuracy of the network on the 10000 test images: 32.040000 %
# This is global 57 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 27.850000 %
# This is global 58 epoch
#  Average loss 0.156
# Accuracy of the network on the 10000 test images: 23.170000 %
# This is global 59 epoch
#  Average loss 0.294
# Accuracy of the network on the 10000 test images: 32.340000 %
# This is global 60 epoch
#  Average loss 0.207
# Accuracy of the network on the 10000 test images: 23.480000 %
# This is global 61 epoch
#  Average loss 0.175
# Accuracy of the network on the 10000 test images: 27.880000 %
# This is global 62 epoch
#  Average loss 0.316
# Accuracy of the network on the 10000 test images: 31.900000 %
# This is global 63 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 25.610000 %
# This is global 64 epoch
#  Average loss 0.345
# Accuracy of the network on the 10000 test images: 25.320000 %
# This is global 65 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 30.780000 %
# This is global 66 epoch
#  Average loss 0.133
# Accuracy of the network on the 10000 test images: 29.600000 %
# This is global 67 epoch
#  Average loss 0.161
# Accuracy of the network on the 10000 test images: 27.570000 %
# This is global 68 epoch
#  Average loss 0.181
# Accuracy of the network on the 10000 test images: 32.740000 %
# This is global 69 epoch
#  Average loss 0.360
# Accuracy of the network on the 10000 test images: 33.210000 %
# This is global 70 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 37.730000 %
# This is global 71 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 26.940000 %
# This is global 72 epoch
#  Average loss 0.163
# Accuracy of the network on the 10000 test images: 30.160000 %
# This is global 73 epoch
#  Average loss 0.205
# Accuracy of the network on the 10000 test images: 37.380000 %
# This is global 74 epoch
#  Average loss 0.184
# Accuracy of the network on the 10000 test images: 37.680000 %
# This is global 75 epoch
#  Average loss 0.182
# Accuracy of the network on the 10000 test images: 36.670000 %
# This is global 76 epoch
#  Average loss 0.145
# Accuracy of the network on the 10000 test images: 35.320000 %
# This is global 77 epoch
#  Average loss 0.260
# Accuracy of the network on the 10000 test images: 36.950000 %
# This is global 78 epoch
#  Average loss 0.137
# Accuracy of the network on the 10000 test images: 40.840000 %
# This is global 79 epoch
#  Average loss 0.143
# Accuracy of the network on the 10000 test images: 34.600000 %
# This is global 80 epoch
#  Average loss 0.164
# Accuracy of the network on the 10000 test images: 36.900000 %
# This is global 81 epoch
#  Average loss 0.254
# Accuracy of the network on the 10000 test images: 23.160000 %
# This is global 82 epoch
#  Average loss 0.158
# Accuracy of the network on the 10000 test images: 36.900000 %
# This is global 83 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 34.780000 %
# This is global 84 epoch
#  Average loss 0.127
# Accuracy of the network on the 10000 test images: 35.280000 %
# This is global 85 epoch
#  Average loss 0.131
# Accuracy of the network on the 10000 test images: 32.220000 %
# This is global 86 epoch
#  Average loss 0.110
# Accuracy of the network on the 10000 test images: 33.510000 %
# This is global 87 epoch
#  Average loss 0.148
# Accuracy of the network on the 10000 test images: 35.150000 %
# This is global 88 epoch
#  Average loss 0.148
# Accuracy of the network on the 10000 test images: 33.710000 %
# This is global 89 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 28.880000 %
# This is global 90 epoch
#  Average loss 0.150
# Accuracy of the network on the 10000 test images: 30.740000 %
# This is global 91 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 38.720000 %
# This is global 92 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 38.940000 %
# This is global 93 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 37.280000 %
# This is global 94 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 43.430000 %
# This is global 95 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 33.630000 %
# This is global 96 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 32.600000 %
# This is global 97 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 40.430000 %
# This is global 98 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 36.840000 %
# This is global 99 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 36.970000 %
# This is global 100 epoch
#  Average loss 0.123
# Accuracy of the network on the 10000 test images: 36.560000 %
# This is global 101 epoch
#  Average loss 0.174
# Accuracy of the network on the 10000 test images: 35.320000 %
# This is global 102 epoch
#  Average loss 0.106
# Accuracy of the network on the 10000 test images: 33.400000 %
# This is global 103 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 38.240000 %
# This is global 104 epoch
#  Average loss 0.135
# Accuracy of the network on the 10000 test images: 34.260000 %
# This is global 105 epoch
#  Average loss 0.140
# Accuracy of the network on the 10000 test images: 38.060000 %
# This is global 106 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 43.040000 %
# This is global 107 epoch
#  Average loss 0.167
# Accuracy of the network on the 10000 test images: 28.220000 %
# This is global 108 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 32.320000 %
# This is global 109 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 35.640000 %
# This is global 110 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 35.860000 %
# This is global 111 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 35.950000 %
# This is global 112 epoch
#  Average loss 0.157
# Accuracy of the network on the 10000 test images: 33.850000 %
# This is global 113 epoch
#  Average loss 0.161
# Accuracy of the network on the 10000 test images: 29.020000 %
# This is global 114 epoch
#  Average loss 0.110
# Accuracy of the network on the 10000 test images: 31.910000 %
# This is global 115 epoch
#  Average loss 0.158
# Accuracy of the network on the 10000 test images: 35.530000 %
# This is global 116 epoch
#  Average loss 0.150
# Accuracy of the network on the 10000 test images: 32.940000 %
# This is global 117 epoch
#  Average loss 0.098
# Accuracy of the network on the 10000 test images: 35.640000 %
# This is global 118 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 37.070000 %
# This is global 119 epoch
#  Average loss 0.140
# Accuracy of the network on the 10000 test images: 39.990000 %
# This is global 120 epoch
#  Average loss 0.125
# Accuracy of the network on the 10000 test images: 35.940000 %
# This is global 121 epoch
#  Average loss 0.112
# Accuracy of the network on the 10000 test images: 34.700000 %
# This is global 122 epoch
#  Average loss 0.098
# Accuracy of the network on the 10000 test images: 34.020000 %
# This is global 123 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 37.400000 %
# This is global 124 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 31.830000 %
# This is global 125 epoch
#  Average loss 0.136
# Accuracy of the network on the 10000 test images: 36.420000 %
# This is global 126 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 30.450000 %
# This is global 127 epoch
#  Average loss 0.124
# Accuracy of the network on the 10000 test images: 36.420000 %
# This is global 128 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 34.530000 %
# This is global 129 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 31.980000 %
# This is global 130 epoch
#  Average loss 0.190
# Accuracy of the network on the 10000 test images: 32.390000 %
# This is global 131 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 35.170000 %
# This is global 132 epoch
#  Average loss 0.180
# Accuracy of the network on the 10000 test images: 34.580000 %
# This is global 133 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 40.930000 %
# This is global 134 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 41.990000 %
# This is global 135 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 43.830000 %
# This is global 136 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 42.740000 %
# This is global 137 epoch
#  Average loss 0.136
# Accuracy of the network on the 10000 test images: 40.170000 %
# This is global 138 epoch
#  Average loss 0.176
# Accuracy of the network on the 10000 test images: 41.780000 %
# This is global 139 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 36.120000 %
# This is global 140 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 38.700000 %
# This is global 141 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 38.120000 %
# This is global 142 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 41.240000 %
# This is global 143 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 29.990000 %
# This is global 144 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 42.710000 %
# This is global 145 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 42.670000 %
# This is global 146 epoch
#  Average loss 0.120
# Accuracy of the network on the 10000 test images: 43.250000 %
# This is global 147 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 45.210000 %
# This is global 148 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 41.610000 %
# This is global 149 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 40.800000 %
# This is global 150 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 41.440000 %
# This is global 151 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 42.120000 %
# This is global 152 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 47.200000 %
# This is global 153 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 45.430000 %
# This is global 154 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 44.210000 %
# This is global 155 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 44.440000 %
# This is global 156 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 38.610000 %
# This is global 157 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 45.750000 %
# This is global 158 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 42.390000 %
# This is global 159 epoch
#  Average loss 0.106
# Accuracy of the network on the 10000 test images: 41.150000 %
# This is global 160 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 26.850000 %
# This is global 161 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 37.310000 %
# This is global 162 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 39.560000 %
# This is global 163 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 41.860000 %
# This is global 164 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 37.970000 %
# This is global 165 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 41.220000 %
# This is global 166 epoch
#  Average loss 0.110
# Accuracy of the network on the 10000 test images: 44.580000 %
# This is global 167 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 41.040000 %
# This is global 168 epoch
#  Average loss 0.157
# Accuracy of the network on the 10000 test images: 38.480000 %
# This is global 169 epoch
#  Average loss 0.103
# Accuracy of the network on the 10000 test images: 44.510000 %
# This is global 170 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 42.410000 %
# This is global 171 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 39.260000 %
# This is global 172 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 44.800000 %
# This is global 173 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 44.750000 %
# This is global 174 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 43.960000 %
# This is global 175 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 46.940000 %
# This is global 176 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 42.560000 %
# This is global 177 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 44.230000 %
# This is global 178 epoch
#  Average loss 0.140
# Accuracy of the network on the 10000 test images: 44.060000 %
# This is global 179 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 41.460000 %
# This is global 180 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 41.220000 %
# This is global 181 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 45.340000 %
# This is global 182 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 46.450000 %
# This is global 183 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 45.600000 %
# This is global 184 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 46.300000 %
# This is global 185 epoch
#  Average loss 0.184
# Accuracy of the network on the 10000 test images: 41.260000 %
# This is global 186 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 40.980000 %
# This is global 187 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 42.560000 %
# This is global 188 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 43.780000 %
# This is global 189 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 42.490000 %
# This is global 190 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 42.970000 %
# This is global 191 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 44.300000 %
# This is global 192 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 38.860000 %
# This is global 193 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 40.130000 %
# This is global 194 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 40.370000 %
# This is global 195 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 43.410000 %
# This is global 196 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 39.820000 %
# This is global 197 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 43.930000 %
# This is global 198 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 45.780000 %
# This is global 199 epoch
#  Average loss 0.142
# Accuracy of the network on the 10000 test images: 43.590000 %
# This is global 200 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 41.290000 %
# This is global 201 epoch
#  Average loss 0.138
# Accuracy of the network on the 10000 test images: 42.960000 %
# This is global 202 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 47.120000 %
# This is global 203 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 43.980000 %
# This is global 204 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 39.650000 %
# This is global 205 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 44.300000 %
# This is global 206 epoch
#  Average loss 0.148
# Accuracy of the network on the 10000 test images: 42.820000 %
# This is global 207 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 38.400000 %
# This is global 208 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 42.710000 %
# This is global 209 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 40.400000 %
# This is global 210 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 40.220000 %
# This is global 211 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 36.410000 %
# This is global 212 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 40.440000 %
# This is global 213 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 41.980000 %
# This is global 214 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 45.250000 %
# This is global 215 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 41.820000 %
# This is global 216 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 44.630000 %
# This is global 217 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 37.750000 %
# This is global 218 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 42.800000 %
# This is global 219 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 44.240000 %
# This is global 220 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 42.080000 %
# This is global 221 epoch
#  Average loss 0.117
# Accuracy of the network on the 10000 test images: 44.550000 %
# This is global 222 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 37.410000 %
# This is global 223 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 40.330000 %
# This is global 224 epoch
#  Average loss 0.028
# Accuracy of the network on the 10000 test images: 39.810000 %
# This is global 225 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 37.360000 %
# This is global 226 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 40.240000 %
# This is global 227 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 44.170000 %
# This is global 228 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 42.440000 %
# This is global 229 epoch
#  Average loss 0.029
# Accuracy of the network on the 10000 test images: 46.190000 %
# This is global 230 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 47.980000 %
# This is global 231 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 38.960000 %
# This is global 232 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 44.320000 %
# This is global 233 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 44.790000 %
# This is global 234 epoch
#  Average loss 0.019
# Accuracy of the network on the 10000 test images: 45.510000 %
# This is global 235 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 43.730000 %
# This is global 236 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 39.390000 %
# This is global 237 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 44.300000 %
# This is global 238 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 39.800000 %
# This is global 239 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 37.170000 %
# This is global 240 epoch
#  Average loss 0.119
# Accuracy of the network on the 10000 test images: 40.790000 %
# This is global 241 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 41.720000 %
# This is global 242 epoch
#  Average loss 0.037
# Accuracy of the network on the 10000 test images: 45.360000 %
# This is global 243 epoch
#  Average loss 0.117
# Accuracy of the network on the 10000 test images: 35.260000 %
# This is global 244 epoch
#  Average loss 0.157
# Accuracy of the network on the 10000 test images: 45.650000 %
# This is global 245 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 34.290000 %
# This is global 246 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 36.510000 %
# This is global 247 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 40.330000 %
# This is global 248 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 43.790000 %
# This is global 249 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 39.730000 %
# This is global 250 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 43.670000 %
# This is global 251 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 47.580000 %
# This is global 252 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 43.040000 %
# This is global 253 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 45.420000 %
# This is global 254 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 45.020000 %
# This is global 255 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 42.640000 %
# This is global 256 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 40.040000 %
# This is global 257 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 42.220000 %
# This is global 258 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 43.110000 %
# This is global 259 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 44.470000 %
# This is global 260 epoch
#  Average loss 0.109
# Accuracy of the network on the 10000 test images: 39.210000 %
# This is global 261 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 42.980000 %
# This is global 262 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 39.070000 %
# This is global 263 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 46.170000 %
# This is global 264 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 44.960000 %
# This is global 265 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 41.910000 %
# This is global 266 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 45.360000 %
# This is global 267 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 42.230000 %
# This is global 268 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 42.910000 %
# This is global 269 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 46.330000 %
# This is global 270 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 43.790000 %
# This is global 271 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 46.230000 %
# This is global 272 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 45.570000 %
# This is global 273 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 46.610000 %
# This is global 274 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 43.650000 %
# This is global 275 epoch
#  Average loss 0.104
# Accuracy of the network on the 10000 test images: 46.400000 %
# This is global 276 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 44.570000 %
# This is global 277 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 38.410000 %
# This is global 278 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 39.420000 %
# This is global 279 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 43.950000 %
# This is global 280 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 46.010000 %
# This is global 281 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 48.830000 %
# This is global 282 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 45.970000 %
# This is global 283 epoch
#  Average loss 0.029
# Accuracy of the network on the 10000 test images: 45.380000 %
# This is global 284 epoch
#  Average loss 0.023
# Accuracy of the network on the 10000 test images: 45.140000 %
# This is global 285 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 43.120000 %
# This is global 286 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 44.980000 %
# This is global 287 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 49.170000 %
# This is global 288 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 46.580000 %
# This is global 289 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 43.750000 %
# This is global 290 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 48.310000 %
# This is global 291 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 45.520000 %
# This is global 292 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 48.900000 %
# This is global 293 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 43.530000 %
# This is global 294 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 49.380000 %
# This is global 295 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 47.420000 %
# This is global 296 epoch
#  Average loss 0.022
# Accuracy of the network on the 10000 test images: 49.750000 %
# This is global 297 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 46.170000 %
# This is global 298 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 43.370000 %
# This is global 299 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 49.300000 %
# This is global 300 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 44.680000 %
# This is global 301 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 39.840000 %
# This is global 302 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 41.800000 %
# This is global 303 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 38.800000 %
# This is global 304 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 47.410000 %
# This is global 305 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 47.740000 %
# This is global 306 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 41.840000 %
# This is global 307 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 45.550000 %
# This is global 308 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 48.990000 %
# This is global 309 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 41.170000 %
# This is global 310 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 43.930000 %
# This is global 311 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 45.950000 %
# This is global 312 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 45.590000 %
# This is global 313 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 47.260000 %
# This is global 314 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 37.710000 %
# This is global 315 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 43.630000 %
# This is global 316 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 45.100000 %
# This is global 317 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 46.000000 %
# This is global 318 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 40.900000 %
# This is global 319 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 45.750000 %
# This is global 320 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 41.440000 %
# This is global 321 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 41.830000 %
# This is global 322 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 40.370000 %
# This is global 323 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 41.480000 %
# This is global 324 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 45.160000 %
# This is global 325 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 44.740000 %
# This is global 326 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 42.840000 %
# This is global 327 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 43.870000 %
# This is global 328 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 45.250000 %
# This is global 329 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 43.930000 %
# This is global 330 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 46.520000 %
# This is global 331 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 46.500000 %
# This is global 332 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 46.190000 %
# This is global 333 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 45.140000 %
# This is global 334 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 45.010000 %
# This is global 335 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 46.430000 %
# This is global 336 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 50.490000 %
# This is global 337 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 45.510000 %
# This is global 338 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 45.600000 %
# This is global 339 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 44.010000 %
# This is global 340 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 46.770000 %
# This is global 341 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 46.230000 %
# This is global 342 epoch
#  Average loss 0.124
# Accuracy of the network on the 10000 test images: 47.460000 %
# This is global 343 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 46.870000 %
# This is global 344 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 47.770000 %
# This is global 345 epoch
#  Average loss 0.037
# Accuracy of the network on the 10000 test images: 43.850000 %
# This is global 346 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 46.790000 %
# This is global 347 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 46.530000 %
# This is global 348 epoch
#  Average loss 0.035
# Accuracy of the network on the 10000 test images: 45.500000 %
# This is global 349 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 46.930000 %
# This is global 350 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 44.330000 %
# This is global 351 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 44.860000 %
# This is global 352 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 45.910000 %
# This is global 353 epoch
#  Average loss 0.021
# Accuracy of the network on the 10000 test images: 43.880000 %
# This is global 354 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 42.770000 %
# This is global 355 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 48.260000 %
# This is global 356 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 43.220000 %
# This is global 357 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 48.130000 %
# This is global 358 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 50.420000 %
# This is global 359 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 40.120000 %
# This is global 360 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 43.480000 %
# This is global 361 epoch
#  Average loss 0.011
# Accuracy of the network on the 10000 test images: 37.950000 %
# This is global 362 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 44.380000 %
# This is global 363 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 46.230000 %
# This is global 364 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 43.980000 %
# This is global 365 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 44.540000 %
# This is global 366 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 48.210000 %
# This is global 367 epoch
#  Average loss 0.029
# Accuracy of the network on the 10000 test images: 49.120000 %
# This is global 368 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 49.020000 %
# This is global 369 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 41.250000 %
# This is global 370 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 45.840000 %
# This is global 371 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 44.190000 %
# This is global 372 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 47.710000 %
# This is global 373 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 45.010000 %
# This is global 374 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 46.190000 %
# This is global 375 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 47.400000 %
# This is global 376 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 47.230000 %
# This is global 377 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 50.890000 %
# This is global 378 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 39.510000 %
# This is global 379 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 46.700000 %
# This is global 380 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 46.260000 %
# This is global 381 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 45.300000 %
# This is global 382 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 48.030000 %
# This is global 383 epoch
#  Average loss 0.024
# Accuracy of the network on the 10000 test images: 43.760000 %
# This is global 384 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 41.070000 %
# This is global 385 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 45.900000 %
# This is global 386 epoch
#  Average loss 0.028
# Accuracy of the network on the 10000 test images: 45.670000 %
# This is global 387 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 45.640000 %
# This is global 388 epoch
#  Average loss 0.029
# Accuracy of the network on the 10000 test images: 47.610000 %
# This is global 389 epoch
#  Average loss 0.021
# Accuracy of the network on the 10000 test images: 46.650000 %
# This is global 390 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 46.020000 %
# This is global 391 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 45.650000 %
# This is global 392 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 32.490000 %
# This is global 393 epoch
#  Average loss 0.033
# Accuracy of the network on the 10000 test images: 43.900000 %
# This is global 394 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 43.320000 %
# This is global 395 epoch
#  Average loss 0.025
# Accuracy of the network on the 10000 test images: 44.950000 %
# This is global 396 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 48.540000 %
# This is global 397 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 47.990000 %
# This is global 398 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 45.870000 %
# This is global 399 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 45.970000 %
# This is global 400 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 45.550000 %
# This is global 401 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 45.350000 %
# This is global 402 epoch
#  Average loss 0.037
# Accuracy of the network on the 10000 test images: 46.020000 %
# This is global 403 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 45.270000 %
# This is global 404 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 42.160000 %
# This is global 405 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 49.130000 %
# This is global 406 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 48.830000 %
# This is global 407 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 49.840000 %
# This is global 408 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 41.360000 %
# This is global 409 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 50.960000 %
# This is global 410 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 46.910000 %
# This is global 411 epoch
#  Average loss 0.021
# Accuracy of the network on the 10000 test images: 44.960000 %
# This is global 412 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 48.980000 %
# This is global 413 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 46.200000 %
# This is global 414 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 44.620000 %
# This is global 415 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 39.790000 %
# This is global 416 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 43.450000 %
# This is global 417 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 43.480000 %
# This is global 418 epoch
#  Average loss 0.025
# Accuracy of the network on the 10000 test images: 43.120000 %
# This is global 419 epoch
#  Average loss 0.019
# Accuracy of the network on the 10000 test images: 39.980000 %
# This is global 420 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 45.310000 %
# This is global 421 epoch
#  Average loss 0.180
# Accuracy of the network on the 10000 test images: 46.660000 %
# This is global 422 epoch
#  Average loss 0.025
# Accuracy of the network on the 10000 test images: 44.560000 %
# This is global 423 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 46.770000 %
# This is global 424 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 47.170000 %
# This is global 425 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 46.090000 %
# This is global 426 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 43.080000 %
# This is global 427 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 44.980000 %
# This is global 428 epoch
#  Average loss 0.025
# Accuracy of the network on the 10000 test images: 45.230000 %
# This is global 429 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 44.490000 %
# This is global 430 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 46.270000 %
# This is global 431 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 47.730000 %
# This is global 432 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 47.840000 %
# This is global 433 epoch
#  Average loss 0.021
# Accuracy of the network on the 10000 test images: 48.710000 %
# This is global 434 epoch
#  Average loss 0.028
# Accuracy of the network on the 10000 test images: 48.380000 %
# This is global 435 epoch
#  Average loss 0.024
# Accuracy of the network on the 10000 test images: 49.530000 %
# This is global 436 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 49.810000 %
# This is global 437 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 48.560000 %
# This is global 438 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 44.340000 %
# This is global 439 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 48.140000 %
# This is global 440 epoch
#  Average loss 0.030
# Accuracy of the network on the 10000 test images: 48.850000 %
# This is global 441 epoch
#  Average loss 0.032
# Accuracy of the network on the 10000 test images: 45.630000 %
# This is global 442 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 49.450000 %
# This is global 443 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 44.810000 %
# This is global 444 epoch
#  Average loss 0.034
# Accuracy of the network on the 10000 test images: 40.060000 %
# This is global 445 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 36.370000 %
# This is global 446 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 47.280000 %
# ...
# This is global 1853 epoch
#  Average loss 0.561
# Accuracy of the network on the 10000 test images: 27.060000 %
# This is global 1854 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.910000 %
# This is global 1855 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 28.690000 %
# This is global 1856 epoch
#  Average loss 0.433
# Accuracy of the network on the 10000 test images: 27.610000 %
# This is global 1857 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.960000 %
# This is global 1858 epoch
#  Average loss 0.482
# Accuracy of the network on the 10000 test images: 27.140000 %
# This is global 1859 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.480000 %
# This is global 1860 epoch
#  Average loss 1340.981
# Accuracy of the network on the 10000 test images: 26.570000 %
# This is global 1861 epoch
#  Average loss 31177382794.362
# Accuracy of the network on the 10000 test images: 27.220000 %
# This is global 1862 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.700000 %
# This is global 1863 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.000000 %
# This is global 1864 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.830000 %
# This is global 1865 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.450000 %
# This is global 1866 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.800000 %
# This is global 1867 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 23.080000 %
# This is global 1868 epoch
#  Average loss 0.381
# Accuracy of the network on the 10000 test images: 24.480000 %
# This is global 1869 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.570000 %
# This is global 1870 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.210000 %
# This is global 1871 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.180000 %
# This is global 1872 epoch
#  Average loss 1113115933792.969
# Accuracy of the network on the 10000 test images: 24.680000 %
# This is global 1873 epoch
#  Average loss 0.434
# Accuracy of the network on the 10000 test images: 24.990000 %
# This is global 1874 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.690000 %
# This is global 1875 epoch
#  Average loss 7001132.331
# Accuracy of the network on the 10000 test images: 24.150000 %
# This is global 1876 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.650000 %
# This is global 1877 epoch
#  Average loss 0.319
# Accuracy of the network on the 10000 test images: 25.990000 %
# This is global 1878 epoch
#  Average loss 3609482281.220
# Accuracy of the network on the 10000 test images: 24.970000 %
# This is global 1879 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.000000 %
# This is global 1880 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.600000 %
# This is global 1881 epoch
#  Average loss 0.309
# Accuracy of the network on the 10000 test images: 27.440000 %
# This is global 1882 epoch
#  Average loss 0.448
# Accuracy of the network on the 10000 test images: 26.660000 %
# This is global 1883 epoch
#  Average loss 41381.641
# Accuracy of the network on the 10000 test images: 25.790000 %
# This is global 1884 epoch
#  Average loss 266.928
# Accuracy of the network on the 10000 test images: 27.230000 %
# This is global 1885 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.630000 %
# This is global 1886 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.130000 %
# This is global 1887 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.420000 %
# This is global 1888 epoch
#  Average loss 0.397
# Accuracy of the network on the 10000 test images: 26.490000 %
# This is global 1889 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.260000 %
# This is global 1890 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.010000 %
# This is global 1891 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.760000 %
# This is global 1892 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.040000 %
# This is global 1893 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.220000 %
# This is global 1894 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.730000 %
# This is global 1895 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.140000 %
# This is global 1896 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.370000 %
# This is global 1897 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.600000 %
# This is global 1898 epoch
#  Average loss 4.646
# Accuracy of the network on the 10000 test images: 27.620000 %
# This is global 1899 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.030000 %
# This is global 1900 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.030000 %
# This is global 1901 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.900000 %
# This is global 1902 epoch
#  Average loss 0.324
# Accuracy of the network on the 10000 test images: 26.520000 %
# This is global 1903 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.320000 %
# This is global 1904 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.880000 %
# This is global 1905 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.190000 %
# This is global 1906 epoch
#  Average loss 0.327
# Accuracy of the network on the 10000 test images: 26.570000 %
# This is global 1907 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.670000 %
# This is global 1908 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.280000 %
# This is global 1909 epoch
#  Average loss 37895584649934.398
# Accuracy of the network on the 10000 test images: 25.830000 %
# This is global 1910 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.630000 %
# This is global 1911 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 27.260000 %
# This is global 1912 epoch
#  Average loss 0.334
# Accuracy of the network on the 10000 test images: 27.260000 %
# This is global 1913 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.700000 %
# This is global 1914 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.340000 %
# This is global 1915 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.000000 %
# This is global 1916 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.580000 %
# This is global 1917 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.110000 %
# This is global 1918 epoch
#  Average loss 0.370
# Accuracy of the network on the 10000 test images: 25.310000 %
# This is global 1919 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.260000 %
# This is global 1920 epoch
#  Average loss 0.294
# Accuracy of the network on the 10000 test images: 26.320000 %
# This is global 1921 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.440000 %
# This is global 1922 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.340000 %
# This is global 1923 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.060000 %
# This is global 1924 epoch
#  Average loss 142.181
# Accuracy of the network on the 10000 test images: 26.840000 %
# This is global 1925 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.240000 %
# This is global 1926 epoch
#  Average loss 0.517
# Accuracy of the network on the 10000 test images: 24.610000 %
# This is global 1927 epoch
#  Average loss 3.551
# Accuracy of the network on the 10000 test images: 23.280000 %
# This is global 1928 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.500000 %
# This is global 1929 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.100000 %
# This is global 1930 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.470000 %
# This is global 1931 epoch
#  Average loss 717334513582997.875
# Accuracy of the network on the 10000 test images: 25.040000 %
# This is global 1932 epoch
#  Average loss 0.349
# Accuracy of the network on the 10000 test images: 28.760000 %
# This is global 1933 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.530000 %
# This is global 1934 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.060000 %
# This is global 1935 epoch
#  Average loss 0.325
# Accuracy of the network on the 10000 test images: 27.830000 %
# This is global 1936 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 29.750000 %
# This is global 1937 epoch
#  Average loss 60564796673.009
# Accuracy of the network on the 10000 test images: 28.150000 %
# This is global 1938 epoch
#  Average loss 29.165
# Accuracy of the network on the 10000 test images: 26.330000 %
# This is global 1939 epoch
#  Average loss 18261416215.688
# Accuracy of the network on the 10000 test images: 26.570000 %
# This is global 1940 epoch
#  Average loss 2361584386386.459
# Accuracy of the network on the 10000 test images: 26.970000 %
# This is global 1941 epoch
#  Average loss 0.446
# Accuracy of the network on the 10000 test images: 26.380000 %
# This is global 1942 epoch
#  Average loss 1.409
# Accuracy of the network on the 10000 test images: 27.400000 %
# This is global 1943 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.550000 %
# This is global 1944 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 28.070000 %
# This is global 1945 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.620000 %
# This is global 1946 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.370000 %
# This is global 1947 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.670000 %
# This is global 1948 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.040000 %
# This is global 1949 epoch
#  Average loss 7150.647
# Accuracy of the network on the 10000 test images: 27.180000 %
# This is global 1950 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.590000 %
# This is global 1951 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.930000 %
# This is global 1952 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.870000 %
# This is global 1953 epoch
#  Average loss 0.339
# Accuracy of the network on the 10000 test images: 23.780000 %
# This is global 1954 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.300000 %
# This is global 1955 epoch
#  Average loss 1913501.498
# Accuracy of the network on the 10000 test images: 24.250000 %
# This is global 1956 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.890000 %
# This is global 1957 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 24.610000 %
# This is global 1958 epoch
#  Average loss 0.353
# Accuracy of the network on the 10000 test images: 23.900000 %
# This is global 1959 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.850000 %
# This is global 1960 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.420000 %
# This is global 1961 epoch
#  Average loss 3743509194619.444
# Accuracy of the network on the 10000 test images: 24.700000 %
# This is global 1962 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.200000 %
# This is global 1963 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.010000 %
# This is global 1964 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.740000 %
# This is global 1965 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.020000 %
# This is global 1966 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.120000 %
# This is global 1967 epoch
#  Average loss 0.331
# Accuracy of the network on the 10000 test images: 23.680000 %
# This is global 1968 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.040000 %
# This is global 1969 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.390000 %
# This is global 1970 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.990000 %
# This is global 1971 epoch
#  Average loss 126435197.234
# Accuracy of the network on the 10000 test images: 24.530000 %
# This is global 1972 epoch
#  Average loss 1907554677421684736.000
# Accuracy of the network on the 10000 test images: 22.990000 %
# This is global 1973 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.240000 %
# This is global 1974 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 23.320000 %
# This is global 1975 epoch
#  Average loss 262954298.472
# Accuracy of the network on the 10000 test images: 25.150000 %
# This is global 1976 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.400000 %
# This is global 1977 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.760000 %
# This is global 1978 epoch
#  Average loss 1.019
# Accuracy of the network on the 10000 test images: 26.410000 %
# This is global 1979 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.500000 %
# This is global 1980 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.940000 %
# This is global 1981 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.980000 %
# This is global 1982 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 27.770000 %
# This is global 1983 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.840000 %
# This is global 1984 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 28.020000 %
# This is global 1985 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.770000 %
# This is global 1986 epoch
#  Average loss 0.426
# Accuracy of the network on the 10000 test images: 28.080000 %
# This is global 1987 epoch
#  Average loss 75306237177685.203
# Accuracy of the network on the 10000 test images: 27.010000 %
# This is global 1988 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 27.320000 %
# This is global 1989 epoch
#  Average loss 8182683151545278.000
# Accuracy of the network on the 10000 test images: 26.470000 %
# This is global 1990 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.730000 %
# This is global 1991 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.030000 %
# This is global 1992 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 23.850000 %
# This is global 1993 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.980000 %
# This is global 1994 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 24.010000 %
# This is global 1995 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.190000 %
# This is global 1996 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.470000 %
# This is global 1997 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.390000 %
# This is global 1998 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.050000 %
# This is global 1999 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 25.590000 %
# This is global 2000 epoch
#  Average loss nan
# Accuracy of the network on the 10000 test images: 26.340000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train[:500]),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train[:500]))],acc_train[:500],label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
C=0.1
num_clients=100
CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
#low boundary 안에 있는 녀석들만 update했을 때
learning_rate=0.0007
for epoch in range(global_epoch):

    #m=max(int(C*num_clients),1)
    m=5
    print(f"This is global {epoch} epoch")
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    first=1
    local_setting=[]
    for repeat in range(10):
        local_gradient=[]
        local_loss=[]
        local_cut=[]
        
        for idx,user in enumerate(selected_user):
            #print(f"client :{idx}")
            if first==1:
                #local_setting.append(LocalUpdate(lr=0.0007,local_epoch=50,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user]))
                local_setting.append(LocalUpdate(lr=learning_rate,local_epoch=3,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user]))
                this_local_setting=local_setting[-1]
            else:
                this_local_setting=local_setting[idx]
            gradient,loss,cut=this_local_setting.train(net=copy.deepcopy(FedAvg_model).to(device),On=True)

            local_gradient.append(copy.deepcopy(gradient))
            #print(local_weight[0].keys())
            local_loss.append(copy.deepcopy(loss))
            local_cut.append(copy.deepcopy(cut))
        #print("Local_gradient")
        #print(local_gradient)
        first=0
        FedAvg_gradient=copy.deepcopy(local_gradient[0])
        for i in range(len(FedAvg_gradient)):
            FedAvg_gradient[i]*=local_cut[0]
        #print(local_gradient)
        #for key in FedAvg_weight.keys():
        for i in range(1,len(local_gradient)):
            FedAvg_gradient=list_add(FedAvg_gradient,local_gradient[i],local_cut[i])
            #print(i)
            #print(FedAvg_gradient[0])
        #print("FedAvg_gradient")
        #print(FedAvg_gradient)
        temp=FedAvg_model.state_dict()
        for idx,key in enumerate(temp.keys()):
            #print(key)
            #print(temp[key].size())
            #print(FedAvg_gradient[idx].size())
            #print(torch.sign(FedAvg_gradient[idx]))
            #print(torch.sign(FedAvg_gradient[idx])*learning_rate)
            temp[key]+=-learning_rate*torch.sign(FedAvg_gradient[idx])
            #print(temp[key])
        FedAvg_model.load_state_dict(temp)
    first=1
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 29.780000 %
# This is global 1 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 31.160000 %
# This is global 2 epoch
#  Average loss 0.027
# Accuracy of the network on the 10000 test images: 30.370000 %
# This is global 3 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 35.280000 %
# This is global 4 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 34.260000 %
# This is global 5 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 34.400000 %
# This is global 6 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 33.770000 %
# This is global 7 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 33.170000 %
# This is global 8 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 30.300000 %
# This is global 9 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 30.660000 %
# This is global 10 epoch
#  Average loss 0.026
# Accuracy of the network on the 10000 test images: 28.370000 %
# This is global 11 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 27.730000 %
# This is global 12 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 29.110000 %
# This is global 13 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 31.020000 %
# This is global 14 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 29.090000 %
# This is global 15 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 28.980000 %
# This is global 16 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 27.150000 %
# This is global 17 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 26.210000 %
# This is global 18 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 26.930000 %
# This is global 19 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 25.080000 %
# This is global 20 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 24.420000 %
# This is global 21 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 24.450000 %
# This is global 22 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 22.940000 %
# This is global 23 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 21.270000 %
# This is global 24 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 20.820000 %
# This is global 25 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 20.750000 %
# This is global 26 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 18.700000 %
# This is global 27 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 19.110000 %
# This is global 28 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 16.900000 %
# This is global 29 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 16.080000 %
# This is global 30 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 17.020000 %
# This is global 31 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 17.850000 %
# This is global 32 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 16.570000 %
# This is global 33 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 19.200000 %
# This is global 34 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 18.790000 %
# This is global 35 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 19.100000 %
# This is global 36 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 19.480000 %
# This is global 37 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 15.650000 %
# This is global 38 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 14.040000 %
# This is global 39 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 14.690000 %
# This is global 40 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 14.610000 %
# This is global 41 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 13.810000 %
# This is global 42 epoch
#  Average loss 1.172
# Accuracy of the network on the 10000 test images: 13.810000 %
# This is global 43 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 13.050000 %
# This is global 44 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 13.990000 %
# This is global 45 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 14.140000 %
# This is global 46 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 12.650000 %
# This is global 47 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 13.230000 %
# This is global 48 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 13.960000 %
# This is global 49 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 13.570000 %
# This is global 50 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 13.620000 %
# This is global 51 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 14.190000 %
# This is global 52 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 13.890000 %
# This is global 53 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 14.380000 %
# This is global 54 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 13.390000 %
# This is global 55 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 14.710000 %
# This is global 56 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 13.060000 %
# This is global 57 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 13.280000 %
# This is global 58 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 12.140000 %
# This is global 59 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 12.500000 %
# This is global 60 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 11.900000 %
# This is global 61 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 12.000000 %
# This is global 62 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 12.080000 %
# This is global 63 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 13.490000 %
# This is global 64 epoch
#  Average loss 0.373
# Accuracy of the network on the 10000 test images: 11.800000 %
# This is global 65 epoch
#  Average loss 0.158
# Accuracy of the network on the 10000 test images: 13.490000 %
# This is global 66 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 12.850000 %
# This is global 67 epoch
#  Average loss 0.133
# Accuracy of the network on the 10000 test images: 12.380000 %
# This is global 68 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 12.290000 %
# This is global 69 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 13.850000 %
# This is global 70 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.750000 %
# This is global 71 epoch
#  Average loss 0.121
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 72 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 12.700000 %
# This is global 73 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 12.540000 %
# This is global 74 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 75 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 12.040000 %
# This is global 76 epoch
#  Average loss 0.436
# Accuracy of the network on the 10000 test images: 11.280000 %
# This is global 77 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 11.870000 %
# This is global 78 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 12.560000 %
# This is global 79 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 11.610000 %
# This is global 80 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.480000 %
# This is global 81 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 12.480000 %
# This is global 82 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 12.850000 %
# This is global 83 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 12.570000 %
# This is global 84 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.030000 %
# This is global 85 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 12.210000 %
# This is global 86 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 11.910000 %
# This is global 87 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 11.670000 %
# This is global 88 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 11.900000 %
# This is global 89 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 11.830000 %
# This is global 90 epoch
#  Average loss 0.812
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 91 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 11.220000 %
# This is global 92 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 11.590000 %
# This is global 93 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 11.400000 %
# This is global 94 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 12.200000 %
# This is global 95 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 12.970000 %
# This is global 96 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 12.470000 %
# This is global 97 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 11.970000 %
# This is global 98 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.730000 %
# This is global 99 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 12.430000 %
# This is global 100 epoch
#  Average loss 0.042
# Accuracy of the network on the 10000 test images: 11.630000 %
# This is global 101 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.130000 %
# This is global 102 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 103 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 10.400000 %
# This is global 104 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 11.180000 %
# This is global 105 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.920000 %
# This is global 106 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.650000 %
# This is global 107 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.550000 %
# This is global 108 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 11.220000 %
# This is global 109 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 11.010000 %
# This is global 110 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 10.830000 %
# This is global 111 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 11.260000 %
# This is global 112 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 11.970000 %
# This is global 113 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.570000 %
# This is global 114 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 11.380000 %
# This is global 115 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 11.200000 %
# This is global 116 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.510000 %
# This is global 117 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.480000 %
# This is global 118 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 12.420000 %
# This is global 119 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 11.560000 %
# This is global 120 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 12.040000 %
# This is global 121 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 12.110000 %
# This is global 122 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 11.970000 %
# This is global 123 epoch
#  Average loss 0.989
# Accuracy of the network on the 10000 test images: 11.960000 %
# This is global 124 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 11.270000 %
# This is global 125 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 11.010000 %
# This is global 126 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 11.270000 %
# This is global 127 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 11.140000 %
# This is global 128 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 11.350000 %
# This is global 129 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.590000 %
# This is global 130 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 12.460000 %
# This is global 131 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 13.160000 %
# This is global 132 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 11.910000 %
# This is global 133 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 12.040000 %
# This is global 134 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.850000 %
# This is global 135 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.000000 %
# This is global 136 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.760000 %
# This is global 137 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 12.120000 %
# This is global 138 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 13.070000 %
# This is global 139 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 12.330000 %
# This is global 140 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 12.540000 %
# This is global 141 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 11.790000 %
# This is global 142 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 13.350000 %
# This is global 143 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 11.750000 %
# This is global 144 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 11.560000 %
# This is global 145 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 11.620000 %
# This is global 146 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 10.690000 %
# This is global 147 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 148 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 10.350000 %
# This is global 149 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.870000 %
# This is global 150 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.640000 %
# This is global 151 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 10.310000 %
# This is global 152 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.570000 %
# This is global 153 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 10.740000 %
# This is global 154 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 11.740000 %
# This is global 155 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.660000 %
# This is global 156 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.510000 %
# This is global 157 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 158 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 10.820000 %
# This is global 159 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 10.390000 %
# This is global 160 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 10.340000 %
# This is global 161 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 162 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 163 epoch
#  Average loss 0.379
# Accuracy of the network on the 10000 test images: 9.720000 %
# This is global 164 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.330000 %
# This is global 165 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 166 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 167 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 9.840000 %
# This is global 168 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.540000 %
# This is global 169 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 170 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.900000 %
# This is global 171 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 172 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 173 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 174 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 11.790000 %
# This is global 175 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 176 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 11.950000 %
# This is global 177 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.670000 %
# This is global 178 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 10.320000 %
# This is global 179 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 180 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 181 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 10.490000 %
# This is global 182 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 183 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 184 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 10.790000 %
# This is global 185 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 186 epoch
#  Average loss 0.321
# Accuracy of the network on the 10000 test images: 10.820000 %
# This is global 187 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.510000 %
# This is global 188 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 10.880000 %
# This is global 189 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 10.920000 %
# This is global 190 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 10.500000 %
# This is global 191 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 9.790000 %
# This is global 192 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.790000 %
# This is global 193 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 10.930000 %
# This is global 194 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 195 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 12.590000 %
# This is global 196 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 11.150000 %
# This is global 197 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.920000 %
# This is global 198 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.210000 %
# This is global 199 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.860000 %
# This is global 200 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.160000 %
# This is global 201 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 11.090000 %
# This is global 202 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 10.820000 %
# This is global 203 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 204 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.730000 %
# This is global 205 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 10.650000 %
# This is global 206 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 207 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.170000 %
# This is global 208 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 11.180000 %
# This is global 209 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.050000 %
# This is global 210 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 211 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 9.750000 %
# This is global 212 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 11.650000 %
# This is global 213 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 214 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.850000 %
# This is global 215 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 9.880000 %
# This is global 216 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 9.950000 %
# This is global 217 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 218 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.680000 %
# This is global 219 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.620000 %
# This is global 220 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 221 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 9.880000 %
# This is global 222 epoch
#  Average loss 0.410
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 223 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 224 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 225 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 9.900000 %
# This is global 226 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 227 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.510000 %
# This is global 228 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 229 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 230 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 231 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.650000 %
# This is global 232 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.980000 %
# This is global 233 epoch
#  Average loss 0.430
# Accuracy of the network on the 10000 test images: 10.870000 %
# This is global 234 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 11.550000 %
# This is global 235 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 11.660000 %
# This is global 236 epoch
#  Average loss 0.120
# Accuracy of the network on the 10000 test images: 11.070000 %
# This is global 237 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.850000 %
# This is global 238 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.220000 %
# This is global 239 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 12.100000 %
# This is global 240 epoch
#  Average loss 0.737
# Accuracy of the network on the 10000 test images: 12.530000 %
# This is global 241 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.960000 %
# This is global 242 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 10.750000 %
# This is global 243 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.860000 %
# This is global 244 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 12.100000 %
# This is global 245 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 11.660000 %
# This is global 246 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 10.970000 %
# This is global 247 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.910000 %
# This is global 248 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 10.680000 %
# This is global 249 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 10.280000 %
# This is global 250 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 9.970000 %
# This is global 251 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 252 epoch
#  Average loss 0.538
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 253 epoch
#  Average loss 0.145
# Accuracy of the network on the 10000 test images: 9.940000 %
# This is global 254 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 255 epoch
#  Average loss 0.489
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 256 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 10.650000 %
# This is global 257 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.860000 %
# This is global 258 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 259 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.940000 %
# This is global 260 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.580000 %
# This is global 261 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 262 epoch
#  Average loss 0.130
# Accuracy of the network on the 10000 test images: 11.810000 %
# This is global 263 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 11.780000 %
# This is global 264 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.770000 %
# This is global 265 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 11.840000 %
# This is global 266 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 267 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 268 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.830000 %
# This is global 269 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 270 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 271 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 272 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 11.220000 %
# This is global 273 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 11.660000 %
# This is global 274 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 275 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 11.760000 %
# This is global 276 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 11.030000 %
# This is global 277 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 12.090000 %
# This is global 278 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 279 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 280 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.940000 %
# This is global 281 epoch
#  Average loss 5.050
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 282 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 9.940000 %
# This is global 283 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 284 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 10.850000 %
# This is global 285 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 11.830000 %
# This is global 286 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 11.560000 %
# This is global 287 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 11.710000 %
# This is global 288 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.830000 %
# This is global 289 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 11.730000 %
# This is global 290 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.560000 %
# This is global 291 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 10.980000 %
# This is global 292 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 11.980000 %
# This is global 293 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 294 epoch
#  Average loss 25.676
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 295 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 296 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 11.870000 %
# This is global 297 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 298 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.600000 %
# This is global 299 epoch
#  Average loss 0.393
# Accuracy of the network on the 10000 test images: 9.770000 %
# This is global 300 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 301 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 302 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 12.150000 %
# This is global 303 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 304 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 12.190000 %
# This is global 305 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.280000 %
# This is global 306 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 12.050000 %
# This is global 307 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 11.550000 %
# This is global 308 epoch
#  Average loss 0.103
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 309 epoch
#  Average loss 0.330
# Accuracy of the network on the 10000 test images: 12.090000 %
# This is global 310 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 12.240000 %
# This is global 311 epoch
#  Average loss 1.268
# Accuracy of the network on the 10000 test images: 11.270000 %
# This is global 312 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 11.850000 %
# This is global 313 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 11.690000 %
# This is global 314 epoch
#  Average loss 0.572
# Accuracy of the network on the 10000 test images: 11.300000 %
# This is global 315 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 11.540000 %
# This is global 316 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 317 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.480000 %
# This is global 318 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 11.290000 %
# This is global 319 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 320 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 321 epoch
#  Average loss 0.171
# Accuracy of the network on the 10000 test images: 11.350000 %
# This is global 322 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.340000 %
# This is global 323 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 324 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 11.880000 %
# This is global 325 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 11.740000 %
# This is global 326 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 11.940000 %
# This is global 327 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 10.200000 %
# This is global 328 epoch
#  Average loss 0.152
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 329 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.880000 %
# This is global 330 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 9.820000 %
# This is global 331 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 332 epoch
#  Average loss 0.668
# Accuracy of the network on the 10000 test images: 9.920000 %
# This is global 333 epoch
#  Average loss 5.132
# Accuracy of the network on the 10000 test images: 9.970000 %
# This is global 334 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 335 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 336 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 337 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 11.480000 %
# This is global 338 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 10.770000 %
# This is global 339 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.620000 %
# This is global 340 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 10.220000 %
# This is global 341 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 9.870000 %
# This is global 342 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 9.870000 %
# This is global 343 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 11.860000 %
# This is global 344 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 345 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 346 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 347 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 10.320000 %
# This is global 348 epoch
#  Average loss 0.550
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 349 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 350 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 11.470000 %
# This is global 351 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 352 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.780000 %
# This is global 353 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 11.400000 %
# This is global 354 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 12.160000 %
# This is global 355 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 11.770000 %
# This is global 356 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 11.110000 %
# This is global 357 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 11.330000 %
# This is global 358 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 11.890000 %
# This is global 359 epoch
#  Average loss 0.925
# Accuracy of the network on the 10000 test images: 11.790000 %
# This is global 360 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 361 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 362 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.410000 %
# This is global 363 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 11.710000 %
# This is global 364 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 11.080000 %
# This is global 365 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.990000 %
# This is global 366 epoch
#  Average loss 2.567
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 367 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 9.880000 %
# This is global 368 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 9.890000 %
# This is global 369 epoch
#  Average loss 5.355
# Accuracy of the network on the 10000 test images: 9.670000 %
# This is global 370 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 10.350000 %
# This is global 371 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 9.800000 %
# This is global 372 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 373 epoch
#  Average loss 5.308
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 374 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 375 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 9.700000 %
# This is global 376 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 9.910000 %
# This is global 377 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 9.890000 %
# This is global 378 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 379 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 11.240000 %
# This is global 380 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.330000 %
# This is global 381 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.640000 %
# This is global 382 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.560000 %
# This is global 383 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 10.940000 %
# This is global 384 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 385 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 10.950000 %
# This is global 386 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 9.760000 %
# This is global 387 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 11.320000 %
# This is global 388 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 389 epoch
#  Average loss 49.738
# Accuracy of the network on the 10000 test images: 9.780000 %
# This is global 390 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 391 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 9.870000 %
# This is global 392 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 9.820000 %
# This is global 393 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 10.490000 %
# This is global 394 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 395 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 396 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 9.880000 %
# This is global 397 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 11.610000 %
# This is global 398 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 399 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.960000 %
# This is global 400 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 401 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 402 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 403 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 404 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 8.430000 %
# This is global 405 epoch
#  Average loss 1.061
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 406 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 9.870000 %
# This is global 407 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 9.850000 %
# This is global 408 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 8.250000 %
# This is global 409 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 10.390000 %
# This is global 410 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 11.350000 %
# This is global 411 epoch
#  Average loss 0.554
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 412 epoch
#  Average loss 0.486
# Accuracy of the network on the 10000 test images: 9.760000 %
# This is global 413 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 414 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 415 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.940000 %
# This is global 416 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 9.870000 %
# This is global 417 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 11.050000 %
# This is global 418 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 419 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 11.210000 %
# This is global 420 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 10.480000 %
# This is global 421 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 9.970000 %
# This is global 422 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 423 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 424 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 11.400000 %
# This is global 425 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 11.740000 %
# This is global 426 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.930000 %
# This is global 427 epoch
#  Average loss 0.103
# Accuracy of the network on the 10000 test images: 11.160000 %
# This is global 428 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 429 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 430 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 11.560000 %
# This is global 431 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.860000 %
# This is global 432 epoch
#  Average loss 5.015
# Accuracy of the network on the 10000 test images: 10.330000 %
# This is global 433 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 434 epoch
#  Average loss 0.138
# Accuracy of the network on the 10000 test images: 10.330000 %
# This is global 435 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 9.920000 %
# This is global 436 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 437 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 438 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 439 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 440 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 441 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 442 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 443 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 10.200000 %
# This is global 444 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 10.120000 %
# This is global 445 epoch
#  Average loss 1.822
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 446 epoch
#  Average loss 156.764
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 447 epoch
#  Average loss 0.151
# ...
# This is global 473 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 10.220000 %
# This is global 474 epoch
#  Average loss 1.289
# Accuracy of the network on the 10000 test images: 10.450000 %
# This is global 475 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 476 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 11.540000 %
# This is global 477 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 10.820000 %
# This is global 478 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 10.240000 %
# This is global 479 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 480 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 481 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 10.220000 %
# This is global 482 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 8.570000 %
# This is global 483 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 10.760000 %
# This is global 484 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 11.390000 %
# This is global 485 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 11.340000 %
# This is global 486 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.310000 %
# This is global 487 epoch
#  Average loss 0.589
# Accuracy of the network on the 10000 test images: 10.510000 %
# This is global 488 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 9.080000 %
# This is global 489 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 9.260000 %
# This is global 490 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 7.810000 %
# This is global 491 epoch
#  Average loss 2.996
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 492 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 13.750000 %
# This is global 493 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.090000 %
# This is global 494 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.550000 %
# This is global 495 epoch
#  Average loss 0.442
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 496 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 497 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 9.430000 %
# This is global 498 epoch
#  Average loss 0.649
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 499 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 8.390000 %
# This is global 500 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 9.860000 %
# This is global 501 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 9.930000 %
# This is global 502 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 9.950000 %
# This is global 503 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 504 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 505 epoch
#  Average loss 0.112
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 506 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 12.460000 %
# This is global 507 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.520000 %
# This is global 508 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 509 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 510 epoch
#  Average loss 0.153
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 511 epoch
#  Average loss 353.284
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 512 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 9.890000 %
# This is global 513 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 12.040000 %
# This is global 514 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 11.490000 %
# This is global 515 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 12.540000 %
# This is global 516 epoch
#  Average loss 380.683
# Accuracy of the network on the 10000 test images: 10.090000 %
# This is global 517 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 518 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 519 epoch
#  Average loss 3.930
# Accuracy of the network on the 10000 test images: 10.380000 %
# This is global 520 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 9.270000 %
# This is global 521 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.330000 %
# This is global 522 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 523 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 9.800000 %
# This is global 524 epoch
#  Average loss 0.549
# Accuracy of the network on the 10000 test images: 9.950000 %
# This is global 525 epoch
#  Average loss 1.300
# Accuracy of the network on the 10000 test images: 11.260000 %
# This is global 526 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 9.840000 %
# This is global 527 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.830000 %
# This is global 528 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 529 epoch
#  Average loss 0.153
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 530 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 531 epoch
#  Average loss 0.418
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 532 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.390000 %
# This is global 533 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 534 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 535 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 536 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 537 epoch
#  Average loss 0.338
# Accuracy of the network on the 10000 test images: 10.220000 %
# This is global 538 epoch
#  Average loss 0.128
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 539 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.370000 %
# This is global 540 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 9.140000 %
# This is global 541 epoch
#  Average loss 0.611
# Accuracy of the network on the 10000 test images: 10.310000 %
# This is global 542 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 13.700000 %
# This is global 543 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 7.960000 %
# This is global 544 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 545 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 9.720000 %
# This is global 546 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 9.790000 %
# This is global 547 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 13.180000 %
# This is global 548 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 10.840000 %
# This is global 549 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 550 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 551 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 11.180000 %
# This is global 552 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 10.510000 %
# This is global 553 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 554 epoch
#  Average loss 2.033
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 555 epoch
#  Average loss 0.109
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 556 epoch
#  Average loss 21.393
# Accuracy of the network on the 10000 test images: 12.690000 %
# This is global 557 epoch
#  Average loss 0.341
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 558 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 11.150000 %
# This is global 559 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 12.360000 %
# This is global 560 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 11.790000 %
# This is global 561 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 9.060000 %
# This is global 562 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 11.470000 %
# This is global 563 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.420000 %
# This is global 564 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 565 epoch
#  Average loss 2.216
# Accuracy of the network on the 10000 test images: 11.510000 %
# This is global 566 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 11.610000 %
# This is global 567 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 11.670000 %
# This is global 568 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 569 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 10.520000 %
# This is global 570 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 571 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.790000 %
# This is global 572 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 573 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 574 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.950000 %
# This is global 575 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 11.120000 %
# This is global 576 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 11.190000 %
# This is global 577 epoch
#  Average loss 0.992
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 578 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 579 epoch
#  Average loss 2.328
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 580 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 10.150000 %
# This is global 581 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 10.200000 %
# This is global 582 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 10.660000 %
# This is global 583 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 10.930000 %
# This is global 584 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 11.340000 %
# This is global 585 epoch
#  Average loss 2.659
# Accuracy of the network on the 10000 test images: 11.150000 %
# This is global 586 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 13.090000 %
# This is global 587 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 13.480000 %
# This is global 588 epoch
#  Average loss 0.081
# Accuracy of the network on the 10000 test images: 10.700000 %
# This is global 589 epoch
#  Average loss 264.521
# Accuracy of the network on the 10000 test images: 10.830000 %
# This is global 590 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.900000 %
# This is global 591 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 592 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.970000 %
# This is global 593 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 11.970000 %
# This is global 594 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 11.970000 %
# This is global 595 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 9.640000 %
# This is global 596 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 10.710000 %
# This is global 597 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 10.210000 %
# This is global 598 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 12.000000 %
# This is global 599 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 600 epoch
#  Average loss 13.451
# Accuracy of the network on the 10000 test images: 12.390000 %
# This is global 601 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 11.960000 %
# This is global 602 epoch
#  Average loss 2.401
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 603 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 13.180000 %
# This is global 604 epoch
#  Average loss 4249.091
# Accuracy of the network on the 10000 test images: 11.200000 %
# This is global 605 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 8.960000 %
# This is global 606 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 9.170000 %
# This is global 607 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 10.940000 %
# This is global 608 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 609 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 610 epoch
#  Average loss 0.158
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 611 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 10.890000 %
# This is global 612 epoch
#  Average loss 34.208
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 613 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 11.140000 %
# This is global 614 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.910000 %
# This is global 615 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 11.920000 %
# This is global 616 epoch
#  Average loss 0.553
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 617 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 11.190000 %
# This is global 618 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 10.420000 %
# This is global 619 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 10.520000 %
# This is global 620 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 621 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 622 epoch

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()
