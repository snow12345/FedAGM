# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="1"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=1
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
def cifar_dirichlet(dataset, n_nets, alpha=0.5):
    '''
    if dataset == 'mnist':
        X_train, y_train, X_test, y_test = load_mnist_data(datadir)
    elif dataset == 'cifar10':
        X_train, y_train, X_test, y_test = load_cifar10_data(datadir)
    '''
    #X_train=dataset[:][0]
    y_train=torch.zeros(len(dataset),dtype=torch.long)
    print(y_train.dtype)
    for a in range(len(dataset)):
        y_train[a]=(dataset[a][1])
    n_train = len(dataset)
    #X_train.shape[0]
    '''
    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_nets)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_nets)}
    '''
    #elif partition == "hetero-dir":
    min_size = 0
    K = 10
    N=len(dataset)
    N = y_train.shape[0]
    net_dataidx_map = {i: np.array([],dtype='int64') for i in range(n_nets)}

    while min_size < 10:
        idx_batch = [[] for _ in range(n_nets)]
        for k in range(K):
            idx_k = np.where(y_train == k)[0]
            np.random.shuffle(idx_k)
            proportions = np.random.dirichlet(np.repeat(alpha, n_nets))
            ## Balance
            proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
            proportions = proportions/proportions.sum()
            proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
            idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
            min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    #traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    return net_dataidx_map
    #return (X_train, y_train, X_test, y_test, net_dataidx_map, traindata_cls_counts)

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        
        
        
        self.conv1_global = nn.Conv2d(3, 32, 3)
        self.pool_global = nn.MaxPool2d(2, 2)
        self.conv2_global = nn.Conv2d(32, 64, 3)
        self.conv3_global = nn.Conv2d(64, 64, 3)
        self.fc1_global = nn.Linear(64 * 4 * 4, 64)
        self.fc2_global = nn.Linear(64, 10)
        self.freeze_model_global_weights()
        
        self.mse=nn.MSELoss()
        #self.fc3 = nn.Linear(84, 10)
    def freeze_model_global_weights(self):
        for n, m in self.named_modules():
            if hasattr(m, "weight") and m.weight is not None and 'global' in n:
                print(f"==> No gradient to {n}.weight")
                m.weight.requires_grad = False
                if m.weight.grad is not None:
                    print(f"==> Setting gradient of {n}.weight to None")
                    m.weight.grad = None

                if hasattr(m, "bias") and m.bias is not None and 'global' in n:
                    print(f"==> No gradient to {n}.bias")
                    m.bias.requires_grad = False

                    if m.bias.grad is not None:
                        print(f"==> Setting gradient of {n}.bias to None")
                        m.bias.grad = None
    def sync_online_and_global(self):
        state_dict=self.state_dict()
        for key in state_dict:
            if 'global' in key:
                x=(key.split("_global"))
                online=(x[0]+x[1])
                state_dict[key]=state_dict[online]
        self.load_state_dict(state_dict)
        
        
        
    def forward(self, x,online_target=False):
        if online_target==False:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = (F.relu(self.conv3(x)))
            x = x.view(-1, 64*4*4)
            x = F.relu(self.fc1(x))
            x = (self.fc2(x))
            return x
        else:
            x1=copy.deepcopy(x)
            
            
            x = self.pool(F.relu(self.conv1(x)))
            x1 = self.pool_global(F.relu(self.conv1_global(x1)))
            diff=self.mse(x,x1)
            
            x = self.pool(F.relu(self.conv2(x)))
            x1 = self.pool_global(F.relu(self.conv2_global(x1)))
            diff+=self.mse(x,x1)
            
            
            x = (F.relu(self.conv3(x)))
            x1 = (F.relu(self.conv3_global(x1)))
            diff+=self.mse(x,x1)
            
            x = x.view(-1, 64*4*4)
            x1 = x1.view(-1, 64*4*4)
            
            x = F.relu(self.fc1(x))
            x1 = F.relu(self.fc1_global(x1))
            diff+=self.mse(x,x1)
            
            
            x = (self.fc2(x))
            x1 = (self.fc2_global(x1))
            diff+=self.mse(x,x1)
            
            
            return x,diff

# %%
net = Net()
net.to(device)
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
#   (conv1_global): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool_global): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_global): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_global): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1_global): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2_global): Linear(in_features=64, out_features=10, bias=True)
#   (mse): MSELoss()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01,momentum=0.5)
loss_train = []
acc_train=[]

# %%
for epoch in range(0):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    for i, data in enumerate(CIFAR_SGD_trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(labels)

        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
       
        
    if epoch%1==0:
        loss_train.append(loss)
        print(f"epoch: {epoch}")
        print(' Average loss {:.3f}'.format( loss))
        for j in range(1):
            net.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %d %%' % (
                100 * correct / total))
        acc_train.append(100 * correct / total)

    net.train()

    '''# 통계를 출력합니다.
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0'''

print('Finished Training')
# Out:
# Finished Training

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# /home/dana/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Accuracy of the network on the 10000 test images: 10 %

# %%
class LocalUpdate(object):
    def __init__(self, lr,local_epoch,device,batch_size, dataset=None, idxs=None,alpha=0.01):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.alpha=alpha

    def train(self, net):
        net.sync_online_and_global()
        net.train()
        # train and update
        optimizer = torch.optim.SGD(net.parameters(), lr=self.lr)

        epoch_loss = []
        for iter in range(self.local_epoch):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs,activation_l2 = net(images,online_target=True)
                loss = self.loss_func(log_probs, labels)+self.alpha*activation_l2
                loss.backward()
                optimizer.step()
                #if batch_idx % 10 == 0:
                #    print('Update Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #        iter, batch_idx * len(images), len(self.ldr_train.dataset),
                #               100. * batch_idx / len(self.ldr_train), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        return net.state_dict(), sum(epoch_loss) / len(epoch_loss)

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=501
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.306
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 1 epoch
#  Average loss 2.303
# Accuracy of the network on the 10000 test images: 16.270000 %
# This is global 2 epoch
#  Average loss 2.301
# Accuracy of the network on the 10000 test images: 17.580000 %
# This is global 3 epoch
#  Average loss 2.298
# Accuracy of the network on the 10000 test images: 20.480000 %
# This is global 4 epoch
#  Average loss 2.294
# Accuracy of the network on the 10000 test images: 21.040000 %
# This is global 5 epoch
#  Average loss 2.282
# Accuracy of the network on the 10000 test images: 21.440000 %
# This is global 6 epoch
#  Average loss 2.253
# Accuracy of the network on the 10000 test images: 17.890000 %
# This is global 7 epoch
#  Average loss 2.202
# Accuracy of the network on the 10000 test images: 20.180000 %
# This is global 8 epoch
#  Average loss 2.156
# Accuracy of the network on the 10000 test images: 25.240000 %
# This is global 9 epoch
#  Average loss 2.129
# Accuracy of the network on the 10000 test images: 23.590000 %
# This is global 10 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 24.230000 %
# This is global 11 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 24.110000 %
# This is global 12 epoch
#  Average loss 2.045
# Accuracy of the network on the 10000 test images: 27.310000 %
# This is global 13 epoch
#  Average loss 2.052
# Accuracy of the network on the 10000 test images: 29.360000 %
# This is global 14 epoch
#  Average loss 2.006
# Accuracy of the network on the 10000 test images: 26.750000 %
# This is global 15 epoch
#  Average loss 1.999
# Accuracy of the network on the 10000 test images: 30.100000 %
# This is global 16 epoch
#  Average loss 1.989
# Accuracy of the network on the 10000 test images: 30.720000 %
# This is global 17 epoch
#  Average loss 1.971
# Accuracy of the network on the 10000 test images: 30.570000 %
# This is global 18 epoch
#  Average loss 1.961
# Accuracy of the network on the 10000 test images: 30.160000 %
# This is global 19 epoch
#  Average loss 1.939
# Accuracy of the network on the 10000 test images: 30.520000 %
# This is global 20 epoch
#  Average loss 1.925
# Accuracy of the network on the 10000 test images: 31.590000 %
# This is global 21 epoch
#  Average loss 1.931
# Accuracy of the network on the 10000 test images: 32.460000 %
# This is global 22 epoch
#  Average loss 1.892
# Accuracy of the network on the 10000 test images: 33.030000 %
# This is global 23 epoch
#  Average loss 1.902
# Accuracy of the network on the 10000 test images: 32.390000 %
# This is global 24 epoch
#  Average loss 1.884
# Accuracy of the network on the 10000 test images: 35.470000 %
# This is global 25 epoch
#  Average loss 1.887
# Accuracy of the network on the 10000 test images: 35.040000 %
# This is global 26 epoch
#  Average loss 1.866
# Accuracy of the network on the 10000 test images: 35.760000 %
# This is global 27 epoch
#  Average loss 1.827
# Accuracy of the network on the 10000 test images: 37.600000 %
# This is global 28 epoch
#  Average loss 1.876
# Accuracy of the network on the 10000 test images: 36.180000 %
# This is global 29 epoch
#  Average loss 1.815
# Accuracy of the network on the 10000 test images: 37.050000 %
# This is global 30 epoch
#  Average loss 1.814
# Accuracy of the network on the 10000 test images: 37.980000 %
# This is global 31 epoch
#  Average loss 1.811
# Accuracy of the network on the 10000 test images: 40.010000 %
# This is global 32 epoch
#  Average loss 1.760
# Accuracy of the network on the 10000 test images: 38.330000 %
# This is global 33 epoch
#  Average loss 1.720
# Accuracy of the network on the 10000 test images: 39.880000 %
# This is global 34 epoch
#  Average loss 1.782
# Accuracy of the network on the 10000 test images: 39.620000 %
# This is global 35 epoch
#  Average loss 1.720
# Accuracy of the network on the 10000 test images: 40.750000 %
# This is global 36 epoch
#  Average loss 1.793
# Accuracy of the network on the 10000 test images: 40.170000 %
# This is global 37 epoch
#  Average loss 1.674
# Accuracy of the network on the 10000 test images: 40.090000 %
# This is global 38 epoch
#  Average loss 1.662
# Accuracy of the network on the 10000 test images: 40.960000 %
# This is global 39 epoch
#  Average loss 1.703
# Accuracy of the network on the 10000 test images: 41.870000 %
# This is global 40 epoch
#  Average loss 1.651
# Accuracy of the network on the 10000 test images: 42.500000 %
# This is global 41 epoch
#  Average loss 1.684
# Accuracy of the network on the 10000 test images: 43.320000 %
# This is global 42 epoch
#  Average loss 1.685
# Accuracy of the network on the 10000 test images: 43.090000 %
# This is global 43 epoch
#  Average loss 1.646
# Accuracy of the network on the 10000 test images: 41.740000 %
# This is global 44 epoch
#  Average loss 1.643
# Accuracy of the network on the 10000 test images: 41.900000 %
# This is global 45 epoch
#  Average loss 1.637
# Accuracy of the network on the 10000 test images: 43.760000 %
# This is global 46 epoch
#  Average loss 1.618
# Accuracy of the network on the 10000 test images: 44.350000 %
# This is global 47 epoch
#  Average loss 1.595
# Accuracy of the network on the 10000 test images: 44.030000 %
# This is global 48 epoch
#  Average loss 1.613
# Accuracy of the network on the 10000 test images: 45.730000 %
# This is global 49 epoch
#  Average loss 1.588
# Accuracy of the network on the 10000 test images: 43.870000 %
# This is global 50 epoch
#  Average loss 1.591
# Accuracy of the network on the 10000 test images: 45.460000 %
# This is global 51 epoch
#  Average loss 1.602
# Accuracy of the network on the 10000 test images: 44.380000 %
# This is global 52 epoch
#  Average loss 1.571
# Accuracy of the network on the 10000 test images: 46.680000 %
# This is global 53 epoch
#  Average loss 1.579
# Accuracy of the network on the 10000 test images: 45.900000 %
# This is global 54 epoch
#  Average loss 1.540
# Accuracy of the network on the 10000 test images: 44.040000 %
# This is global 55 epoch
#  Average loss 1.553
# Accuracy of the network on the 10000 test images: 46.640000 %
# This is global 56 epoch
#  Average loss 1.572
# Accuracy of the network on the 10000 test images: 46.040000 %
# This is global 57 epoch
#  Average loss 1.546
# Accuracy of the network on the 10000 test images: 47.800000 %
# This is global 58 epoch
#  Average loss 1.524
# Accuracy of the network on the 10000 test images: 46.840000 %
# This is global 59 epoch
#  Average loss 1.512
# Accuracy of the network on the 10000 test images: 47.490000 %
# This is global 60 epoch
#  Average loss 1.515
# Accuracy of the network on the 10000 test images: 47.660000 %
# This is global 61 epoch
#  Average loss 1.489
# Accuracy of the network on the 10000 test images: 46.710000 %
# This is global 62 epoch
#  Average loss 1.503
# Accuracy of the network on the 10000 test images: 47.160000 %
# This is global 63 epoch
#  Average loss 1.503
# Accuracy of the network on the 10000 test images: 47.970000 %
# This is global 64 epoch
#  Average loss 1.490
# Accuracy of the network on the 10000 test images: 46.980000 %
# This is global 65 epoch
#  Average loss 1.485
# Accuracy of the network on the 10000 test images: 48.350000 %
# This is global 66 epoch
#  Average loss 1.442
# Accuracy of the network on the 10000 test images: 48.540000 %
# This is global 67 epoch
#  Average loss 1.495
# Accuracy of the network on the 10000 test images: 49.630000 %
# This is global 68 epoch
#  Average loss 1.467
# Accuracy of the network on the 10000 test images: 48.990000 %
# This is global 69 epoch
#  Average loss 1.470
# Accuracy of the network on the 10000 test images: 50.460000 %
# This is global 70 epoch
#  Average loss 1.456
# Accuracy of the network on the 10000 test images: 50.710000 %
# This is global 71 epoch
#  Average loss 1.409
# Accuracy of the network on the 10000 test images: 48.330000 %
# This is global 72 epoch
#  Average loss 1.490
# Accuracy of the network on the 10000 test images: 50.580000 %
# This is global 73 epoch
#  Average loss 1.413
# Accuracy of the network on the 10000 test images: 48.700000 %
# This is global 74 epoch
#  Average loss 1.479
# Accuracy of the network on the 10000 test images: 49.100000 %
# This is global 75 epoch
#  Average loss 1.405
# Accuracy of the network on the 10000 test images: 47.970000 %
# This is global 76 epoch
#  Average loss 1.433
# Accuracy of the network on the 10000 test images: 50.730000 %
# This is global 77 epoch
#  Average loss 1.408
# Accuracy of the network on the 10000 test images: 51.190000 %
# This is global 78 epoch
#  Average loss 1.394
# Accuracy of the network on the 10000 test images: 51.230000 %
# This is global 79 epoch
#  Average loss 1.388
# Accuracy of the network on the 10000 test images: 48.120000 %
# This is global 80 epoch
#  Average loss 1.371
# Accuracy of the network on the 10000 test images: 50.320000 %
# This is global 81 epoch
#  Average loss 1.424
# Accuracy of the network on the 10000 test images: 52.750000 %
# This is global 82 epoch
#  Average loss 1.420
# Accuracy of the network on the 10000 test images: 51.660000 %
# This is global 83 epoch
#  Average loss 1.388
# Accuracy of the network on the 10000 test images: 52.280000 %
# This is global 84 epoch
#  Average loss 1.393
# Accuracy of the network on the 10000 test images: 53.540000 %
# This is global 85 epoch
#  Average loss 1.380
# Accuracy of the network on the 10000 test images: 52.210000 %
# This is global 86 epoch
#  Average loss 1.399
# Accuracy of the network on the 10000 test images: 51.920000 %
# This is global 87 epoch
#  Average loss 1.396
# Accuracy of the network on the 10000 test images: 53.140000 %
# This is global 88 epoch
#  Average loss 1.400
# Accuracy of the network on the 10000 test images: 53.300000 %
# This is global 89 epoch
#  Average loss 1.367
# Accuracy of the network on the 10000 test images: 53.260000 %
# This is global 90 epoch
#  Average loss 1.323
# Accuracy of the network on the 10000 test images: 53.180000 %
# This is global 91 epoch
#  Average loss 1.368
# Accuracy of the network on the 10000 test images: 52.310000 %
# This is global 92 epoch
#  Average loss 1.389
# Accuracy of the network on the 10000 test images: 53.480000 %
# This is global 93 epoch
#  Average loss 1.313
# Accuracy of the network on the 10000 test images: 54.560000 %
# This is global 94 epoch
#  Average loss 1.356
# Accuracy of the network on the 10000 test images: 53.800000 %
# This is global 95 epoch
#  Average loss 1.308
# Accuracy of the network on the 10000 test images: 51.660000 %
# This is global 96 epoch
#  Average loss 1.357
# Accuracy of the network on the 10000 test images: 53.700000 %
# This is global 97 epoch
#  Average loss 1.306
# Accuracy of the network on the 10000 test images: 53.880000 %
# This is global 98 epoch
#  Average loss 1.390
# Accuracy of the network on the 10000 test images: 54.860000 %
# This is global 99 epoch
#  Average loss 1.303
# Accuracy of the network on the 10000 test images: 55.430000 %
# This is global 100 epoch
#  Average loss 1.319
# Accuracy of the network on the 10000 test images: 55.090000 %
# This is global 101 epoch
#  Average loss 1.336
# Accuracy of the network on the 10000 test images: 54.860000 %
# This is global 102 epoch
#  Average loss 1.274
# Accuracy of the network on the 10000 test images: 54.240000 %
# This is global 103 epoch
#  Average loss 1.334
# Accuracy of the network on the 10000 test images: 55.660000 %
# This is global 104 epoch
#  Average loss 1.335
# Accuracy of the network on the 10000 test images: 56.150000 %
# This is global 105 epoch
#  Average loss 1.305
# Accuracy of the network on the 10000 test images: 55.030000 %
# This is global 106 epoch
#  Average loss 1.267
# Accuracy of the network on the 10000 test images: 56.670000 %
# This is global 107 epoch
#  Average loss 1.278
# Accuracy of the network on the 10000 test images: 56.650000 %
# This is global 108 epoch
#  Average loss 1.241
# Accuracy of the network on the 10000 test images: 51.920000 %
# This is global 109 epoch
#  Average loss 1.299
# Accuracy of the network on the 10000 test images: 56.100000 %
# This is global 110 epoch
#  Average loss 1.315
# Accuracy of the network on the 10000 test images: 56.070000 %
# This is global 111 epoch
#  Average loss 1.291
# Accuracy of the network on the 10000 test images: 55.760000 %
# This is global 112 epoch
#  Average loss 1.257
# Accuracy of the network on the 10000 test images: 55.920000 %
# This is global 113 epoch
#  Average loss 1.282
# Accuracy of the network on the 10000 test images: 56.630000 %
# This is global 114 epoch
#  Average loss 1.252
# Accuracy of the network on the 10000 test images: 53.120000 %
# This is global 115 epoch
#  Average loss 1.277
# Accuracy of the network on the 10000 test images: 57.590000 %
# This is global 116 epoch
#  Average loss 1.226
# Accuracy of the network on the 10000 test images: 55.770000 %
# This is global 117 epoch
#  Average loss 1.235
# Accuracy of the network on the 10000 test images: 57.560000 %
# This is global 118 epoch
#  Average loss 1.267
# Accuracy of the network on the 10000 test images: 57.160000 %
# This is global 119 epoch
#  Average loss 1.226
# Accuracy of the network on the 10000 test images: 57.640000 %
# This is global 120 epoch
#  Average loss 1.243
# Accuracy of the network on the 10000 test images: 56.360000 %
# This is global 121 epoch
#  Average loss 1.231
# Accuracy of the network on the 10000 test images: 57.930000 %
# This is global 122 epoch
#  Average loss 1.248
# Accuracy of the network on the 10000 test images: 58.580000 %
# This is global 123 epoch
#  Average loss 1.262
# Accuracy of the network on the 10000 test images: 58.580000 %
# This is global 124 epoch
#  Average loss 1.186
# Accuracy of the network on the 10000 test images: 57.560000 %
# This is global 125 epoch
#  Average loss 1.249
# Accuracy of the network on the 10000 test images: 58.490000 %
# This is global 126 epoch
#  Average loss 1.207
# Accuracy of the network on the 10000 test images: 55.190000 %
# This is global 127 epoch
#  Average loss 1.233
# Accuracy of the network on the 10000 test images: 57.270000 %
# This is global 128 epoch
#  Average loss 1.194
# Accuracy of the network on the 10000 test images: 59.440000 %
# This is global 129 epoch
#  Average loss 1.190
# Accuracy of the network on the 10000 test images: 59.020000 %
# This is global 130 epoch
#  Average loss 1.235
# Accuracy of the network on the 10000 test images: 58.960000 %
# This is global 131 epoch
#  Average loss 1.182
# Accuracy of the network on the 10000 test images: 58.110000 %
# This is global 132 epoch
#  Average loss 1.188
# Accuracy of the network on the 10000 test images: 59.290000 %
# This is global 133 epoch
#  Average loss 1.200
# Accuracy of the network on the 10000 test images: 59.950000 %
# This is global 134 epoch
#  Average loss 1.196
# Accuracy of the network on the 10000 test images: 58.590000 %
# This is global 135 epoch
#  Average loss 1.189
# Accuracy of the network on the 10000 test images: 59.150000 %
# This is global 136 epoch
#  Average loss 1.212
# Accuracy of the network on the 10000 test images: 59.580000 %
# This is global 137 epoch
#  Average loss 1.165
# Accuracy of the network on the 10000 test images: 58.690000 %
# This is global 138 epoch
#  Average loss 1.141
# Accuracy of the network on the 10000 test images: 59.500000 %
# This is global 139 epoch
#  Average loss 1.182
# Accuracy of the network on the 10000 test images: 60.420000 %
# This is global 140 epoch
#  Average loss 1.198
# Accuracy of the network on the 10000 test images: 59.800000 %
# This is global 141 epoch
#  Average loss 1.176
# Accuracy of the network on the 10000 test images: 57.980000 %
# This is global 142 epoch
#  Average loss 1.187
# Accuracy of the network on the 10000 test images: 60.410000 %
# This is global 143 epoch
#  Average loss 1.190
# Accuracy of the network on the 10000 test images: 61.140000 %
# This is global 144 epoch
#  Average loss 1.137
# Accuracy of the network on the 10000 test images: 59.270000 %
# This is global 145 epoch
#  Average loss 1.160
# Accuracy of the network on the 10000 test images: 60.850000 %
# This is global 146 epoch
#  Average loss 1.163
# Accuracy of the network on the 10000 test images: 60.470000 %
# This is global 147 epoch
#  Average loss 1.121
# Accuracy of the network on the 10000 test images: 60.330000 %
# This is global 148 epoch
#  Average loss 1.151
# Accuracy of the network on the 10000 test images: 60.750000 %
# This is global 149 epoch
#  Average loss 1.118
# Accuracy of the network on the 10000 test images: 60.760000 %
# This is global 150 epoch
#  Average loss 1.130
# Accuracy of the network on the 10000 test images: 60.830000 %
# This is global 151 epoch
#  Average loss 1.125
# Accuracy of the network on the 10000 test images: 60.000000 %
# This is global 152 epoch
#  Average loss 1.106
# Accuracy of the network on the 10000 test images: 60.420000 %
# This is global 153 epoch
#  Average loss 1.130
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 154 epoch
#  Average loss 1.067
# Accuracy of the network on the 10000 test images: 61.160000 %
# This is global 155 epoch
#  Average loss 1.108
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 156 epoch
#  Average loss 1.105
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 157 epoch
#  Average loss 1.102
# Accuracy of the network on the 10000 test images: 61.960000 %
# This is global 158 epoch
#  Average loss 1.088
# Accuracy of the network on the 10000 test images: 62.220000 %
# This is global 159 epoch
#  Average loss 1.118
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 160 epoch
#  Average loss 1.098
# Accuracy of the network on the 10000 test images: 61.460000 %
# This is global 161 epoch
#  Average loss 1.118
# Accuracy of the network on the 10000 test images: 61.840000 %
# This is global 162 epoch
#  Average loss 1.087
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 163 epoch
#  Average loss 1.091
# Accuracy of the network on the 10000 test images: 61.310000 %
# This is global 164 epoch
#  Average loss 1.101
# Accuracy of the network on the 10000 test images: 60.640000 %
# This is global 165 epoch
#  Average loss 1.079
# Accuracy of the network on the 10000 test images: 61.160000 %
# This is global 166 epoch
#  Average loss 1.104
# Accuracy of the network on the 10000 test images: 61.770000 %
# This is global 167 epoch
#  Average loss 1.107
# Accuracy of the network on the 10000 test images: 63.060000 %
# This is global 168 epoch
#  Average loss 1.051
# Accuracy of the network on the 10000 test images: 63.180000 %
# This is global 169 epoch
#  Average loss 1.054
# Accuracy of the network on the 10000 test images: 62.980000 %
# This is global 170 epoch
#  Average loss 1.112
# Accuracy of the network on the 10000 test images: 62.030000 %
# This is global 171 epoch
#  Average loss 1.087
# Accuracy of the network on the 10000 test images: 63.100000 %
# This is global 172 epoch
#  Average loss 1.029
# Accuracy of the network on the 10000 test images: 62.660000 %
# This is global 173 epoch
#  Average loss 1.039
# Accuracy of the network on the 10000 test images: 63.000000 %
# This is global 174 epoch
#  Average loss 1.103
# Accuracy of the network on the 10000 test images: 62.570000 %
# This is global 175 epoch
#  Average loss 1.101
# Accuracy of the network on the 10000 test images: 61.550000 %
# This is global 176 epoch
#  Average loss 1.055
# Accuracy of the network on the 10000 test images: 63.560000 %
# This is global 177 epoch
#  Average loss 1.037
# Accuracy of the network on the 10000 test images: 63.050000 %
# This is global 178 epoch
#  Average loss 1.045
# Accuracy of the network on the 10000 test images: 64.070000 %
# This is global 179 epoch
#  Average loss 1.019
# Accuracy of the network on the 10000 test images: 62.200000 %
# This is global 180 epoch
#  Average loss 1.042
# Accuracy of the network on the 10000 test images: 61.440000 %
# This is global 181 epoch
#  Average loss 1.049
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 182 epoch
#  Average loss 1.051
# Accuracy of the network on the 10000 test images: 63.430000 %
# This is global 183 epoch
#  Average loss 1.076
# Accuracy of the network on the 10000 test images: 63.530000 %
# This is global 184 epoch
#  Average loss 0.996
# Accuracy of the network on the 10000 test images: 64.540000 %
# This is global 185 epoch
#  Average loss 1.025
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 186 epoch
#  Average loss 0.998
# Accuracy of the network on the 10000 test images: 64.960000 %
# This is global 187 epoch
#  Average loss 1.049
# Accuracy of the network on the 10000 test images: 63.360000 %
# This is global 188 epoch
#  Average loss 1.009
# Accuracy of the network on the 10000 test images: 63.790000 %
# This is global 189 epoch
#  Average loss 1.007
# Accuracy of the network on the 10000 test images: 63.970000 %
# This is global 190 epoch
#  Average loss 1.013
# Accuracy of the network on the 10000 test images: 64.330000 %
# This is global 191 epoch
#  Average loss 1.019
# Accuracy of the network on the 10000 test images: 64.380000 %
# This is global 192 epoch
#  Average loss 1.033
# Accuracy of the network on the 10000 test images: 64.900000 %
# This is global 193 epoch
#  Average loss 0.971
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 194 epoch
#  Average loss 0.998
# Accuracy of the network on the 10000 test images: 64.920000 %
# This is global 195 epoch
#  Average loss 0.992
# Accuracy of the network on the 10000 test images: 64.840000 %
# This is global 196 epoch
#  Average loss 0.985
# Accuracy of the network on the 10000 test images: 64.890000 %
# This is global 197 epoch
#  Average loss 0.988
# Accuracy of the network on the 10000 test images: 64.780000 %
# This is global 198 epoch
#  Average loss 1.004
# Accuracy of the network on the 10000 test images: 64.360000 %
# This is global 199 epoch
#  Average loss 0.963
# Accuracy of the network on the 10000 test images: 64.960000 %
# This is global 200 epoch
#  Average loss 0.946
# Accuracy of the network on the 10000 test images: 65.350000 %
# This is global 201 epoch
#  Average loss 0.954
# Accuracy of the network on the 10000 test images: 64.950000 %
# This is global 202 epoch
#  Average loss 1.025
# Accuracy of the network on the 10000 test images: 64.820000 %
# This is global 203 epoch
#  Average loss 1.029
# Accuracy of the network on the 10000 test images: 64.630000 %
# This is global 204 epoch
#  Average loss 0.994
# Accuracy of the network on the 10000 test images: 65.080000 %
# This is global 205 epoch
#  Average loss 0.973
# Accuracy of the network on the 10000 test images: 65.070000 %
# This is global 206 epoch
#  Average loss 0.937
# Accuracy of the network on the 10000 test images: 65.220000 %
# This is global 207 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 65.750000 %
# This is global 208 epoch
#  Average loss 0.965
# Accuracy of the network on the 10000 test images: 63.870000 %
# This is global 209 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 65.040000 %
# This is global 210 epoch
#  Average loss 0.935
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 211 epoch
#  Average loss 0.962
# Accuracy of the network on the 10000 test images: 65.390000 %
# This is global 212 epoch
#  Average loss 0.876
# Accuracy of the network on the 10000 test images: 65.400000 %
# This is global 213 epoch
#  Average loss 0.943
# Accuracy of the network on the 10000 test images: 66.300000 %
# This is global 214 epoch
#  Average loss 0.968
# Accuracy of the network on the 10000 test images: 65.110000 %
# This is global 215 epoch
#  Average loss 0.961
# Accuracy of the network on the 10000 test images: 65.810000 %
# This is global 216 epoch
#  Average loss 0.917
# Accuracy of the network on the 10000 test images: 65.380000 %
# This is global 217 epoch
#  Average loss 0.936
# Accuracy of the network on the 10000 test images: 65.600000 %
# This is global 218 epoch
#  Average loss 0.936
# Accuracy of the network on the 10000 test images: 66.460000 %
# This is global 219 epoch
#  Average loss 0.927
# Accuracy of the network on the 10000 test images: 67.060000 %
# This is global 220 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 65.980000 %
# This is global 221 epoch
#  Average loss 0.945
# Accuracy of the network on the 10000 test images: 66.680000 %
# This is global 222 epoch
#  Average loss 0.885
# Accuracy of the network on the 10000 test images: 64.860000 %
# This is global 223 epoch
#  Average loss 0.918
# Accuracy of the network on the 10000 test images: 66.470000 %
# This is global 224 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 66.140000 %
# This is global 225 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 64.390000 %
# This is global 226 epoch
#  Average loss 0.970
# Accuracy of the network on the 10000 test images: 66.990000 %
# This is global 227 epoch
#  Average loss 0.958
# Accuracy of the network on the 10000 test images: 66.210000 %
# This is global 228 epoch
#  Average loss 0.942
# Accuracy of the network on the 10000 test images: 66.820000 %
# This is global 229 epoch
#  Average loss 0.885
# Accuracy of the network on the 10000 test images: 66.160000 %
# This is global 230 epoch
#  Average loss 0.935
# Accuracy of the network on the 10000 test images: 66.340000 %
# This is global 231 epoch
#  Average loss 0.974
# Accuracy of the network on the 10000 test images: 67.020000 %
# This is global 232 epoch
#  Average loss 0.886
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 233 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 66.470000 %
# This is global 234 epoch
#  Average loss 0.941
# Accuracy of the network on the 10000 test images: 66.260000 %
# This is global 235 epoch
#  Average loss 0.885
# Accuracy of the network on the 10000 test images: 66.760000 %
# This is global 236 epoch
#  Average loss 0.913
# Accuracy of the network on the 10000 test images: 67.300000 %
# This is global 237 epoch
#  Average loss 0.919
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 238 epoch
#  Average loss 0.918
# Accuracy of the network on the 10000 test images: 66.830000 %
# This is global 239 epoch
#  Average loss 0.934
# Accuracy of the network on the 10000 test images: 66.570000 %
# This is global 240 epoch
#  Average loss 0.956
# Accuracy of the network on the 10000 test images: 67.450000 %
# This is global 241 epoch
#  Average loss 0.912
# Accuracy of the network on the 10000 test images: 67.470000 %
# This is global 242 epoch
#  Average loss 0.860
# Accuracy of the network on the 10000 test images: 67.400000 %
# This is global 243 epoch
#  Average loss 0.844
# Accuracy of the network on the 10000 test images: 67.570000 %
# This is global 244 epoch
#  Average loss 0.875
# Accuracy of the network on the 10000 test images: 67.000000 %
# This is global 245 epoch
#  Average loss 0.874
# Accuracy of the network on the 10000 test images: 67.810000 %
# This is global 246 epoch
#  Average loss 0.870
# Accuracy of the network on the 10000 test images: 66.260000 %
# This is global 247 epoch
#  Average loss 0.827
# Accuracy of the network on the 10000 test images: 67.950000 %
# This is global 248 epoch
#  Average loss 0.879
# Accuracy of the network on the 10000 test images: 67.650000 %
# This is global 249 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 250 epoch
#  Average loss 0.816
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 251 epoch
#  Average loss 0.850
# Accuracy of the network on the 10000 test images: 66.920000 %
# This is global 252 epoch
#  Average loss 0.921
# Accuracy of the network on the 10000 test images: 68.410000 %
# This is global 253 epoch
#  Average loss 0.879
# Accuracy of the network on the 10000 test images: 68.680000 %
# This is global 254 epoch
#  Average loss 0.868
# Accuracy of the network on the 10000 test images: 68.570000 %
# This is global 255 epoch
#  Average loss 0.909
# Accuracy of the network on the 10000 test images: 68.040000 %
# This is global 256 epoch
#  Average loss 0.856
# Accuracy of the network on the 10000 test images: 68.470000 %
# This is global 257 epoch
#  Average loss 0.887
# Accuracy of the network on the 10000 test images: 68.540000 %
# This is global 258 epoch
#  Average loss 0.866
# Accuracy of the network on the 10000 test images: 68.780000 %
# This is global 259 epoch
#  Average loss 0.867
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 260 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 261 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 262 epoch
#  Average loss 0.743
# Accuracy of the network on the 10000 test images: 67.690000 %
# This is global 263 epoch
#  Average loss 0.767
# Accuracy of the network on the 10000 test images: 68.010000 %
# This is global 264 epoch
#  Average loss 0.847
# Accuracy of the network on the 10000 test images: 68.580000 %
# This is global 265 epoch
#  Average loss 0.811
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 266 epoch
#  Average loss 0.797
# Accuracy of the network on the 10000 test images: 67.630000 %
# This is global 267 epoch
#  Average loss 0.833
# Accuracy of the network on the 10000 test images: 68.940000 %
# This is global 268 epoch
#  Average loss 0.872
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 269 epoch
#  Average loss 0.832
# Accuracy of the network on the 10000 test images: 67.780000 %
# This is global 270 epoch
#  Average loss 0.826
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 271 epoch
#  Average loss 0.800
# Accuracy of the network on the 10000 test images: 68.560000 %
# This is global 272 epoch
#  Average loss 0.755
# Accuracy of the network on the 10000 test images: 69.110000 %
# This is global 273 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 68.740000 %
# This is global 274 epoch
#  Average loss 0.833
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 275 epoch
#  Average loss 0.840
# Accuracy of the network on the 10000 test images: 68.510000 %
# This is global 276 epoch
#  Average loss 0.788
# Accuracy of the network on the 10000 test images: 67.630000 %
# This is global 277 epoch
#  Average loss 0.806
# Accuracy of the network on the 10000 test images: 68.360000 %
# This is global 278 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 69.470000 %
# This is global 279 epoch
#  Average loss 0.772
# Accuracy of the network on the 10000 test images: 68.590000 %
# This is global 280 epoch
#  Average loss 0.811
# Accuracy of the network on the 10000 test images: 68.590000 %
# This is global 281 epoch
#  Average loss 0.867
# Accuracy of the network on the 10000 test images: 68.500000 %
# This is global 282 epoch
#  Average loss 0.783
# Accuracy of the network on the 10000 test images: 69.380000 %
# This is global 283 epoch
#  Average loss 0.818
# Accuracy of the network on the 10000 test images: 69.030000 %
# This is global 284 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 69.230000 %
# This is global 285 epoch
#  Average loss 0.806
# Accuracy of the network on the 10000 test images: 68.640000 %
# This is global 286 epoch
#  Average loss 0.802
# Accuracy of the network on the 10000 test images: 68.780000 %
# This is global 287 epoch
#  Average loss 0.854
# Accuracy of the network on the 10000 test images: 69.120000 %
# This is global 288 epoch
#  Average loss 0.777
# Accuracy of the network on the 10000 test images: 69.340000 %
# This is global 289 epoch
#  Average loss 0.824
# Accuracy of the network on the 10000 test images: 69.900000 %
# This is global 290 epoch
#  Average loss 0.814
# Accuracy of the network on the 10000 test images: 69.420000 %
# This is global 291 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 68.770000 %
# This is global 292 epoch
#  Average loss 0.781
# Accuracy of the network on the 10000 test images: 68.860000 %
# This is global 293 epoch
#  Average loss 0.794
# Accuracy of the network on the 10000 test images: 69.240000 %
# This is global 294 epoch
#  Average loss 0.755
# Accuracy of the network on the 10000 test images: 67.880000 %
# This is global 295 epoch
#  Average loss 0.805
# Accuracy of the network on the 10000 test images: 69.460000 %
# This is global 296 epoch
#  Average loss 0.789
# Accuracy of the network on the 10000 test images: 68.390000 %
# This is global 297 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 69.490000 %
# This is global 298 epoch
#  Average loss 0.740
# Accuracy of the network on the 10000 test images: 68.570000 %
# This is global 299 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 69.570000 %
# This is global 300 epoch
#  Average loss 0.711
# Accuracy of the network on the 10000 test images: 70.250000 %
# This is global 301 epoch
#  Average loss 0.837
# Accuracy of the network on the 10000 test images: 69.470000 %
# This is global 302 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 69.620000 %
# This is global 303 epoch
#  Average loss 0.765
# Accuracy of the network on the 10000 test images: 69.110000 %
# This is global 304 epoch
#  Average loss 0.772
# Accuracy of the network on the 10000 test images: 69.390000 %
# This is global 305 epoch
#  Average loss 0.703
# Accuracy of the network on the 10000 test images: 69.190000 %
# This is global 306 epoch
#  Average loss 0.731
# Accuracy of the network on the 10000 test images: 69.650000 %
# This is global 307 epoch
#  Average loss 0.797
# Accuracy of the network on the 10000 test images: 69.430000 %
# This is global 308 epoch
#  Average loss 0.790
# Accuracy of the network on the 10000 test images: 69.690000 %
# This is global 309 epoch
#  Average loss 0.757
# Accuracy of the network on the 10000 test images: 68.960000 %
# This is global 310 epoch
#  Average loss 0.783
# Accuracy of the network on the 10000 test images: 70.040000 %
# This is global 311 epoch
#  Average loss 0.714
# Accuracy of the network on the 10000 test images: 69.510000 %
# This is global 312 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 68.950000 %
# This is global 313 epoch
#  Average loss 0.625
# Accuracy of the network on the 10000 test images: 69.930000 %
# This is global 314 epoch
#  Average loss 0.694
# Accuracy of the network on the 10000 test images: 69.890000 %
# This is global 315 epoch
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 69.930000 %
# This is global 316 epoch
#  Average loss 0.736
# Accuracy of the network on the 10000 test images: 69.760000 %
# This is global 317 epoch
#  Average loss 0.729
# Accuracy of the network on the 10000 test images: 69.500000 %
# This is global 318 epoch
#  Average loss 0.776
# Accuracy of the network on the 10000 test images: 68.740000 %
# This is global 319 epoch
#  Average loss 0.689
# Accuracy of the network on the 10000 test images: 69.110000 %
# This is global 320 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 69.670000 %
# This is global 321 epoch
#  Average loss 0.769
# Accuracy of the network on the 10000 test images: 69.360000 %
# This is global 322 epoch
#  Average loss 0.803
# Accuracy of the network on the 10000 test images: 69.330000 %
# This is global 323 epoch
#  Average loss 0.707
# Accuracy of the network on the 10000 test images: 69.500000 %
# This is global 324 epoch
#  Average loss 0.694
# Accuracy of the network on the 10000 test images: 68.980000 %
# This is global 325 epoch
#  Average loss 0.747
# Accuracy of the network on the 10000 test images: 69.720000 %
# This is global 326 epoch
#  Average loss 0.757
# Accuracy of the network on the 10000 test images: 69.150000 %
# This is global 327 epoch
#  Average loss 0.649
# Accuracy of the network on the 10000 test images: 70.210000 %
# This is global 328 epoch
#  Average loss 0.671
# Accuracy of the network on the 10000 test images: 70.240000 %
# This is global 329 epoch
#  Average loss 0.696
# Accuracy of the network on the 10000 test images: 70.150000 %
# This is global 330 epoch
#  Average loss 0.742
# Accuracy of the network on the 10000 test images: 69.940000 %
# This is global 331 epoch
#  Average loss 0.778
# Accuracy of the network on the 10000 test images: 70.490000 %
# This is global 332 epoch
#  Average loss 0.688
# Accuracy of the network on the 10000 test images: 70.120000 %
# This is global 333 epoch
#  Average loss 0.725
# Accuracy of the network on the 10000 test images: 69.910000 %
# This is global 334 epoch
#  Average loss 0.734
# Accuracy of the network on the 10000 test images: 70.490000 %
# This is global 335 epoch
#  Average loss 0.667
# Accuracy of the network on the 10000 test images: 69.330000 %
# This is global 336 epoch
#  Average loss 0.654
# Accuracy of the network on the 10000 test images: 69.990000 %
# This is global 337 epoch
#  Average loss 0.628
# Accuracy of the network on the 10000 test images: 70.600000 %
# This is global 338 epoch
#  Average loss 0.597
# Accuracy of the network on the 10000 test images: 69.540000 %
# This is global 339 epoch
#  Average loss 0.762
# Accuracy of the network on the 10000 test images: 70.050000 %
# This is global 340 epoch
#  Average loss 0.772
# Accuracy of the network on the 10000 test images: 69.690000 %
# This is global 341 epoch
#  Average loss 0.727
# Accuracy of the network on the 10000 test images: 69.670000 %
# This is global 342 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 70.450000 %
# This is global 343 epoch
#  Average loss 0.647
# Accuracy of the network on the 10000 test images: 70.120000 %
# This is global 344 epoch
#  Average loss 0.741
# Accuracy of the network on the 10000 test images: 70.620000 %
# This is global 345 epoch
#  Average loss 0.654
# Accuracy of the network on the 10000 test images: 69.940000 %
# This is global 346 epoch
#  Average loss 0.664
# Accuracy of the network on the 10000 test images: 70.370000 %
# This is global 347 epoch
#  Average loss 0.673
# Accuracy of the network on the 10000 test images: 70.130000 %
# This is global 348 epoch
#  Average loss 0.711
# Accuracy of the network on the 10000 test images: 70.710000 %
# This is global 349 epoch
#  Average loss 0.623
# Accuracy of the network on the 10000 test images: 70.160000 %
# This is global 350 epoch
#  Average loss 0.641
# Accuracy of the network on the 10000 test images: 70.510000 %
# This is global 351 epoch
#  Average loss 0.698
# Accuracy of the network on the 10000 test images: 69.760000 %
# This is global 352 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 70.530000 %
# This is global 353 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 70.140000 %
# This is global 354 epoch
#  Average loss 0.639
# Accuracy of the network on the 10000 test images: 70.390000 %
# This is global 355 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 70.310000 %
# This is global 356 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 70.020000 %
# This is global 357 epoch
#  Average loss 0.776
# Accuracy of the network on the 10000 test images: 70.650000 %
# This is global 358 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 69.930000 %
# This is global 359 epoch
#  Average loss 0.651
# Accuracy of the network on the 10000 test images: 71.220000 %
# This is global 360 epoch
#  Average loss 0.674
# Accuracy of the network on the 10000 test images: 70.310000 %
# This is global 361 epoch
#  Average loss 0.690
# Accuracy of the network on the 10000 test images: 70.250000 %
# This is global 362 epoch
#  Average loss 0.679
# Accuracy of the network on the 10000 test images: 70.900000 %
# This is global 363 epoch
#  Average loss 0.659
# Accuracy of the network on the 10000 test images: 69.800000 %
# This is global 364 epoch
#  Average loss 0.597
# Accuracy of the network on the 10000 test images: 70.300000 %
# This is global 365 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 70.500000 %
# This is global 366 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 70.680000 %
# This is global 367 epoch
#  Average loss 0.621
# Accuracy of the network on the 10000 test images: 70.720000 %
# This is global 368 epoch
#  Average loss 0.613
# Accuracy of the network on the 10000 test images: 70.390000 %
# This is global 369 epoch
#  Average loss 0.650
# Accuracy of the network on the 10000 test images: 70.640000 %
# This is global 370 epoch
#  Average loss 0.671
# Accuracy of the network on the 10000 test images: 70.590000 %
# This is global 371 epoch
#  Average loss 0.649
# Accuracy of the network on the 10000 test images: 70.270000 %
# This is global 372 epoch
#  Average loss 0.589
# Accuracy of the network on the 10000 test images: 70.790000 %
# This is global 373 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 69.450000 %
# This is global 374 epoch
#  Average loss 0.664
# Accuracy of the network on the 10000 test images: 69.260000 %
# This is global 375 epoch
#  Average loss 0.613
# Accuracy of the network on the 10000 test images: 70.560000 %
# This is global 376 epoch
#  Average loss 0.667
# Accuracy of the network on the 10000 test images: 70.800000 %
# This is global 377 epoch
#  Average loss 0.549
# Accuracy of the network on the 10000 test images: 70.610000 %
# This is global 378 epoch
#  Average loss 0.610
# Accuracy of the network on the 10000 test images: 71.000000 %
# This is global 379 epoch
#  Average loss 0.667
# Accuracy of the network on the 10000 test images: 70.000000 %
# This is global 380 epoch
#  Average loss 0.661
# Accuracy of the network on the 10000 test images: 70.050000 %
# This is global 381 epoch
#  Average loss 0.670
# Accuracy of the network on the 10000 test images: 70.900000 %
# This is global 382 epoch
#  Average loss 0.651
# Accuracy of the network on the 10000 test images: 69.430000 %
# This is global 383 epoch
#  Average loss 0.625
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 384 epoch
#  Average loss 0.597
# Accuracy of the network on the 10000 test images: 70.690000 %
# This is global 385 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 69.410000 %
# This is global 386 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 71.040000 %
# This is global 387 epoch
#  Average loss 0.704
# Accuracy of the network on the 10000 test images: 70.480000 %
# This is global 388 epoch
#  Average loss 0.617
# Accuracy of the network on the 10000 test images: 70.980000 %
# This is global 389 epoch
#  Average loss 0.594
# Accuracy of the network on the 10000 test images: 70.510000 %
# This is global 390 epoch
#  Average loss 0.675
# Accuracy of the network on the 10000 test images: 70.570000 %
# This is global 391 epoch
#  Average loss 0.561
# Accuracy of the network on the 10000 test images: 71.240000 %
# This is global 392 epoch
#  Average loss 0.569
# Accuracy of the network on the 10000 test images: 70.340000 %
# This is global 393 epoch
#  Average loss 0.730
# Accuracy of the network on the 10000 test images: 71.330000 %
# This is global 394 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 70.750000 %
# This is global 395 epoch
#  Average loss 0.644
# Accuracy of the network on the 10000 test images: 70.570000 %
# This is global 396 epoch
#  Average loss 0.686
# Accuracy of the network on the 10000 test images: 71.240000 %
# This is global 397 epoch
#  Average loss 0.550
# Accuracy of the network on the 10000 test images: 71.080000 %
# This is global 398 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 71.320000 %
# This is global 399 epoch
#  Average loss 0.690
# Accuracy of the network on the 10000 test images: 71.570000 %
# This is global 400 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 71.170000 %
# This is global 401 epoch
#  Average loss 0.545
# Accuracy of the network on the 10000 test images: 71.020000 %
# This is global 402 epoch
#  Average loss 0.657
# Accuracy of the network on the 10000 test images: 71.420000 %
# This is global 403 epoch
#  Average loss 0.637
# Accuracy of the network on the 10000 test images: 70.760000 %
# This is global 404 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 70.970000 %
# This is global 405 epoch
#  Average loss 0.618
# Accuracy of the network on the 10000 test images: 71.450000 %
# This is global 406 epoch
#  Average loss 0.576
# Accuracy of the network on the 10000 test images: 70.000000 %
# This is global 407 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 408 epoch
#  Average loss 0.531
# Accuracy of the network on the 10000 test images: 70.170000 %
# This is global 409 epoch
#  Average loss 0.622
# Accuracy of the network on the 10000 test images: 71.070000 %
# This is global 410 epoch
#  Average loss 0.573
# Accuracy of the network on the 10000 test images: 71.590000 %
# This is global 411 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 70.760000 %
# This is global 412 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 413 epoch
#  Average loss 0.588
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 414 epoch
#  Average loss 0.603
# Accuracy of the network on the 10000 test images: 69.930000 %
# This is global 415 epoch
#  Average loss 0.585
# Accuracy of the network on the 10000 test images: 71.300000 %
# This is global 416 epoch
#  Average loss 0.602
# Accuracy of the network on the 10000 test images: 71.190000 %
# This is global 417 epoch
#  Average loss 0.663
# Accuracy of the network on the 10000 test images: 70.680000 %
# This is global 418 epoch
#  Average loss 0.628
# Accuracy of the network on the 10000 test images: 71.420000 %
# This is global 419 epoch
#  Average loss 0.612
# Accuracy of the network on the 10000 test images: 71.610000 %
# This is global 420 epoch
#  Average loss 0.529
# Accuracy of the network on the 10000 test images: 71.020000 %
# This is global 421 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 71.460000 %
# This is global 422 epoch
#  Average loss 0.531
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 423 epoch
#  Average loss 0.491
# Accuracy of the network on the 10000 test images: 71.190000 %
# This is global 424 epoch
#  Average loss 0.557
# Accuracy of the network on the 10000 test images: 71.370000 %
# This is global 425 epoch
#  Average loss 0.603
# Accuracy of the network on the 10000 test images: 70.670000 %
# This is global 426 epoch
#  Average loss 0.621
# Accuracy of the network on the 10000 test images: 69.780000 %
# This is global 427 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 71.430000 %
# This is global 428 epoch
#  Average loss 0.667
# Accuracy of the network on the 10000 test images: 71.010000 %
# This is global 429 epoch
#  Average loss 0.653
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 430 epoch
#  Average loss 0.492
# Accuracy of the network on the 10000 test images: 71.660000 %
# This is global 431 epoch
#  Average loss 0.544
# Accuracy of the network on the 10000 test images: 71.090000 %
# This is global 432 epoch
#  Average loss 0.558
# Accuracy of the network on the 10000 test images: 71.240000 %
# This is global 433 epoch
#  Average loss 0.610
# Accuracy of the network on the 10000 test images: 70.660000 %
# This is global 434 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 71.400000 %
# This is global 435 epoch
#  Average loss 0.593
# Accuracy of the network on the 10000 test images: 70.680000 %
# This is global 436 epoch
#  Average loss 0.551
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 437 epoch
#  Average loss 0.638
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 438 epoch
#  Average loss 0.567
# Accuracy of the network on the 10000 test images: 71.100000 %
# This is global 439 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 71.390000 %
# This is global 440 epoch
#  Average loss 0.537
# Accuracy of the network on the 10000 test images: 69.720000 %
# This is global 441 epoch
#  Average loss 0.570
# Accuracy of the network on the 10000 test images: 70.970000 %
# This is global 442 epoch
#  Average loss 0.563
# Accuracy of the network on the 10000 test images: 71.230000 %
# This is global 443 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 71.050000 %
# This is global 444 epoch
#  Average loss 0.534
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 445 epoch
#  Average loss 0.494
# Accuracy of the network on the 10000 test images: 71.040000 %
# This is global 446 epoch
#  Average loss 0.587
# Accuracy of the network on the 10000 test images: 71.390000 %
# This is global 447 epoch
#  Average loss 0.558
# Accuracy of the network on the 10000 test images: 69.920000 %
# This is global 448 epoch
#  Average loss 0.520
# Accuracy of the network on the 10000 test images: 71.170000 %
# This is global 449 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 71.060000 %
# This is global 450 epoch
#  Average loss 0.565
# Accuracy of the network on the 10000 test images: 71.410000 %
# This is global 451 epoch
#  Average loss 0.509
# Accuracy of the network on the 10000 test images: 70.860000 %
# This is global 452 epoch
#  Average loss 0.590
# Accuracy of the network on the 10000 test images: 71.070000 %
# This is global 453 epoch
#  Average loss 0.571
# Accuracy of the network on the 10000 test images: 71.010000 %
# This is global 454 epoch
#  Average loss 0.449
# Accuracy of the network on the 10000 test images: 71.110000 %
# This is global 455 epoch
#  Average loss 0.497
# Accuracy of the network on the 10000 test images: 71.100000 %
# This is global 456 epoch
#  Average loss 0.477
# Accuracy of the network on the 10000 test images: 70.760000 %
# This is global 457 epoch
#  Average loss 0.517
# Accuracy of the network on the 10000 test images: 70.650000 %
# This is global 458 epoch
#  Average loss 0.521
# Accuracy of the network on the 10000 test images: 70.610000 %
# This is global 459 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 71.280000 %
# This is global 460 epoch
#  Average loss 0.525
# Accuracy of the network on the 10000 test images: 70.790000 %
# This is global 461 epoch
#  Average loss 0.566
# Accuracy of the network on the 10000 test images: 70.820000 %
# This is global 462 epoch
#  Average loss 0.473
# Accuracy of the network on the 10000 test images: 71.300000 %
# This is global 463 epoch
#  Average loss 0.627
# Accuracy of the network on the 10000 test images: 70.300000 %
# This is global 464 epoch
#  Average loss 0.491
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 465 epoch
#  Average loss 0.360
# Accuracy of the network on the 10000 test images: 70.920000 %
# This is global 466 epoch
#  Average loss 0.559
# Accuracy of the network on the 10000 test images: 70.720000 %
# This is global 467 epoch
#  Average loss 0.548
# Accuracy of the network on the 10000 test images: 71.120000 %
# This is global 468 epoch
#  Average loss 0.585
# Accuracy of the network on the 10000 test images: 70.500000 %
# This is global 469 epoch
#  Average loss 0.642
# Accuracy of the network on the 10000 test images: 70.840000 %
# This is global 470 epoch
#  Average loss 0.476
# Accuracy of the network on the 10000 test images: 71.640000 %
# This is global 471 epoch
#  Average loss 0.474
# Accuracy of the network on the 10000 test images: 71.630000 %
# This is global 472 epoch
#  Average loss 0.431
# Accuracy of the network on the 10000 test images: 71.440000 %
# This is global 473 epoch
#  Average loss 0.581
# Accuracy of the network on the 10000 test images: 70.840000 %
# This is global 474 epoch
#  Average loss 0.383
# Accuracy of the network on the 10000 test images: 71.660000 %
# This is global 475 epoch
#  Average loss 0.467
# Accuracy of the network on the 10000 test images: 71.750000 %
# This is global 476 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 70.750000 %
# This is global 477 epoch
#  Average loss 0.571
# Accuracy of the network on the 10000 test images: 71.560000 %
# This is global 478 epoch
#  Average loss 0.494
# Accuracy of the network on the 10000 test images: 71.420000 %
# This is global 479 epoch
#  Average loss 0.550
# Accuracy of the network on the 10000 test images: 70.580000 %
# This is global 480 epoch
#  Average loss 0.416
# Accuracy of the network on the 10000 test images: 70.740000 %
# This is global 481 epoch
#  Average loss 0.463
# Accuracy of the network on the 10000 test images: 71.430000 %
# This is global 482 epoch
#  Average loss 0.547
# Accuracy of the network on the 10000 test images: 71.170000 %
# This is global 483 epoch
#  Average loss 0.425
# Accuracy of the network on the 10000 test images: 70.860000 %
# This is global 484 epoch
#  Average loss 0.472
# Accuracy of the network on the 10000 test images: 70.310000 %
# This is global 485 epoch
#  Average loss 0.519
# Accuracy of the network on the 10000 test images: 71.230000 %
# This is global 486 epoch
#  Average loss 0.450
# Accuracy of the network on the 10000 test images: 70.560000 %
# This is global 487 epoch
#  Average loss 0.493
# Accuracy of the network on the 10000 test images: 71.160000 %
# This is global 488 epoch
#  Average loss 0.428
# Accuracy of the network on the 10000 test images: 71.420000 %
# This is global 489 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 71.050000 %
# This is global 490 epoch
#  Average loss 0.404
# Accuracy of the network on the 10000 test images: 71.410000 %
# This is global 491 epoch
#  Average loss 0.438
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 492 epoch
#  Average loss 0.523
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 493 epoch
#  Average loss 0.594
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 494 epoch
#  Average loss 0.462
# Accuracy of the network on the 10000 test images: 70.340000 %
# This is global 495 epoch
#  Average loss 0.625
# Accuracy of the network on the 10000 test images: 71.660000 %
# This is global 496 epoch
#  Average loss 0.386
# Accuracy of the network on the 10000 test images: 71.160000 %
# This is global 497 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 71.130000 %
# This is global 498 epoch
#  Average loss 0.534
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 499 epoch
#  Average loss 0.508
# Accuracy of the network on the 10000 test images: 71.570000 %
# This is global 500 epoch
#  Average loss 0.458
# Accuracy of the network on the 10000 test images: 70.870000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_iid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 1.004
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 9.970000 %
# This is global 2 epoch
#  Average loss 0.249
# Accuracy of the network on the 10000 test images: 10.610000 %
# This is global 3 epoch
#  Average loss 0.400
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 5 epoch
#  Average loss 0.541
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 6 epoch
#  Average loss 0.366
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 7 epoch
#  Average loss 0.251
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 8 epoch
#  Average loss 0.299
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 9 epoch
#  Average loss 0.335
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 10 epoch
#  Average loss 0.545
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 11 epoch
#  Average loss 0.608
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 12 epoch
#  Average loss 0.526
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 13 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 14 epoch
#  Average loss 0.346
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 15 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 16 epoch
#  Average loss 0.373
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 17 epoch
#  Average loss 0.326
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 18 epoch
#  Average loss 0.245
# Accuracy of the network on the 10000 test images: 11.840000 %
# This is global 19 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 20 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 21 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 22 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 23 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 24 epoch
#  Average loss 0.173
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 25 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 26 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 27 epoch
#  Average loss 0.312
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 28 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 29 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.870000 %
# This is global 30 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 31 epoch
#  Average loss 0.296
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 32 epoch
#  Average loss 0.202
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 33 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 34 epoch
#  Average loss 0.332
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 35 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 36 epoch
#  Average loss 0.288
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 37 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 38 epoch
#  Average loss 0.326
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 39 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 40 epoch
#  Average loss 0.306
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 41 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 42 epoch
#  Average loss 0.249
# Accuracy of the network on the 10000 test images: 13.840000 %
# This is global 43 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 44 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 45 epoch
#  Average loss 0.265
# Accuracy of the network on the 10000 test images: 11.880000 %
# This is global 46 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 47 epoch
#  Average loss 0.377
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 48 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 49 epoch
#  Average loss 0.309
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 50 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 51 epoch
#  Average loss 0.324
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 52 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 53 epoch
#  Average loss 0.302
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 54 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 55 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 56 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 57 epoch
#  Average loss 0.321
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 58 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 59 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.230000 %
# This is global 60 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 61 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 62 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 63 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 64 epoch
#  Average loss 0.339
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 65 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 66 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 67 epoch
#  Average loss 0.299
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 68 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 69 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 70 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 71 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 72 epoch
#  Average loss 0.334
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 73 epoch
#  Average loss 0.254
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 74 epoch
#  Average loss 0.369
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 75 epoch
#  Average loss 0.385
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 76 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 77 epoch
#  Average loss 0.398
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 78 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 79 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 80 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 81 epoch
#  Average loss 0.339
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 82 epoch
#  Average loss 0.303
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 83 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 84 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 85 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 86 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 87 epoch
#  Average loss 0.208
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 88 epoch
#  Average loss 0.298
# Accuracy of the network on the 10000 test images: 10.560000 %
# This is global 89 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 90 epoch
#  Average loss 0.313
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 91 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 92 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 93 epoch
#  Average loss 0.320
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 94 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 95 epoch
#  Average loss 0.339
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 96 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 97 epoch
#  Average loss 0.429
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 98 epoch
#  Average loss 0.260
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 99 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 100 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 101 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 102 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.120000 %
# This is global 103 epoch
#  Average loss 0.370
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 104 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 105 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 106 epoch
#  Average loss 0.275
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 107 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 108 epoch
#  Average loss 0.319
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 109 epoch
#  Average loss 0.281
# Accuracy of the network on the 10000 test images: 14.610000 %
# This is global 110 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 111 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 112 epoch
#  Average loss 0.220
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 113 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 114 epoch
#  Average loss 0.303
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 115 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 116 epoch
#  Average loss 0.430
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 117 epoch
#  Average loss 0.243
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 118 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 119 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 120 epoch
#  Average loss 0.369
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 121 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 122 epoch
#  Average loss 0.294
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 123 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 124 epoch
#  Average loss 0.382
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 125 epoch
#  Average loss 0.324
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 126 epoch
#  Average loss 0.338
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 127 epoch
#  Average loss 0.298
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 128 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 129 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 130 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 131 epoch
#  Average loss 0.350
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 132 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 133 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 134 epoch
#  Average loss 0.202
# Accuracy of the network on the 10000 test images: 17.620000 %
# This is global 135 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 136 epoch
#  Average loss 0.335
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 137 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.720000 %
# This is global 138 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 139 epoch
#  Average loss 0.374
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 140 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 141 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 142 epoch
#  Average loss 0.229
# Accuracy of the network on the 10000 test images: 16.240000 %
# This is global 143 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 11.650000 %
# This is global 144 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 145 epoch
#  Average loss 0.315
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 146 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 147 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 12.120000 %
# This is global 148 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 149 epoch
#  Average loss 0.328
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 150 epoch
#  Average loss 0.190
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 151 epoch
#  Average loss 0.451
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 152 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 153 epoch
#  Average loss 0.268
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 154 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 155 epoch
#  Average loss 0.329
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 156 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 157 epoch
#  Average loss 0.295
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 158 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 159 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 160 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 12.820000 %
# This is global 161 epoch
#  Average loss 0.255
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 162 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 163 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 11.560000 %
# This is global 164 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 165 epoch
#  Average loss 0.303
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 166 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 167 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 168 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 169 epoch
#  Average loss 0.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 170 epoch
#  Average loss 0.436
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 171 epoch
#  Average loss 0.313
# Accuracy of the network on the 10000 test images: 11.290000 %
# This is global 172 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 173 epoch
#  Average loss 0.308
# Accuracy of the network on the 10000 test images: 13.550000 %
# This is global 174 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 175 epoch
#  Average loss 0.229
# Accuracy of the network on the 10000 test images: 10.780000 %
# This is global 176 epoch
#  Average loss 0.211
# Accuracy of the network on the 10000 test images: 13.170000 %
# This is global 177 epoch
#  Average loss 0.169
# Accuracy of the network on the 10000 test images: 17.270000 %
# This is global 178 epoch
#  Average loss 0.412
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 179 epoch
#  Average loss 0.312
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 180 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 181 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 182 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 183 epoch
#  Average loss 0.375
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 184 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 185 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 186 epoch
#  Average loss 0.186
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 187 epoch
#  Average loss 0.326
# Accuracy of the network on the 10000 test images: 12.000000 %
# This is global 188 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 189 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 190 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 191 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 192 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 14.380000 %
# This is global 193 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.950000 %
# This is global 194 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 195 epoch
#  Average loss 0.333
# Accuracy of the network on the 10000 test images: 15.750000 %
# This is global 196 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 197 epoch
#  Average loss 0.344
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 198 epoch
#  Average loss 0.344
# Accuracy of the network on the 10000 test images: 12.840000 %
# This is global 199 epoch
#  Average loss 0.298
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 200 epoch
#  Average loss 0.344
# Accuracy of the network on the 10000 test images: 9.970000 %
# This is global 201 epoch
#  Average loss 0.265
# Accuracy of the network on the 10000 test images: 15.470000 %
# This is global 202 epoch
#  Average loss 0.317
# Accuracy of the network on the 10000 test images: 14.740000 %
# This is global 203 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 16.820000 %
# This is global 204 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 11.590000 %
# This is global 205 epoch
#  Average loss 0.286
# Accuracy of the network on the 10000 test images: 13.350000 %
# This is global 206 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 207 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 208 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 14.880000 %
# This is global 209 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 15.240000 %
# This is global 210 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 211 epoch
#  Average loss 0.302
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 212 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 10.730000 %
# This is global 213 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 15.430000 %
# This is global 214 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 11.830000 %
# This is global 215 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 11.260000 %
# This is global 216 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 14.990000 %
# This is global 217 epoch
#  Average loss 0.192
# Accuracy of the network on the 10000 test images: 14.560000 %
# This is global 218 epoch
#  Average loss 0.249
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 219 epoch
#  Average loss 0.272
# Accuracy of the network on the 10000 test images: 17.190000 %
# This is global 220 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 221 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 17.260000 %
# This is global 222 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 17.010000 %
# This is global 223 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 11.280000 %
# This is global 224 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 13.000000 %
# This is global 225 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 226 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 18.850000 %
# This is global 227 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 11.760000 %
# This is global 228 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 229 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 14.460000 %
# This is global 230 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 231 epoch
#  Average loss 0.251
# Accuracy of the network on the 10000 test images: 11.950000 %
# This is global 232 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 16.940000 %
# This is global 233 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 13.410000 %
# This is global 234 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 10.130000 %
# This is global 235 epoch
#  Average loss 0.229
# Accuracy of the network on the 10000 test images: 12.060000 %
# This is global 236 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 237 epoch
#  Average loss 0.328
# Accuracy of the network on the 10000 test images: 12.680000 %
# This is global 238 epoch
#  Average loss 0.313
# Accuracy of the network on the 10000 test images: 14.090000 %
# This is global 239 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 240 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 12.920000 %
# This is global 241 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 19.040000 %
# This is global 242 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 20.950000 %
# This is global 243 epoch
#  Average loss 0.202
# Accuracy of the network on the 10000 test images: 11.060000 %
# This is global 244 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 13.780000 %
# This is global 245 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 246 epoch
#  Average loss 0.386
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 247 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 15.860000 %
# This is global 248 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 16.250000 %
# This is global 249 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 15.610000 %
# This is global 250 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 16.920000 %
# This is global 251 epoch
#  Average loss 0.268
# Accuracy of the network on the 10000 test images: 12.900000 %
# This is global 252 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 20.040000 %
# This is global 253 epoch
#  Average loss 0.297
# Accuracy of the network on the 10000 test images: 12.990000 %
# This is global 254 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 15.920000 %
# This is global 255 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 14.390000 %
# This is global 256 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 17.230000 %
# This is global 257 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 11.390000 %
# This is global 258 epoch
#  Average loss 0.347
# Accuracy of the network on the 10000 test images: 18.010000 %
# This is global 259 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 19.110000 %
# This is global 260 epoch
#  Average loss 0.208
# Accuracy of the network on the 10000 test images: 11.760000 %
# This is global 261 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 262 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.910000 %
# This is global 263 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 264 epoch
#  Average loss 0.283
# Accuracy of the network on the 10000 test images: 14.060000 %
# This is global 265 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 13.700000 %
# This is global 266 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 17.570000 %
# This is global 267 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 268 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 269 epoch
#  Average loss 0.206
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 270 epoch
#  Average loss 0.274
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 271 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 13.130000 %
# This is global 272 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 10.350000 %
# This is global 273 epoch
#  Average loss 0.317
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 274 epoch
#  Average loss 0.296
# Accuracy of the network on the 10000 test images: 17.630000 %
# This is global 275 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 276 epoch
#  Average loss 0.302
# Accuracy of the network on the 10000 test images: 11.020000 %
# This is global 277 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 19.950000 %
# This is global 278 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 16.740000 %
# This is global 279 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 12.800000 %
# This is global 280 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 14.230000 %
# This is global 281 epoch
#  Average loss 0.191
# Accuracy of the network on the 10000 test images: 17.360000 %
# This is global 282 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 14.440000 %
# This is global 283 epoch
#  Average loss 0.281
# Accuracy of the network on the 10000 test images: 16.630000 %
# This is global 284 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 18.740000 %
# This is global 285 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 16.550000 %
# This is global 286 epoch
#  Average loss 0.281
# Accuracy of the network on the 10000 test images: 13.250000 %
# This is global 287 epoch
#  Average loss 0.171
# Accuracy of the network on the 10000 test images: 14.470000 %
# This is global 288 epoch
#  Average loss 0.298
# Accuracy of the network on the 10000 test images: 17.500000 %
# This is global 289 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 16.470000 %
# This is global 290 epoch
#  Average loss 0.173
# Accuracy of the network on the 10000 test images: 17.210000 %
# This is global 291 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 14.330000 %
# This is global 292 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 13.520000 %
# This is global 293 epoch
#  Average loss 0.388
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 294 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 12.890000 %
# This is global 295 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 15.680000 %
# This is global 296 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 297 epoch
#  Average loss 0.318
# Accuracy of the network on the 10000 test images: 17.120000 %
# This is global 298 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 16.460000 %
# This is global 299 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 17.200000 %
# This is global 300 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 13.410000 %
# This is global 301 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 302 epoch
#  Average loss 0.289
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 303 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 14.890000 %
# This is global 304 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 17.320000 %
# This is global 305 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 306 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 14.850000 %
# This is global 307 epoch
#  Average loss 0.298
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 308 epoch
#  Average loss 0.319
# Accuracy of the network on the 10000 test images: 16.500000 %
# This is global 309 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 17.060000 %
# This is global 310 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 15.690000 %
# This is global 311 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 16.530000 %
# This is global 312 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 14.880000 %
# This is global 313 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 15.960000 %
# This is global 314 epoch
#  Average loss 0.212
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 315 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 11.190000 %
# This is global 316 epoch
#  Average loss 0.272
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 317 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 16.640000 %
# This is global 318 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 10.540000 %
# This is global 319 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 16.150000 %
# This is global 320 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 321 epoch
#  Average loss 0.274
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 322 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 13.200000 %
# This is global 323 epoch
#  Average loss 0.309
# Accuracy of the network on the 10000 test images: 11.130000 %
# This is global 324 epoch
#  Average loss 0.191
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 325 epoch
#  Average loss 0.353
# Accuracy of the network on the 10000 test images: 12.850000 %
# This is global 326 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 327 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 15.740000 %
# This is global 328 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 329 epoch
#  Average loss 0.281
# Accuracy of the network on the 10000 test images: 20.000000 %
# This is global 330 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 331 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 11.130000 %
# This is global 332 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 11.720000 %
# This is global 333 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 14.240000 %
# This is global 334 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 335 epoch
#  Average loss 0.308
# Accuracy of the network on the 10000 test images: 14.310000 %
# This is global 336 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 15.450000 %
# This is global 337 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 16.960000 %
# This is global 338 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 17.390000 %
# This is global 339 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 15.760000 %
# This is global 340 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 17.670000 %
# This is global 341 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 11.780000 %
# This is global 342 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 17.210000 %
# This is global 343 epoch
#  Average loss 0.220
# Accuracy of the network on the 10000 test images: 15.430000 %
# This is global 344 epoch
#  Average loss 0.188
# Accuracy of the network on the 10000 test images: 14.150000 %
# This is global 345 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 17.360000 %
# This is global 346 epoch
#  Average loss 0.170
# Accuracy of the network on the 10000 test images: 22.240000 %
# This is global 347 epoch
#  Average loss 0.362
# Accuracy of the network on the 10000 test images: 17.970000 %
# This is global 348 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 15.070000 %
# This is global 349 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 15.710000 %
# This is global 350 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 11.910000 %
# This is global 351 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 18.350000 %
# This is global 352 epoch
#  Average loss 0.308
# Accuracy of the network on the 10000 test images: 17.390000 %
# This is global 353 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 10.900000 %
# This is global 354 epoch
#  Average loss 0.328
# Accuracy of the network on the 10000 test images: 17.940000 %
# This is global 355 epoch
#  Average loss 0.251
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 356 epoch
#  Average loss 0.190
# Accuracy of the network on the 10000 test images: 13.200000 %
# This is global 357 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 358 epoch
#  Average loss 0.296
# Accuracy of the network on the 10000 test images: 14.440000 %
# This is global 359 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 12.320000 %
# This is global 360 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 18.450000 %
# This is global 361 epoch
#  Average loss 0.309
# Accuracy of the network on the 10000 test images: 15.100000 %
# This is global 362 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 19.990000 %
# This is global 363 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 11.700000 %
# This is global 364 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 16.050000 %
# This is global 365 epoch
#  Average loss 0.184
# Accuracy of the network on the 10000 test images: 10.500000 %
# This is global 366 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 18.360000 %
# This is global 367 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 21.710000 %
# This is global 368 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 11.130000 %
# This is global 369 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 19.900000 %
# This is global 370 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 19.550000 %
# This is global 371 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 17.280000 %
# This is global 372 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 12.640000 %
# This is global 373 epoch
#  Average loss 0.286
# Accuracy of the network on the 10000 test images: 15.940000 %
# This is global 374 epoch
#  Average loss 0.211
# Accuracy of the network on the 10000 test images: 20.340000 %
# This is global 375 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 16.610000 %
# This is global 376 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 16.100000 %
# This is global 377 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 20.650000 %
# This is global 378 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 18.570000 %
# This is global 379 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 22.330000 %
# This is global 380 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 11.060000 %
# This is global 381 epoch
#  Average loss 0.245
# Accuracy of the network on the 10000 test images: 21.860000 %
# This is global 382 epoch
#  Average loss 0.186
# Accuracy of the network on the 10000 test images: 16.030000 %
# This is global 383 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 13.780000 %
# This is global 384 epoch
#  Average loss 0.353
# Accuracy of the network on the 10000 test images: 17.540000 %
# This is global 385 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 12.580000 %
# This is global 386 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 14.730000 %
# This is global 387 epoch
#  Average loss 0.274
# Accuracy of the network on the 10000 test images: 17.690000 %
# This is global 388 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 22.100000 %
# This is global 389 epoch
#  Average loss 0.245
# Accuracy of the network on the 10000 test images: 19.990000 %
# This is global 390 epoch
#  Average loss 0.212
# Accuracy of the network on the 10000 test images: 19.630000 %
# This is global 391 epoch
#  Average loss 0.181
# Accuracy of the network on the 10000 test images: 16.300000 %
# This is global 392 epoch
#  Average loss 0.362
# Accuracy of the network on the 10000 test images: 15.180000 %
# This is global 393 epoch
#  Average loss 0.321
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 394 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 13.870000 %
# This is global 395 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 18.170000 %
# This is global 396 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 17.590000 %
# This is global 397 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 21.250000 %
# This is global 398 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 14.990000 %
# This is global 399 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 400 epoch
#  Average loss 0.324
# Accuracy of the network on the 10000 test images: 12.990000 %
# This is global 401 epoch
#  Average loss 0.325
# Accuracy of the network on the 10000 test images: 17.570000 %
# This is global 402 epoch
#  Average loss 0.296
# Accuracy of the network on the 10000 test images: 18.270000 %
# This is global 403 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 15.430000 %
# This is global 404 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 10.640000 %
# This is global 405 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 19.840000 %
# This is global 406 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 15.750000 %
# This is global 407 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 14.840000 %
# This is global 408 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.610000 %
# This is global 409 epoch
#  Average loss 0.260
# Accuracy of the network on the 10000 test images: 14.570000 %
# This is global 410 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 16.740000 %
# This is global 411 epoch
#  Average loss 0.320
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 412 epoch
#  Average loss 0.315
# Accuracy of the network on the 10000 test images: 14.960000 %
# This is global 413 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 12.950000 %
# This is global 414 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 13.320000 %
# This is global 415 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 19.500000 %
# This is global 416 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 18.780000 %
# This is global 417 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 20.840000 %
# This is global 418 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 11.270000 %
# This is global 419 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 14.600000 %
# This is global 420 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 25.080000 %
# This is global 421 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 19.000000 %
# This is global 422 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 16.570000 %
# This is global 423 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 18.940000 %
# This is global 424 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 20.440000 %
# This is global 425 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 20.060000 %
# This is global 426 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 20.400000 %
# This is global 427 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 21.030000 %
# This is global 428 epoch
#  Average loss 0.190
# Accuracy of the network on the 10000 test images: 21.310000 %
# This is global 429 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 14.470000 %
# This is global 430 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 17.860000 %
# This is global 431 epoch
#  Average loss 0.304
# Accuracy of the network on the 10000 test images: 15.580000 %
# This is global 432 epoch
#  Average loss 0.270
# Accuracy of the network on the 10000 test images: 18.620000 %
# This is global 433 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 14.490000 %
# This is global 434 epoch
#  Average loss 0.319
# Accuracy of the network on the 10000 test images: 20.590000 %
# This is global 435 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 18.540000 %
# This is global 436 epoch
#  Average loss 0.258
# Accuracy of the network on the 10000 test images: 17.240000 %
# This is global 437 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 13.990000 %
# This is global 438 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 16.710000 %
# This is global 439 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 19.900000 %
# This is global 440 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 15.590000 %
# This is global 441 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 19.710000 %
# This is global 442 epoch
#  Average loss 0.173
# Accuracy of the network on the 10000 test images: 17.060000 %
# This is global 443 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 21.560000 %
# This is global 444 epoch
#  Average loss 0.272
# Accuracy of the network on the 10000 test images: 15.600000 %
# This is global 445 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 15.450000 %
# This is global 446 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 18.250000 %
# ...
# This is global 4853 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 69.320000 %
# This is global 4854 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 66.630000 %
# This is global 4855 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 69.130000 %
# This is global 4856 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 66.380000 %
# This is global 4857 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 66.000000 %
# This is global 4858 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4859 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 68.580000 %
# This is global 4860 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 4861 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 68.910000 %
# This is global 4862 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 68.410000 %
# This is global 4863 epoch
#  Average loss 0.103
# Accuracy of the network on the 10000 test images: 64.380000 %
# This is global 4864 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 66.640000 %
# This is global 4865 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 64.750000 %
# This is global 4866 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4867 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 66.800000 %
# This is global 4868 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 64.750000 %
# This is global 4869 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 68.420000 %
# This is global 4870 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 65.580000 %
# This is global 4871 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 65.420000 %
# This is global 4872 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 64.700000 %
# This is global 4873 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 63.660000 %
# This is global 4874 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 66.220000 %
# This is global 4875 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 64.080000 %
# This is global 4876 epoch
#  Average loss 0.138
# Accuracy of the network on the 10000 test images: 70.630000 %
# This is global 4877 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 69.850000 %
# This is global 4878 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 64.420000 %
# This is global 4879 epoch
#  Average loss 0.128
# Accuracy of the network on the 10000 test images: 69.300000 %
# This is global 4880 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 64.810000 %
# This is global 4881 epoch
#  Average loss 0.082
# Accuracy of the network on the 10000 test images: 64.940000 %
# This is global 4882 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 63.310000 %
# This is global 4883 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 69.560000 %
# This is global 4884 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 67.230000 %
# This is global 4885 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 64.640000 %
# This is global 4886 epoch
#  Average loss 0.104
# Accuracy of the network on the 10000 test images: 69.670000 %
# This is global 4887 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 64.820000 %
# This is global 4888 epoch
#  Average loss 0.127
# Accuracy of the network on the 10000 test images: 65.970000 %
# This is global 4889 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 59.080000 %
# This is global 4890 epoch
#  Average loss 0.113
# Accuracy of the network on the 10000 test images: 67.660000 %
# This is global 4891 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 67.490000 %
# This is global 4892 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 4893 epoch
#  Average loss 0.131
# Accuracy of the network on the 10000 test images: 63.470000 %
# This is global 4894 epoch
#  Average loss 0.149
# Accuracy of the network on the 10000 test images: 63.120000 %
# This is global 4895 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4896 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 65.150000 %
# This is global 4897 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 66.390000 %
# This is global 4898 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 67.970000 %
# This is global 4899 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 68.280000 %
# This is global 4900 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 69.150000 %
# This is global 4901 epoch
#  Average loss 0.074
# Accuracy of the network on the 10000 test images: 61.900000 %
# This is global 4902 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 66.900000 %
# This is global 4903 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 46.960000 %
# This is global 4904 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 62.140000 %
# This is global 4905 epoch
#  Average loss 0.141
# Accuracy of the network on the 10000 test images: 64.730000 %
# This is global 4906 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 65.930000 %
# This is global 4907 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 59.080000 %
# This is global 4908 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 62.230000 %
# This is global 4909 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 60.600000 %
# This is global 4910 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 63.880000 %
# This is global 4911 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 66.950000 %
# This is global 4912 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 65.190000 %
# This is global 4913 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 55.700000 %
# This is global 4914 epoch
#  Average loss 0.127
# Accuracy of the network on the 10000 test images: 66.780000 %
# This is global 4915 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 68.660000 %
# This is global 4916 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 69.440000 %
# This is global 4917 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 66.320000 %
# This is global 4918 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 69.030000 %
# This is global 4919 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 64.180000 %
# This is global 4920 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 58.510000 %
# This is global 4921 epoch
#  Average loss 0.127
# Accuracy of the network on the 10000 test images: 60.910000 %
# This is global 4922 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4923 epoch
#  Average loss 0.118
# Accuracy of the network on the 10000 test images: 64.720000 %
# This is global 4924 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 62.750000 %
# This is global 4925 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 61.810000 %
# This is global 4926 epoch
#  Average loss 0.130
# Accuracy of the network on the 10000 test images: 62.780000 %
# This is global 4927 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 67.400000 %
# This is global 4928 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 67.300000 %
# This is global 4929 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 61.670000 %
# This is global 4930 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 61.980000 %
# This is global 4931 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 61.290000 %
# This is global 4932 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 66.630000 %
# This is global 4933 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 65.700000 %
# This is global 4934 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 66.790000 %
# This is global 4935 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 68.340000 %
# This is global 4936 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 66.600000 %
# This is global 4937 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 65.260000 %
# This is global 4938 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 64.820000 %
# This is global 4939 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 56.640000 %
# This is global 4940 epoch
#  Average loss 0.175
# Accuracy of the network on the 10000 test images: 56.650000 %
# This is global 4941 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 61.820000 %
# This is global 4942 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 54.350000 %
# This is global 4943 epoch
#  Average loss 0.135
# Accuracy of the network on the 10000 test images: 68.760000 %
# This is global 4944 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 4945 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 68.040000 %
# This is global 4946 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 66.870000 %
# This is global 4947 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 56.490000 %
# This is global 4948 epoch
#  Average loss 0.113
# Accuracy of the network on the 10000 test images: 66.450000 %
# This is global 4949 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 68.940000 %
# This is global 4950 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 67.120000 %
# This is global 4951 epoch
#  Average loss 0.135
# Accuracy of the network on the 10000 test images: 63.020000 %
# This is global 4952 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 65.140000 %
# This is global 4953 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 65.950000 %
# This is global 4954 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 65.180000 %
# This is global 4955 epoch
#  Average loss 0.083
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 4956 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 66.220000 %
# This is global 4957 epoch
#  Average loss 0.110
# Accuracy of the network on the 10000 test images: 68.950000 %
# This is global 4958 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 70.680000 %
# This is global 4959 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 69.370000 %
# This is global 4960 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 65.020000 %
# This is global 4961 epoch
#  Average loss 0.106
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 4962 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 65.690000 %
# This is global 4963 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 4964 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 67.810000 %
# This is global 4965 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 58.680000 %
# This is global 4966 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4967 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 65.650000 %
# This is global 4968 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 65.320000 %
# This is global 4969 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 64.930000 %
# This is global 4970 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 62.510000 %
# This is global 4971 epoch
#  Average loss 0.097
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 4972 epoch
#  Average loss 0.116
# Accuracy of the network on the 10000 test images: 66.690000 %
# This is global 4973 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 65.750000 %
# This is global 4974 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 64.960000 %
# This is global 4975 epoch
#  Average loss 0.119
# Accuracy of the network on the 10000 test images: 61.350000 %
# This is global 4976 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 67.660000 %
# This is global 4977 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 65.890000 %
# This is global 4978 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 62.770000 %
# This is global 4979 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 67.120000 %
# This is global 4980 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 68.530000 %
# This is global 4981 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 60.010000 %
# This is global 4982 epoch
#  Average loss 0.155
# Accuracy of the network on the 10000 test images: 65.390000 %
# This is global 4983 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 67.200000 %
# This is global 4984 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 66.320000 %
# This is global 4985 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 65.340000 %
# This is global 4986 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4987 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 67.120000 %
# This is global 4988 epoch
#  Average loss 0.124
# Accuracy of the network on the 10000 test images: 67.410000 %
# This is global 4989 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 67.660000 %
# This is global 4990 epoch
#  Average loss 0.064
# Accuracy of the network on the 10000 test images: 68.450000 %
# This is global 4991 epoch
#  Average loss 0.120
# Accuracy of the network on the 10000 test images: 56.190000 %
# This is global 4992 epoch
#  Average loss 0.155
# Accuracy of the network on the 10000 test images: 64.780000 %
# This is global 4993 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 65.420000 %
# This is global 4994 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 67.470000 %
# This is global 4995 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 69.280000 %
# This is global 4996 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 67.910000 %
# This is global 4997 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 4998 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 67.130000 %
# This is global 4999 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 61.900000 %
# This is global 5000 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 68.170000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_noniid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %%
print(max(acc_train))
# Out:
# 70.68
