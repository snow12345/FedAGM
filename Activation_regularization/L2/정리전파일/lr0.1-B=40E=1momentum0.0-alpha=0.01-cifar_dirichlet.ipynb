# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="1"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=1
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
def cifar_dirichlet(dataset, n_nets, alpha=0.5):
    '''
    if dataset == 'mnist':
        X_train, y_train, X_test, y_test = load_mnist_data(datadir)
    elif dataset == 'cifar10':
        X_train, y_train, X_test, y_test = load_cifar10_data(datadir)
    '''
    #X_train=dataset[:][0]
    y_train=torch.zeros(len(dataset),dtype=torch.long)
    print(y_train.dtype)
    for a in range(len(dataset)):
        y_train[a]=(dataset[a][1])
    n_train = len(dataset)
    #X_train.shape[0]
    '''
    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_nets)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_nets)}
    '''
    #elif partition == "hetero-dir":
    min_size = 0
    K = 10
    N=len(dataset)
    N = y_train.shape[0]
    net_dataidx_map = {i: np.array([],dtype='int64') for i in range(n_nets)}

    while min_size < 10:
        idx_batch = [[] for _ in range(n_nets)]
        for k in range(K):
            idx_k = np.where(y_train == k)[0]
            np.random.shuffle(idx_k)
            proportions = np.random.dirichlet(np.repeat(alpha, n_nets))
            ## Balance
            proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
            proportions = proportions/proportions.sum()
            proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
            idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
            min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    #traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    return net_dataidx_map
    #return (X_train, y_train, X_test, y_test, net_dataidx_map, traindata_cls_counts)

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        
        
        
        self.conv1_global = nn.Conv2d(3, 32, 3)
        self.pool_global = nn.MaxPool2d(2, 2)
        self.conv2_global = nn.Conv2d(32, 64, 3)
        self.conv3_global = nn.Conv2d(64, 64, 3)
        self.fc1_global = nn.Linear(64 * 4 * 4, 64)
        self.fc2_global = nn.Linear(64, 10)
        self.freeze_model_global_weights()
        
        self.mse=nn.MSELoss()
        #self.fc3 = nn.Linear(84, 10)
    def freeze_model_global_weights(self):
        for n, m in self.named_modules():
            if hasattr(m, "weight") and m.weight is not None and 'global' in n:
                print(f"==> No gradient to {n}.weight")
                m.weight.requires_grad = False
                if m.weight.grad is not None:
                    print(f"==> Setting gradient of {n}.weight to None")
                    m.weight.grad = None

                if hasattr(m, "bias") and m.bias is not None and 'global' in n:
                    print(f"==> No gradient to {n}.bias")
                    m.bias.requires_grad = False

                    if m.bias.grad is not None:
                        print(f"==> Setting gradient of {n}.bias to None")
                        m.bias.grad = None
    def sync_online_and_global(self):
        state_dict=self.state_dict()
        for key in state_dict:
            if 'global' in key:
                x=(key.split("_global"))
                online=(x[0]+x[1])
                state_dict[key]=state_dict[online]
        self.load_state_dict(state_dict)
        
        
        
    def forward(self, x,online_target=False):
        if online_target==False:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = (F.relu(self.conv3(x)))
            x = x.view(-1, 64*4*4)
            x = F.relu(self.fc1(x))
            x = (self.fc2(x))
            return x
        else:
            x1=copy.deepcopy(x)
            
            
            x = self.pool(F.relu(self.conv1(x)))
            x1 = self.pool_global(F.relu(self.conv1_global(x1)))
            diff=self.mse(x,x1)
            
            x = self.pool(F.relu(self.conv2(x)))
            x1 = self.pool_global(F.relu(self.conv2_global(x1)))
            diff+=self.mse(x,x1)
            
            
            x = (F.relu(self.conv3(x)))
            x1 = (F.relu(self.conv3_global(x1)))
            diff+=self.mse(x,x1)
            
            x = x.view(-1, 64*4*4)
            x1 = x1.view(-1, 64*4*4)
            
            x = F.relu(self.fc1(x))
            x1 = F.relu(self.fc1_global(x1))
            diff+=self.mse(x,x1)
            
            
            x = (self.fc2(x))
            x1 = (self.fc2_global(x1))
            diff+=self.mse(x,x1)
            
            
            return x,diff

# %%
net = Net()
net.to(device)
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
#   (conv1_global): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool_global): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_global): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_global): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1_global): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2_global): Linear(in_features=64, out_features=10, bias=True)
#   (mse): MSELoss()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01,momentum=0.5)
loss_train = []
acc_train=[]

# %%
for epoch in range(0):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    for i, data in enumerate(CIFAR_SGD_trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(labels)

        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
       
        
    if epoch%1==0:
        loss_train.append(loss)
        print(f"epoch: {epoch}")
        print(' Average loss {:.3f}'.format( loss))
        for j in range(1):
            net.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %d %%' % (
                100 * correct / total))
        acc_train.append(100 * correct / total)

    net.train()

    '''# 통계를 출력합니다.
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0'''

print('Finished Training')
# Out:
# Finished Training

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# /home/dana/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Accuracy of the network on the 10000 test images: 10 %

# %%
class LocalUpdate(object):
    def __init__(self, lr,local_epoch,device,batch_size, dataset=None, idxs=None,alpha=0.01):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.alpha=alpha

    def train(self, net):
        net.sync_online_and_global()
        net.train()
        # train and update
        optimizer = torch.optim.SGD(net.parameters(), lr=self.lr)

        epoch_loss = []
        for iter in range(self.local_epoch):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs,activation_l2 = net(images,online_target=True)
                loss = self.loss_func(log_probs, labels)+self.alpha*activation_l2
                loss.backward()
                optimizer.step()
                #if batch_idx % 10 == 0:
                #    print('Update Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #        iter, batch_idx * len(images), len(self.ldr_train.dataset),
                #               100. * batch_idx / len(self.ldr_train), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        return net.state_dict(), sum(epoch_loss) / len(epoch_loss)

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=0
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_iid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
CIFAR_noniid_dataset=cifar_dirichlet(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]
# Out:
# torch.int64

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 1.626
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 2 epoch
#  Average loss 1.662
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 3 epoch
#  Average loss 1.623
# Accuracy of the network on the 10000 test images: 15.750000 %
# This is global 4 epoch
#  Average loss 1.952
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 5 epoch
#  Average loss 1.763
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 6 epoch
#  Average loss 1.736
# Accuracy of the network on the 10000 test images: 16.720000 %
# This is global 7 epoch
#  Average loss 1.770
# Accuracy of the network on the 10000 test images: 13.150000 %
# This is global 8 epoch
#  Average loss 1.698
# Accuracy of the network on the 10000 test images: 11.650000 %
# This is global 9 epoch
#  Average loss 1.666
# Accuracy of the network on the 10000 test images: 14.350000 %
# This is global 10 epoch
#  Average loss 1.658
# Accuracy of the network on the 10000 test images: 16.880000 %
# This is global 11 epoch
#  Average loss 1.702
# Accuracy of the network on the 10000 test images: 20.550000 %
# This is global 12 epoch
#  Average loss 1.636
# Accuracy of the network on the 10000 test images: 19.890000 %
# This is global 13 epoch
#  Average loss 1.382
# Accuracy of the network on the 10000 test images: 18.780000 %
# This is global 14 epoch
#  Average loss 1.267
# Accuracy of the network on the 10000 test images: 15.700000 %
# This is global 15 epoch
#  Average loss 1.506
# Accuracy of the network on the 10000 test images: 15.250000 %
# This is global 16 epoch
#  Average loss 1.577
# Accuracy of the network on the 10000 test images: 24.510000 %
# This is global 17 epoch
#  Average loss 1.467
# Accuracy of the network on the 10000 test images: 22.920000 %
# This is global 18 epoch
#  Average loss 1.815
# Accuracy of the network on the 10000 test images: 17.060000 %
# This is global 19 epoch
#  Average loss 1.705
# Accuracy of the network on the 10000 test images: 24.420000 %
# This is global 20 epoch
#  Average loss 1.674
# Accuracy of the network on the 10000 test images: 25.340000 %
# This is global 21 epoch
#  Average loss 1.475
# Accuracy of the network on the 10000 test images: 25.740000 %
# This is global 22 epoch
#  Average loss 1.378
# Accuracy of the network on the 10000 test images: 17.540000 %
# This is global 23 epoch
#  Average loss 1.496
# Accuracy of the network on the 10000 test images: 25.940000 %
# This is global 24 epoch
#  Average loss 1.329
# Accuracy of the network on the 10000 test images: 24.630000 %
# This is global 25 epoch
#  Average loss 1.501
# Accuracy of the network on the 10000 test images: 26.380000 %
# This is global 26 epoch
#  Average loss 1.405
# Accuracy of the network on the 10000 test images: 27.700000 %
# This is global 27 epoch
#  Average loss 1.498
# Accuracy of the network on the 10000 test images: 28.250000 %
# This is global 28 epoch
#  Average loss 1.502
# Accuracy of the network on the 10000 test images: 25.110000 %
# This is global 29 epoch
#  Average loss 1.482
# Accuracy of the network on the 10000 test images: 29.610000 %
# This is global 30 epoch
#  Average loss 1.524
# Accuracy of the network on the 10000 test images: 29.620000 %
# This is global 31 epoch
#  Average loss 1.360
# Accuracy of the network on the 10000 test images: 28.080000 %
# This is global 32 epoch
#  Average loss 1.316
# Accuracy of the network on the 10000 test images: 29.150000 %
# This is global 33 epoch
#  Average loss 1.382
# Accuracy of the network on the 10000 test images: 32.480000 %
# This is global 34 epoch
#  Average loss 1.283
# Accuracy of the network on the 10000 test images: 32.320000 %
# This is global 35 epoch
#  Average loss 1.368
# Accuracy of the network on the 10000 test images: 33.850000 %
# This is global 36 epoch
#  Average loss 1.192
# Accuracy of the network on the 10000 test images: 34.080000 %
# This is global 37 epoch
#  Average loss 1.375
# Accuracy of the network on the 10000 test images: 35.110000 %
# This is global 38 epoch
#  Average loss 1.329
# Accuracy of the network on the 10000 test images: 35.410000 %
# This is global 39 epoch
#  Average loss 1.368
# Accuracy of the network on the 10000 test images: 29.470000 %
# This is global 40 epoch
#  Average loss 1.292
# Accuracy of the network on the 10000 test images: 36.630000 %
# This is global 41 epoch
#  Average loss 1.319
# Accuracy of the network on the 10000 test images: 34.550000 %
# This is global 42 epoch
#  Average loss 1.261
# Accuracy of the network on the 10000 test images: 34.880000 %
# This is global 43 epoch
#  Average loss 1.246
# Accuracy of the network on the 10000 test images: 32.970000 %
# This is global 44 epoch
#  Average loss 1.253
# Accuracy of the network on the 10000 test images: 28.940000 %
# This is global 45 epoch
#  Average loss 1.186
# Accuracy of the network on the 10000 test images: 35.830000 %
# This is global 46 epoch
#  Average loss 1.299
# Accuracy of the network on the 10000 test images: 35.210000 %
# This is global 47 epoch
#  Average loss 1.290
# Accuracy of the network on the 10000 test images: 33.480000 %
# This is global 48 epoch
#  Average loss 1.275
# Accuracy of the network on the 10000 test images: 41.010000 %
# This is global 49 epoch
#  Average loss 1.298
# Accuracy of the network on the 10000 test images: 35.910000 %
# This is global 50 epoch
#  Average loss 1.265
# Accuracy of the network on the 10000 test images: 38.070000 %
# This is global 51 epoch
#  Average loss 1.130
# Accuracy of the network on the 10000 test images: 34.190000 %
# This is global 52 epoch
#  Average loss 1.087
# Accuracy of the network on the 10000 test images: 36.230000 %
# This is global 53 epoch
#  Average loss 1.161
# Accuracy of the network on the 10000 test images: 29.300000 %
# This is global 54 epoch
#  Average loss 1.321
# Accuracy of the network on the 10000 test images: 36.040000 %
# This is global 55 epoch
#  Average loss 1.335
# Accuracy of the network on the 10000 test images: 39.230000 %
# This is global 56 epoch
#  Average loss 1.193
# Accuracy of the network on the 10000 test images: 40.690000 %
# This is global 57 epoch
#  Average loss 1.219
# Accuracy of the network on the 10000 test images: 42.920000 %
# This is global 58 epoch
#  Average loss 1.231
# Accuracy of the network on the 10000 test images: 41.130000 %
# This is global 59 epoch
#  Average loss 1.036
# Accuracy of the network on the 10000 test images: 39.610000 %
# This is global 60 epoch
#  Average loss 1.177
# Accuracy of the network on the 10000 test images: 33.150000 %
# This is global 61 epoch
#  Average loss 1.229
# Accuracy of the network on the 10000 test images: 39.670000 %
# This is global 62 epoch
#  Average loss 1.141
# Accuracy of the network on the 10000 test images: 43.300000 %
# This is global 63 epoch
#  Average loss 1.016
# Accuracy of the network on the 10000 test images: 39.830000 %
# This is global 64 epoch
#  Average loss 1.143
# Accuracy of the network on the 10000 test images: 40.530000 %
# This is global 65 epoch
#  Average loss 1.101
# Accuracy of the network on the 10000 test images: 38.800000 %
# This is global 66 epoch
#  Average loss 1.256
# Accuracy of the network on the 10000 test images: 41.570000 %
# This is global 67 epoch
#  Average loss 1.050
# Accuracy of the network on the 10000 test images: 42.450000 %
# This is global 68 epoch
#  Average loss 1.103
# Accuracy of the network on the 10000 test images: 41.440000 %
# This is global 69 epoch
#  Average loss 1.190
# Accuracy of the network on the 10000 test images: 39.430000 %
# This is global 70 epoch
#  Average loss 1.250
# Accuracy of the network on the 10000 test images: 42.380000 %
# This is global 71 epoch
#  Average loss 1.145
# Accuracy of the network on the 10000 test images: 42.900000 %
# This is global 72 epoch
#  Average loss 1.052
# Accuracy of the network on the 10000 test images: 38.520000 %
# This is global 73 epoch
#  Average loss 1.014
# Accuracy of the network on the 10000 test images: 37.490000 %
# This is global 74 epoch
#  Average loss 1.066
# Accuracy of the network on the 10000 test images: 42.910000 %
# This is global 75 epoch
#  Average loss 1.010
# Accuracy of the network on the 10000 test images: 41.270000 %
# This is global 76 epoch
#  Average loss 1.108
# Accuracy of the network on the 10000 test images: 45.210000 %
# This is global 77 epoch
#  Average loss 1.029
# Accuracy of the network on the 10000 test images: 43.600000 %
# This is global 78 epoch
#  Average loss 1.156
# Accuracy of the network on the 10000 test images: 43.080000 %
# This is global 79 epoch
#  Average loss 1.155
# Accuracy of the network on the 10000 test images: 38.750000 %
# This is global 80 epoch
#  Average loss 1.048
# Accuracy of the network on the 10000 test images: 35.950000 %
# This is global 81 epoch
#  Average loss 1.093
# Accuracy of the network on the 10000 test images: 37.640000 %
# This is global 82 epoch
#  Average loss 0.935
# Accuracy of the network on the 10000 test images: 43.820000 %
# This is global 83 epoch
#  Average loss 0.919
# Accuracy of the network on the 10000 test images: 40.500000 %
# This is global 84 epoch
#  Average loss 1.024
# Accuracy of the network on the 10000 test images: 43.110000 %
# This is global 85 epoch
#  Average loss 1.085
# Accuracy of the network on the 10000 test images: 45.890000 %
# This is global 86 epoch
#  Average loss 1.103
# Accuracy of the network on the 10000 test images: 44.750000 %
# This is global 87 epoch
#  Average loss 1.147
# Accuracy of the network on the 10000 test images: 45.290000 %
# This is global 88 epoch
#  Average loss 1.110
# Accuracy of the network on the 10000 test images: 29.480000 %
# This is global 89 epoch
#  Average loss 0.928
# Accuracy of the network on the 10000 test images: 41.050000 %
# This is global 90 epoch
#  Average loss 1.095
# Accuracy of the network on the 10000 test images: 47.900000 %
# This is global 91 epoch
#  Average loss 0.867
# Accuracy of the network on the 10000 test images: 43.450000 %
# This is global 92 epoch
#  Average loss 1.153
# Accuracy of the network on the 10000 test images: 46.420000 %
# This is global 93 epoch
#  Average loss 1.061
# Accuracy of the network on the 10000 test images: 44.010000 %
# This is global 94 epoch
#  Average loss 1.148
# Accuracy of the network on the 10000 test images: 42.590000 %
# This is global 95 epoch
#  Average loss 0.973
# Accuracy of the network on the 10000 test images: 46.830000 %
# This is global 96 epoch
#  Average loss 1.052
# Accuracy of the network on the 10000 test images: 48.180000 %
# This is global 97 epoch
#  Average loss 1.010
# Accuracy of the network on the 10000 test images: 41.650000 %
# This is global 98 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 45.490000 %
# This is global 99 epoch
#  Average loss 0.951
# Accuracy of the network on the 10000 test images: 49.500000 %
# This is global 100 epoch
#  Average loss 1.126
# Accuracy of the network on the 10000 test images: 49.500000 %
# This is global 101 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 45.050000 %
# This is global 102 epoch
#  Average loss 1.135
# Accuracy of the network on the 10000 test images: 47.100000 %
# This is global 103 epoch
#  Average loss 1.004
# Accuracy of the network on the 10000 test images: 50.390000 %
# This is global 104 epoch
#  Average loss 0.929
# Accuracy of the network on the 10000 test images: 52.010000 %
# This is global 105 epoch
#  Average loss 0.973
# Accuracy of the network on the 10000 test images: 48.890000 %
# This is global 106 epoch
#  Average loss 1.045
# Accuracy of the network on the 10000 test images: 45.200000 %
# This is global 107 epoch
#  Average loss 1.021
# Accuracy of the network on the 10000 test images: 36.180000 %
# This is global 108 epoch
#  Average loss 1.004
# Accuracy of the network on the 10000 test images: 46.580000 %
# This is global 109 epoch
#  Average loss 1.055
# Accuracy of the network on the 10000 test images: 48.480000 %
# This is global 110 epoch
#  Average loss 1.044
# Accuracy of the network on the 10000 test images: 46.480000 %
# This is global 111 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 43.650000 %
# This is global 112 epoch
#  Average loss 1.059
# Accuracy of the network on the 10000 test images: 45.950000 %
# This is global 113 epoch
#  Average loss 0.982
# Accuracy of the network on the 10000 test images: 45.440000 %
# This is global 114 epoch
#  Average loss 0.870
# Accuracy of the network on the 10000 test images: 50.710000 %
# This is global 115 epoch
#  Average loss 0.961
# Accuracy of the network on the 10000 test images: 53.360000 %
# This is global 116 epoch
#  Average loss 0.886
# Accuracy of the network on the 10000 test images: 50.800000 %
# This is global 117 epoch
#  Average loss 1.151
# Accuracy of the network on the 10000 test images: 41.100000 %
# This is global 118 epoch
#  Average loss 0.903
# Accuracy of the network on the 10000 test images: 49.960000 %
# This is global 119 epoch
#  Average loss 1.069
# Accuracy of the network on the 10000 test images: 44.200000 %
# This is global 120 epoch
#  Average loss 0.945
# Accuracy of the network on the 10000 test images: 43.100000 %
# This is global 121 epoch
#  Average loss 0.933
# Accuracy of the network on the 10000 test images: 45.230000 %
# This is global 122 epoch
#  Average loss 1.012
# Accuracy of the network on the 10000 test images: 51.900000 %
# This is global 123 epoch
#  Average loss 0.917
# Accuracy of the network on the 10000 test images: 52.750000 %
# This is global 124 epoch
#  Average loss 0.831
# Accuracy of the network on the 10000 test images: 50.080000 %
# This is global 125 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 50.340000 %
# This is global 126 epoch
#  Average loss 0.975
# Accuracy of the network on the 10000 test images: 49.400000 %
# This is global 127 epoch
#  Average loss 0.923
# Accuracy of the network on the 10000 test images: 45.250000 %
# This is global 128 epoch
#  Average loss 0.885
# Accuracy of the network on the 10000 test images: 52.880000 %
# This is global 129 epoch
#  Average loss 0.971
# Accuracy of the network on the 10000 test images: 47.770000 %
# This is global 130 epoch
#  Average loss 0.836
# Accuracy of the network on the 10000 test images: 50.450000 %
# This is global 131 epoch
#  Average loss 0.830
# Accuracy of the network on the 10000 test images: 43.420000 %
# This is global 132 epoch
#  Average loss 1.139
# Accuracy of the network on the 10000 test images: 50.440000 %
# This is global 133 epoch
#  Average loss 0.862
# Accuracy of the network on the 10000 test images: 48.260000 %
# This is global 134 epoch
#  Average loss 1.116
# Accuracy of the network on the 10000 test images: 50.400000 %
# This is global 135 epoch
#  Average loss 0.931
# Accuracy of the network on the 10000 test images: 52.980000 %
# This is global 136 epoch
#  Average loss 0.880
# Accuracy of the network on the 10000 test images: 54.600000 %
# This is global 137 epoch
#  Average loss 0.818
# Accuracy of the network on the 10000 test images: 52.510000 %
# This is global 138 epoch
#  Average loss 1.049
# Accuracy of the network on the 10000 test images: 55.420000 %
# This is global 139 epoch
#  Average loss 0.727
# Accuracy of the network on the 10000 test images: 52.190000 %
# This is global 140 epoch
#  Average loss 0.947
# Accuracy of the network on the 10000 test images: 55.490000 %
# This is global 141 epoch
#  Average loss 0.931
# Accuracy of the network on the 10000 test images: 53.870000 %
# This is global 142 epoch
#  Average loss 0.845
# Accuracy of the network on the 10000 test images: 47.390000 %
# This is global 143 epoch
#  Average loss 0.916
# Accuracy of the network on the 10000 test images: 52.340000 %
# This is global 144 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 42.960000 %
# This is global 145 epoch
#  Average loss 0.863
# Accuracy of the network on the 10000 test images: 49.880000 %
# This is global 146 epoch
#  Average loss 0.730
# Accuracy of the network on the 10000 test images: 51.550000 %
# This is global 147 epoch
#  Average loss 0.778
# Accuracy of the network on the 10000 test images: 52.880000 %
# This is global 148 epoch
#  Average loss 0.828
# Accuracy of the network on the 10000 test images: 44.360000 %
# This is global 149 epoch
#  Average loss 0.857
# Accuracy of the network on the 10000 test images: 53.710000 %
# This is global 150 epoch
#  Average loss 0.954
# Accuracy of the network on the 10000 test images: 52.600000 %
# This is global 151 epoch
#  Average loss 1.035
# Accuracy of the network on the 10000 test images: 53.850000 %
# This is global 152 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 54.750000 %
# This is global 153 epoch
#  Average loss 1.055
# Accuracy of the network on the 10000 test images: 54.450000 %
# This is global 154 epoch
#  Average loss 0.816
# Accuracy of the network on the 10000 test images: 44.600000 %
# This is global 155 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 48.360000 %
# This is global 156 epoch
#  Average loss 1.034
# Accuracy of the network on the 10000 test images: 51.530000 %
# This is global 157 epoch
#  Average loss 1.066
# Accuracy of the network on the 10000 test images: 53.920000 %
# This is global 158 epoch
#  Average loss 0.967
# Accuracy of the network on the 10000 test images: 56.510000 %
# This is global 159 epoch
#  Average loss 0.910
# Accuracy of the network on the 10000 test images: 53.210000 %
# This is global 160 epoch
#  Average loss 0.946
# Accuracy of the network on the 10000 test images: 52.570000 %
# This is global 161 epoch
#  Average loss 0.794
# Accuracy of the network on the 10000 test images: 52.160000 %
# This is global 162 epoch
#  Average loss 0.698
# Accuracy of the network on the 10000 test images: 52.210000 %
# This is global 163 epoch
#  Average loss 0.859
# Accuracy of the network on the 10000 test images: 53.280000 %
# This is global 164 epoch
#  Average loss 1.000
# Accuracy of the network on the 10000 test images: 55.610000 %
# This is global 165 epoch
#  Average loss 0.919
# Accuracy of the network on the 10000 test images: 52.610000 %
# This is global 166 epoch
#  Average loss 0.945
# Accuracy of the network on the 10000 test images: 57.400000 %
# This is global 167 epoch
#  Average loss 0.748
# Accuracy of the network on the 10000 test images: 55.010000 %
# This is global 168 epoch
#  Average loss 0.897
# Accuracy of the network on the 10000 test images: 52.910000 %
# This is global 169 epoch
#  Average loss 0.861
# Accuracy of the network on the 10000 test images: 55.980000 %
# This is global 170 epoch
#  Average loss 0.769
# Accuracy of the network on the 10000 test images: 53.900000 %
# This is global 171 epoch
#  Average loss 0.840
# Accuracy of the network on the 10000 test images: 56.870000 %
# This is global 172 epoch
#  Average loss 0.872
# Accuracy of the network on the 10000 test images: 53.840000 %
# This is global 173 epoch
#  Average loss 0.914
# Accuracy of the network on the 10000 test images: 54.650000 %
# This is global 174 epoch
#  Average loss 0.930
# Accuracy of the network on the 10000 test images: 57.610000 %
# This is global 175 epoch
#  Average loss 0.743
# Accuracy of the network on the 10000 test images: 58.270000 %
# This is global 176 epoch
#  Average loss 0.969
# Accuracy of the network on the 10000 test images: 56.960000 %
# This is global 177 epoch
#  Average loss 0.850
# Accuracy of the network on the 10000 test images: 54.050000 %
# This is global 178 epoch
#  Average loss 0.830
# Accuracy of the network on the 10000 test images: 55.330000 %
# This is global 179 epoch
#  Average loss 0.985
# Accuracy of the network on the 10000 test images: 55.720000 %
# This is global 180 epoch
#  Average loss 0.886
# Accuracy of the network on the 10000 test images: 56.200000 %
# This is global 181 epoch
#  Average loss 0.749
# Accuracy of the network on the 10000 test images: 52.390000 %
# This is global 182 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 56.710000 %
# This is global 183 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 56.020000 %
# This is global 184 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 57.630000 %
# This is global 185 epoch
#  Average loss 0.931
# Accuracy of the network on the 10000 test images: 57.600000 %
# This is global 186 epoch
#  Average loss 0.919
# Accuracy of the network on the 10000 test images: 51.670000 %
# This is global 187 epoch
#  Average loss 0.832
# Accuracy of the network on the 10000 test images: 59.840000 %
# This is global 188 epoch
#  Average loss 0.789
# Accuracy of the network on the 10000 test images: 47.200000 %
# This is global 189 epoch
#  Average loss 1.009
# Accuracy of the network on the 10000 test images: 52.250000 %
# This is global 190 epoch
#  Average loss 0.824
# Accuracy of the network on the 10000 test images: 48.660000 %
# This is global 191 epoch
#  Average loss 0.845
# Accuracy of the network on the 10000 test images: 58.250000 %
# This is global 192 epoch
#  Average loss 0.751
# Accuracy of the network on the 10000 test images: 57.900000 %
# This is global 193 epoch
#  Average loss 0.674
# Accuracy of the network on the 10000 test images: 50.730000 %
# This is global 194 epoch
#  Average loss 0.706
# Accuracy of the network on the 10000 test images: 48.110000 %
# This is global 195 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 50.830000 %
# This is global 196 epoch
#  Average loss 0.778
# Accuracy of the network on the 10000 test images: 59.010000 %
# This is global 197 epoch
#  Average loss 0.875
# Accuracy of the network on the 10000 test images: 50.280000 %
# This is global 198 epoch
#  Average loss 0.709
# Accuracy of the network on the 10000 test images: 56.070000 %
# This is global 199 epoch
#  Average loss 0.842
# Accuracy of the network on the 10000 test images: 55.970000 %
# This is global 200 epoch
#  Average loss 0.796
# Accuracy of the network on the 10000 test images: 57.510000 %
# This is global 201 epoch
#  Average loss 0.820
# Accuracy of the network on the 10000 test images: 55.720000 %
# This is global 202 epoch
#  Average loss 0.867
# Accuracy of the network on the 10000 test images: 48.750000 %
# This is global 203 epoch
#  Average loss 0.766
# Accuracy of the network on the 10000 test images: 59.890000 %
# This is global 204 epoch
#  Average loss 0.946
# Accuracy of the network on the 10000 test images: 58.250000 %
# This is global 205 epoch
#  Average loss 0.782
# Accuracy of the network on the 10000 test images: 58.850000 %
# This is global 206 epoch
#  Average loss 0.777
# Accuracy of the network on the 10000 test images: 53.070000 %
# This is global 207 epoch
#  Average loss 0.878
# Accuracy of the network on the 10000 test images: 56.470000 %
# This is global 208 epoch
#  Average loss 0.809
# Accuracy of the network on the 10000 test images: 49.900000 %
# This is global 209 epoch
#  Average loss 0.830
# Accuracy of the network on the 10000 test images: 57.950000 %
# This is global 210 epoch
#  Average loss 0.803
# Accuracy of the network on the 10000 test images: 51.550000 %
# This is global 211 epoch
#  Average loss 0.801
# Accuracy of the network on the 10000 test images: 58.400000 %
# This is global 212 epoch
#  Average loss 0.842
# Accuracy of the network on the 10000 test images: 59.630000 %
# This is global 213 epoch
#  Average loss 0.705
# Accuracy of the network on the 10000 test images: 59.700000 %
# This is global 214 epoch
#  Average loss 0.814
# Accuracy of the network on the 10000 test images: 57.850000 %
# This is global 215 epoch
#  Average loss 0.758
# Accuracy of the network on the 10000 test images: 60.130000 %
# This is global 216 epoch
#  Average loss 0.830
# Accuracy of the network on the 10000 test images: 53.580000 %
# This is global 217 epoch
#  Average loss 0.816
# Accuracy of the network on the 10000 test images: 59.030000 %
# This is global 218 epoch
#  Average loss 0.672
# Accuracy of the network on the 10000 test images: 58.720000 %
# This is global 219 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 59.450000 %
# This is global 220 epoch
#  Average loss 0.684
# Accuracy of the network on the 10000 test images: 57.140000 %
# This is global 221 epoch
#  Average loss 0.683
# Accuracy of the network on the 10000 test images: 60.000000 %
# This is global 222 epoch
#  Average loss 0.700
# Accuracy of the network on the 10000 test images: 59.140000 %
# This is global 223 epoch
#  Average loss 0.856
# Accuracy of the network on the 10000 test images: 58.370000 %
# This is global 224 epoch
#  Average loss 0.801
# Accuracy of the network on the 10000 test images: 58.890000 %
# This is global 225 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 60.700000 %
# This is global 226 epoch
#  Average loss 0.722
# Accuracy of the network on the 10000 test images: 51.030000 %
# This is global 227 epoch
#  Average loss 0.747
# Accuracy of the network on the 10000 test images: 56.480000 %
# This is global 228 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 51.720000 %
# This is global 229 epoch
#  Average loss 0.709
# Accuracy of the network on the 10000 test images: 59.070000 %
# This is global 230 epoch
#  Average loss 0.684
# Accuracy of the network on the 10000 test images: 60.790000 %
# This is global 231 epoch
#  Average loss 0.825
# Accuracy of the network on the 10000 test images: 61.080000 %
# This is global 232 epoch
#  Average loss 0.782
# Accuracy of the network on the 10000 test images: 58.400000 %
# This is global 233 epoch
#  Average loss 0.683
# Accuracy of the network on the 10000 test images: 56.970000 %
# This is global 234 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 57.270000 %
# This is global 235 epoch
#  Average loss 0.790
# Accuracy of the network on the 10000 test images: 58.560000 %
# This is global 236 epoch
#  Average loss 0.763
# Accuracy of the network on the 10000 test images: 62.560000 %
# This is global 237 epoch
#  Average loss 0.828
# Accuracy of the network on the 10000 test images: 60.940000 %
# This is global 238 epoch
#  Average loss 0.695
# Accuracy of the network on the 10000 test images: 58.820000 %
# This is global 239 epoch
#  Average loss 0.788
# Accuracy of the network on the 10000 test images: 58.210000 %
# This is global 240 epoch
#  Average loss 0.739
# Accuracy of the network on the 10000 test images: 62.580000 %
# This is global 241 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 60.460000 %
# This is global 242 epoch
#  Average loss 0.630
# Accuracy of the network on the 10000 test images: 60.550000 %
# This is global 243 epoch
#  Average loss 0.695
# Accuracy of the network on the 10000 test images: 61.620000 %
# This is global 244 epoch
#  Average loss 0.780
# Accuracy of the network on the 10000 test images: 56.590000 %
# This is global 245 epoch
#  Average loss 0.825
# Accuracy of the network on the 10000 test images: 56.800000 %
# This is global 246 epoch
#  Average loss 0.653
# Accuracy of the network on the 10000 test images: 62.160000 %
# This is global 247 epoch
#  Average loss 0.670
# Accuracy of the network on the 10000 test images: 58.330000 %
# This is global 248 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 61.410000 %
# This is global 249 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 58.160000 %
# This is global 250 epoch
#  Average loss 0.664
# Accuracy of the network on the 10000 test images: 62.580000 %
# This is global 251 epoch
#  Average loss 0.643
# Accuracy of the network on the 10000 test images: 60.610000 %
# This is global 252 epoch
#  Average loss 0.751
# Accuracy of the network on the 10000 test images: 60.640000 %
# This is global 253 epoch
#  Average loss 0.764
# Accuracy of the network on the 10000 test images: 58.420000 %
# This is global 254 epoch
#  Average loss 0.854
# Accuracy of the network on the 10000 test images: 60.310000 %
# This is global 255 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 62.270000 %
# This is global 256 epoch
#  Average loss 0.688
# Accuracy of the network on the 10000 test images: 63.350000 %
# This is global 257 epoch
#  Average loss 0.781
# Accuracy of the network on the 10000 test images: 61.010000 %
# This is global 258 epoch
#  Average loss 0.656
# Accuracy of the network on the 10000 test images: 61.210000 %
# This is global 259 epoch
#  Average loss 0.670
# Accuracy of the network on the 10000 test images: 59.880000 %
# This is global 260 epoch
#  Average loss 0.846
# Accuracy of the network on the 10000 test images: 59.350000 %
# This is global 261 epoch
#  Average loss 0.471
# Accuracy of the network on the 10000 test images: 55.020000 %
# This is global 262 epoch
#  Average loss 0.723
# Accuracy of the network on the 10000 test images: 57.820000 %
# This is global 263 epoch
#  Average loss 0.812
# Accuracy of the network on the 10000 test images: 64.190000 %
# This is global 264 epoch
#  Average loss 0.581
# Accuracy of the network on the 10000 test images: 61.440000 %
# This is global 265 epoch
#  Average loss 0.528
# Accuracy of the network on the 10000 test images: 57.560000 %
# This is global 266 epoch
#  Average loss 0.754
# Accuracy of the network on the 10000 test images: 60.770000 %
# This is global 267 epoch
#  Average loss 0.653
# Accuracy of the network on the 10000 test images: 60.720000 %
# This is global 268 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 61.800000 %
# This is global 269 epoch
#  Average loss 0.713
# Accuracy of the network on the 10000 test images: 63.730000 %
# This is global 270 epoch
#  Average loss 0.716
# Accuracy of the network on the 10000 test images: 57.150000 %
# This is global 271 epoch
#  Average loss 0.686
# Accuracy of the network on the 10000 test images: 57.630000 %
# This is global 272 epoch
#  Average loss 0.588
# Accuracy of the network on the 10000 test images: 60.760000 %
# This is global 273 epoch
#  Average loss 0.822
# Accuracy of the network on the 10000 test images: 60.520000 %
# This is global 274 epoch
#  Average loss 0.693
# Accuracy of the network on the 10000 test images: 60.810000 %
# This is global 275 epoch
#  Average loss 0.567
# Accuracy of the network on the 10000 test images: 59.740000 %
# This is global 276 epoch
#  Average loss 0.761
# Accuracy of the network on the 10000 test images: 56.640000 %
# This is global 277 epoch
#  Average loss 0.838
# Accuracy of the network on the 10000 test images: 61.050000 %
# This is global 278 epoch
#  Average loss 0.691
# Accuracy of the network on the 10000 test images: 61.150000 %
# This is global 279 epoch
#  Average loss 0.564
# Accuracy of the network on the 10000 test images: 55.490000 %
# This is global 280 epoch
#  Average loss 0.840
# Accuracy of the network on the 10000 test images: 64.700000 %
# This is global 281 epoch
#  Average loss 0.586
# Accuracy of the network on the 10000 test images: 63.200000 %
# This is global 282 epoch
#  Average loss 0.665
# Accuracy of the network on the 10000 test images: 62.230000 %
# This is global 283 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 63.760000 %
# This is global 284 epoch
#  Average loss 0.779
# Accuracy of the network on the 10000 test images: 61.470000 %
# This is global 285 epoch
#  Average loss 0.755
# Accuracy of the network on the 10000 test images: 61.010000 %
# This is global 286 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 64.110000 %
# This is global 287 epoch
#  Average loss 0.678
# Accuracy of the network on the 10000 test images: 64.380000 %
# This is global 288 epoch
#  Average loss 0.699
# Accuracy of the network on the 10000 test images: 62.610000 %
# This is global 289 epoch
#  Average loss 0.678
# Accuracy of the network on the 10000 test images: 63.280000 %
# This is global 290 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 52.530000 %
# This is global 291 epoch
#  Average loss 0.766
# Accuracy of the network on the 10000 test images: 63.120000 %
# This is global 292 epoch
#  Average loss 0.641
# Accuracy of the network on the 10000 test images: 56.860000 %
# This is global 293 epoch
#  Average loss 0.693
# Accuracy of the network on the 10000 test images: 64.820000 %
# This is global 294 epoch
#  Average loss 0.666
# Accuracy of the network on the 10000 test images: 61.130000 %
# This is global 295 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 61.280000 %
# This is global 296 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 63.420000 %
# This is global 297 epoch
#  Average loss 0.710
# Accuracy of the network on the 10000 test images: 64.880000 %
# This is global 298 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 58.940000 %
# This is global 299 epoch
#  Average loss 0.655
# Accuracy of the network on the 10000 test images: 64.650000 %
# This is global 300 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 64.690000 %
# This is global 301 epoch
#  Average loss 0.620
# Accuracy of the network on the 10000 test images: 62.680000 %
# This is global 302 epoch
#  Average loss 0.633
# Accuracy of the network on the 10000 test images: 61.750000 %
# This is global 303 epoch
#  Average loss 0.579
# Accuracy of the network on the 10000 test images: 64.380000 %
# This is global 304 epoch
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 61.730000 %
# This is global 305 epoch
#  Average loss 0.729
# Accuracy of the network on the 10000 test images: 58.960000 %
# This is global 306 epoch
#  Average loss 0.758
# Accuracy of the network on the 10000 test images: 63.260000 %
# This is global 307 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 62.550000 %
# This is global 308 epoch
#  Average loss 0.680
# Accuracy of the network on the 10000 test images: 65.340000 %
# This is global 309 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 62.370000 %
# This is global 310 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 57.150000 %
# This is global 311 epoch
#  Average loss 0.611
# Accuracy of the network on the 10000 test images: 60.170000 %
# This is global 312 epoch
#  Average loss 0.626
# Accuracy of the network on the 10000 test images: 65.110000 %
# This is global 313 epoch
#  Average loss 0.696
# Accuracy of the network on the 10000 test images: 64.570000 %
# This is global 314 epoch
#  Average loss 0.601
# Accuracy of the network on the 10000 test images: 62.890000 %
# This is global 315 epoch
#  Average loss 0.687
# Accuracy of the network on the 10000 test images: 66.400000 %
# This is global 316 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 60.480000 %
# This is global 317 epoch
#  Average loss 0.700
# Accuracy of the network on the 10000 test images: 63.610000 %
# This is global 318 epoch
#  Average loss 0.740
# Accuracy of the network on the 10000 test images: 42.820000 %
# This is global 319 epoch
#  Average loss 1.086
# Accuracy of the network on the 10000 test images: 47.370000 %
# This is global 320 epoch
#  Average loss 0.635
# Accuracy of the network on the 10000 test images: 58.620000 %
# This is global 321 epoch
#  Average loss 0.617
# Accuracy of the network on the 10000 test images: 60.610000 %
# This is global 322 epoch
#  Average loss 0.654
# Accuracy of the network on the 10000 test images: 65.000000 %
# This is global 323 epoch
#  Average loss 0.568
# Accuracy of the network on the 10000 test images: 64.100000 %
# This is global 324 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 61.410000 %
# This is global 325 epoch
#  Average loss 0.651
# Accuracy of the network on the 10000 test images: 59.550000 %
# This is global 326 epoch
#  Average loss 0.617
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 327 epoch
#  Average loss 0.659
# Accuracy of the network on the 10000 test images: 64.750000 %
# This is global 328 epoch
#  Average loss 0.689
# Accuracy of the network on the 10000 test images: 63.540000 %
# This is global 329 epoch
#  Average loss 0.717
# Accuracy of the network on the 10000 test images: 63.700000 %
# This is global 330 epoch
#  Average loss 0.695
# Accuracy of the network on the 10000 test images: 66.330000 %
# This is global 331 epoch
#  Average loss 0.543
# Accuracy of the network on the 10000 test images: 63.930000 %
# This is global 332 epoch
#  Average loss 0.534
# Accuracy of the network on the 10000 test images: 53.970000 %
# This is global 333 epoch
#  Average loss 0.697
# Accuracy of the network on the 10000 test images: 64.710000 %
# This is global 334 epoch
#  Average loss 0.543
# Accuracy of the network on the 10000 test images: 63.160000 %
# This is global 335 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 63.700000 %
# This is global 336 epoch
#  Average loss 0.624
# Accuracy of the network on the 10000 test images: 63.080000 %
# This is global 337 epoch
#  Average loss 0.615
# Accuracy of the network on the 10000 test images: 65.620000 %
# This is global 338 epoch
#  Average loss 0.595
# Accuracy of the network on the 10000 test images: 65.220000 %
# This is global 339 epoch
#  Average loss 0.737
# Accuracy of the network on the 10000 test images: 62.030000 %
# This is global 340 epoch
#  Average loss 0.649
# Accuracy of the network on the 10000 test images: 67.560000 %
# This is global 341 epoch
#  Average loss 0.526
# Accuracy of the network on the 10000 test images: 65.100000 %
# This is global 342 epoch
#  Average loss 0.632
# Accuracy of the network on the 10000 test images: 64.900000 %
# This is global 343 epoch
#  Average loss 0.506
# Accuracy of the network on the 10000 test images: 65.870000 %
# This is global 344 epoch
#  Average loss 0.568
# Accuracy of the network on the 10000 test images: 66.030000 %
# This is global 345 epoch
#  Average loss 0.662
# Accuracy of the network on the 10000 test images: 65.250000 %
# This is global 346 epoch
#  Average loss 0.584
# Accuracy of the network on the 10000 test images: 66.690000 %
# This is global 347 epoch
#  Average loss 0.511
# Accuracy of the network on the 10000 test images: 63.600000 %
# This is global 348 epoch
#  Average loss 0.700
# Accuracy of the network on the 10000 test images: 59.440000 %
# This is global 349 epoch
#  Average loss 0.702
# Accuracy of the network on the 10000 test images: 64.920000 %
# This is global 350 epoch
#  Average loss 0.598
# Accuracy of the network on the 10000 test images: 66.990000 %
# This is global 351 epoch
#  Average loss 0.565
# Accuracy of the network on the 10000 test images: 62.060000 %
# This is global 352 epoch
#  Average loss 0.584
# Accuracy of the network on the 10000 test images: 65.890000 %
# This is global 353 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 67.870000 %
# This is global 354 epoch
#  Average loss 0.583
# Accuracy of the network on the 10000 test images: 65.890000 %
# This is global 355 epoch
#  Average loss 0.475
# Accuracy of the network on the 10000 test images: 59.170000 %
# This is global 356 epoch
#  Average loss 0.517
# Accuracy of the network on the 10000 test images: 62.630000 %
# This is global 357 epoch
#  Average loss 0.617
# Accuracy of the network on the 10000 test images: 65.190000 %
# This is global 358 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 67.390000 %
# This is global 359 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 66.810000 %
# This is global 360 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 65.090000 %
# This is global 361 epoch
#  Average loss 0.657
# Accuracy of the network on the 10000 test images: 67.270000 %
# This is global 362 epoch
#  Average loss 0.590
# Accuracy of the network on the 10000 test images: 49.660000 %
# This is global 363 epoch
#  Average loss 0.698
# Accuracy of the network on the 10000 test images: 66.270000 %
# This is global 364 epoch
#  Average loss 0.580
# Accuracy of the network on the 10000 test images: 64.340000 %
# This is global 365 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 64.670000 %
# This is global 366 epoch
#  Average loss 0.569
# Accuracy of the network on the 10000 test images: 66.730000 %
# This is global 367 epoch
#  Average loss 0.569
# Accuracy of the network on the 10000 test images: 64.130000 %
# This is global 368 epoch
#  Average loss 0.505
# Accuracy of the network on the 10000 test images: 61.050000 %
# This is global 369 epoch
#  Average loss 0.446
# Accuracy of the network on the 10000 test images: 65.250000 %
# This is global 370 epoch
#  Average loss 0.680
# Accuracy of the network on the 10000 test images: 62.420000 %
# This is global 371 epoch
#  Average loss 0.539
# Accuracy of the network on the 10000 test images: 66.050000 %
# This is global 372 epoch
#  Average loss 0.571
# Accuracy of the network on the 10000 test images: 59.100000 %
# This is global 373 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 65.930000 %
# This is global 374 epoch
#  Average loss 0.450
# Accuracy of the network on the 10000 test images: 64.170000 %
# This is global 375 epoch
#  Average loss 0.478
# Accuracy of the network on the 10000 test images: 66.280000 %
# This is global 376 epoch
#  Average loss 0.477
# Accuracy of the network on the 10000 test images: 65.360000 %
# This is global 377 epoch
#  Average loss 0.583
# Accuracy of the network on the 10000 test images: 63.150000 %
# This is global 378 epoch
#  Average loss 0.665
# Accuracy of the network on the 10000 test images: 66.810000 %
# This is global 379 epoch
#  Average loss 0.528
# Accuracy of the network on the 10000 test images: 62.120000 %
# This is global 380 epoch
#  Average loss 0.632
# Accuracy of the network on the 10000 test images: 63.210000 %
# This is global 381 epoch
#  Average loss 0.528
# Accuracy of the network on the 10000 test images: 67.010000 %
# This is global 382 epoch
#  Average loss 0.494
# Accuracy of the network on the 10000 test images: 66.430000 %
# This is global 383 epoch
#  Average loss 0.565
# Accuracy of the network on the 10000 test images: 66.430000 %
# This is global 384 epoch
#  Average loss 0.510
# Accuracy of the network on the 10000 test images: 63.600000 %
# This is global 385 epoch
#  Average loss 0.633
# Accuracy of the network on the 10000 test images: 63.690000 %
# This is global 386 epoch
#  Average loss 0.483
# Accuracy of the network on the 10000 test images: 62.690000 %
# This is global 387 epoch
#  Average loss 0.530
# Accuracy of the network on the 10000 test images: 64.940000 %
# This is global 388 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 67.330000 %
# This is global 389 epoch
#  Average loss 0.511
# Accuracy of the network on the 10000 test images: 66.940000 %
# This is global 390 epoch
#  Average loss 0.447
# Accuracy of the network on the 10000 test images: 66.920000 %
# This is global 391 epoch
#  Average loss 0.583
# Accuracy of the network on the 10000 test images: 67.700000 %
# This is global 392 epoch
#  Average loss 0.505
# Accuracy of the network on the 10000 test images: 65.180000 %
# This is global 393 epoch
#  Average loss 0.502
# Accuracy of the network on the 10000 test images: 66.300000 %
# This is global 394 epoch
#  Average loss 0.542
# Accuracy of the network on the 10000 test images: 65.990000 %
# This is global 395 epoch
#  Average loss 0.406
# Accuracy of the network on the 10000 test images: 66.980000 %
# This is global 396 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 65.960000 %
# This is global 397 epoch
#  Average loss 0.447
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 398 epoch
#  Average loss 0.582
# Accuracy of the network on the 10000 test images: 66.190000 %
# This is global 399 epoch
#  Average loss 0.704
# Accuracy of the network on the 10000 test images: 62.420000 %
# This is global 400 epoch
#  Average loss 0.568
# Accuracy of the network on the 10000 test images: 65.800000 %
# This is global 401 epoch
#  Average loss 0.549
# Accuracy of the network on the 10000 test images: 65.270000 %
# This is global 402 epoch
#  Average loss 0.613
# Accuracy of the network on the 10000 test images: 64.800000 %
# This is global 403 epoch
#  Average loss 0.475
# Accuracy of the network on the 10000 test images: 66.700000 %
# This is global 404 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 66.810000 %
# This is global 405 epoch
#  Average loss 0.427
# Accuracy of the network on the 10000 test images: 65.890000 %
# This is global 406 epoch
#  Average loss 0.477
# Accuracy of the network on the 10000 test images: 68.320000 %
# This is global 407 epoch
#  Average loss 0.603
# Accuracy of the network on the 10000 test images: 62.300000 %
# This is global 408 epoch
#  Average loss 0.536
# Accuracy of the network on the 10000 test images: 63.480000 %
# This is global 409 epoch
#  Average loss 0.594
# Accuracy of the network on the 10000 test images: 65.810000 %
# This is global 410 epoch
#  Average loss 0.539
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 411 epoch
#  Average loss 0.537
# Accuracy of the network on the 10000 test images: 64.540000 %
# This is global 412 epoch
#  Average loss 0.451
# Accuracy of the network on the 10000 test images: 68.880000 %
# This is global 413 epoch
#  Average loss 0.500
# Accuracy of the network on the 10000 test images: 68.520000 %
# This is global 414 epoch
#  Average loss 0.457
# Accuracy of the network on the 10000 test images: 65.780000 %
# This is global 415 epoch
#  Average loss 0.443
# Accuracy of the network on the 10000 test images: 68.340000 %
# This is global 416 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 64.930000 %
# This is global 417 epoch
#  Average loss 0.487
# Accuracy of the network on the 10000 test images: 67.640000 %
# This is global 418 epoch
#  Average loss 0.538
# Accuracy of the network on the 10000 test images: 66.560000 %
# This is global 419 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 66.880000 %
# This is global 420 epoch
#  Average loss 0.489
# Accuracy of the network on the 10000 test images: 64.090000 %
# This is global 421 epoch
#  Average loss 0.419
# Accuracy of the network on the 10000 test images: 66.310000 %
# This is global 422 epoch
#  Average loss 0.462
# Accuracy of the network on the 10000 test images: 64.540000 %
# This is global 423 epoch
#  Average loss 0.472
# Accuracy of the network on the 10000 test images: 65.390000 %
# This is global 424 epoch
#  Average loss 0.584
# Accuracy of the network on the 10000 test images: 65.980000 %
# This is global 425 epoch
#  Average loss 0.423
# Accuracy of the network on the 10000 test images: 65.460000 %
# This is global 426 epoch
#  Average loss 0.549
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 427 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 64.900000 %
# This is global 428 epoch
#  Average loss 0.495
# Accuracy of the network on the 10000 test images: 68.040000 %
# This is global 429 epoch
#  Average loss 0.573
# Accuracy of the network on the 10000 test images: 61.690000 %
# This is global 430 epoch
#  Average loss 0.504
# Accuracy of the network on the 10000 test images: 66.800000 %
# This is global 431 epoch
#  Average loss 0.490
# Accuracy of the network on the 10000 test images: 68.380000 %
# This is global 432 epoch
#  Average loss 0.503
# Accuracy of the network on the 10000 test images: 64.600000 %
# This is global 433 epoch
#  Average loss 0.441
# Accuracy of the network on the 10000 test images: 67.890000 %
# This is global 434 epoch
#  Average loss 0.435
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 435 epoch
#  Average loss 0.441
# Accuracy of the network on the 10000 test images: 65.280000 %
# This is global 436 epoch
#  Average loss 0.462
# Accuracy of the network on the 10000 test images: 66.600000 %
# This is global 437 epoch
#  Average loss 0.469
# Accuracy of the network on the 10000 test images: 54.960000 %
# This is global 438 epoch
#  Average loss 0.615
# Accuracy of the network on the 10000 test images: 66.850000 %
# This is global 439 epoch
#  Average loss 0.494
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 440 epoch
#  Average loss 0.453
# Accuracy of the network on the 10000 test images: 65.530000 %
# This is global 441 epoch
#  Average loss 0.421
# Accuracy of the network on the 10000 test images: 67.410000 %
# This is global 442 epoch
#  Average loss 0.524
# Accuracy of the network on the 10000 test images: 67.330000 %
# This is global 443 epoch
#  Average loss 0.457
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 444 epoch
#  Average loss 0.596
# Accuracy of the network on the 10000 test images: 57.190000 %
# This is global 445 epoch
#  Average loss 0.501
# Accuracy of the network on the 10000 test images: 66.680000 %
# This is global 446 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 58.690000 %
# ...
# This is global 4853 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4854 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.260000 %
# This is global 4855 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.260000 %
# This is global 4856 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4857 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4858 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4859 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.280000 %
# This is global 4860 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4861 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4862 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4863 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4864 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4865 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4866 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4867 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4868 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4869 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4870 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4871 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.250000 %
# This is global 4872 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4873 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4874 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4875 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4876 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4877 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4878 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4879 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4880 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4881 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4882 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4883 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4884 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.260000 %
# This is global 4885 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4886 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4887 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4888 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4889 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4890 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4891 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4892 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4893 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4894 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4895 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4896 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4897 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4898 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4899 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4900 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4901 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4902 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4903 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.080000 %
# This is global 4904 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4905 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4906 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4907 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4908 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4909 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4910 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4911 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4912 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.280000 %
# This is global 4913 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4914 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4915 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4916 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4917 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4918 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4919 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4920 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4921 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4922 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4923 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4924 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4925 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4926 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.080000 %
# This is global 4927 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4928 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4929 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4930 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.020000 %
# This is global 4931 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.000000 %
# This is global 4932 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4933 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 4934 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4935 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4936 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4937 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 67.970000 %
# This is global 4938 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.000000 %
# This is global 4939 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4940 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 67.980000 %
# This is global 4941 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4942 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4943 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4944 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4945 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4946 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4947 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 4948 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4949 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4950 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4951 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4952 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4953 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4954 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4955 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.100000 %
# This is global 4956 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.010000 %
# This is global 4957 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4958 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.050000 %
# This is global 4959 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4960 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.130000 %
# This is global 4961 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4962 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4963 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4964 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.250000 %
# This is global 4965 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 4966 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4967 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4968 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4969 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.120000 %
# This is global 4970 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.080000 %
# This is global 4971 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4972 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.030000 %
# This is global 4973 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4974 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4975 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4976 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4977 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4978 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4979 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.080000 %
# This is global 4980 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.040000 %
# This is global 4981 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4982 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.110000 %
# This is global 4983 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.090000 %
# This is global 4984 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.070000 %
# This is global 4985 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 4986 epoch
#  Average loss 0.002
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4987 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.250000 %
# This is global 4988 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4989 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.150000 %
# This is global 4990 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.240000 %
# This is global 4991 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.250000 %
# This is global 4992 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4993 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.170000 %
# This is global 4994 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 4995 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 4996 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.230000 %
# This is global 4997 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.220000 %
# This is global 4998 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.210000 %
# This is global 4999 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.190000 %
# This is global 5000 epoch
#  Average loss 0.001
# Accuracy of the network on the 10000 test images: 68.200000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_noniid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %%
print(max(acc_train))
# Out:
# 69.98
