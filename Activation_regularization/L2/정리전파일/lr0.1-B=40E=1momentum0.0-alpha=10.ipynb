# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="1"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=1
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
def cifar_dirichlet(dataset, n_nets, alpha=0.5):
    '''
    if dataset == 'mnist':
        X_train, y_train, X_test, y_test = load_mnist_data(datadir)
    elif dataset == 'cifar10':
        X_train, y_train, X_test, y_test = load_cifar10_data(datadir)
    '''
    #X_train=dataset[:][0]
    y_train=torch.zeros(len(dataset),dtype=torch.long)
    print(y_train.dtype)
    for a in range(len(dataset)):
        y_train[a]=(dataset[a][1])
    n_train = len(dataset)
    #X_train.shape[0]
    '''
    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_nets)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_nets)}
    '''
    #elif partition == "hetero-dir":
    min_size = 0
    K = 10
    N=len(dataset)
    N = y_train.shape[0]
    net_dataidx_map = {i: np.array([],dtype='int64') for i in range(n_nets)}

    while min_size < 10:
        idx_batch = [[] for _ in range(n_nets)]
        for k in range(K):
            idx_k = np.where(y_train == k)[0]
            np.random.shuffle(idx_k)
            proportions = np.random.dirichlet(np.repeat(alpha, n_nets))
            ## Balance
            proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
            proportions = proportions/proportions.sum()
            proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
            idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
            min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    #traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    return net_dataidx_map
    #return (X_train, y_train, X_test, y_test, net_dataidx_map, traindata_cls_counts)

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        
        
        
        self.conv1_global = nn.Conv2d(3, 32, 3)
        self.pool_global = nn.MaxPool2d(2, 2)
        self.conv2_global = nn.Conv2d(32, 64, 3)
        self.conv3_global = nn.Conv2d(64, 64, 3)
        self.fc1_global = nn.Linear(64 * 4 * 4, 64)
        self.fc2_global = nn.Linear(64, 10)
        self.freeze_model_global_weights()
        
        self.mse=nn.MSELoss()
        #self.fc3 = nn.Linear(84, 10)
    def freeze_model_global_weights(self):
        for n, m in self.named_modules():
            if hasattr(m, "weight") and m.weight is not None and 'global' in n:
                print(f"==> No gradient to {n}.weight")
                m.weight.requires_grad = False
                if m.weight.grad is not None:
                    print(f"==> Setting gradient of {n}.weight to None")
                    m.weight.grad = None

                if hasattr(m, "bias") and m.bias is not None and 'global' in n:
                    print(f"==> No gradient to {n}.bias")
                    m.bias.requires_grad = False

                    if m.bias.grad is not None:
                        print(f"==> Setting gradient of {n}.bias to None")
                        m.bias.grad = None
    def sync_online_and_global(self):
        state_dict=self.state_dict()
        for key in state_dict:
            if 'global' in key:
                x=(key.split("_global"))
                online=(x[0]+x[1])
                state_dict[key]=state_dict[online]
        self.load_state_dict(state_dict)
        
        
        
    def forward(self, x,online_target=False):
        if online_target==False:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = (F.relu(self.conv3(x)))
            x = x.view(-1, 64*4*4)
            x = F.relu(self.fc1(x))
            x = (self.fc2(x))
            return x
        else:
            x1=copy.deepcopy(x)
            
            
            x = self.pool(F.relu(self.conv1(x)))
            x1 = self.pool_global(F.relu(self.conv1_global(x1)))
            diff=self.mse(x,x1)
            
            x = self.pool(F.relu(self.conv2(x)))
            x1 = self.pool_global(F.relu(self.conv2_global(x1)))
            diff+=self.mse(x,x1)
            
            
            x = (F.relu(self.conv3(x)))
            x1 = (F.relu(self.conv3_global(x1)))
            diff+=self.mse(x,x1)
            
            x = x.view(-1, 64*4*4)
            x1 = x1.view(-1, 64*4*4)
            
            x = F.relu(self.fc1(x))
            x1 = F.relu(self.fc1_global(x1))
            diff+=self.mse(x,x1)
            
            
            x = (self.fc2(x))
            x1 = (self.fc2_global(x1))
            diff+=self.mse(x,x1)
            
            
            return x,diff

# %%
net = Net()
net.to(device)
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
#   (conv1_global): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool_global): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_global): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_global): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1_global): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2_global): Linear(in_features=64, out_features=10, bias=True)
#   (mse): MSELoss()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01,momentum=0.5)
loss_train = []
acc_train=[]

# %%
for epoch in range(0):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    for i, data in enumerate(CIFAR_SGD_trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(labels)

        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
       
        
    if epoch%1==0:
        loss_train.append(loss)
        print(f"epoch: {epoch}")
        print(' Average loss {:.3f}'.format( loss))
        for j in range(1):
            net.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %d %%' % (
                100 * correct / total))
        acc_train.append(100 * correct / total)

    net.train()

    '''# 통계를 출력합니다.
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0'''

print('Finished Training')
# Out:
# Finished Training

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# /home/dana/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Accuracy of the network on the 10000 test images: 10 %

# %%
class LocalUpdate(object):
    def __init__(self, lr,local_epoch,device,batch_size, dataset=None, idxs=None,alpha=10):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.alpha=alpha

    def train(self, net):
        net.sync_online_and_global()
        net.train()
        # train and update
        optimizer = torch.optim.SGD(net.parameters(), lr=self.lr)

        epoch_loss = []
        for iter in range(self.local_epoch):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs,activation_l2 = net(images,online_target=True)
                loss = self.loss_func(log_probs, labels)+self.alpha*activation_l2
                loss.backward()
                optimizer.step()
                #if batch_idx % 10 == 0:
                #    print('Update Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #        iter, batch_idx * len(images), len(self.ldr_train.dataset),
                #               100. * batch_idx / len(self.ldr_train), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        return net.state_dict(), sum(epoch_loss) / len(epoch_loss)

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=501
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.305
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 1 epoch
#  Average loss 2.304
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 2 epoch
#  Average loss 2.304
# Accuracy of the network on the 10000 test images: 10.410000 %
# This is global 3 epoch
#  Average loss 2.299
# Accuracy of the network on the 10000 test images: 13.450000 %
# This is global 4 epoch
#  Average loss 2.300
# Accuracy of the network on the 10000 test images: 15.800000 %
# This is global 5 epoch
#  Average loss 2.299
# Accuracy of the network on the 10000 test images: 17.280000 %
# This is global 6 epoch
#  Average loss 2.294
# Accuracy of the network on the 10000 test images: 19.720000 %
# This is global 7 epoch
#  Average loss 2.292
# Accuracy of the network on the 10000 test images: 17.910000 %
# This is global 8 epoch
#  Average loss 2.287
# Accuracy of the network on the 10000 test images: 19.490000 %
# This is global 9 epoch
#  Average loss 2.283
# Accuracy of the network on the 10000 test images: 21.980000 %
# This is global 10 epoch
#  Average loss 2.284
# Accuracy of the network on the 10000 test images: 24.050000 %
# This is global 11 epoch
#  Average loss 2.280
# Accuracy of the network on the 10000 test images: 24.290000 %
# This is global 12 epoch
#  Average loss 2.271
# Accuracy of the network on the 10000 test images: 23.530000 %
# This is global 13 epoch
#  Average loss 2.267
# Accuracy of the network on the 10000 test images: 23.890000 %
# This is global 14 epoch
#  Average loss 2.308
# Accuracy of the network on the 10000 test images: 24.420000 %
# This is global 15 epoch
#  Average loss 2.280
# Accuracy of the network on the 10000 test images: 24.340000 %
# This is global 16 epoch
#  Average loss 2.282
# Accuracy of the network on the 10000 test images: 24.300000 %
# This is global 17 epoch
#  Average loss 2.266
# Accuracy of the network on the 10000 test images: 24.980000 %
# This is global 18 epoch
#  Average loss 2.264
# Accuracy of the network on the 10000 test images: 25.820000 %
# This is global 19 epoch
#  Average loss 2.289
# Accuracy of the network on the 10000 test images: 25.470000 %
# This is global 20 epoch
#  Average loss 2.235
# Accuracy of the network on the 10000 test images: 25.890000 %
# This is global 21 epoch
#  Average loss 2.238
# Accuracy of the network on the 10000 test images: 26.490000 %
# This is global 22 epoch
#  Average loss 2.221
# Accuracy of the network on the 10000 test images: 27.230000 %
# This is global 23 epoch
#  Average loss 2.237
# Accuracy of the network on the 10000 test images: 26.340000 %
# This is global 24 epoch
#  Average loss 2.223
# Accuracy of the network on the 10000 test images: 27.930000 %
# This is global 25 epoch
#  Average loss 2.235
# Accuracy of the network on the 10000 test images: 28.540000 %
# This is global 26 epoch
#  Average loss 2.347
# Accuracy of the network on the 10000 test images: 29.270000 %
# This is global 27 epoch
#  Average loss 2.199
# Accuracy of the network on the 10000 test images: 29.850000 %
# This is global 28 epoch
#  Average loss 2.207
# Accuracy of the network on the 10000 test images: 30.320000 %
# This is global 29 epoch
#  Average loss 2.188
# Accuracy of the network on the 10000 test images: 30.160000 %
# This is global 30 epoch
#  Average loss 2.246
# Accuracy of the network on the 10000 test images: 30.770000 %
# This is global 31 epoch
#  Average loss 2.215
# Accuracy of the network on the 10000 test images: 30.670000 %
# This is global 32 epoch
#  Average loss 2.294
# Accuracy of the network on the 10000 test images: 29.350000 %
# This is global 33 epoch
#  Average loss 2.196
# Accuracy of the network on the 10000 test images: 29.590000 %
# This is global 34 epoch
#  Average loss 2.203
# Accuracy of the network on the 10000 test images: 29.790000 %
# This is global 35 epoch
#  Average loss 2.190
# Accuracy of the network on the 10000 test images: 30.690000 %
# This is global 36 epoch
#  Average loss 2.182
# Accuracy of the network on the 10000 test images: 30.950000 %
# This is global 37 epoch
#  Average loss 2.218
# Accuracy of the network on the 10000 test images: 31.030000 %
# This is global 38 epoch
#  Average loss 2.452
# Accuracy of the network on the 10000 test images: 28.530000 %
# This is global 39 epoch
#  Average loss 2.160
# Accuracy of the network on the 10000 test images: 29.840000 %
# This is global 40 epoch
#  Average loss 2.171
# Accuracy of the network on the 10000 test images: 30.470000 %
# This is global 41 epoch
#  Average loss 2.183
# Accuracy of the network on the 10000 test images: 31.370000 %
# This is global 42 epoch
#  Average loss 2.145
# Accuracy of the network on the 10000 test images: 31.910000 %
# This is global 43 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 31.950000 %
# This is global 44 epoch
#  Average loss 2.291
# Accuracy of the network on the 10000 test images: 32.460000 %
# This is global 45 epoch
#  Average loss 2.130
# Accuracy of the network on the 10000 test images: 32.740000 %
# This is global 46 epoch
#  Average loss 2.155
# Accuracy of the network on the 10000 test images: 33.180000 %
# This is global 47 epoch
#  Average loss 2.145
# Accuracy of the network on the 10000 test images: 34.160000 %
# This is global 48 epoch
#  Average loss 2.116
# Accuracy of the network on the 10000 test images: 34.270000 %
# This is global 49 epoch
#  Average loss 2.180
# Accuracy of the network on the 10000 test images: 33.040000 %
# This is global 50 epoch
#  Average loss 2.253
# Accuracy of the network on the 10000 test images: 32.780000 %
# This is global 51 epoch
#  Average loss 2.118
# Accuracy of the network on the 10000 test images: 33.810000 %
# This is global 52 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 34.300000 %
# This is global 53 epoch
#  Average loss 2.116
# Accuracy of the network on the 10000 test images: 34.060000 %
# This is global 54 epoch
#  Average loss 2.117
# Accuracy of the network on the 10000 test images: 34.920000 %
# This is global 55 epoch
#  Average loss 2.157
# Accuracy of the network on the 10000 test images: 34.490000 %
# This is global 56 epoch
#  Average loss 2.124
# Accuracy of the network on the 10000 test images: 32.170000 %
# This is global 57 epoch
#  Average loss 2.122
# Accuracy of the network on the 10000 test images: 35.620000 %
# This is global 58 epoch
#  Average loss 2.098
# Accuracy of the network on the 10000 test images: 36.680000 %
# This is global 59 epoch
#  Average loss 2.076
# Accuracy of the network on the 10000 test images: 37.420000 %
# This is global 60 epoch
#  Average loss 2.071
# Accuracy of the network on the 10000 test images: 37.870000 %
# This is global 61 epoch
#  Average loss 2.067
# Accuracy of the network on the 10000 test images: 37.660000 %
# This is global 62 epoch
#  Average loss 2.152
# Accuracy of the network on the 10000 test images: 37.700000 %
# This is global 63 epoch
#  Average loss 2.065
# Accuracy of the network on the 10000 test images: 38.190000 %
# This is global 64 epoch
#  Average loss 2.072
# Accuracy of the network on the 10000 test images: 38.010000 %
# This is global 65 epoch
#  Average loss 2.109
# Accuracy of the network on the 10000 test images: 38.440000 %
# This is global 66 epoch
#  Average loss 2.042
# Accuracy of the network on the 10000 test images: 38.680000 %
# This is global 67 epoch
#  Average loss 2.007
# Accuracy of the network on the 10000 test images: 38.700000 %
# This is global 68 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 38.010000 %
# This is global 69 epoch
#  Average loss 2.073
# Accuracy of the network on the 10000 test images: 38.350000 %
# This is global 70 epoch
#  Average loss 2.047
# Accuracy of the network on the 10000 test images: 38.700000 %
# This is global 71 epoch
#  Average loss 2.080
# Accuracy of the network on the 10000 test images: 39.260000 %
# This is global 72 epoch
#  Average loss 2.031
# Accuracy of the network on the 10000 test images: 39.380000 %
# This is global 73 epoch
#  Average loss 2.031
# Accuracy of the network on the 10000 test images: 39.180000 %
# This is global 74 epoch
#  Average loss 2.013
# Accuracy of the network on the 10000 test images: 39.910000 %
# This is global 75 epoch
#  Average loss 2.094
# Accuracy of the network on the 10000 test images: 39.680000 %
# This is global 76 epoch
#  Average loss 2.036
# Accuracy of the network on the 10000 test images: 39.740000 %
# This is global 77 epoch
#  Average loss 2.075
# Accuracy of the network on the 10000 test images: 39.690000 %
# This is global 78 epoch
#  Average loss 1.966
# Accuracy of the network on the 10000 test images: 40.630000 %
# This is global 79 epoch
#  Average loss 2.050
# Accuracy of the network on the 10000 test images: 40.070000 %
# This is global 80 epoch
#  Average loss 2.046
# Accuracy of the network on the 10000 test images: 39.720000 %
# This is global 81 epoch
#  Average loss 2.016
# Accuracy of the network on the 10000 test images: 39.820000 %
# This is global 82 epoch
#  Average loss 2.002
# Accuracy of the network on the 10000 test images: 40.410000 %
# This is global 83 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 39.780000 %
# This is global 84 epoch
#  Average loss 1.988
# Accuracy of the network on the 10000 test images: 40.730000 %
# This is global 85 epoch
#  Average loss 1.928
# Accuracy of the network on the 10000 test images: 41.080000 %
# This is global 86 epoch
#  Average loss 2.005
# Accuracy of the network on the 10000 test images: 41.030000 %
# This is global 87 epoch
#  Average loss 2.009
# Accuracy of the network on the 10000 test images: 41.530000 %
# This is global 88 epoch
#  Average loss 1.940
# Accuracy of the network on the 10000 test images: 41.440000 %
# This is global 89 epoch
#  Average loss 1.989
# Accuracy of the network on the 10000 test images: 41.690000 %
# This is global 90 epoch
#  Average loss 2.018
# Accuracy of the network on the 10000 test images: 41.500000 %
# This is global 91 epoch
#  Average loss 1.975
# Accuracy of the network on the 10000 test images: 41.880000 %
# This is global 92 epoch
#  Average loss 1.959
# Accuracy of the network on the 10000 test images: 42.450000 %
# This is global 93 epoch
#  Average loss 2.110
# Accuracy of the network on the 10000 test images: 42.410000 %
# This is global 94 epoch
#  Average loss 1.910
# Accuracy of the network on the 10000 test images: 43.090000 %
# This is global 95 epoch
#  Average loss 1.927
# Accuracy of the network on the 10000 test images: 42.830000 %
# This is global 96 epoch
#  Average loss 1.961
# Accuracy of the network on the 10000 test images: 42.540000 %
# This is global 97 epoch
#  Average loss 1.934
# Accuracy of the network on the 10000 test images: 41.510000 %
# This is global 98 epoch
#  Average loss 2.459
# Accuracy of the network on the 10000 test images: 39.820000 %
# This is global 99 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 40.680000 %
# This is global 100 epoch
#  Average loss 1.966
# Accuracy of the network on the 10000 test images: 41.690000 %
# This is global 101 epoch
#  Average loss 2.000
# Accuracy of the network on the 10000 test images: 42.390000 %
# This is global 102 epoch
#  Average loss 2.000
# Accuracy of the network on the 10000 test images: 42.250000 %
# This is global 103 epoch
#  Average loss 1.874
# Accuracy of the network on the 10000 test images: 42.550000 %
# This is global 104 epoch
#  Average loss 1.921
# Accuracy of the network on the 10000 test images: 43.120000 %
# This is global 105 epoch
#  Average loss 2.007
# Accuracy of the network on the 10000 test images: 42.050000 %
# This is global 106 epoch
#  Average loss 2.048
# Accuracy of the network on the 10000 test images: 41.970000 %
# This is global 107 epoch
#  Average loss 1.870
# Accuracy of the network on the 10000 test images: 43.110000 %
# This is global 108 epoch
#  Average loss 1.877
# Accuracy of the network on the 10000 test images: 43.450000 %
# This is global 109 epoch
#  Average loss 1.874
# Accuracy of the network on the 10000 test images: 42.700000 %
# This is global 110 epoch
#  Average loss 2.007
# Accuracy of the network on the 10000 test images: 42.830000 %
# This is global 111 epoch
#  Average loss 2.044
# Accuracy of the network on the 10000 test images: 42.950000 %
# This is global 112 epoch
#  Average loss 1.854
# Accuracy of the network on the 10000 test images: 43.620000 %
# This is global 113 epoch
#  Average loss 1.919
# Accuracy of the network on the 10000 test images: 44.840000 %
# This is global 114 epoch
#  Average loss 1.868
# Accuracy of the network on the 10000 test images: 44.780000 %
# This is global 115 epoch
#  Average loss 1.923
# Accuracy of the network on the 10000 test images: 45.090000 %
# This is global 116 epoch
#  Average loss 1.910
# Accuracy of the network on the 10000 test images: 44.620000 %
# This is global 117 epoch
#  Average loss 1.913
# Accuracy of the network on the 10000 test images: 44.950000 %
# This is global 118 epoch
#  Average loss 1.850
# Accuracy of the network on the 10000 test images: 45.030000 %
# This is global 119 epoch
#  Average loss 1.894
# Accuracy of the network on the 10000 test images: 44.820000 %
# This is global 120 epoch
#  Average loss 1.921
# Accuracy of the network on the 10000 test images: 44.440000 %
# This is global 121 epoch
#  Average loss 1.995
# Accuracy of the network on the 10000 test images: 45.160000 %
# This is global 122 epoch
#  Average loss 1.894
# Accuracy of the network on the 10000 test images: 44.380000 %
# This is global 123 epoch
#  Average loss 1.882
# Accuracy of the network on the 10000 test images: 45.200000 %
# This is global 124 epoch
#  Average loss 1.844
# Accuracy of the network on the 10000 test images: 45.520000 %
# This is global 125 epoch
#  Average loss 1.889
# Accuracy of the network on the 10000 test images: 45.480000 %
# This is global 126 epoch
#  Average loss 1.824
# Accuracy of the network on the 10000 test images: 45.950000 %
# This is global 127 epoch
#  Average loss 2.138
# Accuracy of the network on the 10000 test images: 44.700000 %
# This is global 128 epoch
#  Average loss 1.896
# Accuracy of the network on the 10000 test images: 45.290000 %
# This is global 129 epoch
#  Average loss 1.958
# Accuracy of the network on the 10000 test images: 44.200000 %
# This is global 130 epoch
#  Average loss 2.026
# Accuracy of the network on the 10000 test images: 45.410000 %
# This is global 131 epoch
#  Average loss 1.837
# Accuracy of the network on the 10000 test images: 45.100000 %
# This is global 132 epoch
#  Average loss 1.997
# Accuracy of the network on the 10000 test images: 44.710000 %
# This is global 133 epoch
#  Average loss 2.014
# Accuracy of the network on the 10000 test images: 46.620000 %
# This is global 134 epoch
#  Average loss 1.782
# Accuracy of the network on the 10000 test images: 46.950000 %
# This is global 135 epoch
#  Average loss 1.780
# Accuracy of the network on the 10000 test images: 46.930000 %
# This is global 136 epoch
#  Average loss 1.794
# Accuracy of the network on the 10000 test images: 47.210000 %
# This is global 137 epoch
#  Average loss 1.800
# Accuracy of the network on the 10000 test images: 47.340000 %
# This is global 138 epoch
#  Average loss 1.907
# Accuracy of the network on the 10000 test images: 46.670000 %
# This is global 139 epoch
#  Average loss 1.798
# Accuracy of the network on the 10000 test images: 46.800000 %
# This is global 140 epoch
#  Average loss 1.846
# Accuracy of the network on the 10000 test images: 46.990000 %
# This is global 141 epoch
#  Average loss 1.794
# Accuracy of the network on the 10000 test images: 47.090000 %
# This is global 142 epoch
#  Average loss 1.896
# Accuracy of the network on the 10000 test images: 47.030000 %
# This is global 143 epoch
#  Average loss 1.742
# Accuracy of the network on the 10000 test images: 47.170000 %
# This is global 144 epoch
#  Average loss 1.833
# Accuracy of the network on the 10000 test images: 47.560000 %
# This is global 145 epoch
#  Average loss 1.815
# Accuracy of the network on the 10000 test images: 47.820000 %
# This is global 146 epoch
#  Average loss 1.846
# Accuracy of the network on the 10000 test images: 47.960000 %
# This is global 147 epoch
#  Average loss 1.783
# Accuracy of the network on the 10000 test images: 48.540000 %
# This is global 148 epoch
#  Average loss 1.761
# Accuracy of the network on the 10000 test images: 49.100000 %
# This is global 149 epoch
#  Average loss 1.737
# Accuracy of the network on the 10000 test images: 48.980000 %
# This is global 150 epoch
#  Average loss 1.844
# Accuracy of the network on the 10000 test images: 48.750000 %
# This is global 151 epoch
#  Average loss 1.760
# Accuracy of the network on the 10000 test images: 48.860000 %
# This is global 152 epoch
#  Average loss 1.852
# Accuracy of the network on the 10000 test images: 48.520000 %
# This is global 153 epoch
#  Average loss 1.801
# Accuracy of the network on the 10000 test images: 48.030000 %
# This is global 154 epoch
#  Average loss 1.918
# Accuracy of the network on the 10000 test images: 47.900000 %
# This is global 155 epoch
#  Average loss 1.814
# Accuracy of the network on the 10000 test images: 47.510000 %
# This is global 156 epoch
#  Average loss 1.802
# Accuracy of the network on the 10000 test images: 48.030000 %
# This is global 157 epoch
#  Average loss 1.770
# Accuracy of the network on the 10000 test images: 48.470000 %
# This is global 158 epoch
#  Average loss 2.239
# Accuracy of the network on the 10000 test images: 47.940000 %
# This is global 159 epoch
#  Average loss 1.725
# Accuracy of the network on the 10000 test images: 48.580000 %
# This is global 160 epoch
#  Average loss 1.730
# Accuracy of the network on the 10000 test images: 48.690000 %
# This is global 161 epoch
#  Average loss 1.730
# Accuracy of the network on the 10000 test images: 48.110000 %
# This is global 162 epoch
#  Average loss 2.012
# Accuracy of the network on the 10000 test images: 47.840000 %
# This is global 163 epoch
#  Average loss 1.722
# Accuracy of the network on the 10000 test images: 48.260000 %
# This is global 164 epoch
#  Average loss 1.812
# Accuracy of the network on the 10000 test images: 49.320000 %
# This is global 165 epoch
#  Average loss 1.709
# Accuracy of the network on the 10000 test images: 49.330000 %
# This is global 166 epoch
#  Average loss 1.743
# Accuracy of the network on the 10000 test images: 49.310000 %
# This is global 167 epoch
#  Average loss 1.753
# Accuracy of the network on the 10000 test images: 49.820000 %
# This is global 168 epoch
#  Average loss 1.842
# Accuracy of the network on the 10000 test images: 49.680000 %
# This is global 169 epoch
#  Average loss 1.687
# Accuracy of the network on the 10000 test images: 49.820000 %
# This is global 170 epoch
#  Average loss 1.824
# Accuracy of the network on the 10000 test images: 49.170000 %
# This is global 171 epoch
#  Average loss 1.840
# Accuracy of the network on the 10000 test images: 47.920000 %
# This is global 172 epoch
#  Average loss 2.179
# Accuracy of the network on the 10000 test images: 47.120000 %
# This is global 173 epoch
#  Average loss 1.799
# Accuracy of the network on the 10000 test images: 47.460000 %
# This is global 174 epoch
#  Average loss 1.808
# Accuracy of the network on the 10000 test images: 48.320000 %
# This is global 175 epoch
#  Average loss 1.788
# Accuracy of the network on the 10000 test images: 48.410000 %
# This is global 176 epoch
#  Average loss 1.876
# Accuracy of the network on the 10000 test images: 48.570000 %
# This is global 177 epoch
#  Average loss 2.245
# Accuracy of the network on the 10000 test images: 47.440000 %
# This is global 178 epoch
#  Average loss 1.747
# Accuracy of the network on the 10000 test images: 48.460000 %
# This is global 179 epoch
#  Average loss 1.737
# Accuracy of the network on the 10000 test images: 49.320000 %
# This is global 180 epoch
#  Average loss 1.689
# Accuracy of the network on the 10000 test images: 49.760000 %
# This is global 181 epoch
#  Average loss 1.715
# Accuracy of the network on the 10000 test images: 49.740000 %
# This is global 182 epoch
#  Average loss 1.947
# Accuracy of the network on the 10000 test images: 48.300000 %
# This is global 183 epoch
#  Average loss 1.794
# Accuracy of the network on the 10000 test images: 48.250000 %
# This is global 184 epoch
#  Average loss 1.903
# Accuracy of the network on the 10000 test images: 49.280000 %
# This is global 185 epoch
#  Average loss 1.785
# Accuracy of the network on the 10000 test images: 48.460000 %
# This is global 186 epoch
#  Average loss 1.842
# Accuracy of the network on the 10000 test images: 46.860000 %
# This is global 187 epoch
#  Average loss 1.932
# Accuracy of the network on the 10000 test images: 48.110000 %
# This is global 188 epoch
#  Average loss 1.710
# Accuracy of the network on the 10000 test images: 49.130000 %
# This is global 189 epoch
#  Average loss 1.731
# Accuracy of the network on the 10000 test images: 50.120000 %
# This is global 190 epoch
#  Average loss 1.673
# Accuracy of the network on the 10000 test images: 50.210000 %
# This is global 191 epoch
#  Average loss 1.695
# Accuracy of the network on the 10000 test images: 50.220000 %
# This is global 192 epoch
#  Average loss 1.731
# Accuracy of the network on the 10000 test images: 51.410000 %
# This is global 193 epoch
#  Average loss 1.700
# Accuracy of the network on the 10000 test images: 51.940000 %
# This is global 194 epoch
#  Average loss 1.818
# Accuracy of the network on the 10000 test images: 51.070000 %
# This is global 195 epoch
#  Average loss 1.662
# Accuracy of the network on the 10000 test images: 51.460000 %
# This is global 196 epoch
#  Average loss 1.775
# Accuracy of the network on the 10000 test images: 51.340000 %
# This is global 197 epoch
#  Average loss 1.608
# Accuracy of the network on the 10000 test images: 51.990000 %
# This is global 198 epoch
#  Average loss 1.707
# Accuracy of the network on the 10000 test images: 52.280000 %
# This is global 199 epoch
#  Average loss 1.637
# Accuracy of the network on the 10000 test images: 52.360000 %
# This is global 200 epoch
#  Average loss 1.714
# Accuracy of the network on the 10000 test images: 52.800000 %
# This is global 201 epoch
#  Average loss 1.629
# Accuracy of the network on the 10000 test images: 52.950000 %
# This is global 202 epoch
#  Average loss 1.707
# Accuracy of the network on the 10000 test images: 52.660000 %
# This is global 203 epoch
#  Average loss 1.807
# Accuracy of the network on the 10000 test images: 52.530000 %
# This is global 204 epoch
#  Average loss 1.652
# Accuracy of the network on the 10000 test images: 52.810000 %
# This is global 205 epoch
#  Average loss 1.668
# Accuracy of the network on the 10000 test images: 52.930000 %
# This is global 206 epoch
#  Average loss 1.842
# Accuracy of the network on the 10000 test images: 52.330000 %
# This is global 207 epoch
#  Average loss 1.704
# Accuracy of the network on the 10000 test images: 51.990000 %
# This is global 208 epoch
#  Average loss 1.818
# Accuracy of the network on the 10000 test images: 51.400000 %
# This is global 209 epoch
#  Average loss 1.687
# Accuracy of the network on the 10000 test images: 51.690000 %
# This is global 210 epoch
#  Average loss 1.855
# Accuracy of the network on the 10000 test images: 51.920000 %
# This is global 211 epoch
#  Average loss 1.732
# Accuracy of the network on the 10000 test images: 52.070000 %
# This is global 212 epoch
#  Average loss 1.659
# Accuracy of the network on the 10000 test images: 52.890000 %
# This is global 213 epoch
#  Average loss 1.696
# Accuracy of the network on the 10000 test images: 53.670000 %
# This is global 214 epoch
#  Average loss 1.637
# Accuracy of the network on the 10000 test images: 53.290000 %
# This is global 215 epoch
#  Average loss 1.771
# Accuracy of the network on the 10000 test images: 53.140000 %
# This is global 216 epoch
#  Average loss 1.816
# Accuracy of the network on the 10000 test images: 51.840000 %
# This is global 217 epoch
#  Average loss 1.744
# Accuracy of the network on the 10000 test images: 52.060000 %
# This is global 218 epoch
#  Average loss 1.728
# Accuracy of the network on the 10000 test images: 51.680000 %
# This is global 219 epoch
#  Average loss 1.720
# Accuracy of the network on the 10000 test images: 52.120000 %
# This is global 220 epoch
#  Average loss 1.610
# Accuracy of the network on the 10000 test images: 52.430000 %
# This is global 221 epoch
#  Average loss 1.651
# Accuracy of the network on the 10000 test images: 52.820000 %
# This is global 222 epoch
#  Average loss 1.592
# Accuracy of the network on the 10000 test images: 53.070000 %
# This is global 223 epoch
#  Average loss 1.805
# Accuracy of the network on the 10000 test images: 52.690000 %
# This is global 224 epoch
#  Average loss 1.626
# Accuracy of the network on the 10000 test images: 52.570000 %
# This is global 225 epoch
#  Average loss 1.654
# Accuracy of the network on the 10000 test images: 52.340000 %
# This is global 226 epoch
#  Average loss 2.577
# Accuracy of the network on the 10000 test images: 49.690000 %
# This is global 227 epoch
#  Average loss 1.680
# Accuracy of the network on the 10000 test images: 51.000000 %
# This is global 228 epoch
#  Average loss 1.626
# Accuracy of the network on the 10000 test images: 51.450000 %
# This is global 229 epoch
#  Average loss 1.621
# Accuracy of the network on the 10000 test images: 51.970000 %
# This is global 230 epoch
#  Average loss 1.658
# Accuracy of the network on the 10000 test images: 51.980000 %
# This is global 231 epoch
#  Average loss 1.614
# Accuracy of the network on the 10000 test images: 52.160000 %
# This is global 232 epoch
#  Average loss 1.631
# Accuracy of the network on the 10000 test images: 52.170000 %
# This is global 233 epoch
#  Average loss 1.646
# Accuracy of the network on the 10000 test images: 51.800000 %
# This is global 234 epoch
#  Average loss 1.631
# Accuracy of the network on the 10000 test images: 52.480000 %
# This is global 235 epoch
#  Average loss 1.778
# Accuracy of the network on the 10000 test images: 52.240000 %
# This is global 236 epoch
#  Average loss 1.752
# Accuracy of the network on the 10000 test images: 52.430000 %
# This is global 237 epoch
#  Average loss 1.580
# Accuracy of the network on the 10000 test images: 52.140000 %
# This is global 238 epoch
#  Average loss 1.649
# Accuracy of the network on the 10000 test images: 52.440000 %
# This is global 239 epoch
#  Average loss 1.622
# Accuracy of the network on the 10000 test images: 52.120000 %
# This is global 240 epoch
#  Average loss 1.606
# Accuracy of the network on the 10000 test images: 53.260000 %
# This is global 241 epoch
#  Average loss 1.705
# Accuracy of the network on the 10000 test images: 52.210000 %
# This is global 242 epoch
#  Average loss 1.960
# Accuracy of the network on the 10000 test images: 52.110000 %
# This is global 243 epoch
#  Average loss 1.612
# Accuracy of the network on the 10000 test images: 53.160000 %
# This is global 244 epoch
#  Average loss 1.615
# Accuracy of the network on the 10000 test images: 53.150000 %
# This is global 245 epoch
#  Average loss 1.660
# Accuracy of the network on the 10000 test images: 53.710000 %
# This is global 246 epoch
#  Average loss 1.597
# Accuracy of the network on the 10000 test images: 53.530000 %
# This is global 247 epoch
#  Average loss 1.564
# Accuracy of the network on the 10000 test images: 53.190000 %
# This is global 248 epoch
#  Average loss 1.592
# Accuracy of the network on the 10000 test images: 53.720000 %
# This is global 249 epoch
#  Average loss 1.714
# Accuracy of the network on the 10000 test images: 54.160000 %
# This is global 250 epoch
#  Average loss 1.613
# Accuracy of the network on the 10000 test images: 54.110000 %
# This is global 251 epoch
#  Average loss 1.730
# Accuracy of the network on the 10000 test images: 54.050000 %
# This is global 252 epoch
#  Average loss 1.859
# Accuracy of the network on the 10000 test images: 53.990000 %
# This is global 253 epoch
#  Average loss 1.781
# Accuracy of the network on the 10000 test images: 54.210000 %
# This is global 254 epoch
#  Average loss 1.577
# Accuracy of the network on the 10000 test images: 54.560000 %
# This is global 255 epoch
#  Average loss 1.495
# Accuracy of the network on the 10000 test images: 54.660000 %
# This is global 256 epoch
#  Average loss 1.669
# Accuracy of the network on the 10000 test images: 53.670000 %
# This is global 257 epoch
#  Average loss 1.592
# Accuracy of the network on the 10000 test images: 54.570000 %
# This is global 258 epoch
#  Average loss 1.609
# Accuracy of the network on the 10000 test images: 54.610000 %
# This is global 259 epoch
#  Average loss 1.573
# Accuracy of the network on the 10000 test images: 54.940000 %
# This is global 260 epoch
#  Average loss 1.712
# Accuracy of the network on the 10000 test images: 54.590000 %
# This is global 261 epoch
#  Average loss 1.742
# Accuracy of the network on the 10000 test images: 54.510000 %
# This is global 262 epoch
#  Average loss 1.562
# Accuracy of the network on the 10000 test images: 54.370000 %
# This is global 263 epoch
#  Average loss 1.523
# Accuracy of the network on the 10000 test images: 54.990000 %
# This is global 264 epoch
#  Average loss 1.643
# Accuracy of the network on the 10000 test images: 55.010000 %
# This is global 265 epoch
#  Average loss 1.674
# Accuracy of the network on the 10000 test images: 54.330000 %
# This is global 266 epoch
#  Average loss 1.516
# Accuracy of the network on the 10000 test images: 55.180000 %
# This is global 267 epoch
#  Average loss 1.547
# Accuracy of the network on the 10000 test images: 55.760000 %
# This is global 268 epoch
#  Average loss 1.601
# Accuracy of the network on the 10000 test images: 55.980000 %
# This is global 269 epoch
#  Average loss 1.556
# Accuracy of the network on the 10000 test images: 56.140000 %
# This is global 270 epoch
#  Average loss 1.642
# Accuracy of the network on the 10000 test images: 56.030000 %
# This is global 271 epoch
#  Average loss 1.625
# Accuracy of the network on the 10000 test images: 56.060000 %
# This is global 272 epoch
#  Average loss 1.632
# Accuracy of the network on the 10000 test images: 56.000000 %
# This is global 273 epoch
#  Average loss 1.639
# Accuracy of the network on the 10000 test images: 56.150000 %
# This is global 274 epoch
#  Average loss 1.500
# Accuracy of the network on the 10000 test images: 56.190000 %
# This is global 275 epoch
#  Average loss 1.481
# Accuracy of the network on the 10000 test images: 55.760000 %
# This is global 276 epoch
#  Average loss 1.587
# Accuracy of the network on the 10000 test images: 54.790000 %
# This is global 277 epoch
#  Average loss 1.614
# Accuracy of the network on the 10000 test images: 55.370000 %
# This is global 278 epoch
#  Average loss 1.692
# Accuracy of the network on the 10000 test images: 55.090000 %
# This is global 279 epoch
#  Average loss 1.783
# Accuracy of the network on the 10000 test images: 55.910000 %
# This is global 280 epoch
#  Average loss 1.499
# Accuracy of the network on the 10000 test images: 56.340000 %
# This is global 281 epoch
#  Average loss 1.527
# Accuracy of the network on the 10000 test images: 56.860000 %
# This is global 282 epoch
#  Average loss 1.572
# Accuracy of the network on the 10000 test images: 56.640000 %
# This is global 283 epoch
#  Average loss 1.571
# Accuracy of the network on the 10000 test images: 56.590000 %
# This is global 284 epoch
#  Average loss 1.556
# Accuracy of the network on the 10000 test images: 56.610000 %
# This is global 285 epoch
#  Average loss 1.596
# Accuracy of the network on the 10000 test images: 56.870000 %
# This is global 286 epoch
#  Average loss 1.606
# Accuracy of the network on the 10000 test images: 55.720000 %
# This is global 287 epoch
#  Average loss 1.810
# Accuracy of the network on the 10000 test images: 54.910000 %
# This is global 288 epoch
#  Average loss 1.607
# Accuracy of the network on the 10000 test images: 54.760000 %
# This is global 289 epoch
#  Average loss 1.614
# Accuracy of the network on the 10000 test images: 53.980000 %
# This is global 290 epoch
#  Average loss 1.798
# Accuracy of the network on the 10000 test images: 53.080000 %
# This is global 291 epoch
#  Average loss 1.705
# Accuracy of the network on the 10000 test images: 53.880000 %
# This is global 292 epoch
#  Average loss 1.531
# Accuracy of the network on the 10000 test images: 54.720000 %
# This is global 293 epoch
#  Average loss 1.560
# Accuracy of the network on the 10000 test images: 54.700000 %
# This is global 294 epoch
#  Average loss 1.465
# Accuracy of the network on the 10000 test images: 55.520000 %
# This is global 295 epoch
#  Average loss 1.553
# Accuracy of the network on the 10000 test images: 57.090000 %
# This is global 296 epoch
#  Average loss 1.486
# Accuracy of the network on the 10000 test images: 56.940000 %
# This is global 297 epoch
#  Average loss 1.430
# Accuracy of the network on the 10000 test images: 57.580000 %
# This is global 298 epoch
#  Average loss 1.823
# Accuracy of the network on the 10000 test images: 57.530000 %
# This is global 299 epoch
#  Average loss 1.617
# Accuracy of the network on the 10000 test images: 56.870000 %
# This is global 300 epoch
#  Average loss 1.595
# Accuracy of the network on the 10000 test images: 57.330000 %
# This is global 301 epoch
#  Average loss 1.467
# Accuracy of the network on the 10000 test images: 57.300000 %
# This is global 302 epoch
#  Average loss 1.495
# Accuracy of the network on the 10000 test images: 57.130000 %
# This is global 303 epoch
#  Average loss 1.452
# Accuracy of the network on the 10000 test images: 57.280000 %
# This is global 304 epoch
#  Average loss 1.438
# Accuracy of the network on the 10000 test images: 57.270000 %
# This is global 305 epoch
#  Average loss 1.542
# Accuracy of the network on the 10000 test images: 57.540000 %
# This is global 306 epoch
#  Average loss 1.653
# Accuracy of the network on the 10000 test images: 56.600000 %
# This is global 307 epoch
#  Average loss 1.874
# Accuracy of the network on the 10000 test images: 56.120000 %
# This is global 308 epoch
#  Average loss 1.454
# Accuracy of the network on the 10000 test images: 56.600000 %
# This is global 309 epoch
#  Average loss 1.631
# Accuracy of the network on the 10000 test images: 57.090000 %
# This is global 310 epoch
#  Average loss 1.486
# Accuracy of the network on the 10000 test images: 57.270000 %
# This is global 311 epoch
#  Average loss 1.684
# Accuracy of the network on the 10000 test images: 56.210000 %
# This is global 312 epoch
#  Average loss 4.381
# Accuracy of the network on the 10000 test images: 41.830000 %
# This is global 313 epoch
#  Average loss 1.860
# Accuracy of the network on the 10000 test images: 44.640000 %
# This is global 314 epoch
#  Average loss 1.814
# Accuracy of the network on the 10000 test images: 47.260000 %
# This is global 315 epoch
#  Average loss 1.733
# Accuracy of the network on the 10000 test images: 47.660000 %
# This is global 316 epoch
#  Average loss 1.785
# Accuracy of the network on the 10000 test images: 49.590000 %
# This is global 317 epoch
#  Average loss 1.699
# Accuracy of the network on the 10000 test images: 51.320000 %
# This is global 318 epoch
#  Average loss 1.743
# Accuracy of the network on the 10000 test images: 51.160000 %
# This is global 319 epoch
#  Average loss 1.642
# Accuracy of the network on the 10000 test images: 52.170000 %
# This is global 320 epoch
#  Average loss 1.751
# Accuracy of the network on the 10000 test images: 53.780000 %
# This is global 321 epoch
#  Average loss 1.777
# Accuracy of the network on the 10000 test images: 54.320000 %
# This is global 322 epoch
#  Average loss 1.556
# Accuracy of the network on the 10000 test images: 55.230000 %
# This is global 323 epoch
#  Average loss 1.576
# Accuracy of the network on the 10000 test images: 55.660000 %
# This is global 324 epoch
#  Average loss 1.570
# Accuracy of the network on the 10000 test images: 56.040000 %
# This is global 325 epoch
#  Average loss 1.587
# Accuracy of the network on the 10000 test images: 56.270000 %
# This is global 326 epoch
#  Average loss 1.689
# Accuracy of the network on the 10000 test images: 56.050000 %
# This is global 327 epoch
#  Average loss 1.601
# Accuracy of the network on the 10000 test images: 55.780000 %
# This is global 328 epoch
#  Average loss 1.656
# Accuracy of the network on the 10000 test images: 56.030000 %
# This is global 329 epoch
#  Average loss 1.526
# Accuracy of the network on the 10000 test images: 56.370000 %
# This is global 330 epoch
#  Average loss 1.682
# Accuracy of the network on the 10000 test images: 55.920000 %
# This is global 331 epoch
#  Average loss 1.624
# Accuracy of the network on the 10000 test images: 55.260000 %
# This is global 332 epoch
#  Average loss 1.659
# Accuracy of the network on the 10000 test images: 55.700000 %
# This is global 333 epoch
#  Average loss 1.605
# Accuracy of the network on the 10000 test images: 55.950000 %
# This is global 334 epoch
#  Average loss 1.550
# Accuracy of the network on the 10000 test images: 56.320000 %
# This is global 335 epoch
#  Average loss 1.530
# Accuracy of the network on the 10000 test images: 56.400000 %
# This is global 336 epoch
#  Average loss 1.552
# Accuracy of the network on the 10000 test images: 56.060000 %
# This is global 337 epoch
#  Average loss 1.853
# Accuracy of the network on the 10000 test images: 55.660000 %
# This is global 338 epoch
#  Average loss 1.554
# Accuracy of the network on the 10000 test images: 56.300000 %
# This is global 339 epoch
#  Average loss 1.532
# Accuracy of the network on the 10000 test images: 56.940000 %
# This is global 340 epoch
#  Average loss 1.486
# Accuracy of the network on the 10000 test images: 56.160000 %
# This is global 341 epoch
#  Average loss 1.482
# Accuracy of the network on the 10000 test images: 56.280000 %
# This is global 342 epoch
#  Average loss 1.560
# Accuracy of the network on the 10000 test images: 55.000000 %
# This is global 343 epoch
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 56.820000 %
# This is global 344 epoch
#  Average loss 1.488
# Accuracy of the network on the 10000 test images: 57.420000 %
# This is global 345 epoch
#  Average loss 1.555
# Accuracy of the network on the 10000 test images: 57.530000 %
# This is global 346 epoch
#  Average loss 1.479
# Accuracy of the network on the 10000 test images: 57.900000 %
# This is global 347 epoch
#  Average loss 1.523
# Accuracy of the network on the 10000 test images: 57.820000 %
# This is global 348 epoch
#  Average loss 1.789
# Accuracy of the network on the 10000 test images: 57.440000 %
# This is global 349 epoch
#  Average loss 1.434
# Accuracy of the network on the 10000 test images: 57.770000 %
# This is global 350 epoch
#  Average loss 1.476
# Accuracy of the network on the 10000 test images: 58.330000 %
# This is global 351 epoch
#  Average loss 1.438
# Accuracy of the network on the 10000 test images: 58.550000 %
# This is global 352 epoch
#  Average loss 1.493
# Accuracy of the network on the 10000 test images: 58.010000 %
# This is global 353 epoch
#  Average loss 1.481
# Accuracy of the network on the 10000 test images: 58.180000 %
# This is global 354 epoch
#  Average loss 1.530
# Accuracy of the network on the 10000 test images: 57.930000 %
# This is global 355 epoch
#  Average loss 1.464
# Accuracy of the network on the 10000 test images: 57.710000 %
# This is global 356 epoch
#  Average loss 1.516
# Accuracy of the network on the 10000 test images: 57.720000 %
# This is global 357 epoch
#  Average loss 1.478
# Accuracy of the network on the 10000 test images: 58.050000 %
# This is global 358 epoch
#  Average loss 1.564
# Accuracy of the network on the 10000 test images: 57.310000 %
# This is global 359 epoch
#  Average loss 1.686
# Accuracy of the network on the 10000 test images: 56.730000 %
# This is global 360 epoch
#  Average loss 1.533
# Accuracy of the network on the 10000 test images: 56.980000 %
# This is global 361 epoch
#  Average loss 1.538
# Accuracy of the network on the 10000 test images: 57.270000 %
# This is global 362 epoch
#  Average loss 1.504
# Accuracy of the network on the 10000 test images: 57.780000 %
# This is global 363 epoch
#  Average loss 1.567
# Accuracy of the network on the 10000 test images: 58.190000 %
# This is global 364 epoch
#  Average loss 1.537
# Accuracy of the network on the 10000 test images: 58.030000 %
# This is global 365 epoch
#  Average loss 1.581
# Accuracy of the network on the 10000 test images: 57.670000 %
# This is global 366 epoch
#  Average loss 1.372
# Accuracy of the network on the 10000 test images: 58.170000 %
# This is global 367 epoch
#  Average loss 1.444
# Accuracy of the network on the 10000 test images: 58.380000 %
# This is global 368 epoch
#  Average loss 1.498
# Accuracy of the network on the 10000 test images: 57.200000 %
# This is global 369 epoch
#  Average loss 1.552
# Accuracy of the network on the 10000 test images: 57.360000 %
# This is global 370 epoch
#  Average loss 1.401
# Accuracy of the network on the 10000 test images: 58.320000 %
# This is global 371 epoch
#  Average loss 1.469
# Accuracy of the network on the 10000 test images: 58.370000 %
# This is global 372 epoch
#  Average loss 1.438
# Accuracy of the network on the 10000 test images: 58.840000 %
# This is global 373 epoch
#  Average loss 1.452
# Accuracy of the network on the 10000 test images: 59.190000 %
# This is global 374 epoch
#  Average loss 1.609
# Accuracy of the network on the 10000 test images: 58.410000 %
# This is global 375 epoch
#  Average loss 1.477
# Accuracy of the network on the 10000 test images: 58.640000 %
# This is global 376 epoch
#  Average loss 1.632
# Accuracy of the network on the 10000 test images: 57.930000 %
# This is global 377 epoch
#  Average loss 1.494
# Accuracy of the network on the 10000 test images: 57.960000 %
# This is global 378 epoch
#  Average loss 1.534
# Accuracy of the network on the 10000 test images: 58.690000 %
# This is global 379 epoch
#  Average loss 1.636
# Accuracy of the network on the 10000 test images: 58.360000 %
# This is global 380 epoch
#  Average loss 1.579
# Accuracy of the network on the 10000 test images: 58.000000 %
# This is global 381 epoch
#  Average loss 1.768
# Accuracy of the network on the 10000 test images: 57.850000 %
# This is global 382 epoch
#  Average loss 2.016
# Accuracy of the network on the 10000 test images: 58.310000 %
# This is global 383 epoch
#  Average loss 1.648
# Accuracy of the network on the 10000 test images: 59.110000 %
# This is global 384 epoch
#  Average loss 1.380
# Accuracy of the network on the 10000 test images: 59.780000 %
# This is global 385 epoch
#  Average loss 1.375
# Accuracy of the network on the 10000 test images: 60.100000 %
# This is global 386 epoch
#  Average loss 1.332
# Accuracy of the network on the 10000 test images: 60.020000 %
# This is global 387 epoch
#  Average loss 1.481
# Accuracy of the network on the 10000 test images: 59.950000 %
# This is global 388 epoch
#  Average loss 1.529
# Accuracy of the network on the 10000 test images: 59.670000 %
# This is global 389 epoch
#  Average loss 1.734
# Accuracy of the network on the 10000 test images: 59.290000 %
# This is global 390 epoch
#  Average loss 1.388
# Accuracy of the network on the 10000 test images: 59.860000 %
# This is global 391 epoch
#  Average loss 1.328
# Accuracy of the network on the 10000 test images: 60.290000 %
# This is global 392 epoch
#  Average loss 1.407
# Accuracy of the network on the 10000 test images: 60.130000 %
# This is global 393 epoch
#  Average loss 1.702
# Accuracy of the network on the 10000 test images: 59.690000 %
# This is global 394 epoch
#  Average loss 1.450
# Accuracy of the network on the 10000 test images: 60.010000 %
# This is global 395 epoch
#  Average loss 1.305
# Accuracy of the network on the 10000 test images: 60.280000 %
# This is global 396 epoch
#  Average loss 1.528
# Accuracy of the network on the 10000 test images: 60.440000 %
# This is global 397 epoch
#  Average loss 1.571
# Accuracy of the network on the 10000 test images: 59.850000 %
# This is global 398 epoch
#  Average loss 1.497
# Accuracy of the network on the 10000 test images: 58.970000 %
# This is global 399 epoch
#  Average loss 1.516
# Accuracy of the network on the 10000 test images: 59.170000 %
# This is global 400 epoch
#  Average loss 1.504
# Accuracy of the network on the 10000 test images: 59.210000 %
# This is global 401 epoch
#  Average loss 1.460
# Accuracy of the network on the 10000 test images: 59.290000 %
# This is global 402 epoch
#  Average loss 1.753
# Accuracy of the network on the 10000 test images: 59.850000 %
# This is global 403 epoch
#  Average loss 1.315
# Accuracy of the network on the 10000 test images: 59.830000 %
# This is global 404 epoch
#  Average loss 1.427
# Accuracy of the network on the 10000 test images: 60.360000 %
# This is global 405 epoch
#  Average loss 1.408
# Accuracy of the network on the 10000 test images: 60.750000 %
# This is global 406 epoch
#  Average loss 1.353
# Accuracy of the network on the 10000 test images: 60.300000 %
# This is global 407 epoch
#  Average loss 1.470
# Accuracy of the network on the 10000 test images: 59.700000 %
# This is global 408 epoch
#  Average loss 1.443
# Accuracy of the network on the 10000 test images: 60.820000 %
# This is global 409 epoch
#  Average loss 1.464
# Accuracy of the network on the 10000 test images: 60.240000 %
# This is global 410 epoch
#  Average loss 1.395
# Accuracy of the network on the 10000 test images: 60.550000 %
# This is global 411 epoch
#  Average loss 1.600
# Accuracy of the network on the 10000 test images: 59.750000 %
# This is global 412 epoch
#  Average loss 1.556
# Accuracy of the network on the 10000 test images: 60.140000 %
# This is global 413 epoch
#  Average loss 1.379
# Accuracy of the network on the 10000 test images: 60.190000 %
# This is global 414 epoch
#  Average loss 1.687
# Accuracy of the network on the 10000 test images: 60.790000 %
# This is global 415 epoch
#  Average loss 1.312
# Accuracy of the network on the 10000 test images: 60.950000 %
# This is global 416 epoch
#  Average loss 1.367
# Accuracy of the network on the 10000 test images: 60.710000 %
# This is global 417 epoch
#  Average loss 1.499
# Accuracy of the network on the 10000 test images: 60.970000 %
# This is global 418 epoch
#  Average loss 1.297
# Accuracy of the network on the 10000 test images: 61.160000 %
# This is global 419 epoch
#  Average loss 2.247
# Accuracy of the network on the 10000 test images: 58.730000 %
# This is global 420 epoch
#  Average loss 1.429
# Accuracy of the network on the 10000 test images: 59.460000 %
# This is global 421 epoch
#  Average loss 1.358
# Accuracy of the network on the 10000 test images: 60.360000 %
# This is global 422 epoch
#  Average loss 1.367
# Accuracy of the network on the 10000 test images: 61.040000 %
# This is global 423 epoch
#  Average loss 1.355
# Accuracy of the network on the 10000 test images: 61.200000 %
# This is global 424 epoch
#  Average loss 1.334
# Accuracy of the network on the 10000 test images: 61.260000 %
# This is global 425 epoch
#  Average loss 1.313
# Accuracy of the network on the 10000 test images: 61.060000 %
# This is global 426 epoch
#  Average loss 1.492
# Accuracy of the network on the 10000 test images: 60.710000 %
# This is global 427 epoch
#  Average loss 1.396
# Accuracy of the network on the 10000 test images: 60.610000 %
# This is global 428 epoch
#  Average loss 1.366
# Accuracy of the network on the 10000 test images: 60.630000 %
# This is global 429 epoch
#  Average loss 1.512
# Accuracy of the network on the 10000 test images: 61.540000 %
# This is global 430 epoch
#  Average loss 1.385
# Accuracy of the network on the 10000 test images: 61.190000 %
# This is global 431 epoch
#  Average loss 1.411
# Accuracy of the network on the 10000 test images: 60.980000 %
# This is global 432 epoch
#  Average loss 1.497
# Accuracy of the network on the 10000 test images: 61.190000 %
# This is global 433 epoch
#  Average loss 1.266
# Accuracy of the network on the 10000 test images: 61.320000 %
# This is global 434 epoch
#  Average loss 1.421
# Accuracy of the network on the 10000 test images: 61.010000 %
# This is global 435 epoch
#  Average loss 1.445
# Accuracy of the network on the 10000 test images: 61.070000 %
# This is global 436 epoch
#  Average loss 1.388
# Accuracy of the network on the 10000 test images: 61.280000 %
# This is global 437 epoch
#  Average loss 1.411
# Accuracy of the network on the 10000 test images: 60.610000 %
# This is global 438 epoch
#  Average loss 1.360
# Accuracy of the network on the 10000 test images: 60.920000 %
# This is global 439 epoch
#  Average loss 1.546
# Accuracy of the network on the 10000 test images: 59.910000 %
# This is global 440 epoch
#  Average loss 1.675
# Accuracy of the network on the 10000 test images: 58.440000 %
# This is global 441 epoch
#  Average loss 1.744
# Accuracy of the network on the 10000 test images: 60.510000 %
# This is global 442 epoch
#  Average loss 1.380
# Accuracy of the network on the 10000 test images: 60.650000 %
# This is global 443 epoch
#  Average loss 1.272
# Accuracy of the network on the 10000 test images: 60.770000 %
# This is global 444 epoch
#  Average loss 1.345
# Accuracy of the network on the 10000 test images: 60.540000 %
# This is global 445 epoch
#  Average loss 1.541
# Accuracy of the network on the 10000 test images: 61.290000 %
# This is global 446 epoch
#  Average loss 1.304
# Accuracy of the network on the 10000 test images: 61.770000 %
# This is global 447 epoch
#  Average loss 1.525
# Accuracy of the network on the 10000 test images: 60.210000 %
# This is global 448 epoch
#  Average loss 1.406
# Accuracy of the network on the 10000 test images: 60.180000 %
# This is global 449 epoch
#  Average loss 1.460
# Accuracy of the network on the 10000 test images: 60.760000 %
# This is global 450 epoch
#  Average loss 1.421
# Accuracy of the network on the 10000 test images: 61.200000 %
# This is global 451 epoch
#  Average loss 1.390
# Accuracy of the network on the 10000 test images: 61.150000 %
# This is global 452 epoch
#  Average loss 1.374
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 453 epoch
#  Average loss 1.349
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 454 epoch
#  Average loss 1.494
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 455 epoch
#  Average loss 1.449
# Accuracy of the network on the 10000 test images: 61.720000 %
# This is global 456 epoch
#  Average loss 1.386
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 457 epoch
#  Average loss 1.385
# Accuracy of the network on the 10000 test images: 61.860000 %
# This is global 458 epoch
#  Average loss 1.449
# Accuracy of the network on the 10000 test images: 61.370000 %
# This is global 459 epoch
#  Average loss 1.295
# Accuracy of the network on the 10000 test images: 61.490000 %
# This is global 460 epoch
#  Average loss 1.456
# Accuracy of the network on the 10000 test images: 60.310000 %
# This is global 461 epoch
#  Average loss 1.767
# Accuracy of the network on the 10000 test images: 59.890000 %
# This is global 462 epoch
#  Average loss 1.785
# Accuracy of the network on the 10000 test images: 59.920000 %
# This is global 463 epoch
#  Average loss 1.379
# Accuracy of the network on the 10000 test images: 60.350000 %
# This is global 464 epoch
#  Average loss 1.345
# Accuracy of the network on the 10000 test images: 60.630000 %
# This is global 465 epoch
#  Average loss 1.556
# Accuracy of the network on the 10000 test images: 61.210000 %
# This is global 466 epoch
#  Average loss 1.618
# Accuracy of the network on the 10000 test images: 60.260000 %
# This is global 467 epoch
#  Average loss 1.677
# Accuracy of the network on the 10000 test images: 61.050000 %
# This is global 468 epoch
#  Average loss 1.405
# Accuracy of the network on the 10000 test images: 61.750000 %
# This is global 469 epoch
#  Average loss 1.397
# Accuracy of the network on the 10000 test images: 62.060000 %
# This is global 470 epoch
#  Average loss 1.308
# Accuracy of the network on the 10000 test images: 62.340000 %
# This is global 471 epoch
#  Average loss 1.286
# Accuracy of the network on the 10000 test images: 62.730000 %
# This is global 472 epoch
#  Average loss 1.425
# Accuracy of the network on the 10000 test images: 62.700000 %
# This is global 473 epoch
#  Average loss 1.402
# Accuracy of the network on the 10000 test images: 62.560000 %
# This is global 474 epoch
#  Average loss 1.460
# Accuracy of the network on the 10000 test images: 61.910000 %
# This is global 475 epoch
#  Average loss 1.662
# Accuracy of the network on the 10000 test images: 60.970000 %
# This is global 476 epoch
#  Average loss 1.570
# Accuracy of the network on the 10000 test images: 61.390000 %
# This is global 477 epoch
#  Average loss 1.382
# Accuracy of the network on the 10000 test images: 62.110000 %
# This is global 478 epoch
#  Average loss 1.370
# Accuracy of the network on the 10000 test images: 62.090000 %
# This is global 479 epoch
#  Average loss 1.476
# Accuracy of the network on the 10000 test images: 62.420000 %
# This is global 480 epoch
#  Average loss 1.389
# Accuracy of the network on the 10000 test images: 62.320000 %
# This is global 481 epoch
#  Average loss 1.323
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 482 epoch
#  Average loss 1.502
# Accuracy of the network on the 10000 test images: 61.620000 %
# This is global 483 epoch
#  Average loss 1.398
# Accuracy of the network on the 10000 test images: 61.420000 %
# This is global 484 epoch
#  Average loss 1.590
# Accuracy of the network on the 10000 test images: 61.490000 %
# This is global 485 epoch
#  Average loss 1.380
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 486 epoch
#  Average loss 1.476
# Accuracy of the network on the 10000 test images: 61.350000 %
# This is global 487 epoch
#  Average loss 1.426
# Accuracy of the network on the 10000 test images: 61.600000 %
# This is global 488 epoch
#  Average loss 1.454
# Accuracy of the network on the 10000 test images: 62.210000 %
# This is global 489 epoch
#  Average loss 1.670
# Accuracy of the network on the 10000 test images: 61.440000 %
# This is global 490 epoch
#  Average loss 1.485
# Accuracy of the network on the 10000 test images: 61.640000 %
# This is global 491 epoch
#  Average loss 1.377
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 492 epoch
#  Average loss 1.237
# Accuracy of the network on the 10000 test images: 62.290000 %
# This is global 493 epoch
#  Average loss 1.371
# Accuracy of the network on the 10000 test images: 62.240000 %
# This is global 494 epoch
#  Average loss 1.544
# Accuracy of the network on the 10000 test images: 62.230000 %
# This is global 495 epoch
#  Average loss 1.257
# Accuracy of the network on the 10000 test images: 62.150000 %
# This is global 496 epoch
#  Average loss 1.302
# Accuracy of the network on the 10000 test images: 62.650000 %
# This is global 497 epoch
#  Average loss 1.304
# Accuracy of the network on the 10000 test images: 62.650000 %
# This is global 498 epoch
#  Average loss 1.340
# Accuracy of the network on the 10000 test images: 62.180000 %
# This is global 499 epoch
#  Average loss 1.337
# Accuracy of the network on the 10000 test images: 61.300000 %
# This is global 500 epoch
#  Average loss 1.429
# Accuracy of the network on the 10000 test images: 61.870000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_iid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.115
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 2 epoch
#  Average loss 2.158
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 3 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 9.300000 %
# This is global 4 epoch
#  Average loss 2.196
# Accuracy of the network on the 10000 test images: 9.140000 %
# This is global 5 epoch
#  Average loss 2.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 6 epoch
#  Average loss 2.202
# Accuracy of the network on the 10000 test images: 10.370000 %
# This is global 7 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 9.350000 %
# This is global 8 epoch
#  Average loss 2.197
# Accuracy of the network on the 10000 test images: 8.780000 %
# This is global 9 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 10 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 10.390000 %
# This is global 11 epoch
#  Average loss 2.210
# Accuracy of the network on the 10000 test images: 10.480000 %
# This is global 12 epoch
#  Average loss 2.143
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 13 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 14 epoch
#  Average loss 2.082
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 15 epoch
#  Average loss 2.133
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 16 epoch
#  Average loss 2.141
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 17 epoch
#  Average loss 2.088
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 18 epoch
#  Average loss 2.124
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 19 epoch
#  Average loss 2.152
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 20 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 10.420000 %
# This is global 21 epoch
#  Average loss 2.237
# Accuracy of the network on the 10000 test images: 10.430000 %
# This is global 22 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.560000 %
# This is global 23 epoch
#  Average loss 2.142
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 24 epoch
#  Average loss 2.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 25 epoch
#  Average loss 2.113
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 26 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 27 epoch
#  Average loss 2.076
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 28 epoch
#  Average loss 2.224
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 29 epoch
#  Average loss 2.110
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 30 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 31 epoch
#  Average loss 2.184
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 32 epoch
#  Average loss 2.070
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 33 epoch
#  Average loss 2.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 34 epoch
#  Average loss 2.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 35 epoch
#  Average loss 2.047
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 36 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 37 epoch
#  Average loss 2.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 38 epoch
#  Average loss 2.052
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 39 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 40 epoch
#  Average loss 2.184
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 41 epoch
#  Average loss 2.136
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 42 epoch
#  Average loss 2.074
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 43 epoch
#  Average loss 2.172
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 44 epoch
#  Average loss 2.116
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 45 epoch
#  Average loss 2.067
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 46 epoch
#  Average loss 2.129
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 47 epoch
#  Average loss 2.033
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 48 epoch
#  Average loss 2.182
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 49 epoch
#  Average loss 2.122
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 50 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 51 epoch
#  Average loss 2.146
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 52 epoch
#  Average loss 2.170
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 53 epoch
#  Average loss 2.119
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 54 epoch
#  Average loss 2.209
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 55 epoch
#  Average loss 2.032
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 56 epoch
#  Average loss 2.113
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 57 epoch
#  Average loss 2.259
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 58 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 59 epoch
#  Average loss 2.045
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 60 epoch
#  Average loss 2.014
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 61 epoch
#  Average loss 2.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 62 epoch
#  Average loss 2.340
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 63 epoch
#  Average loss 2.156
# Accuracy of the network on the 10000 test images: 9.960000 %
# This is global 64 epoch
#  Average loss 2.180
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 65 epoch
#  Average loss 2.114
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 66 epoch
#  Average loss 2.130
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 67 epoch
#  Average loss 2.150
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 68 epoch
#  Average loss 2.086
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 69 epoch
#  Average loss 2.046
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 70 epoch
#  Average loss 2.070
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 71 epoch
#  Average loss 2.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 72 epoch
#  Average loss 2.230
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 73 epoch
#  Average loss 2.065
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 74 epoch
#  Average loss 2.166
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 75 epoch
#  Average loss 2.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 76 epoch
#  Average loss 1.953
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 77 epoch
#  Average loss 2.117
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 78 epoch
#  Average loss 2.088
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 79 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 80 epoch
#  Average loss 2.052
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 81 epoch
#  Average loss 2.089
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 82 epoch
#  Average loss 2.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 83 epoch
#  Average loss 2.198
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 84 epoch
#  Average loss 2.051
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 85 epoch
#  Average loss 2.109
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 86 epoch
#  Average loss 2.287
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 87 epoch
#  Average loss 2.296
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 88 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 89 epoch
#  Average loss 2.363
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 90 epoch
#  Average loss 2.200
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 91 epoch
#  Average loss 2.136
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 92 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 11.570000 %
# This is global 93 epoch
#  Average loss 2.073
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 94 epoch
#  Average loss 2.142
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 95 epoch
#  Average loss 2.093
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 96 epoch
#  Average loss 1.985
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 97 epoch
#  Average loss 2.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 98 epoch
#  Average loss 2.030
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 99 epoch
#  Average loss 2.208
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 100 epoch
#  Average loss 2.179
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 101 epoch
#  Average loss 2.161
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 102 epoch
#  Average loss 2.167
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 103 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 104 epoch
#  Average loss 2.085
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 105 epoch
#  Average loss 2.100
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 106 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 107 epoch
#  Average loss 2.143
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 108 epoch
#  Average loss 2.045
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 109 epoch
#  Average loss 2.140
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 110 epoch
#  Average loss 2.172
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 111 epoch
#  Average loss 2.133
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 112 epoch
#  Average loss 2.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 113 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 10.090000 %
# This is global 114 epoch
#  Average loss 2.143
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 115 epoch
#  Average loss 2.086
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 116 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 117 epoch
#  Average loss 2.088
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 118 epoch
#  Average loss 2.183
# Accuracy of the network on the 10000 test images: 11.070000 %
# This is global 119 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 120 epoch
#  Average loss 2.225
# Accuracy of the network on the 10000 test images: 10.360000 %
# This is global 121 epoch
#  Average loss 2.135
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 122 epoch
#  Average loss 2.171
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 123 epoch
#  Average loss 2.242
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 124 epoch
#  Average loss 2.100
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 125 epoch
#  Average loss 2.048
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 126 epoch
#  Average loss 2.194
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 127 epoch
#  Average loss 2.107
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 128 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 129 epoch
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 130 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 131 epoch
#  Average loss 2.232
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 132 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 133 epoch
#  Average loss 2.220
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 134 epoch
#  Average loss 2.160
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 135 epoch
#  Average loss 2.115
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 136 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 137 epoch
#  Average loss 2.085
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 138 epoch
#  Average loss 2.170
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 139 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 140 epoch
#  Average loss 2.137
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 141 epoch
#  Average loss 2.049
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 142 epoch
#  Average loss 2.101
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 143 epoch
#  Average loss 2.072
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 144 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 145 epoch
#  Average loss 2.049
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 146 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 147 epoch
#  Average loss 2.173
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 148 epoch
#  Average loss 1.979
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 149 epoch
#  Average loss 2.088
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 150 epoch
#  Average loss 2.185
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 151 epoch
#  Average loss 2.087
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 152 epoch
#  Average loss 2.122
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 153 epoch
#  Average loss 2.044
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 154 epoch
#  Average loss 2.180
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 155 epoch
#  Average loss 2.097
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 156 epoch
#  Average loss 1.967
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 157 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 158 epoch
#  Average loss 2.268
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 159 epoch
#  Average loss 2.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 160 epoch
#  Average loss 1.999
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 161 epoch
#  Average loss 2.176
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 162 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 163 epoch
#  Average loss 2.119
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 164 epoch
#  Average loss 2.054
# Accuracy of the network on the 10000 test images: 10.120000 %
# This is global 165 epoch
#  Average loss 2.099
# Accuracy of the network on the 10000 test images: 10.240000 %
# This is global 166 epoch
#  Average loss 2.292
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 167 epoch
#  Average loss 2.197
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 168 epoch
#  Average loss 2.248
# Accuracy of the network on the 10000 test images: 11.120000 %
# This is global 169 epoch
#  Average loss 2.127
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 170 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 171 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 172 epoch
#  Average loss 2.131
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 173 epoch
#  Average loss 2.271
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 174 epoch
#  Average loss 2.098
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 175 epoch
#  Average loss 2.106
# Accuracy of the network on the 10000 test images: 10.110000 %
# This is global 176 epoch
#  Average loss 2.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 177 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 178 epoch
#  Average loss 2.140
# Accuracy of the network on the 10000 test images: 10.990000 %
# This is global 179 epoch
#  Average loss 2.231
# Accuracy of the network on the 10000 test images: 11.130000 %
# This is global 180 epoch
#  Average loss 2.050
# Accuracy of the network on the 10000 test images: 15.410000 %
# This is global 181 epoch
#  Average loss 2.159
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 182 epoch
#  Average loss 2.159
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 183 epoch
#  Average loss 2.028
# Accuracy of the network on the 10000 test images: 10.730000 %
# This is global 184 epoch
#  Average loss 1.990
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 185 epoch
#  Average loss 2.059
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 186 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 187 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 188 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 189 epoch
#  Average loss 2.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 190 epoch
#  Average loss 2.233
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 191 epoch
#  Average loss 2.081
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 192 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 193 epoch
#  Average loss 2.038
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 194 epoch
#  Average loss 2.004
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 195 epoch
#  Average loss 1.988
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 196 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 197 epoch
#  Average loss 1.941
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 198 epoch
#  Average loss 2.042
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 199 epoch
#  Average loss 1.968
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 200 epoch
#  Average loss 2.402
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 201 epoch
#  Average loss 2.125
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 202 epoch
#  Average loss 2.010
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 203 epoch
#  Average loss 2.231
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 204 epoch
#  Average loss 1.991
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 205 epoch
#  Average loss 2.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 206 epoch
#  Average loss 2.313
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 207 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 208 epoch
#  Average loss 2.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 209 epoch
#  Average loss 2.114
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 210 epoch
#  Average loss 2.097
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 211 epoch
#  Average loss 2.037
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 212 epoch
#  Average loss 2.066
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 213 epoch
#  Average loss 2.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 214 epoch
#  Average loss 2.109
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 215 epoch
#  Average loss 2.059
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 216 epoch
#  Average loss 2.013
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 217 epoch
#  Average loss 1.981
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 218 epoch
#  Average loss 1.988
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 219 epoch
#  Average loss 2.229
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 220 epoch
#  Average loss 2.356
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 221 epoch
#  Average loss 2.083
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 222 epoch
#  Average loss 2.209
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 223 epoch
#  Average loss 2.164
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 224 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 225 epoch
#  Average loss 2.072
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 226 epoch
#  Average loss 2.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 227 epoch
#  Average loss 2.110
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 228 epoch
#  Average loss 2.148
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 229 epoch
#  Average loss 2.110
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 230 epoch
#  Average loss 2.015
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 231 epoch
#  Average loss 2.007
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 232 epoch
#  Average loss 2.212
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 233 epoch
#  Average loss 2.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 234 epoch
#  Average loss 1.962
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 235 epoch
#  Average loss 1.821
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 236 epoch
#  Average loss 2.148
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 237 epoch
#  Average loss 2.168
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 238 epoch
#  Average loss 2.008
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 239 epoch
#  Average loss 2.106
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 240 epoch
#  Average loss 2.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 241 epoch
#  Average loss 2.170
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 242 epoch
#  Average loss 1.909
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 243 epoch
#  Average loss 2.099
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 244 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 12.310000 %
# This is global 245 epoch
#  Average loss 2.139
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 246 epoch
#  Average loss 2.253
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 247 epoch
#  Average loss 2.380
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 248 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 249 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 250 epoch
#  Average loss 2.107
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 251 epoch
#  Average loss 2.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 252 epoch
#  Average loss 2.131
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 253 epoch
#  Average loss 2.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 254 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 255 epoch
#  Average loss 2.031
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 256 epoch
#  Average loss 2.127
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 257 epoch
#  Average loss 2.040
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 258 epoch
#  Average loss 2.417
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 259 epoch
#  Average loss 2.156
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 260 epoch
#  Average loss 2.104
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 261 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 262 epoch
#  Average loss 2.133
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 263 epoch
#  Average loss 2.183
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 264 epoch
#  Average loss 2.142
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 265 epoch
#  Average loss 2.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 266 epoch
#  Average loss 2.100
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 267 epoch
#  Average loss 2.036
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 268 epoch
#  Average loss 2.162
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 269 epoch
#  Average loss 2.139
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 270 epoch
#  Average loss 2.155
# Accuracy of the network on the 10000 test images: 10.640000 %
# This is global 271 epoch
#  Average loss 2.028
# Accuracy of the network on the 10000 test images: 10.790000 %
# This is global 272 epoch
#  Average loss 2.013
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 273 epoch
#  Average loss 2.151
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 274 epoch
#  Average loss 2.066
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 275 epoch
#  Average loss 2.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 276 epoch
#  Average loss 2.222
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 277 epoch
#  Average loss 2.023
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 278 epoch
#  Average loss 2.050
# Accuracy of the network on the 10000 test images: 13.400000 %
# This is global 279 epoch
#  Average loss 2.249
# Accuracy of the network on the 10000 test images: 13.430000 %
# This is global 280 epoch
#  Average loss 2.172
# Accuracy of the network on the 10000 test images: 13.410000 %
# This is global 281 epoch
#  Average loss 2.122
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 282 epoch
#  Average loss 2.016
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 283 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 284 epoch
#  Average loss 2.057
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 285 epoch
#  Average loss 2.071
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 286 epoch
#  Average loss 2.270
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 287 epoch
#  Average loss 2.055
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 288 epoch
#  Average loss 2.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 289 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 290 epoch
#  Average loss 2.085
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 291 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 292 epoch
#  Average loss 2.051
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 293 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 294 epoch
#  Average loss 2.109
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 295 epoch
#  Average loss 2.063
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 296 epoch
#  Average loss 2.127
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 297 epoch
#  Average loss 2.038
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 298 epoch
#  Average loss 2.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 299 epoch
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 300 epoch
#  Average loss 2.265
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 301 epoch
#  Average loss 2.129
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 302 epoch
#  Average loss 2.108
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 303 epoch
#  Average loss 2.157
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 304 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 305 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 306 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 307 epoch
#  Average loss 2.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 308 epoch
#  Average loss 2.166
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 309 epoch
#  Average loss 2.028
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 310 epoch
#  Average loss 2.020
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 311 epoch
#  Average loss 2.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 312 epoch
#  Average loss 2.028
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 313 epoch
#  Average loss 2.186
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 314 epoch
#  Average loss 2.169
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 315 epoch
#  Average loss 1.951
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 316 epoch
#  Average loss 2.048
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 317 epoch
#  Average loss 2.055
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 318 epoch
#  Average loss 2.257
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 319 epoch
#  Average loss 2.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 320 epoch
#  Average loss 2.044
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 321 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 322 epoch
#  Average loss 2.094
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 323 epoch
#  Average loss 2.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 324 epoch
#  Average loss 2.143
# Accuracy of the network on the 10000 test images: 12.110000 %
# This is global 325 epoch
#  Average loss 2.194
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 326 epoch
#  Average loss 2.108
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 327 epoch
#  Average loss 2.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 328 epoch
#  Average loss 2.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 329 epoch
#  Average loss 2.259
# Accuracy of the network on the 10000 test images: 11.060000 %
# This is global 330 epoch
#  Average loss 2.107
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 331 epoch
#  Average loss 2.129
# Accuracy of the network on the 10000 test images: 12.520000 %
# This is global 332 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 333 epoch
#  Average loss 2.132
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 334 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 335 epoch
#  Average loss 2.144
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 336 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 337 epoch
#  Average loss 2.182
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 338 epoch
#  Average loss 2.084
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 339 epoch
#  Average loss 2.061
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 340 epoch
#  Average loss 2.237
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 341 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 342 epoch
#  Average loss 2.230
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 343 epoch
#  Average loss 2.057
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 344 epoch
#  Average loss 2.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 345 epoch
#  Average loss 2.130
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 346 epoch
#  Average loss 2.178
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 347 epoch
#  Average loss 2.179
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 348 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 349 epoch
#  Average loss 2.133
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 350 epoch
#  Average loss 2.135
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 351 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 352 epoch
#  Average loss 2.107
# Accuracy of the network on the 10000 test images: 15.350000 %
# This is global 353 epoch
#  Average loss 2.019
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 354 epoch
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 12.120000 %
# This is global 355 epoch
#  Average loss 1.961
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 356 epoch
#  Average loss 2.261
# Accuracy of the network on the 10000 test images: 12.410000 %
# This is global 357 epoch
#  Average loss 2.115
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 358 epoch
#  Average loss 2.135
# Accuracy of the network on the 10000 test images: 14.500000 %
# This is global 359 epoch
#  Average loss 2.014
# Accuracy of the network on the 10000 test images: 14.810000 %
# This is global 360 epoch
#  Average loss 2.176
# Accuracy of the network on the 10000 test images: 15.050000 %
# This is global 361 epoch
#  Average loss 2.046
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 362 epoch
#  Average loss 2.144
# Accuracy of the network on the 10000 test images: 15.510000 %
# This is global 363 epoch
#  Average loss 2.089
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 364 epoch
#  Average loss 2.089
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 365 epoch
#  Average loss 2.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 366 epoch
#  Average loss 2.022
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 367 epoch
#  Average loss 2.127
# Accuracy of the network on the 10000 test images: 11.020000 %
# This is global 368 epoch
#  Average loss 2.099
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 369 epoch
#  Average loss 2.195
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 370 epoch
#  Average loss 2.156
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 371 epoch
#  Average loss 2.087
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 372 epoch
#  Average loss 2.139
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 373 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 374 epoch
#  Average loss 2.133
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 375 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 376 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 377 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.040000 %
# This is global 378 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 379 epoch
#  Average loss 2.136
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 380 epoch
#  Average loss 2.113
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 381 epoch
#  Average loss 2.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 382 epoch
#  Average loss 2.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 383 epoch
#  Average loss 2.022
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 384 epoch
#  Average loss 2.021
# Accuracy of the network on the 10000 test images: 11.480000 %
# This is global 385 epoch
#  Average loss 2.207
# Accuracy of the network on the 10000 test images: 10.680000 %
# This is global 386 epoch
#  Average loss 2.263
# Accuracy of the network on the 10000 test images: 10.880000 %
# This is global 387 epoch
#  Average loss 2.111
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 388 epoch
#  Average loss 2.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 389 epoch
#  Average loss 2.144
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 390 epoch
#  Average loss 2.098
# Accuracy of the network on the 10000 test images: 14.690000 %
# This is global 391 epoch
#  Average loss 2.119
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 392 epoch
#  Average loss 2.099
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 393 epoch
#  Average loss 2.117
# Accuracy of the network on the 10000 test images: 13.830000 %
# This is global 394 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 395 epoch
#  Average loss 2.090
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 396 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 13.680000 %
# This is global 397 epoch
#  Average loss 2.140
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 398 epoch
#  Average loss 2.003
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 399 epoch
#  Average loss 2.129
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 400 epoch
#  Average loss 2.029
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 401 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 402 epoch
#  Average loss 2.101
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 403 epoch
#  Average loss 2.132
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 404 epoch
#  Average loss 2.051
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 405 epoch
#  Average loss 2.246
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 406 epoch
#  Average loss 2.098
# Accuracy of the network on the 10000 test images: 11.640000 %
# This is global 407 epoch
#  Average loss 2.028
# Accuracy of the network on the 10000 test images: 12.000000 %
# This is global 408 epoch
#  Average loss 2.257
# Accuracy of the network on the 10000 test images: 12.080000 %
# This is global 409 epoch
#  Average loss 2.146
# Accuracy of the network on the 10000 test images: 12.420000 %
# This is global 410 epoch
#  Average loss 2.200
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 411 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 412 epoch
#  Average loss 2.023
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 413 epoch
#  Average loss 2.115
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 414 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 415 epoch
#  Average loss 2.038
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 416 epoch
#  Average loss 2.126
# Accuracy of the network on the 10000 test images: 10.100000 %
# This is global 417 epoch
#  Average loss 2.025
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 418 epoch
#  Average loss 2.183
# Accuracy of the network on the 10000 test images: 11.420000 %
# This is global 419 epoch
#  Average loss 2.117
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 420 epoch
#  Average loss 2.083
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 421 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 422 epoch
#  Average loss 2.113
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 423 epoch
#  Average loss 2.151
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 424 epoch
#  Average loss 2.077
# Accuracy of the network on the 10000 test images: 12.140000 %
# This is global 425 epoch
#  Average loss 2.279
# Accuracy of the network on the 10000 test images: 12.360000 %
# This is global 426 epoch
#  Average loss 2.180
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 427 epoch
#  Average loss 2.074
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 428 epoch
#  Average loss 2.027
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 429 epoch
#  Average loss 2.008
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 430 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 431 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 12.910000 %
# This is global 432 epoch
#  Average loss 2.003
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 433 epoch
#  Average loss 2.090
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 434 epoch
#  Average loss 2.477
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 435 epoch
#  Average loss 2.073
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 436 epoch
#  Average loss 2.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 437 epoch
#  Average loss 2.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 438 epoch
#  Average loss 2.170
# Accuracy of the network on the 10000 test images: 12.220000 %
# This is global 439 epoch
#  Average loss 2.203
# Accuracy of the network on the 10000 test images: 12.410000 %
# This is global 440 epoch
#  Average loss 2.218
# Accuracy of the network on the 10000 test images: 14.360000 %
# This is global 441 epoch
#  Average loss 2.097
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 442 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 443 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 444 epoch
#  Average loss 1.973
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 445 epoch
#  Average loss 2.111
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 446 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# ...
# This is global 4853 epoch
#  Average loss 2.115
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4854 epoch
#  Average loss 2.126
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4855 epoch
#  Average loss 2.090
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 4856 epoch
#  Average loss 2.148
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4857 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4858 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4859 epoch
#  Average loss 1.935
# Accuracy of the network on the 10000 test images: 10.880000 %
# This is global 4860 epoch
#  Average loss 2.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4861 epoch
#  Average loss 2.268
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4862 epoch
#  Average loss 2.160
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4863 epoch
#  Average loss 2.113
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4864 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4865 epoch
#  Average loss 2.091
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4866 epoch
#  Average loss 1.955
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4867 epoch
#  Average loss 2.176
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4868 epoch
#  Average loss 2.298
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4869 epoch
#  Average loss 2.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4870 epoch
#  Average loss 2.184
# Accuracy of the network on the 10000 test images: 10.190000 %
# This is global 4871 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.160000 %
# This is global 4872 epoch
#  Average loss 2.281
# Accuracy of the network on the 10000 test images: 10.340000 %
# This is global 4873 epoch
#  Average loss 2.153
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4874 epoch
#  Average loss 2.116
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4875 epoch
#  Average loss 2.168
# Accuracy of the network on the 10000 test images: 11.760000 %
# This is global 4876 epoch
#  Average loss 2.154
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4877 epoch
#  Average loss 2.124
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4878 epoch
#  Average loss 2.161
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4879 epoch
#  Average loss 2.221
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4880 epoch
#  Average loss 2.181
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4881 epoch
#  Average loss 2.143
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 4882 epoch
#  Average loss 2.123
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 4883 epoch
#  Average loss 2.098
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4884 epoch
#  Average loss 2.193
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4885 epoch
#  Average loss 2.106
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4886 epoch
#  Average loss 2.082
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4887 epoch
#  Average loss 2.107
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4888 epoch
#  Average loss 2.106
# Accuracy of the network on the 10000 test images: 10.080000 %
# This is global 4889 epoch
#  Average loss 2.037
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4890 epoch
#  Average loss 2.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4891 epoch
#  Average loss 1.995
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4892 epoch
#  Average loss 2.243
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4893 epoch
#  Average loss 2.204
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4894 epoch
#  Average loss 2.090
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4895 epoch
#  Average loss 2.016
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4896 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 4897 epoch
#  Average loss 2.150
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4898 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 4899 epoch
#  Average loss 2.063
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4900 epoch
#  Average loss 2.146
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4901 epoch
#  Average loss 2.170
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 4902 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4903 epoch
#  Average loss 2.131
# Accuracy of the network on the 10000 test images: 10.060000 %
# This is global 4904 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4905 epoch
#  Average loss 2.130
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4906 epoch
#  Average loss 2.010
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4907 epoch
#  Average loss 2.080
# Accuracy of the network on the 10000 test images: 10.220000 %
# This is global 4908 epoch
#  Average loss 1.980
# Accuracy of the network on the 10000 test images: 10.240000 %
# This is global 4909 epoch
#  Average loss 2.266
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 4910 epoch
#  Average loss 2.104
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4911 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4912 epoch
#  Average loss 2.101
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4913 epoch
#  Average loss 2.055
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4914 epoch
#  Average loss 2.046
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 4915 epoch
#  Average loss 2.183
# Accuracy of the network on the 10000 test images: 10.090000 %
# This is global 4916 epoch
#  Average loss 1.932
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4917 epoch
#  Average loss 2.401
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4918 epoch
#  Average loss 2.158
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4919 epoch
#  Average loss 2.212
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4920 epoch
#  Average loss 2.078
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4921 epoch
#  Average loss 2.111
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4922 epoch
#  Average loss 2.270
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4923 epoch
#  Average loss 2.059
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4924 epoch
#  Average loss 2.005
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4925 epoch
#  Average loss 2.095
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4926 epoch
#  Average loss 2.347
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4927 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 4928 epoch
#  Average loss 2.038
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4929 epoch
#  Average loss 2.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4930 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4931 epoch
#  Average loss 2.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4932 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4933 epoch
#  Average loss 2.147
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4934 epoch
#  Average loss 2.027
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4935 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4936 epoch
#  Average loss 2.206
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4937 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4938 epoch
#  Average loss 2.097
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4939 epoch
#  Average loss 2.055
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4940 epoch
#  Average loss 2.319
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4941 epoch
#  Average loss 2.102
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4942 epoch
#  Average loss 2.134
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4943 epoch
#  Average loss 2.025
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4944 epoch
#  Average loss 2.011
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4945 epoch
#  Average loss 2.200
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4946 epoch
#  Average loss 2.270
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4947 epoch
#  Average loss 1.960
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4948 epoch
#  Average loss 2.073
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4949 epoch
#  Average loss 2.099
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4950 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4951 epoch
#  Average loss 2.271
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4952 epoch
#  Average loss 1.983
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4953 epoch
#  Average loss 2.171
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4954 epoch
#  Average loss 2.132
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4955 epoch
#  Average loss 2.074
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4956 epoch
#  Average loss 2.079
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4957 epoch
#  Average loss 2.052
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4958 epoch
#  Average loss 2.055
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4959 epoch
#  Average loss 2.279
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 4960 epoch
#  Average loss 2.105
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4961 epoch
#  Average loss 2.198
# Accuracy of the network on the 10000 test images: 10.180000 %
# This is global 4962 epoch
#  Average loss 1.964
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4963 epoch
#  Average loss 2.064
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4964 epoch
#  Average loss 2.166
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4965 epoch
#  Average loss 2.035
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4966 epoch
#  Average loss 2.255
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4967 epoch
#  Average loss 2.160
# Accuracy of the network on the 10000 test images: 10.250000 %
# This is global 4968 epoch
#  Average loss 2.021
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4969 epoch
#  Average loss 2.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4970 epoch
#  Average loss 2.092
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4971 epoch
#  Average loss 2.072
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4972 epoch
#  Average loss 2.156
# Accuracy of the network on the 10000 test images: 10.170000 %
# This is global 4973 epoch
#  Average loss 2.161
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4974 epoch
#  Average loss 2.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4975 epoch
#  Average loss 2.168
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4976 epoch
#  Average loss 2.286
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4977 epoch
#  Average loss 2.147
# Accuracy of the network on the 10000 test images: 11.040000 %
# This is global 4978 epoch
#  Average loss 2.112
# Accuracy of the network on the 10000 test images: 10.050000 %
# This is global 4979 epoch
#  Average loss 2.121
# Accuracy of the network on the 10000 test images: 11.650000 %
# This is global 4980 epoch
#  Average loss 2.128
# Accuracy of the network on the 10000 test images: 10.120000 %
# This is global 4981 epoch
#  Average loss 2.186
# Accuracy of the network on the 10000 test images: 11.070000 %
# This is global 4982 epoch
#  Average loss 2.169
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 4983 epoch
#  Average loss 2.124
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4984 epoch
#  Average loss 2.077
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4985 epoch
#  Average loss 2.190
# Accuracy of the network on the 10000 test images: 10.380000 %
# This is global 4986 epoch
#  Average loss 2.050
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4987 epoch
#  Average loss 2.180
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4988 epoch
#  Average loss 2.021
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4989 epoch
#  Average loss 2.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4990 epoch
#  Average loss 2.071
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4991 epoch
#  Average loss 2.305
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4992 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4993 epoch
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4994 epoch
#  Average loss 2.106
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4995 epoch
#  Average loss 2.081
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4996 epoch
#  Average loss 2.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4997 epoch
#  Average loss 2.167
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4998 epoch
#  Average loss 2.176
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4999 epoch
#  Average loss 2.065
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 5000 epoch
#  Average loss 2.076
# Accuracy of the network on the 10000 test images: 10.100000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_noniid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %%
print(max(acc_train))
# Out:
# 24.69
