# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="3"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=1
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
def cifar_dirichlet(dataset, n_nets, alpha=0.5):
    '''
    if dataset == 'mnist':
        X_train, y_train, X_test, y_test = load_mnist_data(datadir)
    elif dataset == 'cifar10':
        X_train, y_train, X_test, y_test = load_cifar10_data(datadir)
    '''
    #X_train=dataset[:][0]
    y_train=torch.zeros(len(dataset),dtype=torch.long)
    print(y_train.dtype)
    for a in range(len(dataset)):
        y_train[a]=(dataset[a][1])
    n_train = len(dataset)
    #X_train.shape[0]
    '''
    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_nets)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_nets)}
    '''
    #elif partition == "hetero-dir":
    min_size = 0
    K = 10
    N=len(dataset)
    N = y_train.shape[0]
    net_dataidx_map = {i: np.array([],dtype='int64') for i in range(n_nets)}

    while min_size < 10:
        idx_batch = [[] for _ in range(n_nets)]
        for k in range(K):
            idx_k = np.where(y_train == k)[0]
            np.random.shuffle(idx_k)
            proportions = np.random.dirichlet(np.repeat(alpha, n_nets))
            ## Balance
            proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
            proportions = proportions/proportions.sum()
            proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
            idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
            min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    #traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    return net_dataidx_map
    #return (X_train, y_train, X_test, y_test, net_dataidx_map, traindata_cls_counts)

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        
        
        
        self.conv1_global = nn.Conv2d(3, 32, 3)
        self.pool_global = nn.MaxPool2d(2, 2)
        self.conv2_global = nn.Conv2d(32, 64, 3)
        self.conv3_global = nn.Conv2d(64, 64, 3)
        self.fc1_global = nn.Linear(64 * 4 * 4, 64)
        self.fc2_global = nn.Linear(64, 10)
        self.freeze_model_global_weights()
        
        self.mse=nn.MSELoss()
        #self.fc3 = nn.Linear(84, 10)
    def freeze_model_global_weights(self):
        for n, m in self.named_modules():
            if hasattr(m, "weight") and m.weight is not None and 'global' in n:
                print(f"==> No gradient to {n}.weight")
                m.weight.requires_grad = False
                if m.weight.grad is not None:
                    print(f"==> Setting gradient of {n}.weight to None")
                    m.weight.grad = None

                if hasattr(m, "bias") and m.bias is not None and 'global' in n:
                    print(f"==> No gradient to {n}.bias")
                    m.bias.requires_grad = False

                    if m.bias.grad is not None:
                        print(f"==> Setting gradient of {n}.bias to None")
                        m.bias.grad = None
    def sync_online_and_global(self):
        state_dict=self.state_dict()
        for key in state_dict:
            if 'global' in key:
                x=(key.split("_global"))
                online=(x[0]+x[1])
                state_dict[key]=state_dict[online]
        self.load_state_dict(state_dict)
        
        
        
    def forward(self, x,online_target=False):
        if online_target==False:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = (F.relu(self.conv3(x)))
            x = x.view(-1, 64*4*4)
            x = F.relu(self.fc1(x))
            x = (self.fc2(x))
            return x
        else:
            x1=copy.deepcopy(x)
            
            
            x = self.pool(F.relu(self.conv1(x)))
            x1 = self.pool_global(F.relu(self.conv1_global(x1)))
            diff=self.mse(x,x1)
            
            x = self.pool(F.relu(self.conv2(x)))
            x1 = self.pool_global(F.relu(self.conv2_global(x1)))
            diff+=self.mse(x,x1)
            
            
            x = (F.relu(self.conv3(x)))
            x1 = (F.relu(self.conv3_global(x1)))
            diff+=self.mse(x,x1)
            
            x = x.view(-1, 64*4*4)
            x1 = x1.view(-1, 64*4*4)
            
            x = F.relu(self.fc1(x))
            x1 = F.relu(self.fc1_global(x1))
            diff+=self.mse(x,x1)
            
            
            x = (self.fc2(x))
            x1 = (self.fc2_global(x1))
            diff+=self.mse(x,x1)
            
            
            return x,diff

# %%
net = Net()
net.to(device)
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
#   (conv1_global): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool_global): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_global): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_global): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1_global): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2_global): Linear(in_features=64, out_features=10, bias=True)
#   (mse): MSELoss()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01,momentum=0.5)
loss_train = []
acc_train=[]

# %%
for epoch in range(0):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    for i, data in enumerate(CIFAR_SGD_trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(labels)

        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
       
        
    if epoch%1==0:
        loss_train.append(loss)
        print(f"epoch: {epoch}")
        print(' Average loss {:.3f}'.format( loss))
        for j in range(1):
            net.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %d %%' % (
                100 * correct / total))
        acc_train.append(100 * correct / total)

    net.train()

    '''# 통계를 출력합니다.
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0'''

print('Finished Training')
# Out:
# Finished Training

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# /home/dana/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Accuracy of the network on the 10000 test images: 10 %

# %%
class LocalUpdate(object):
    def __init__(self, lr,local_epoch,device,batch_size, dataset=None, idxs=None,alpha=1):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.alpha=alpha

    def train(self, net):
        net.sync_online_and_global()
        net.train()
        # train and update
        optimizer = torch.optim.SGD(net.parameters(), lr=self.lr)

        epoch_loss = []
        for iter in range(self.local_epoch):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs,activation_l2 = net(images,online_target=True)
                loss = self.loss_func(log_probs, labels)+self.alpha*activation_l2
                loss.backward()
                optimizer.step()
                #if batch_idx % 10 == 0:
                #    print('Update Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #        iter, batch_idx * len(images), len(self.ldr_train.dataset),
                #               100. * batch_idx / len(self.ldr_train), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        return net.state_dict(), sum(epoch_loss) / len(epoch_loss)

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=0
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_iid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
CIFAR_noniid_dataset=cifar_dirichlet(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]
# Out:
# torch.int64

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.163
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 2.116
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 2 epoch
#  Average loss 2.149
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 3 epoch
#  Average loss 2.122
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4 epoch
#  Average loss 2.021
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 5 epoch
#  Average loss 2.068
# Accuracy of the network on the 10000 test images: 16.430000 %
# This is global 6 epoch
#  Average loss 2.010
# Accuracy of the network on the 10000 test images: 16.070000 %
# This is global 7 epoch
#  Average loss 2.062
# Accuracy of the network on the 10000 test images: 16.190000 %
# This is global 8 epoch
#  Average loss 1.925
# Accuracy of the network on the 10000 test images: 19.610000 %
# This is global 9 epoch
#  Average loss 2.037
# Accuracy of the network on the 10000 test images: 20.980000 %
# This is global 10 epoch
#  Average loss 1.947
# Accuracy of the network on the 10000 test images: 18.630000 %
# This is global 11 epoch
#  Average loss 1.985
# Accuracy of the network on the 10000 test images: 19.360000 %
# This is global 12 epoch
#  Average loss 2.002
# Accuracy of the network on the 10000 test images: 22.400000 %
# This is global 13 epoch
#  Average loss 2.029
# Accuracy of the network on the 10000 test images: 18.240000 %
# This is global 14 epoch
#  Average loss 1.887
# Accuracy of the network on the 10000 test images: 24.360000 %
# This is global 15 epoch
#  Average loss 1.917
# Accuracy of the network on the 10000 test images: 24.160000 %
# This is global 16 epoch
#  Average loss 1.938
# Accuracy of the network on the 10000 test images: 27.120000 %
# This is global 17 epoch
#  Average loss 1.824
# Accuracy of the network on the 10000 test images: 26.670000 %
# This is global 18 epoch
#  Average loss 1.833
# Accuracy of the network on the 10000 test images: 20.950000 %
# This is global 19 epoch
#  Average loss 1.933
# Accuracy of the network on the 10000 test images: 20.040000 %
# This is global 20 epoch
#  Average loss 1.833
# Accuracy of the network on the 10000 test images: 26.370000 %
# This is global 21 epoch
#  Average loss 1.771
# Accuracy of the network on the 10000 test images: 26.730000 %
# This is global 22 epoch
#  Average loss 1.762
# Accuracy of the network on the 10000 test images: 25.270000 %
# This is global 23 epoch
#  Average loss 1.768
# Accuracy of the network on the 10000 test images: 24.790000 %
# This is global 24 epoch
#  Average loss 1.941
# Accuracy of the network on the 10000 test images: 29.220000 %
# This is global 25 epoch
#  Average loss 1.909
# Accuracy of the network on the 10000 test images: 32.470000 %
# This is global 26 epoch
#  Average loss 1.802
# Accuracy of the network on the 10000 test images: 29.810000 %
# This is global 27 epoch
#  Average loss 1.706
# Accuracy of the network on the 10000 test images: 27.960000 %
# This is global 28 epoch
#  Average loss 1.790
# Accuracy of the network on the 10000 test images: 30.500000 %
# This is global 29 epoch
#  Average loss 1.747
# Accuracy of the network on the 10000 test images: 31.310000 %
# This is global 30 epoch
#  Average loss 1.822
# Accuracy of the network on the 10000 test images: 31.400000 %
# This is global 31 epoch
#  Average loss 1.729
# Accuracy of the network on the 10000 test images: 31.700000 %
# This is global 32 epoch
#  Average loss 1.771
# Accuracy of the network on the 10000 test images: 35.060000 %
# This is global 33 epoch
#  Average loss 1.702
# Accuracy of the network on the 10000 test images: 28.840000 %
# This is global 34 epoch
#  Average loss 1.705
# Accuracy of the network on the 10000 test images: 35.090000 %
# This is global 35 epoch
#  Average loss 1.649
# Accuracy of the network on the 10000 test images: 30.040000 %
# This is global 36 epoch
#  Average loss 1.770
# Accuracy of the network on the 10000 test images: 35.610000 %
# This is global 37 epoch
#  Average loss 1.699
# Accuracy of the network on the 10000 test images: 33.180000 %
# This is global 38 epoch
#  Average loss 1.674
# Accuracy of the network on the 10000 test images: 32.280000 %
# This is global 39 epoch
#  Average loss 1.645
# Accuracy of the network on the 10000 test images: 29.720000 %
# This is global 40 epoch
#  Average loss 1.636
# Accuracy of the network on the 10000 test images: 32.480000 %
# This is global 41 epoch
#  Average loss 1.735
# Accuracy of the network on the 10000 test images: 38.450000 %
# This is global 42 epoch
#  Average loss 1.645
# Accuracy of the network on the 10000 test images: 33.280000 %
# This is global 43 epoch
#  Average loss 1.686
# Accuracy of the network on the 10000 test images: 36.120000 %
# This is global 44 epoch
#  Average loss 1.680
# Accuracy of the network on the 10000 test images: 32.110000 %
# This is global 45 epoch
#  Average loss 1.664
# Accuracy of the network on the 10000 test images: 36.480000 %
# This is global 46 epoch
#  Average loss 1.730
# Accuracy of the network on the 10000 test images: 37.150000 %
# This is global 47 epoch
#  Average loss 1.583
# Accuracy of the network on the 10000 test images: 36.930000 %
# This is global 48 epoch
#  Average loss 1.535
# Accuracy of the network on the 10000 test images: 38.920000 %
# This is global 49 epoch
#  Average loss 1.461
# Accuracy of the network on the 10000 test images: 36.590000 %
# This is global 50 epoch
#  Average loss 1.601
# Accuracy of the network on the 10000 test images: 37.550000 %
# This is global 51 epoch
#  Average loss 1.654
# Accuracy of the network on the 10000 test images: 37.520000 %
# This is global 52 epoch
#  Average loss 1.468
# Accuracy of the network on the 10000 test images: 35.760000 %
# This is global 53 epoch
#  Average loss 1.536
# Accuracy of the network on the 10000 test images: 41.260000 %
# This is global 54 epoch
#  Average loss 1.502
# Accuracy of the network on the 10000 test images: 38.860000 %
# This is global 55 epoch
#  Average loss 1.508
# Accuracy of the network on the 10000 test images: 39.310000 %
# This is global 56 epoch
#  Average loss 1.600
# Accuracy of the network on the 10000 test images: 37.420000 %
# This is global 57 epoch
#  Average loss 1.538
# Accuracy of the network on the 10000 test images: 35.730000 %
# This is global 58 epoch
#  Average loss 1.636
# Accuracy of the network on the 10000 test images: 38.210000 %
# This is global 59 epoch
#  Average loss 1.461
# Accuracy of the network on the 10000 test images: 37.550000 %
# This is global 60 epoch
#  Average loss 1.459
# Accuracy of the network on the 10000 test images: 37.530000 %
# This is global 61 epoch
#  Average loss 1.610
# Accuracy of the network on the 10000 test images: 36.340000 %
# This is global 62 epoch
#  Average loss 1.507
# Accuracy of the network on the 10000 test images: 40.060000 %
# This is global 63 epoch
#  Average loss 1.474
# Accuracy of the network on the 10000 test images: 40.290000 %
# This is global 64 epoch
#  Average loss 1.478
# Accuracy of the network on the 10000 test images: 37.470000 %
# This is global 65 epoch
#  Average loss 1.521
# Accuracy of the network on the 10000 test images: 40.310000 %
# This is global 66 epoch
#  Average loss 1.483
# Accuracy of the network on the 10000 test images: 40.900000 %
# This is global 67 epoch
#  Average loss 1.525
# Accuracy of the network on the 10000 test images: 45.020000 %
# This is global 68 epoch
#  Average loss 1.447
# Accuracy of the network on the 10000 test images: 43.570000 %
# This is global 69 epoch
#  Average loss 1.420
# Accuracy of the network on the 10000 test images: 44.210000 %
# This is global 70 epoch
#  Average loss 1.482
# Accuracy of the network on the 10000 test images: 43.950000 %
# This is global 71 epoch
#  Average loss 1.492
# Accuracy of the network on the 10000 test images: 43.730000 %
# This is global 72 epoch
#  Average loss 1.408
# Accuracy of the network on the 10000 test images: 41.340000 %
# This is global 73 epoch
#  Average loss 1.517
# Accuracy of the network on the 10000 test images: 44.360000 %
# This is global 74 epoch
#  Average loss 1.440
# Accuracy of the network on the 10000 test images: 46.130000 %
# This is global 75 epoch
#  Average loss 1.330
# Accuracy of the network on the 10000 test images: 44.020000 %
# This is global 76 epoch
#  Average loss 1.298
# Accuracy of the network on the 10000 test images: 40.180000 %
# This is global 77 epoch
#  Average loss 1.475
# Accuracy of the network on the 10000 test images: 43.550000 %
# This is global 78 epoch
#  Average loss 1.400
# Accuracy of the network on the 10000 test images: 45.180000 %
# This is global 79 epoch
#  Average loss 1.471
# Accuracy of the network on the 10000 test images: 46.550000 %
# This is global 80 epoch
#  Average loss 1.521
# Accuracy of the network on the 10000 test images: 45.580000 %
# This is global 81 epoch
#  Average loss 1.373
# Accuracy of the network on the 10000 test images: 42.130000 %
# This is global 82 epoch
#  Average loss 1.468
# Accuracy of the network on the 10000 test images: 46.240000 %
# This is global 83 epoch
#  Average loss 1.363
# Accuracy of the network on the 10000 test images: 46.630000 %
# This is global 84 epoch
#  Average loss 1.526
# Accuracy of the network on the 10000 test images: 45.460000 %
# This is global 85 epoch
#  Average loss 1.430
# Accuracy of the network on the 10000 test images: 44.490000 %
# This is global 86 epoch
#  Average loss 1.424
# Accuracy of the network on the 10000 test images: 43.920000 %
# This is global 87 epoch
#  Average loss 1.489
# Accuracy of the network on the 10000 test images: 46.390000 %
# This is global 88 epoch
#  Average loss 1.323
# Accuracy of the network on the 10000 test images: 44.430000 %
# This is global 89 epoch
#  Average loss 1.455
# Accuracy of the network on the 10000 test images: 46.220000 %
# This is global 90 epoch
#  Average loss 1.467
# Accuracy of the network on the 10000 test images: 48.190000 %
# This is global 91 epoch
#  Average loss 1.346
# Accuracy of the network on the 10000 test images: 47.010000 %
# This is global 92 epoch
#  Average loss 1.353
# Accuracy of the network on the 10000 test images: 46.660000 %
# This is global 93 epoch
#  Average loss 1.402
# Accuracy of the network on the 10000 test images: 47.370000 %
# This is global 94 epoch
#  Average loss 1.274
# Accuracy of the network on the 10000 test images: 47.850000 %
# This is global 95 epoch
#  Average loss 1.462
# Accuracy of the network on the 10000 test images: 45.700000 %
# This is global 96 epoch
#  Average loss 1.484
# Accuracy of the network on the 10000 test images: 47.580000 %
# This is global 97 epoch
#  Average loss 1.330
# Accuracy of the network on the 10000 test images: 48.000000 %
# This is global 98 epoch
#  Average loss 1.287
# Accuracy of the network on the 10000 test images: 46.660000 %
# This is global 99 epoch
#  Average loss 1.339
# Accuracy of the network on the 10000 test images: 45.270000 %
# This is global 100 epoch
#  Average loss 1.419
# Accuracy of the network on the 10000 test images: 46.750000 %
# This is global 101 epoch
#  Average loss 1.419
# Accuracy of the network on the 10000 test images: 48.170000 %
# This is global 102 epoch
#  Average loss 1.450
# Accuracy of the network on the 10000 test images: 47.600000 %
# This is global 103 epoch
#  Average loss 1.314
# Accuracy of the network on the 10000 test images: 48.650000 %
# This is global 104 epoch
#  Average loss 1.377
# Accuracy of the network on the 10000 test images: 49.470000 %
# This is global 105 epoch
#  Average loss 1.327
# Accuracy of the network on the 10000 test images: 50.870000 %
# This is global 106 epoch
#  Average loss 1.350
# Accuracy of the network on the 10000 test images: 48.850000 %
# This is global 107 epoch
#  Average loss 1.454
# Accuracy of the network on the 10000 test images: 47.930000 %
# This is global 108 epoch
#  Average loss 1.326
# Accuracy of the network on the 10000 test images: 49.170000 %
# This is global 109 epoch
#  Average loss 1.470
# Accuracy of the network on the 10000 test images: 50.420000 %
# This is global 110 epoch
#  Average loss 1.305
# Accuracy of the network on the 10000 test images: 49.940000 %
# This is global 111 epoch
#  Average loss 1.386
# Accuracy of the network on the 10000 test images: 49.760000 %
# This is global 112 epoch
#  Average loss 1.377
# Accuracy of the network on the 10000 test images: 49.480000 %
# This is global 113 epoch
#  Average loss 1.327
# Accuracy of the network on the 10000 test images: 48.880000 %
# This is global 114 epoch
#  Average loss 1.386
# Accuracy of the network on the 10000 test images: 51.580000 %
# This is global 115 epoch
#  Average loss 1.386
# Accuracy of the network on the 10000 test images: 48.140000 %
# This is global 116 epoch
#  Average loss 1.247
# Accuracy of the network on the 10000 test images: 50.420000 %
# This is global 117 epoch
#  Average loss 1.325
# Accuracy of the network on the 10000 test images: 50.040000 %
# This is global 118 epoch
#  Average loss 1.333
# Accuracy of the network on the 10000 test images: 51.080000 %
# This is global 119 epoch
#  Average loss 1.249
# Accuracy of the network on the 10000 test images: 50.490000 %
# This is global 120 epoch
#  Average loss 1.318
# Accuracy of the network on the 10000 test images: 52.220000 %
# This is global 121 epoch
#  Average loss 1.243
# Accuracy of the network on the 10000 test images: 50.370000 %
# This is global 122 epoch
#  Average loss 1.311
# Accuracy of the network on the 10000 test images: 50.750000 %
# This is global 123 epoch
#  Average loss 1.342
# Accuracy of the network on the 10000 test images: 49.860000 %
# This is global 124 epoch
#  Average loss 1.256
# Accuracy of the network on the 10000 test images: 48.630000 %
# This is global 125 epoch
#  Average loss 1.323
# Accuracy of the network on the 10000 test images: 48.490000 %
# This is global 126 epoch
#  Average loss 1.324
# Accuracy of the network on the 10000 test images: 50.980000 %
# This is global 127 epoch
#  Average loss 1.319
# Accuracy of the network on the 10000 test images: 51.310000 %
# This is global 128 epoch
#  Average loss 1.341
# Accuracy of the network on the 10000 test images: 52.310000 %
# This is global 129 epoch
#  Average loss 1.278
# Accuracy of the network on the 10000 test images: 50.510000 %
# This is global 130 epoch
#  Average loss 1.310
# Accuracy of the network on the 10000 test images: 50.240000 %
# This is global 131 epoch
#  Average loss 1.303
# Accuracy of the network on the 10000 test images: 52.700000 %
# This is global 132 epoch
#  Average loss 1.253
# Accuracy of the network on the 10000 test images: 48.920000 %
# This is global 133 epoch
#  Average loss 1.291
# Accuracy of the network on the 10000 test images: 53.270000 %
# This is global 134 epoch
#  Average loss 1.227
# Accuracy of the network on the 10000 test images: 49.990000 %
# This is global 135 epoch
#  Average loss 1.323
# Accuracy of the network on the 10000 test images: 53.900000 %
# This is global 136 epoch
#  Average loss 1.241
# Accuracy of the network on the 10000 test images: 52.290000 %
# This is global 137 epoch
#  Average loss 1.288
# Accuracy of the network on the 10000 test images: 52.370000 %
# This is global 138 epoch
#  Average loss 1.212
# Accuracy of the network on the 10000 test images: 51.450000 %
# This is global 139 epoch
#  Average loss 1.259
# Accuracy of the network on the 10000 test images: 52.140000 %
# This is global 140 epoch
#  Average loss 1.261
# Accuracy of the network on the 10000 test images: 52.150000 %
# This is global 141 epoch
#  Average loss 1.255
# Accuracy of the network on the 10000 test images: 51.060000 %
# This is global 142 epoch
#  Average loss 1.310
# Accuracy of the network on the 10000 test images: 51.530000 %
# This is global 143 epoch
#  Average loss 1.215
# Accuracy of the network on the 10000 test images: 52.690000 %
# This is global 144 epoch
#  Average loss 1.198
# Accuracy of the network on the 10000 test images: 52.890000 %
# This is global 145 epoch
#  Average loss 1.216
# Accuracy of the network on the 10000 test images: 52.230000 %
# This is global 146 epoch
#  Average loss 1.304
# Accuracy of the network on the 10000 test images: 54.550000 %
# This is global 147 epoch
#  Average loss 1.248
# Accuracy of the network on the 10000 test images: 54.910000 %
# This is global 148 epoch
#  Average loss 1.215
# Accuracy of the network on the 10000 test images: 52.850000 %
# This is global 149 epoch
#  Average loss 1.250
# Accuracy of the network on the 10000 test images: 54.520000 %
# This is global 150 epoch
#  Average loss 1.294
# Accuracy of the network on the 10000 test images: 54.150000 %
# This is global 151 epoch
#  Average loss 1.310
# Accuracy of the network on the 10000 test images: 54.310000 %
# This is global 152 epoch
#  Average loss 1.235
# Accuracy of the network on the 10000 test images: 54.350000 %
# This is global 153 epoch
#  Average loss 1.273
# Accuracy of the network on the 10000 test images: 53.900000 %
# This is global 154 epoch
#  Average loss 1.257
# Accuracy of the network on the 10000 test images: 51.900000 %
# This is global 155 epoch
#  Average loss 1.191
# Accuracy of the network on the 10000 test images: 53.410000 %
# This is global 156 epoch
#  Average loss 1.282
# Accuracy of the network on the 10000 test images: 54.610000 %
# This is global 157 epoch
#  Average loss 1.213
# Accuracy of the network on the 10000 test images: 52.870000 %
# This is global 158 epoch
#  Average loss 1.235
# Accuracy of the network on the 10000 test images: 53.810000 %
# This is global 159 epoch
#  Average loss 1.226
# Accuracy of the network on the 10000 test images: 53.110000 %
# This is global 160 epoch
#  Average loss 1.320
# Accuracy of the network on the 10000 test images: 52.740000 %
# This is global 161 epoch
#  Average loss 1.178
# Accuracy of the network on the 10000 test images: 56.190000 %
# This is global 162 epoch
#  Average loss 1.138
# Accuracy of the network on the 10000 test images: 56.200000 %
# This is global 163 epoch
#  Average loss 1.196
# Accuracy of the network on the 10000 test images: 55.140000 %
# This is global 164 epoch
#  Average loss 1.193
# Accuracy of the network on the 10000 test images: 55.940000 %
# This is global 165 epoch
#  Average loss 1.302
# Accuracy of the network on the 10000 test images: 56.310000 %
# This is global 166 epoch
#  Average loss 1.166
# Accuracy of the network on the 10000 test images: 55.900000 %
# This is global 167 epoch
#  Average loss 1.294
# Accuracy of the network on the 10000 test images: 56.930000 %
# This is global 168 epoch
#  Average loss 1.254
# Accuracy of the network on the 10000 test images: 56.960000 %
# This is global 169 epoch
#  Average loss 1.238
# Accuracy of the network on the 10000 test images: 54.040000 %
# This is global 170 epoch
#  Average loss 1.289
# Accuracy of the network on the 10000 test images: 56.400000 %
# This is global 171 epoch
#  Average loss 1.151
# Accuracy of the network on the 10000 test images: 56.430000 %
# This is global 172 epoch
#  Average loss 1.251
# Accuracy of the network on the 10000 test images: 54.570000 %
# This is global 173 epoch
#  Average loss 1.188
# Accuracy of the network on the 10000 test images: 56.260000 %
# This is global 174 epoch
#  Average loss 1.152
# Accuracy of the network on the 10000 test images: 57.130000 %
# This is global 175 epoch
#  Average loss 1.167
# Accuracy of the network on the 10000 test images: 57.310000 %
# This is global 176 epoch
#  Average loss 1.224
# Accuracy of the network on the 10000 test images: 57.490000 %
# This is global 177 epoch
#  Average loss 1.237
# Accuracy of the network on the 10000 test images: 56.860000 %
# This is global 178 epoch
#  Average loss 1.109
# Accuracy of the network on the 10000 test images: 53.100000 %
# This is global 179 epoch
#  Average loss 1.259
# Accuracy of the network on the 10000 test images: 57.370000 %
# This is global 180 epoch
#  Average loss 1.123
# Accuracy of the network on the 10000 test images: 51.780000 %
# This is global 181 epoch
#  Average loss 1.222
# Accuracy of the network on the 10000 test images: 53.460000 %
# This is global 182 epoch
#  Average loss 1.172
# Accuracy of the network on the 10000 test images: 57.110000 %
# This is global 183 epoch
#  Average loss 1.249
# Accuracy of the network on the 10000 test images: 57.500000 %
# This is global 184 epoch
#  Average loss 1.252
# Accuracy of the network on the 10000 test images: 57.810000 %
# This is global 185 epoch
#  Average loss 1.096
# Accuracy of the network on the 10000 test images: 56.420000 %
# This is global 186 epoch
#  Average loss 1.110
# Accuracy of the network on the 10000 test images: 57.760000 %
# This is global 187 epoch
#  Average loss 1.072
# Accuracy of the network on the 10000 test images: 57.150000 %
# This is global 188 epoch
#  Average loss 1.155
# Accuracy of the network on the 10000 test images: 57.410000 %
# This is global 189 epoch
#  Average loss 1.085
# Accuracy of the network on the 10000 test images: 57.850000 %
# This is global 190 epoch
#  Average loss 1.157
# Accuracy of the network on the 10000 test images: 49.470000 %
# This is global 191 epoch
#  Average loss 1.215
# Accuracy of the network on the 10000 test images: 51.280000 %
# This is global 192 epoch
#  Average loss 1.154
# Accuracy of the network on the 10000 test images: 53.800000 %
# This is global 193 epoch
#  Average loss 1.036
# Accuracy of the network on the 10000 test images: 55.020000 %
# This is global 194 epoch
#  Average loss 1.124
# Accuracy of the network on the 10000 test images: 56.780000 %
# This is global 195 epoch
#  Average loss 1.144
# Accuracy of the network on the 10000 test images: 58.760000 %
# This is global 196 epoch
#  Average loss 1.207
# Accuracy of the network on the 10000 test images: 58.450000 %
# This is global 197 epoch
#  Average loss 1.217
# Accuracy of the network on the 10000 test images: 56.770000 %
# This is global 198 epoch
#  Average loss 1.131
# Accuracy of the network on the 10000 test images: 55.750000 %
# This is global 199 epoch
#  Average loss 1.188
# Accuracy of the network on the 10000 test images: 57.710000 %
# This is global 200 epoch
#  Average loss 1.112
# Accuracy of the network on the 10000 test images: 56.370000 %
# This is global 201 epoch
#  Average loss 1.159
# Accuracy of the network on the 10000 test images: 59.450000 %
# This is global 202 epoch
#  Average loss 1.133
# Accuracy of the network on the 10000 test images: 55.810000 %
# This is global 203 epoch
#  Average loss 1.195
# Accuracy of the network on the 10000 test images: 57.160000 %
# This is global 204 epoch
#  Average loss 1.150
# Accuracy of the network on the 10000 test images: 58.150000 %
# This is global 205 epoch
#  Average loss 1.138
# Accuracy of the network on the 10000 test images: 58.000000 %
# This is global 206 epoch
#  Average loss 1.127
# Accuracy of the network on the 10000 test images: 56.960000 %
# This is global 207 epoch
#  Average loss 1.058
# Accuracy of the network on the 10000 test images: 55.820000 %
# This is global 208 epoch
#  Average loss 1.163
# Accuracy of the network on the 10000 test images: 54.270000 %
# This is global 209 epoch
#  Average loss 1.102
# Accuracy of the network on the 10000 test images: 58.380000 %
# This is global 210 epoch
#  Average loss 1.119
# Accuracy of the network on the 10000 test images: 59.270000 %
# This is global 211 epoch
#  Average loss 1.102
# Accuracy of the network on the 10000 test images: 59.280000 %
# This is global 212 epoch
#  Average loss 1.074
# Accuracy of the network on the 10000 test images: 58.380000 %
# This is global 213 epoch
#  Average loss 1.140
# Accuracy of the network on the 10000 test images: 59.240000 %
# This is global 214 epoch
#  Average loss 1.065
# Accuracy of the network on the 10000 test images: 58.340000 %
# This is global 215 epoch
#  Average loss 1.072
# Accuracy of the network on the 10000 test images: 59.060000 %
# This is global 216 epoch
#  Average loss 0.955
# Accuracy of the network on the 10000 test images: 59.010000 %
# This is global 217 epoch
#  Average loss 1.056
# Accuracy of the network on the 10000 test images: 60.250000 %
# This is global 218 epoch
#  Average loss 1.064
# Accuracy of the network on the 10000 test images: 59.510000 %
# This is global 219 epoch
#  Average loss 1.126
# Accuracy of the network on the 10000 test images: 59.050000 %
# This is global 220 epoch
#  Average loss 1.123
# Accuracy of the network on the 10000 test images: 59.410000 %
# This is global 221 epoch
#  Average loss 1.150
# Accuracy of the network on the 10000 test images: 59.040000 %
# This is global 222 epoch
#  Average loss 1.124
# Accuracy of the network on the 10000 test images: 58.470000 %
# This is global 223 epoch
#  Average loss 1.102
# Accuracy of the network on the 10000 test images: 58.910000 %
# This is global 224 epoch
#  Average loss 1.105
# Accuracy of the network on the 10000 test images: 58.720000 %
# This is global 225 epoch
#  Average loss 1.123
# Accuracy of the network on the 10000 test images: 59.970000 %
# This is global 226 epoch
#  Average loss 1.149
# Accuracy of the network on the 10000 test images: 59.250000 %
# This is global 227 epoch
#  Average loss 1.116
# Accuracy of the network on the 10000 test images: 59.150000 %
# This is global 228 epoch
#  Average loss 1.108
# Accuracy of the network on the 10000 test images: 59.190000 %
# This is global 229 epoch
#  Average loss 1.014
# Accuracy of the network on the 10000 test images: 60.180000 %
# This is global 230 epoch
#  Average loss 1.083
# Accuracy of the network on the 10000 test images: 60.040000 %
# This is global 231 epoch
#  Average loss 1.096
# Accuracy of the network on the 10000 test images: 60.900000 %
# This is global 232 epoch
#  Average loss 1.148
# Accuracy of the network on the 10000 test images: 60.590000 %
# This is global 233 epoch
#  Average loss 1.002
# Accuracy of the network on the 10000 test images: 61.000000 %
# This is global 234 epoch
#  Average loss 1.023
# Accuracy of the network on the 10000 test images: 58.400000 %
# This is global 235 epoch
#  Average loss 1.099
# Accuracy of the network on the 10000 test images: 58.060000 %
# This is global 236 epoch
#  Average loss 1.147
# Accuracy of the network on the 10000 test images: 59.070000 %
# This is global 237 epoch
#  Average loss 1.107
# Accuracy of the network on the 10000 test images: 60.930000 %
# This is global 238 epoch
#  Average loss 1.105
# Accuracy of the network on the 10000 test images: 61.270000 %
# This is global 239 epoch
#  Average loss 1.031
# Accuracy of the network on the 10000 test images: 60.770000 %
# This is global 240 epoch
#  Average loss 0.981
# Accuracy of the network on the 10000 test images: 61.150000 %
# This is global 241 epoch
#  Average loss 1.084
# Accuracy of the network on the 10000 test images: 58.760000 %
# This is global 242 epoch
#  Average loss 1.073
# Accuracy of the network on the 10000 test images: 58.650000 %
# This is global 243 epoch
#  Average loss 1.074
# Accuracy of the network on the 10000 test images: 59.480000 %
# This is global 244 epoch
#  Average loss 1.121
# Accuracy of the network on the 10000 test images: 61.790000 %
# This is global 245 epoch
#  Average loss 1.088
# Accuracy of the network on the 10000 test images: 61.840000 %
# This is global 246 epoch
#  Average loss 1.089
# Accuracy of the network on the 10000 test images: 62.560000 %
# This is global 247 epoch
#  Average loss 0.980
# Accuracy of the network on the 10000 test images: 60.540000 %
# This is global 248 epoch
#  Average loss 1.100
# Accuracy of the network on the 10000 test images: 60.300000 %
# This is global 249 epoch
#  Average loss 1.080
# Accuracy of the network on the 10000 test images: 61.460000 %
# This is global 250 epoch
#  Average loss 1.101
# Accuracy of the network on the 10000 test images: 62.460000 %
# This is global 251 epoch
#  Average loss 1.014
# Accuracy of the network on the 10000 test images: 61.970000 %
# This is global 252 epoch
#  Average loss 1.110
# Accuracy of the network on the 10000 test images: 61.640000 %
# This is global 253 epoch
#  Average loss 1.026
# Accuracy of the network on the 10000 test images: 61.600000 %
# This is global 254 epoch
#  Average loss 1.058
# Accuracy of the network on the 10000 test images: 61.030000 %
# This is global 255 epoch
#  Average loss 0.997
# Accuracy of the network on the 10000 test images: 61.640000 %
# This is global 256 epoch
#  Average loss 1.028
# Accuracy of the network on the 10000 test images: 60.560000 %
# This is global 257 epoch
#  Average loss 1.065
# Accuracy of the network on the 10000 test images: 60.960000 %
# This is global 258 epoch
#  Average loss 1.030
# Accuracy of the network on the 10000 test images: 63.110000 %
# This is global 259 epoch
#  Average loss 1.049
# Accuracy of the network on the 10000 test images: 62.880000 %
# This is global 260 epoch
#  Average loss 1.053
# Accuracy of the network on the 10000 test images: 60.720000 %
# This is global 261 epoch
#  Average loss 1.048
# Accuracy of the network on the 10000 test images: 61.490000 %
# This is global 262 epoch
#  Average loss 1.029
# Accuracy of the network on the 10000 test images: 59.830000 %
# This is global 263 epoch
#  Average loss 1.118
# Accuracy of the network on the 10000 test images: 60.700000 %
# This is global 264 epoch
#  Average loss 1.015
# Accuracy of the network on the 10000 test images: 61.130000 %
# This is global 265 epoch
#  Average loss 1.010
# Accuracy of the network on the 10000 test images: 61.280000 %
# This is global 266 epoch
#  Average loss 1.125
# Accuracy of the network on the 10000 test images: 59.700000 %
# This is global 267 epoch
#  Average loss 0.964
# Accuracy of the network on the 10000 test images: 62.340000 %
# This is global 268 epoch
#  Average loss 0.980
# Accuracy of the network on the 10000 test images: 59.200000 %
# This is global 269 epoch
#  Average loss 0.867
# Accuracy of the network on the 10000 test images: 60.200000 %
# This is global 270 epoch
#  Average loss 0.958
# Accuracy of the network on the 10000 test images: 59.090000 %
# This is global 271 epoch
#  Average loss 1.012
# Accuracy of the network on the 10000 test images: 59.660000 %
# This is global 272 epoch
#  Average loss 1.038
# Accuracy of the network on the 10000 test images: 63.650000 %
# This is global 273 epoch
#  Average loss 1.075
# Accuracy of the network on the 10000 test images: 61.910000 %
# This is global 274 epoch
#  Average loss 1.026
# Accuracy of the network on the 10000 test images: 62.110000 %
# This is global 275 epoch
#  Average loss 1.072
# Accuracy of the network on the 10000 test images: 62.380000 %
# This is global 276 epoch
#  Average loss 0.937
# Accuracy of the network on the 10000 test images: 61.730000 %
# This is global 277 epoch
#  Average loss 1.000
# Accuracy of the network on the 10000 test images: 61.520000 %
# This is global 278 epoch
#  Average loss 1.059
# Accuracy of the network on the 10000 test images: 61.490000 %
# This is global 279 epoch
#  Average loss 1.002
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 280 epoch
#  Average loss 0.973
# Accuracy of the network on the 10000 test images: 63.080000 %
# This is global 281 epoch
#  Average loss 0.923
# Accuracy of the network on the 10000 test images: 60.960000 %
# This is global 282 epoch
#  Average loss 1.032
# Accuracy of the network on the 10000 test images: 63.720000 %
# This is global 283 epoch
#  Average loss 0.991
# Accuracy of the network on the 10000 test images: 64.260000 %
# This is global 284 epoch
#  Average loss 0.999
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 285 epoch
#  Average loss 0.988
# Accuracy of the network on the 10000 test images: 62.610000 %
# This is global 286 epoch
#  Average loss 1.013
# Accuracy of the network on the 10000 test images: 60.480000 %
# This is global 287 epoch
#  Average loss 0.995
# Accuracy of the network on the 10000 test images: 62.460000 %
# This is global 288 epoch
#  Average loss 0.941
# Accuracy of the network on the 10000 test images: 62.900000 %
# This is global 289 epoch
#  Average loss 0.978
# Accuracy of the network on the 10000 test images: 63.010000 %
# This is global 290 epoch
#  Average loss 0.929
# Accuracy of the network on the 10000 test images: 62.370000 %
# This is global 291 epoch
#  Average loss 1.177
# Accuracy of the network on the 10000 test images: 63.560000 %
# This is global 292 epoch
#  Average loss 0.998
# Accuracy of the network on the 10000 test images: 61.740000 %
# This is global 293 epoch
#  Average loss 0.972
# Accuracy of the network on the 10000 test images: 62.940000 %
# This is global 294 epoch
#  Average loss 1.062
# Accuracy of the network on the 10000 test images: 61.240000 %
# This is global 295 epoch
#  Average loss 1.028
# Accuracy of the network on the 10000 test images: 59.440000 %
# This is global 296 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 59.120000 %
# This is global 297 epoch
#  Average loss 0.986
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 298 epoch
#  Average loss 0.957
# Accuracy of the network on the 10000 test images: 60.770000 %
# This is global 299 epoch
#  Average loss 0.998
# Accuracy of the network on the 10000 test images: 62.330000 %
# This is global 300 epoch
#  Average loss 0.958
# Accuracy of the network on the 10000 test images: 62.330000 %
# This is global 301 epoch
#  Average loss 1.021
# Accuracy of the network on the 10000 test images: 63.220000 %
# This is global 302 epoch
#  Average loss 0.964
# Accuracy of the network on the 10000 test images: 63.410000 %
# This is global 303 epoch
#  Average loss 0.999
# Accuracy of the network on the 10000 test images: 64.150000 %
# This is global 304 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 64.420000 %
# This is global 305 epoch
#  Average loss 1.036
# Accuracy of the network on the 10000 test images: 62.920000 %
# This is global 306 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 63.190000 %
# This is global 307 epoch
#  Average loss 0.977
# Accuracy of the network on the 10000 test images: 64.160000 %
# This is global 308 epoch
#  Average loss 0.915
# Accuracy of the network on the 10000 test images: 64.160000 %
# This is global 309 epoch
#  Average loss 0.906
# Accuracy of the network on the 10000 test images: 63.410000 %
# This is global 310 epoch
#  Average loss 0.976
# Accuracy of the network on the 10000 test images: 64.510000 %
# This is global 311 epoch
#  Average loss 0.916
# Accuracy of the network on the 10000 test images: 63.760000 %
# This is global 312 epoch
#  Average loss 0.807
# Accuracy of the network on the 10000 test images: 63.130000 %
# This is global 313 epoch
#  Average loss 0.962
# Accuracy of the network on the 10000 test images: 63.470000 %
# This is global 314 epoch
#  Average loss 0.917
# Accuracy of the network on the 10000 test images: 63.080000 %
# This is global 315 epoch
#  Average loss 1.012
# Accuracy of the network on the 10000 test images: 63.650000 %
# This is global 316 epoch
#  Average loss 0.984
# Accuracy of the network on the 10000 test images: 63.950000 %
# This is global 317 epoch
#  Average loss 0.858
# Accuracy of the network on the 10000 test images: 64.930000 %
# This is global 318 epoch
#  Average loss 0.839
# Accuracy of the network on the 10000 test images: 64.530000 %
# This is global 319 epoch
#  Average loss 0.868
# Accuracy of the network on the 10000 test images: 65.740000 %
# This is global 320 epoch
#  Average loss 0.992
# Accuracy of the network on the 10000 test images: 62.890000 %
# This is global 321 epoch
#  Average loss 0.995
# Accuracy of the network on the 10000 test images: 64.220000 %
# This is global 322 epoch
#  Average loss 1.056
# Accuracy of the network on the 10000 test images: 65.190000 %
# This is global 323 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 63.770000 %
# This is global 324 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 64.200000 %
# This is global 325 epoch
#  Average loss 0.967
# Accuracy of the network on the 10000 test images: 62.250000 %
# This is global 326 epoch
#  Average loss 0.952
# Accuracy of the network on the 10000 test images: 64.590000 %
# This is global 327 epoch
#  Average loss 0.958
# Accuracy of the network on the 10000 test images: 65.150000 %
# This is global 328 epoch
#  Average loss 0.833
# Accuracy of the network on the 10000 test images: 65.000000 %
# This is global 329 epoch
#  Average loss 0.859
# Accuracy of the network on the 10000 test images: 64.850000 %
# This is global 330 epoch
#  Average loss 0.876
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 331 epoch
#  Average loss 0.948
# Accuracy of the network on the 10000 test images: 64.560000 %
# This is global 332 epoch
#  Average loss 0.926
# Accuracy of the network on the 10000 test images: 65.060000 %
# This is global 333 epoch
#  Average loss 0.920
# Accuracy of the network on the 10000 test images: 63.090000 %
# This is global 334 epoch
#  Average loss 0.921
# Accuracy of the network on the 10000 test images: 65.340000 %
# This is global 335 epoch
#  Average loss 0.954
# Accuracy of the network on the 10000 test images: 64.970000 %
# This is global 336 epoch
#  Average loss 0.925
# Accuracy of the network on the 10000 test images: 63.700000 %
# This is global 337 epoch
#  Average loss 0.982
# Accuracy of the network on the 10000 test images: 63.080000 %
# This is global 338 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 64.590000 %
# This is global 339 epoch
#  Average loss 0.831
# Accuracy of the network on the 10000 test images: 65.250000 %
# This is global 340 epoch
#  Average loss 0.912
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 341 epoch
#  Average loss 0.833
# Accuracy of the network on the 10000 test images: 64.760000 %
# This is global 342 epoch
#  Average loss 0.885
# Accuracy of the network on the 10000 test images: 63.750000 %
# This is global 343 epoch
#  Average loss 0.842
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 344 epoch
#  Average loss 0.853
# Accuracy of the network on the 10000 test images: 65.020000 %
# This is global 345 epoch
#  Average loss 0.892
# Accuracy of the network on the 10000 test images: 63.870000 %
# This is global 346 epoch
#  Average loss 0.914
# Accuracy of the network on the 10000 test images: 64.020000 %
# This is global 347 epoch
#  Average loss 0.762
# Accuracy of the network on the 10000 test images: 62.210000 %
# This is global 348 epoch
#  Average loss 1.054
# Accuracy of the network on the 10000 test images: 60.790000 %
# This is global 349 epoch
#  Average loss 0.909
# Accuracy of the network on the 10000 test images: 64.170000 %
# This is global 350 epoch
#  Average loss 0.982
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 351 epoch
#  Average loss 0.853
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 352 epoch
#  Average loss 0.802
# Accuracy of the network on the 10000 test images: 62.090000 %
# This is global 353 epoch
#  Average loss 1.006
# Accuracy of the network on the 10000 test images: 63.990000 %
# This is global 354 epoch
#  Average loss 0.941
# Accuracy of the network on the 10000 test images: 64.570000 %
# This is global 355 epoch
#  Average loss 0.854
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 356 epoch
#  Average loss 0.754
# Accuracy of the network on the 10000 test images: 63.800000 %
# This is global 357 epoch
#  Average loss 0.877
# Accuracy of the network on the 10000 test images: 64.120000 %
# This is global 358 epoch
#  Average loss 0.922
# Accuracy of the network on the 10000 test images: 65.990000 %
# This is global 359 epoch
#  Average loss 0.943
# Accuracy of the network on the 10000 test images: 65.420000 %
# This is global 360 epoch
#  Average loss 0.882
# Accuracy of the network on the 10000 test images: 66.090000 %
# This is global 361 epoch
#  Average loss 0.866
# Accuracy of the network on the 10000 test images: 65.850000 %
# This is global 362 epoch
#  Average loss 0.789
# Accuracy of the network on the 10000 test images: 65.980000 %
# This is global 363 epoch
#  Average loss 0.881
# Accuracy of the network on the 10000 test images: 66.270000 %
# This is global 364 epoch
#  Average loss 0.891
# Accuracy of the network on the 10000 test images: 66.650000 %
# This is global 365 epoch
#  Average loss 0.912
# Accuracy of the network on the 10000 test images: 67.130000 %
# This is global 366 epoch
#  Average loss 0.917
# Accuracy of the network on the 10000 test images: 66.420000 %
# This is global 367 epoch
#  Average loss 0.873
# Accuracy of the network on the 10000 test images: 66.860000 %
# This is global 368 epoch
#  Average loss 0.936
# Accuracy of the network on the 10000 test images: 66.130000 %
# This is global 369 epoch
#  Average loss 0.897
# Accuracy of the network on the 10000 test images: 66.340000 %
# This is global 370 epoch
#  Average loss 0.952
# Accuracy of the network on the 10000 test images: 66.500000 %
# This is global 371 epoch
#  Average loss 0.879
# Accuracy of the network on the 10000 test images: 66.820000 %
# This is global 372 epoch
#  Average loss 1.015
# Accuracy of the network on the 10000 test images: 64.550000 %
# This is global 373 epoch
#  Average loss 0.873
# Accuracy of the network on the 10000 test images: 65.440000 %
# This is global 374 epoch
#  Average loss 0.822
# Accuracy of the network on the 10000 test images: 63.390000 %
# This is global 375 epoch
#  Average loss 0.967
# Accuracy of the network on the 10000 test images: 66.970000 %
# This is global 376 epoch
#  Average loss 0.858
# Accuracy of the network on the 10000 test images: 65.690000 %
# This is global 377 epoch
#  Average loss 0.877
# Accuracy of the network on the 10000 test images: 66.620000 %
# This is global 378 epoch
#  Average loss 0.839
# Accuracy of the network on the 10000 test images: 66.180000 %
# This is global 379 epoch
#  Average loss 0.899
# Accuracy of the network on the 10000 test images: 66.300000 %
# This is global 380 epoch
#  Average loss 0.941
# Accuracy of the network on the 10000 test images: 66.000000 %
# This is global 381 epoch
#  Average loss 0.818
# Accuracy of the network on the 10000 test images: 64.560000 %
# This is global 382 epoch
#  Average loss 0.874
# Accuracy of the network on the 10000 test images: 63.760000 %
# This is global 383 epoch
#  Average loss 0.841
# Accuracy of the network on the 10000 test images: 65.000000 %
# This is global 384 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 65.690000 %
# This is global 385 epoch
#  Average loss 0.859
# Accuracy of the network on the 10000 test images: 64.910000 %
# This is global 386 epoch
#  Average loss 0.761
# Accuracy of the network on the 10000 test images: 64.990000 %
# This is global 387 epoch
#  Average loss 0.791
# Accuracy of the network on the 10000 test images: 65.030000 %
# This is global 388 epoch
#  Average loss 0.913
# Accuracy of the network on the 10000 test images: 67.220000 %
# This is global 389 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 65.900000 %
# This is global 390 epoch
#  Average loss 0.792
# Accuracy of the network on the 10000 test images: 66.090000 %
# This is global 391 epoch
#  Average loss 0.951
# Accuracy of the network on the 10000 test images: 66.740000 %
# This is global 392 epoch
#  Average loss 0.896
# Accuracy of the network on the 10000 test images: 66.630000 %
# This is global 393 epoch
#  Average loss 0.813
# Accuracy of the network on the 10000 test images: 66.990000 %
# This is global 394 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 66.290000 %
# This is global 395 epoch
#  Average loss 0.763
# Accuracy of the network on the 10000 test images: 66.370000 %
# This is global 396 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 67.170000 %
# This is global 397 epoch
#  Average loss 0.800
# Accuracy of the network on the 10000 test images: 67.430000 %
# This is global 398 epoch
#  Average loss 0.737
# Accuracy of the network on the 10000 test images: 66.720000 %
# This is global 399 epoch
#  Average loss 0.800
# Accuracy of the network on the 10000 test images: 65.100000 %
# This is global 400 epoch
#  Average loss 0.809
# Accuracy of the network on the 10000 test images: 65.380000 %
# This is global 401 epoch
#  Average loss 0.927
# Accuracy of the network on the 10000 test images: 62.870000 %
# This is global 402 epoch
#  Average loss 0.957
# Accuracy of the network on the 10000 test images: 65.300000 %
# This is global 403 epoch
#  Average loss 0.881
# Accuracy of the network on the 10000 test images: 63.700000 %
# This is global 404 epoch
#  Average loss 1.007
# Accuracy of the network on the 10000 test images: 66.710000 %
# This is global 405 epoch
#  Average loss 0.831
# Accuracy of the network on the 10000 test images: 67.150000 %
# This is global 406 epoch
#  Average loss 0.824
# Accuracy of the network on the 10000 test images: 67.060000 %
# This is global 407 epoch
#  Average loss 0.832
# Accuracy of the network on the 10000 test images: 66.650000 %
# This is global 408 epoch
#  Average loss 0.937
# Accuracy of the network on the 10000 test images: 66.860000 %
# This is global 409 epoch
#  Average loss 0.924
# Accuracy of the network on the 10000 test images: 66.240000 %
# This is global 410 epoch
#  Average loss 0.841
# Accuracy of the network on the 10000 test images: 66.650000 %
# This is global 411 epoch
#  Average loss 0.858
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 412 epoch
#  Average loss 0.950
# Accuracy of the network on the 10000 test images: 67.200000 %
# This is global 413 epoch
#  Average loss 0.818
# Accuracy of the network on the 10000 test images: 65.160000 %
# This is global 414 epoch
#  Average loss 0.799
# Accuracy of the network on the 10000 test images: 66.520000 %
# This is global 415 epoch
#  Average loss 0.872
# Accuracy of the network on the 10000 test images: 66.040000 %
# This is global 416 epoch
#  Average loss 1.028
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 417 epoch
#  Average loss 0.839
# Accuracy of the network on the 10000 test images: 62.910000 %
# This is global 418 epoch
#  Average loss 0.897
# Accuracy of the network on the 10000 test images: 64.300000 %
# This is global 419 epoch
#  Average loss 0.803
# Accuracy of the network on the 10000 test images: 63.890000 %
# This is global 420 epoch
#  Average loss 0.860
# Accuracy of the network on the 10000 test images: 66.600000 %
# This is global 421 epoch
#  Average loss 0.753
# Accuracy of the network on the 10000 test images: 63.520000 %
# This is global 422 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 65.230000 %
# This is global 423 epoch
#  Average loss 0.723
# Accuracy of the network on the 10000 test images: 63.520000 %
# This is global 424 epoch
#  Average loss 1.011
# Accuracy of the network on the 10000 test images: 66.580000 %
# This is global 425 epoch
#  Average loss 0.774
# Accuracy of the network on the 10000 test images: 66.980000 %
# This is global 426 epoch
#  Average loss 0.931
# Accuracy of the network on the 10000 test images: 67.000000 %
# This is global 427 epoch
#  Average loss 0.882
# Accuracy of the network on the 10000 test images: 65.460000 %
# This is global 428 epoch
#  Average loss 0.785
# Accuracy of the network on the 10000 test images: 66.150000 %
# This is global 429 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 65.990000 %
# This is global 430 epoch
#  Average loss 0.832
# Accuracy of the network on the 10000 test images: 66.700000 %
# This is global 431 epoch
#  Average loss 0.828
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 432 epoch
#  Average loss 0.889
# Accuracy of the network on the 10000 test images: 67.520000 %
# This is global 433 epoch
#  Average loss 0.865
# Accuracy of the network on the 10000 test images: 67.990000 %
# This is global 434 epoch
#  Average loss 0.916
# Accuracy of the network on the 10000 test images: 67.540000 %
# This is global 435 epoch
#  Average loss 0.810
# Accuracy of the network on the 10000 test images: 66.550000 %
# This is global 436 epoch
#  Average loss 0.831
# Accuracy of the network on the 10000 test images: 66.660000 %
# This is global 437 epoch
#  Average loss 0.788
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 438 epoch
#  Average loss 0.841
# Accuracy of the network on the 10000 test images: 67.910000 %
# This is global 439 epoch
#  Average loss 0.783
# Accuracy of the network on the 10000 test images: 68.010000 %
# This is global 440 epoch
#  Average loss 0.865
# Accuracy of the network on the 10000 test images: 67.610000 %
# This is global 441 epoch
#  Average loss 0.835
# Accuracy of the network on the 10000 test images: 67.700000 %
# This is global 442 epoch
#  Average loss 0.851
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 443 epoch
#  Average loss 0.837
# Accuracy of the network on the 10000 test images: 67.610000 %
# This is global 444 epoch
#  Average loss 0.766
# Accuracy of the network on the 10000 test images: 67.920000 %
# This is global 445 epoch
#  Average loss 0.779
# Accuracy of the network on the 10000 test images: 66.490000 %
# This is global 446 epoch
#  Average loss 0.844
# Accuracy of the network on the 10000 test images: 67.030000 %
# ...
# This is global 4853 epoch
#  Average loss 0.202
# Accuracy of the network on the 10000 test images: 62.530000 %
# This is global 4854 epoch
#  Average loss 0.108
# Accuracy of the network on the 10000 test images: 62.390000 %
# This is global 4855 epoch
#  Average loss 0.117
# Accuracy of the network on the 10000 test images: 62.520000 %
# This is global 4856 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 62.060000 %
# This is global 4857 epoch
#  Average loss 0.127
# Accuracy of the network on the 10000 test images: 62.270000 %
# This is global 4858 epoch
#  Average loss 0.104
# Accuracy of the network on the 10000 test images: 62.530000 %
# This is global 4859 epoch
#  Average loss 0.192
# Accuracy of the network on the 10000 test images: 62.270000 %
# This is global 4860 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 62.410000 %
# This is global 4861 epoch
#  Average loss 0.120
# Accuracy of the network on the 10000 test images: 62.310000 %
# This is global 4862 epoch
#  Average loss 0.169
# Accuracy of the network on the 10000 test images: 62.150000 %
# This is global 4863 epoch
#  Average loss 0.141
# Accuracy of the network on the 10000 test images: 62.220000 %
# This is global 4864 epoch
#  Average loss 0.119
# Accuracy of the network on the 10000 test images: 62.200000 %
# This is global 4865 epoch
#  Average loss 0.160
# Accuracy of the network on the 10000 test images: 62.000000 %
# This is global 4866 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 62.250000 %
# This is global 4867 epoch
#  Average loss 0.155
# Accuracy of the network on the 10000 test images: 61.930000 %
# This is global 4868 epoch
#  Average loss 0.180
# Accuracy of the network on the 10000 test images: 62.000000 %
# This is global 4869 epoch
#  Average loss 0.140
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 4870 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 4871 epoch
#  Average loss 0.112
# Accuracy of the network on the 10000 test images: 61.910000 %
# This is global 4872 epoch
#  Average loss 0.179
# Accuracy of the network on the 10000 test images: 61.760000 %
# This is global 4873 epoch
#  Average loss 0.113
# Accuracy of the network on the 10000 test images: 61.850000 %
# This is global 4874 epoch
#  Average loss 0.129
# Accuracy of the network on the 10000 test images: 62.250000 %
# This is global 4875 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 62.120000 %
# This is global 4876 epoch
#  Average loss 0.175
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 4877 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 62.030000 %
# This is global 4878 epoch
#  Average loss 0.130
# Accuracy of the network on the 10000 test images: 61.890000 %
# This is global 4879 epoch
#  Average loss 0.176
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 4880 epoch
#  Average loss 0.303
# Accuracy of the network on the 10000 test images: 61.070000 %
# This is global 4881 epoch
#  Average loss 0.511
# Accuracy of the network on the 10000 test images: 61.120000 %
# This is global 4882 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 61.270000 %
# This is global 4883 epoch
#  Average loss 0.309
# Accuracy of the network on the 10000 test images: 61.240000 %
# This is global 4884 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 4885 epoch
#  Average loss 0.328
# Accuracy of the network on the 10000 test images: 61.480000 %
# This is global 4886 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 61.380000 %
# This is global 4887 epoch
#  Average loss 0.186
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4888 epoch
#  Average loss 0.269
# Accuracy of the network on the 10000 test images: 61.180000 %
# This is global 4889 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 61.350000 %
# This is global 4890 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 61.490000 %
# This is global 4891 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 61.230000 %
# This is global 4892 epoch
#  Average loss 0.229
# Accuracy of the network on the 10000 test images: 61.600000 %
# This is global 4893 epoch
#  Average loss 0.208
# Accuracy of the network on the 10000 test images: 61.680000 %
# This is global 4894 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 61.580000 %
# This is global 4895 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 61.900000 %
# This is global 4896 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 61.780000 %
# This is global 4897 epoch
#  Average loss 0.149
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4898 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 62.140000 %
# This is global 4899 epoch
#  Average loss 0.105
# Accuracy of the network on the 10000 test images: 62.260000 %
# This is global 4900 epoch
#  Average loss 0.155
# Accuracy of the network on the 10000 test images: 61.960000 %
# This is global 4901 epoch
#  Average loss 0.139
# Accuracy of the network on the 10000 test images: 61.870000 %
# This is global 4902 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 61.600000 %
# This is global 4903 epoch
#  Average loss 0.299
# Accuracy of the network on the 10000 test images: 61.950000 %
# This is global 4904 epoch
#  Average loss 0.121
# Accuracy of the network on the 10000 test images: 62.080000 %
# This is global 4905 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 62.180000 %
# This is global 4906 epoch
#  Average loss 0.134
# Accuracy of the network on the 10000 test images: 62.320000 %
# This is global 4907 epoch
#  Average loss 0.132
# Accuracy of the network on the 10000 test images: 62.260000 %
# This is global 4908 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 4909 epoch
#  Average loss 0.100
# Accuracy of the network on the 10000 test images: 62.120000 %
# This is global 4910 epoch
#  Average loss 0.123
# Accuracy of the network on the 10000 test images: 62.190000 %
# This is global 4911 epoch
#  Average loss 0.087
# Accuracy of the network on the 10000 test images: 62.340000 %
# This is global 4912 epoch
#  Average loss 0.361
# Accuracy of the network on the 10000 test images: 62.080000 %
# This is global 4913 epoch
#  Average loss 0.138
# Accuracy of the network on the 10000 test images: 61.900000 %
# This is global 4914 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 61.850000 %
# This is global 4915 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 62.190000 %
# This is global 4916 epoch
#  Average loss 0.142
# Accuracy of the network on the 10000 test images: 62.210000 %
# This is global 4917 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 62.290000 %
# This is global 4918 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 61.990000 %
# This is global 4919 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 62.400000 %
# This is global 4920 epoch
#  Average loss 0.106
# Accuracy of the network on the 10000 test images: 62.150000 %
# This is global 4921 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 62.280000 %
# This is global 4922 epoch
#  Average loss 0.170
# Accuracy of the network on the 10000 test images: 62.120000 %
# This is global 4923 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 62.160000 %
# This is global 4924 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 62.430000 %
# This is global 4925 epoch
#  Average loss 0.109
# Accuracy of the network on the 10000 test images: 62.250000 %
# This is global 4926 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 62.260000 %
# This is global 4927 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 62.360000 %
# This is global 4928 epoch
#  Average loss 0.121
# Accuracy of the network on the 10000 test images: 62.120000 %
# This is global 4929 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 62.300000 %
# This is global 4930 epoch
#  Average loss 0.120
# Accuracy of the network on the 10000 test images: 62.410000 %
# This is global 4931 epoch
#  Average loss 0.180
# Accuracy of the network on the 10000 test images: 62.430000 %
# This is global 4932 epoch
#  Average loss 0.107
# Accuracy of the network on the 10000 test images: 62.220000 %
# This is global 4933 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 61.320000 %
# This is global 4934 epoch
#  Average loss 0.445
# Accuracy of the network on the 10000 test images: 60.970000 %
# This is global 4935 epoch
#  Average loss 0.388
# Accuracy of the network on the 10000 test images: 61.220000 %
# This is global 4936 epoch
#  Average loss 0.530
# Accuracy of the network on the 10000 test images: 61.110000 %
# This is global 4937 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 61.380000 %
# This is global 4938 epoch
#  Average loss 0.150
# Accuracy of the network on the 10000 test images: 61.770000 %
# This is global 4939 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 61.650000 %
# This is global 4940 epoch
#  Average loss 0.182
# Accuracy of the network on the 10000 test images: 61.660000 %
# This is global 4941 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 4942 epoch
#  Average loss 0.136
# Accuracy of the network on the 10000 test images: 61.660000 %
# This is global 4943 epoch
#  Average loss 0.139
# Accuracy of the network on the 10000 test images: 61.810000 %
# This is global 4944 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 61.760000 %
# This is global 4945 epoch
#  Average loss 0.146
# Accuracy of the network on the 10000 test images: 61.870000 %
# This is global 4946 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 62.130000 %
# This is global 4947 epoch
#  Average loss 0.167
# Accuracy of the network on the 10000 test images: 61.870000 %
# This is global 4948 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 61.630000 %
# This is global 4949 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 61.550000 %
# This is global 4950 epoch
#  Average loss 0.159
# Accuracy of the network on the 10000 test images: 61.770000 %
# This is global 4951 epoch
#  Average loss 0.152
# Accuracy of the network on the 10000 test images: 62.030000 %
# This is global 4952 epoch
#  Average loss 0.133
# Accuracy of the network on the 10000 test images: 62.100000 %
# This is global 4953 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 61.700000 %
# This is global 4954 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 61.750000 %
# This is global 4955 epoch
#  Average loss 0.206
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4956 epoch
#  Average loss 0.147
# Accuracy of the network on the 10000 test images: 62.000000 %
# This is global 4957 epoch
#  Average loss 0.123
# Accuracy of the network on the 10000 test images: 61.800000 %
# This is global 4958 epoch
#  Average loss 0.150
# Accuracy of the network on the 10000 test images: 61.790000 %
# This is global 4959 epoch
#  Average loss 0.206
# Accuracy of the network on the 10000 test images: 61.720000 %
# This is global 4960 epoch
#  Average loss 0.151
# Accuracy of the network on the 10000 test images: 61.860000 %
# This is global 4961 epoch
#  Average loss 0.141
# Accuracy of the network on the 10000 test images: 62.010000 %
# This is global 4962 epoch
#  Average loss 0.133
# Accuracy of the network on the 10000 test images: 62.080000 %
# This is global 4963 epoch
#  Average loss 0.137
# Accuracy of the network on the 10000 test images: 62.070000 %
# This is global 4964 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 62.060000 %
# This is global 4965 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 62.170000 %
# This is global 4966 epoch
#  Average loss 0.142
# Accuracy of the network on the 10000 test images: 62.060000 %
# This is global 4967 epoch
#  Average loss 0.112
# Accuracy of the network on the 10000 test images: 62.330000 %
# This is global 4968 epoch
#  Average loss 0.181
# Accuracy of the network on the 10000 test images: 62.130000 %
# This is global 4969 epoch
#  Average loss 0.113
# Accuracy of the network on the 10000 test images: 62.370000 %
# This is global 4970 epoch
#  Average loss 0.109
# Accuracy of the network on the 10000 test images: 62.040000 %
# This is global 4971 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 62.310000 %
# This is global 4972 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 62.380000 %
# This is global 4973 epoch
#  Average loss 0.115
# Accuracy of the network on the 10000 test images: 62.250000 %
# This is global 4974 epoch
#  Average loss 0.113
# Accuracy of the network on the 10000 test images: 62.170000 %
# This is global 4975 epoch
#  Average loss 0.145
# Accuracy of the network on the 10000 test images: 61.890000 %
# This is global 4976 epoch
#  Average loss 0.110
# Accuracy of the network on the 10000 test images: 61.640000 %
# This is global 4977 epoch
#  Average loss 0.095
# Accuracy of the network on the 10000 test images: 61.740000 %
# This is global 4978 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 62.090000 %
# This is global 4979 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 62.200000 %
# This is global 4980 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 62.170000 %
# This is global 4981 epoch
#  Average loss 0.190
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4982 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 60.980000 %
# This is global 4983 epoch
#  Average loss 0.124
# Accuracy of the network on the 10000 test images: 61.060000 %
# This is global 4984 epoch
#  Average loss 0.163
# Accuracy of the network on the 10000 test images: 61.460000 %
# This is global 4985 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 61.460000 %
# This is global 4986 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 4987 epoch
#  Average loss 0.207
# Accuracy of the network on the 10000 test images: 61.180000 %
# This is global 4988 epoch
#  Average loss 0.192
# Accuracy of the network on the 10000 test images: 61.240000 %
# This is global 4989 epoch
#  Average loss 0.162
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4990 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 61.970000 %
# This is global 4991 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 61.910000 %
# This is global 4992 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 62.100000 %
# This is global 4993 epoch
#  Average loss 0.146
# Accuracy of the network on the 10000 test images: 61.940000 %
# This is global 4994 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 62.030000 %
# This is global 4995 epoch
#  Average loss 0.102
# Accuracy of the network on the 10000 test images: 61.760000 %
# This is global 4996 epoch
#  Average loss 0.144
# Accuracy of the network on the 10000 test images: 61.880000 %
# This is global 4997 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 61.740000 %
# This is global 4998 epoch
#  Average loss 0.096
# Accuracy of the network on the 10000 test images: 61.980000 %
# This is global 4999 epoch
#  Average loss 0.179
# Accuracy of the network on the 10000 test images: 61.760000 %
# This is global 5000 epoch
#  Average loss 0.172
# Accuracy of the network on the 10000 test images: 60.090000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_noniid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %%
print(max(acc_train))
# Out:
# 69.3
