# %%
import torch
import torchvision
from torchvision import datasets, transforms
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import copy
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   

os.environ["CUDA_VISIBLE_DEVICES"]="1"

import matplotlib.pyplot as plt
import torch.optim as optim

# %%
torch.manual_seed(0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
CIFAR_SGD_trainloader = torch.utils.data.DataLoader(trainset, batch_size=500,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    #print(npimg)
    print(np.transpose(npimg, (1, 2, 0)).shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(np.transpose(npimg))#, (1, 2, 0)))
    plt.show()

# %%
'''for i in range(5):
    tmp=trainset[i]
    fig=plt.figure
    plt.imshow(np.transpose(tmp[0],(1,2,0)))
    plt.show()
    print(classes[tmp[1]])'''
# Out:
# 'for i in range(5):\n    tmp=trainset[i]\n    fig=plt.figure\n    plt.imshow(np.transpose(tmp[0],(1,2,0)))\n    plt.show()\n    print(classes[tmp[1]])'

# %%
'''# get some random training images
dataiter = iter(CIFAR_SGD_trainloader)
images, labels = dataiter.next()
print(images.shape)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# print size of single image
print(images[1].shape)'''
# Out:
# "# get some random training images\ndataiter = iter(CIFAR_SGD_trainloader)\nimages, labels = dataiter.next()\nprint(images.shape)\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n# print size of single image\nprint(images[1].shape)"

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return torch.tensor(image), torch.tensor(label)

# %%
def cifar_iid(dataset, num_users):
    """
    Sample I.I.D. client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    #num_items=8
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

# %%
'''cifar_iid_dataset=cifar_iid(trainset,2)
print(cifar_iid_dataset)'''
# Out:
# 'cifar_iid_dataset=cifar_iid(trainset,2)\nprint(cifar_iid_dataset)'

# %%
'''num_clients=2
num_items=8

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=8\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_iid_dataset[x])
    for i in range(num_items):
        image=trainset[index_list[i]][0]
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        plt.imshow(np.transpose(image,(1,2,0)))
        plt.show()
        print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_iid_dataset[x])\n    for i in range(num_items):\n        image=trainset[index_list[i]][0]\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        plt.imshow(np.transpose(image,(1,2,0)))\n        plt.show()\n        print(classes[trainset[index_list[i]][1]])'

# %%
def cifar_noniid(dataset, num_users):
    """
    Sample non-I.I.D client data from CIFAR10 dataset
    :param dataset:
    :param num_users:
    :return:
    """
    #num_shards, num_imgs = 200, 250
    #num_shards, num_imgs = 200, 250
    class_per_user=1
    num_shards=num_users*class_per_user
    num_imgs=int(len(dataset)/num_shards)
    idx_shard = [i for i in range(num_shards)]
    dict_users = {i: np.array([],dtype='int64') for i in range(num_users)}
    idxs = np.arange(num_shards*num_imgs)
    # labels = dataset.train_labels.numpy()
    #labels = np.array(dataset.train_labels)

    labels=[]
    for element in dataset:
        labels.append(int(element[1]))
    #print(type(labels[0]))
    labels=np.array(labels)
    #labels=labels.astype('int64')
    # sort labels
    
    idxs_labels = np.vstack((idxs, labels))
    idxs_labels = idxs_labels[:, idxs_labels[1, :].argsort()]
    idxs = idxs_labels[0, :]

    # divide and assign
    for i in range(num_users):
        rand_set = set(np.random.choice(idx_shard, class_per_user, replace=False))
        idx_shard = list(set(idx_shard) - rand_set)
        for rand in rand_set:
            dict_users[i] = np.concatenate(
                (dict_users[i], idxs[rand*num_imgs:(rand+1)*num_imgs]), axis=0)
    return dict_users

# %%
def cifar_dirichlet(dataset, n_nets, alpha=0.5):
    '''
    if dataset == 'mnist':
        X_train, y_train, X_test, y_test = load_mnist_data(datadir)
    elif dataset == 'cifar10':
        X_train, y_train, X_test, y_test = load_cifar10_data(datadir)
    '''
    #X_train=dataset[:][0]
    y_train=torch.zeros(len(dataset),dtype=torch.long)
    print(y_train.dtype)
    for a in range(len(dataset)):
        y_train[a]=(dataset[a][1])
    n_train = len(dataset)
    #X_train.shape[0]
    '''
    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_nets)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_nets)}
    '''
    #elif partition == "hetero-dir":
    min_size = 0
    K = 10
    N=len(dataset)
    N = y_train.shape[0]
    net_dataidx_map = {i: np.array([],dtype='int64') for i in range(n_nets)}

    while min_size < 10:
        idx_batch = [[] for _ in range(n_nets)]
        for k in range(K):
            idx_k = np.where(y_train == k)[0]
            np.random.shuffle(idx_k)
            proportions = np.random.dirichlet(np.repeat(alpha, n_nets))
            ## Balance
            proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
            proportions = proportions/proportions.sum()
            proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
            idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
            min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    #traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    return net_dataidx_map
    #return (X_train, y_train, X_test, y_test, net_dataidx_map, traindata_cls_counts)

# %%
'''cifar_noniid_dataset=cifar_noniid(trainset,2)
print(cifar_noniid_dataset)'''
# Out:
# 'cifar_noniid_dataset=cifar_noniid(trainset,2)\nprint(cifar_noniid_dataset)'

# %%
'''num_clients=2
num_items=250*2

for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)
    dataiter=iter(CIFAR_client_trainloader)
    for i in range(int(num_items/4)):
        images,labels=dataiter.next()
        print(images.shape)
        #print(trainset[index_list[i]])
        #print(image)
        fig=plt.figure
        imshow(torchvision.utils.make_grid(images))
        print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
        #print(classes[trainset[index_list[i]][1]])'''
# Out:
# 'num_clients=2\nnum_items=250*2\n\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    CIFAR_client_trainloader=DataLoader(DatasetSplit(trainset,index_list),batch_size=4,shuffle=False,num_workers=2)\n    dataiter=iter(CIFAR_client_trainloader)\n    for i in range(int(num_items/4)):\n        images,labels=dataiter.next()\n        print(images.shape)\n        #print(trainset[index_list[i]])\n        #print(image)\n        fig=plt.figure\n        imshow(torchvision.utils.make_grid(images))\n        print(\' \'.join(\'%5s\' % classes[labels[j]] for j in range(4)))\n        #print(classes[trainset[index_list[i]][1]])'

# %%
'''num_clients=2
num_items=5
num_imgs=250
cifar_noniid_dataset=cifar_noniid(trainset, num_clients)
#print(cifar_noniid_dataset)
for x in range(num_clients):
    print(f"This is {x} client")
    index_list=list(cifar_noniid_dataset[x])
    #print(index_list)
    #print(index_list[0])
    #print(type(index_list[0]))
    for y in range(2):
        for i in range(num_items):
            image=trainset[index_list[i+num_imgs*y]][0]
            #print(image)
            fig=plt.figure
            plt.imshow(np.transpose(image,(1,2,0)))
            plt.show()
            print(classes[trainset[index_list[i+num_imgs*y]][1]])'''
# Out:
# 'num_clients=2\nnum_items=5\nnum_imgs=250\ncifar_noniid_dataset=cifar_noniid(trainset, num_clients)\n#print(cifar_noniid_dataset)\nfor x in range(num_clients):\n    print(f"This is {x} client")\n    index_list=list(cifar_noniid_dataset[x])\n    #print(index_list)\n    #print(index_list[0])\n    #print(type(index_list[0]))\n    for y in range(2):\n        for i in range(num_items):\n            image=trainset[index_list[i+num_imgs*y]][0]\n            #print(image)\n            fig=plt.figure\n            plt.imshow(np.transpose(image,(1,2,0)))\n            plt.show()\n            print(classes[trainset[index_list[i+num_imgs*y]][1]])'

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.fc2 = nn.Linear(64, 10)
        
        
        
        self.conv1_global = nn.Conv2d(3, 32, 3)
        self.pool_global = nn.MaxPool2d(2, 2)
        self.conv2_global = nn.Conv2d(32, 64, 3)
        self.conv3_global = nn.Conv2d(64, 64, 3)
        self.fc1_global = nn.Linear(64 * 4 * 4, 64)
        self.fc2_global = nn.Linear(64, 10)
        self.freeze_model_global_weights()
        
        self.mse=nn.MSELoss()
        #self.fc3 = nn.Linear(84, 10)
    def freeze_model_global_weights(self):
        for n, m in self.named_modules():
            if hasattr(m, "weight") and m.weight is not None and 'global' in n:
                print(f"==> No gradient to {n}.weight")
                m.weight.requires_grad = False
                if m.weight.grad is not None:
                    print(f"==> Setting gradient of {n}.weight to None")
                    m.weight.grad = None

                if hasattr(m, "bias") and m.bias is not None and 'global' in n:
                    print(f"==> No gradient to {n}.bias")
                    m.bias.requires_grad = False

                    if m.bias.grad is not None:
                        print(f"==> Setting gradient of {n}.bias to None")
                        m.bias.grad = None
    def sync_online_and_global(self):
        state_dict=self.state_dict()
        for key in state_dict:
            if 'global' in key:
                x=(key.split("_global"))
                online=(x[0]+x[1])
                state_dict[key]=state_dict[online]
        self.load_state_dict(state_dict)
        
        
        
    def forward(self, x,online_target=False):
        if online_target==False:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = (F.relu(self.conv3(x)))
            x = x.view(-1, 64*4*4)
            x = F.relu(self.fc1(x))
            x = (self.fc2(x))
            return x
        else:
            x1=copy.deepcopy(x)
            
            
            x = self.pool(F.relu(self.conv1(x)))
            x1 = self.pool_global(F.relu(self.conv1_global(x1)))
            diff=self.mse(x,x1)
            
            x = self.pool(F.relu(self.conv2(x)))
            x1 = self.pool_global(F.relu(self.conv2_global(x1)))
            diff+=self.mse(x,x1)
            
            
            x = (F.relu(self.conv3(x)))
            x1 = (F.relu(self.conv3_global(x1)))
            diff+=self.mse(x,x1)
            
            x = x.view(-1, 64*4*4)
            x1 = x1.view(-1, 64*4*4)
            
            x = F.relu(self.fc1(x))
            x1 = F.relu(self.fc1_global(x1))
            diff+=self.mse(x,x1)
            
            
            x = (self.fc2(x))
            x1 = (self.fc2_global(x1))
            diff+=self.mse(x,x1)
            
            
            return x,diff

# %%
net = Net()
net.to(device)
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
#   (conv1_global): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool_global): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_global): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_global): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1_global): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2_global): Linear(in_features=64, out_features=10, bias=True)
#   (mse): MSELoss()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01,momentum=0.5)
loss_train = []
acc_train=[]

# %%
for epoch in range(0):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    for i, data in enumerate(CIFAR_SGD_trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(labels)

        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
       
        
    if epoch%1==0:
        loss_train.append(loss)
        print(f"epoch: {epoch}")
        print(' Average loss {:.3f}'.format( loss))
        for j in range(1):
            net.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %d %%' % (
                100 * correct / total))
        acc_train.append(100 * correct / total)

    net.train()

    '''# 통계를 출력합니다.
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0'''

print('Finished Training')
# Out:
# Finished Training

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# /home/dana/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Accuracy of the network on the 10000 test images: 10 %

# %%
class LocalUpdate(object):
    def __init__(self, lr,local_epoch,device,batch_size, dataset=None, idxs=None,alpha=0.001):
        self.lr=lr
        self.local_epoch=local_epoch
        self.device=device
        self.loss_func = nn.CrossEntropyLoss()
        self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset, idxs), batch_size=batch_size, shuffle=True)
        self.alpha=alpha

    def train(self, net):
        net.sync_online_and_global()
        net.train()
        # train and update
        optimizer = torch.optim.SGD(net.parameters(), lr=self.lr)

        epoch_loss = []
        for iter in range(self.local_epoch):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                net.zero_grad()
                log_probs,activation_l2 = net(images,online_target=True)
                loss = self.loss_func(log_probs, labels)+self.alpha*activation_l2
                loss.backward()
                optimizer.step()
                #if batch_idx % 10 == 0:
                #    print('Update Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #        iter, batch_idx * len(images), len(self.ldr_train.dataset),
                #               100. * batch_idx / len(self.ldr_train), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))
        return net.state_dict(), sum(epoch_loss) / len(epoch_loss)

# %% [markdown]
# cifar10 FedAvg iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=501
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
#CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_iid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 2.305
# Accuracy of the network on the 10000 test images: 10.350000 %
# This is global 1 epoch
#  Average loss 2.302
# Accuracy of the network on the 10000 test images: 14.310000 %
# This is global 2 epoch
#  Average loss 2.300
# Accuracy of the network on the 10000 test images: 13.640000 %
# This is global 3 epoch
#  Average loss 2.298
# Accuracy of the network on the 10000 test images: 13.910000 %
# This is global 4 epoch
#  Average loss 2.291
# Accuracy of the network on the 10000 test images: 13.620000 %
# This is global 5 epoch
#  Average loss 2.278
# Accuracy of the network on the 10000 test images: 21.690000 %
# This is global 6 epoch
#  Average loss 2.242
# Accuracy of the network on the 10000 test images: 21.760000 %
# This is global 7 epoch
#  Average loss 2.186
# Accuracy of the network on the 10000 test images: 19.930000 %
# This is global 8 epoch
#  Average loss 2.148
# Accuracy of the network on the 10000 test images: 22.870000 %
# This is global 9 epoch
#  Average loss 2.096
# Accuracy of the network on the 10000 test images: 24.870000 %
# This is global 10 epoch
#  Average loss 2.104
# Accuracy of the network on the 10000 test images: 26.740000 %
# This is global 11 epoch
#  Average loss 2.066
# Accuracy of the network on the 10000 test images: 26.380000 %
# This is global 12 epoch
#  Average loss 2.059
# Accuracy of the network on the 10000 test images: 28.150000 %
# This is global 13 epoch
#  Average loss 2.053
# Accuracy of the network on the 10000 test images: 25.250000 %
# This is global 14 epoch
#  Average loss 2.017
# Accuracy of the network on the 10000 test images: 27.030000 %
# This is global 15 epoch
#  Average loss 1.993
# Accuracy of the network on the 10000 test images: 30.520000 %
# This is global 16 epoch
#  Average loss 1.973
# Accuracy of the network on the 10000 test images: 31.060000 %
# This is global 17 epoch
#  Average loss 1.973
# Accuracy of the network on the 10000 test images: 29.010000 %
# This is global 18 epoch
#  Average loss 1.934
# Accuracy of the network on the 10000 test images: 32.540000 %
# This is global 19 epoch
#  Average loss 1.922
# Accuracy of the network on the 10000 test images: 31.430000 %
# This is global 20 epoch
#  Average loss 1.938
# Accuracy of the network on the 10000 test images: 31.510000 %
# This is global 21 epoch
#  Average loss 1.916
# Accuracy of the network on the 10000 test images: 33.760000 %
# This is global 22 epoch
#  Average loss 1.907
# Accuracy of the network on the 10000 test images: 33.890000 %
# This is global 23 epoch
#  Average loss 1.884
# Accuracy of the network on the 10000 test images: 31.660000 %
# This is global 24 epoch
#  Average loss 1.885
# Accuracy of the network on the 10000 test images: 33.190000 %
# This is global 25 epoch
#  Average loss 1.883
# Accuracy of the network on the 10000 test images: 34.250000 %
# This is global 26 epoch
#  Average loss 1.845
# Accuracy of the network on the 10000 test images: 35.930000 %
# This is global 27 epoch
#  Average loss 1.820
# Accuracy of the network on the 10000 test images: 36.150000 %
# This is global 28 epoch
#  Average loss 1.826
# Accuracy of the network on the 10000 test images: 38.830000 %
# This is global 29 epoch
#  Average loss 1.817
# Accuracy of the network on the 10000 test images: 37.360000 %
# This is global 30 epoch
#  Average loss 1.783
# Accuracy of the network on the 10000 test images: 39.230000 %
# This is global 31 epoch
#  Average loss 1.828
# Accuracy of the network on the 10000 test images: 37.500000 %
# This is global 32 epoch
#  Average loss 1.730
# Accuracy of the network on the 10000 test images: 39.520000 %
# This is global 33 epoch
#  Average loss 1.765
# Accuracy of the network on the 10000 test images: 37.830000 %
# This is global 34 epoch
#  Average loss 1.738
# Accuracy of the network on the 10000 test images: 40.390000 %
# This is global 35 epoch
#  Average loss 1.741
# Accuracy of the network on the 10000 test images: 39.610000 %
# This is global 36 epoch
#  Average loss 1.703
# Accuracy of the network on the 10000 test images: 41.240000 %
# This is global 37 epoch
#  Average loss 1.707
# Accuracy of the network on the 10000 test images: 40.930000 %
# This is global 38 epoch
#  Average loss 1.726
# Accuracy of the network on the 10000 test images: 42.080000 %
# This is global 39 epoch
#  Average loss 1.701
# Accuracy of the network on the 10000 test images: 42.000000 %
# This is global 40 epoch
#  Average loss 1.662
# Accuracy of the network on the 10000 test images: 42.220000 %
# This is global 41 epoch
#  Average loss 1.617
# Accuracy of the network on the 10000 test images: 41.860000 %
# This is global 42 epoch
#  Average loss 1.637
# Accuracy of the network on the 10000 test images: 42.780000 %
# This is global 43 epoch
#  Average loss 1.636
# Accuracy of the network on the 10000 test images: 43.170000 %
# This is global 44 epoch
#  Average loss 1.653
# Accuracy of the network on the 10000 test images: 42.450000 %
# This is global 45 epoch
#  Average loss 1.605
# Accuracy of the network on the 10000 test images: 44.320000 %
# This is global 46 epoch
#  Average loss 1.607
# Accuracy of the network on the 10000 test images: 42.500000 %
# This is global 47 epoch
#  Average loss 1.627
# Accuracy of the network on the 10000 test images: 45.070000 %
# This is global 48 epoch
#  Average loss 1.552
# Accuracy of the network on the 10000 test images: 44.930000 %
# This is global 49 epoch
#  Average loss 1.645
# Accuracy of the network on the 10000 test images: 45.520000 %
# This is global 50 epoch
#  Average loss 1.574
# Accuracy of the network on the 10000 test images: 46.710000 %
# This is global 51 epoch
#  Average loss 1.566
# Accuracy of the network on the 10000 test images: 45.060000 %
# This is global 52 epoch
#  Average loss 1.582
# Accuracy of the network on the 10000 test images: 46.990000 %
# This is global 53 epoch
#  Average loss 1.565
# Accuracy of the network on the 10000 test images: 47.570000 %
# This is global 54 epoch
#  Average loss 1.543
# Accuracy of the network on the 10000 test images: 46.100000 %
# This is global 55 epoch
#  Average loss 1.528
# Accuracy of the network on the 10000 test images: 46.590000 %
# This is global 56 epoch
#  Average loss 1.532
# Accuracy of the network on the 10000 test images: 46.020000 %
# This is global 57 epoch
#  Average loss 1.512
# Accuracy of the network on the 10000 test images: 46.770000 %
# This is global 58 epoch
#  Average loss 1.543
# Accuracy of the network on the 10000 test images: 48.510000 %
# This is global 59 epoch
#  Average loss 1.467
# Accuracy of the network on the 10000 test images: 48.200000 %
# This is global 60 epoch
#  Average loss 1.461
# Accuracy of the network on the 10000 test images: 47.760000 %
# This is global 61 epoch
#  Average loss 1.525
# Accuracy of the network on the 10000 test images: 48.150000 %
# This is global 62 epoch
#  Average loss 1.485
# Accuracy of the network on the 10000 test images: 47.900000 %
# This is global 63 epoch
#  Average loss 1.483
# Accuracy of the network on the 10000 test images: 48.720000 %
# This is global 64 epoch
#  Average loss 1.476
# Accuracy of the network on the 10000 test images: 49.030000 %
# This is global 65 epoch
#  Average loss 1.472
# Accuracy of the network on the 10000 test images: 49.190000 %
# This is global 66 epoch
#  Average loss 1.507
# Accuracy of the network on the 10000 test images: 49.050000 %
# This is global 67 epoch
#  Average loss 1.445
# Accuracy of the network on the 10000 test images: 48.110000 %
# This is global 68 epoch
#  Average loss 1.453
# Accuracy of the network on the 10000 test images: 48.300000 %
# This is global 69 epoch
#  Average loss 1.425
# Accuracy of the network on the 10000 test images: 48.560000 %
# This is global 70 epoch
#  Average loss 1.457
# Accuracy of the network on the 10000 test images: 49.760000 %
# This is global 71 epoch
#  Average loss 1.450
# Accuracy of the network on the 10000 test images: 48.840000 %
# This is global 72 epoch
#  Average loss 1.432
# Accuracy of the network on the 10000 test images: 51.230000 %
# This is global 73 epoch
#  Average loss 1.366
# Accuracy of the network on the 10000 test images: 49.880000 %
# This is global 74 epoch
#  Average loss 1.426
# Accuracy of the network on the 10000 test images: 51.190000 %
# This is global 75 epoch
#  Average loss 1.396
# Accuracy of the network on the 10000 test images: 51.460000 %
# This is global 76 epoch
#  Average loss 1.415
# Accuracy of the network on the 10000 test images: 50.590000 %
# This is global 77 epoch
#  Average loss 1.395
# Accuracy of the network on the 10000 test images: 50.490000 %
# This is global 78 epoch
#  Average loss 1.393
# Accuracy of the network on the 10000 test images: 52.510000 %
# This is global 79 epoch
#  Average loss 1.399
# Accuracy of the network on the 10000 test images: 51.060000 %
# This is global 80 epoch
#  Average loss 1.398
# Accuracy of the network on the 10000 test images: 52.120000 %
# This is global 81 epoch
#  Average loss 1.410
# Accuracy of the network on the 10000 test images: 51.350000 %
# This is global 82 epoch
#  Average loss 1.391
# Accuracy of the network on the 10000 test images: 50.950000 %
# This is global 83 epoch
#  Average loss 1.369
# Accuracy of the network on the 10000 test images: 51.580000 %
# This is global 84 epoch
#  Average loss 1.355
# Accuracy of the network on the 10000 test images: 51.560000 %
# This is global 85 epoch
#  Average loss 1.420
# Accuracy of the network on the 10000 test images: 52.360000 %
# This is global 86 epoch
#  Average loss 1.414
# Accuracy of the network on the 10000 test images: 51.440000 %
# This is global 87 epoch
#  Average loss 1.347
# Accuracy of the network on the 10000 test images: 52.780000 %
# This is global 88 epoch
#  Average loss 1.352
# Accuracy of the network on the 10000 test images: 53.970000 %
# This is global 89 epoch
#  Average loss 1.342
# Accuracy of the network on the 10000 test images: 54.050000 %
# This is global 90 epoch
#  Average loss 1.371
# Accuracy of the network on the 10000 test images: 54.150000 %
# This is global 91 epoch
#  Average loss 1.319
# Accuracy of the network on the 10000 test images: 53.000000 %
# This is global 92 epoch
#  Average loss 1.363
# Accuracy of the network on the 10000 test images: 54.690000 %
# This is global 93 epoch
#  Average loss 1.357
# Accuracy of the network on the 10000 test images: 53.490000 %
# This is global 94 epoch
#  Average loss 1.351
# Accuracy of the network on the 10000 test images: 53.040000 %
# This is global 95 epoch
#  Average loss 1.333
# Accuracy of the network on the 10000 test images: 54.830000 %
# This is global 96 epoch
#  Average loss 1.298
# Accuracy of the network on the 10000 test images: 54.750000 %
# This is global 97 epoch
#  Average loss 1.299
# Accuracy of the network on the 10000 test images: 55.500000 %
# This is global 98 epoch
#  Average loss 1.321
# Accuracy of the network on the 10000 test images: 55.850000 %
# This is global 99 epoch
#  Average loss 1.287
# Accuracy of the network on the 10000 test images: 52.560000 %
# This is global 100 epoch
#  Average loss 1.322
# Accuracy of the network on the 10000 test images: 55.490000 %
# This is global 101 epoch
#  Average loss 1.285
# Accuracy of the network on the 10000 test images: 55.130000 %
# This is global 102 epoch
#  Average loss 1.315
# Accuracy of the network on the 10000 test images: 55.670000 %
# This is global 103 epoch
#  Average loss 1.288
# Accuracy of the network on the 10000 test images: 54.090000 %
# This is global 104 epoch
#  Average loss 1.249
# Accuracy of the network on the 10000 test images: 56.290000 %
# This is global 105 epoch
#  Average loss 1.258
# Accuracy of the network on the 10000 test images: 55.470000 %
# This is global 106 epoch
#  Average loss 1.250
# Accuracy of the network on the 10000 test images: 56.120000 %
# This is global 107 epoch
#  Average loss 1.261
# Accuracy of the network on the 10000 test images: 56.140000 %
# This is global 108 epoch
#  Average loss 1.276
# Accuracy of the network on the 10000 test images: 56.550000 %
# This is global 109 epoch
#  Average loss 1.234
# Accuracy of the network on the 10000 test images: 56.730000 %
# This is global 110 epoch
#  Average loss 1.226
# Accuracy of the network on the 10000 test images: 56.000000 %
# This is global 111 epoch
#  Average loss 1.304
# Accuracy of the network on the 10000 test images: 57.210000 %
# This is global 112 epoch
#  Average loss 1.281
# Accuracy of the network on the 10000 test images: 56.450000 %
# This is global 113 epoch
#  Average loss 1.248
# Accuracy of the network on the 10000 test images: 57.000000 %
# This is global 114 epoch
#  Average loss 1.241
# Accuracy of the network on the 10000 test images: 57.720000 %
# This is global 115 epoch
#  Average loss 1.210
# Accuracy of the network on the 10000 test images: 56.970000 %
# This is global 116 epoch
#  Average loss 1.221
# Accuracy of the network on the 10000 test images: 56.950000 %
# This is global 117 epoch
#  Average loss 1.246
# Accuracy of the network on the 10000 test images: 57.680000 %
# This is global 118 epoch
#  Average loss 1.265
# Accuracy of the network on the 10000 test images: 58.160000 %
# This is global 119 epoch
#  Average loss 1.252
# Accuracy of the network on the 10000 test images: 58.330000 %
# This is global 120 epoch
#  Average loss 1.227
# Accuracy of the network on the 10000 test images: 57.750000 %
# This is global 121 epoch
#  Average loss 1.243
# Accuracy of the network on the 10000 test images: 57.730000 %
# This is global 122 epoch
#  Average loss 1.219
# Accuracy of the network on the 10000 test images: 58.070000 %
# This is global 123 epoch
#  Average loss 1.209
# Accuracy of the network on the 10000 test images: 58.120000 %
# This is global 124 epoch
#  Average loss 1.203
# Accuracy of the network on the 10000 test images: 57.190000 %
# This is global 125 epoch
#  Average loss 1.215
# Accuracy of the network on the 10000 test images: 58.610000 %
# This is global 126 epoch
#  Average loss 1.231
# Accuracy of the network on the 10000 test images: 59.120000 %
# This is global 127 epoch
#  Average loss 1.182
# Accuracy of the network on the 10000 test images: 57.910000 %
# This is global 128 epoch
#  Average loss 1.232
# Accuracy of the network on the 10000 test images: 59.250000 %
# This is global 129 epoch
#  Average loss 1.181
# Accuracy of the network on the 10000 test images: 59.800000 %
# This is global 130 epoch
#  Average loss 1.152
# Accuracy of the network on the 10000 test images: 58.820000 %
# This is global 131 epoch
#  Average loss 1.197
# Accuracy of the network on the 10000 test images: 58.690000 %
# This is global 132 epoch
#  Average loss 1.171
# Accuracy of the network on the 10000 test images: 56.810000 %
# This is global 133 epoch
#  Average loss 1.184
# Accuracy of the network on the 10000 test images: 58.910000 %
# This is global 134 epoch
#  Average loss 1.129
# Accuracy of the network on the 10000 test images: 59.190000 %
# This is global 135 epoch
#  Average loss 1.252
# Accuracy of the network on the 10000 test images: 59.600000 %
# This is global 136 epoch
#  Average loss 1.125
# Accuracy of the network on the 10000 test images: 60.060000 %
# This is global 137 epoch
#  Average loss 1.129
# Accuracy of the network on the 10000 test images: 57.320000 %
# This is global 138 epoch
#  Average loss 1.193
# Accuracy of the network on the 10000 test images: 59.160000 %
# This is global 139 epoch
#  Average loss 1.156
# Accuracy of the network on the 10000 test images: 59.460000 %
# This is global 140 epoch
#  Average loss 1.131
# Accuracy of the network on the 10000 test images: 60.580000 %
# This is global 141 epoch
#  Average loss 1.168
# Accuracy of the network on the 10000 test images: 61.000000 %
# This is global 142 epoch
#  Average loss 1.166
# Accuracy of the network on the 10000 test images: 61.330000 %
# This is global 143 epoch
#  Average loss 1.175
# Accuracy of the network on the 10000 test images: 60.930000 %
# This is global 144 epoch
#  Average loss 1.121
# Accuracy of the network on the 10000 test images: 60.800000 %
# This is global 145 epoch
#  Average loss 1.148
# Accuracy of the network on the 10000 test images: 60.880000 %
# This is global 146 epoch
#  Average loss 1.106
# Accuracy of the network on the 10000 test images: 60.320000 %
# This is global 147 epoch
#  Average loss 1.114
# Accuracy of the network on the 10000 test images: 60.450000 %
# This is global 148 epoch
#  Average loss 1.080
# Accuracy of the network on the 10000 test images: 58.320000 %
# This is global 149 epoch
#  Average loss 1.185
# Accuracy of the network on the 10000 test images: 61.450000 %
# This is global 150 epoch
#  Average loss 1.097
# Accuracy of the network on the 10000 test images: 60.420000 %
# This is global 151 epoch
#  Average loss 1.113
# Accuracy of the network on the 10000 test images: 60.600000 %
# This is global 152 epoch
#  Average loss 1.129
# Accuracy of the network on the 10000 test images: 60.730000 %
# This is global 153 epoch
#  Average loss 1.079
# Accuracy of the network on the 10000 test images: 62.000000 %
# This is global 154 epoch
#  Average loss 1.095
# Accuracy of the network on the 10000 test images: 61.950000 %
# This is global 155 epoch
#  Average loss 1.140
# Accuracy of the network on the 10000 test images: 61.740000 %
# This is global 156 epoch
#  Average loss 1.135
# Accuracy of the network on the 10000 test images: 60.950000 %
# This is global 157 epoch
#  Average loss 1.069
# Accuracy of the network on the 10000 test images: 59.680000 %
# This is global 158 epoch
#  Average loss 1.095
# Accuracy of the network on the 10000 test images: 62.090000 %
# This is global 159 epoch
#  Average loss 1.113
# Accuracy of the network on the 10000 test images: 60.630000 %
# This is global 160 epoch
#  Average loss 1.074
# Accuracy of the network on the 10000 test images: 62.230000 %
# This is global 161 epoch
#  Average loss 1.090
# Accuracy of the network on the 10000 test images: 62.320000 %
# This is global 162 epoch
#  Average loss 1.057
# Accuracy of the network on the 10000 test images: 62.180000 %
# This is global 163 epoch
#  Average loss 1.099
# Accuracy of the network on the 10000 test images: 62.920000 %
# This is global 164 epoch
#  Average loss 1.053
# Accuracy of the network on the 10000 test images: 62.930000 %
# This is global 165 epoch
#  Average loss 1.046
# Accuracy of the network on the 10000 test images: 62.020000 %
# This is global 166 epoch
#  Average loss 1.050
# Accuracy of the network on the 10000 test images: 62.790000 %
# This is global 167 epoch
#  Average loss 1.103
# Accuracy of the network on the 10000 test images: 62.980000 %
# This is global 168 epoch
#  Average loss 1.047
# Accuracy of the network on the 10000 test images: 62.720000 %
# This is global 169 epoch
#  Average loss 1.056
# Accuracy of the network on the 10000 test images: 62.810000 %
# This is global 170 epoch
#  Average loss 1.067
# Accuracy of the network on the 10000 test images: 60.480000 %
# This is global 171 epoch
#  Average loss 1.041
# Accuracy of the network on the 10000 test images: 62.470000 %
# This is global 172 epoch
#  Average loss 1.080
# Accuracy of the network on the 10000 test images: 63.360000 %
# This is global 173 epoch
#  Average loss 1.032
# Accuracy of the network on the 10000 test images: 62.620000 %
# This is global 174 epoch
#  Average loss 1.052
# Accuracy of the network on the 10000 test images: 63.670000 %
# This is global 175 epoch
#  Average loss 1.023
# Accuracy of the network on the 10000 test images: 62.970000 %
# This is global 176 epoch
#  Average loss 1.039
# Accuracy of the network on the 10000 test images: 63.610000 %
# This is global 177 epoch
#  Average loss 1.018
# Accuracy of the network on the 10000 test images: 64.210000 %
# This is global 178 epoch
#  Average loss 1.037
# Accuracy of the network on the 10000 test images: 64.190000 %
# This is global 179 epoch
#  Average loss 0.990
# Accuracy of the network on the 10000 test images: 64.480000 %
# This is global 180 epoch
#  Average loss 1.033
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 181 epoch
#  Average loss 0.974
# Accuracy of the network on the 10000 test images: 63.190000 %
# This is global 182 epoch
#  Average loss 1.039
# Accuracy of the network on the 10000 test images: 62.830000 %
# This is global 183 epoch
#  Average loss 0.995
# Accuracy of the network on the 10000 test images: 64.260000 %
# This is global 184 epoch
#  Average loss 1.027
# Accuracy of the network on the 10000 test images: 63.960000 %
# This is global 185 epoch
#  Average loss 0.933
# Accuracy of the network on the 10000 test images: 64.950000 %
# This is global 186 epoch
#  Average loss 0.987
# Accuracy of the network on the 10000 test images: 65.160000 %
# This is global 187 epoch
#  Average loss 0.975
# Accuracy of the network on the 10000 test images: 63.680000 %
# This is global 188 epoch
#  Average loss 0.991
# Accuracy of the network on the 10000 test images: 63.740000 %
# This is global 189 epoch
#  Average loss 1.051
# Accuracy of the network on the 10000 test images: 62.330000 %
# This is global 190 epoch
#  Average loss 0.951
# Accuracy of the network on the 10000 test images: 64.780000 %
# This is global 191 epoch
#  Average loss 1.017
# Accuracy of the network on the 10000 test images: 64.370000 %
# This is global 192 epoch
#  Average loss 1.000
# Accuracy of the network on the 10000 test images: 65.290000 %
# This is global 193 epoch
#  Average loss 0.972
# Accuracy of the network on the 10000 test images: 65.680000 %
# This is global 194 epoch
#  Average loss 1.017
# Accuracy of the network on the 10000 test images: 64.590000 %
# This is global 195 epoch
#  Average loss 0.975
# Accuracy of the network on the 10000 test images: 63.940000 %
# This is global 196 epoch
#  Average loss 0.941
# Accuracy of the network on the 10000 test images: 65.050000 %
# This is global 197 epoch
#  Average loss 0.954
# Accuracy of the network on the 10000 test images: 64.840000 %
# This is global 198 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 65.650000 %
# This is global 199 epoch
#  Average loss 1.005
# Accuracy of the network on the 10000 test images: 65.290000 %
# This is global 200 epoch
#  Average loss 0.966
# Accuracy of the network on the 10000 test images: 64.930000 %
# This is global 201 epoch
#  Average loss 0.991
# Accuracy of the network on the 10000 test images: 64.650000 %
# This is global 202 epoch
#  Average loss 0.953
# Accuracy of the network on the 10000 test images: 65.800000 %
# This is global 203 epoch
#  Average loss 1.009
# Accuracy of the network on the 10000 test images: 65.570000 %
# This is global 204 epoch
#  Average loss 0.951
# Accuracy of the network on the 10000 test images: 65.880000 %
# This is global 205 epoch
#  Average loss 0.944
# Accuracy of the network on the 10000 test images: 65.550000 %
# This is global 206 epoch
#  Average loss 1.005
# Accuracy of the network on the 10000 test images: 65.040000 %
# This is global 207 epoch
#  Average loss 0.967
# Accuracy of the network on the 10000 test images: 65.840000 %
# This is global 208 epoch
#  Average loss 0.899
# Accuracy of the network on the 10000 test images: 65.370000 %
# This is global 209 epoch
#  Average loss 1.012
# Accuracy of the network on the 10000 test images: 63.600000 %
# This is global 210 epoch
#  Average loss 0.952
# Accuracy of the network on the 10000 test images: 64.840000 %
# This is global 211 epoch
#  Average loss 1.026
# Accuracy of the network on the 10000 test images: 65.990000 %
# This is global 212 epoch
#  Average loss 0.914
# Accuracy of the network on the 10000 test images: 66.500000 %
# This is global 213 epoch
#  Average loss 0.902
# Accuracy of the network on the 10000 test images: 66.080000 %
# This is global 214 epoch
#  Average loss 0.906
# Accuracy of the network on the 10000 test images: 66.450000 %
# This is global 215 epoch
#  Average loss 0.937
# Accuracy of the network on the 10000 test images: 64.590000 %
# This is global 216 epoch
#  Average loss 0.985
# Accuracy of the network on the 10000 test images: 66.090000 %
# This is global 217 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 65.970000 %
# This is global 218 epoch
#  Average loss 0.879
# Accuracy of the network on the 10000 test images: 65.440000 %
# This is global 219 epoch
#  Average loss 0.908
# Accuracy of the network on the 10000 test images: 66.090000 %
# This is global 220 epoch
#  Average loss 0.951
# Accuracy of the network on the 10000 test images: 64.240000 %
# This is global 221 epoch
#  Average loss 0.944
# Accuracy of the network on the 10000 test images: 67.050000 %
# This is global 222 epoch
#  Average loss 0.835
# Accuracy of the network on the 10000 test images: 66.400000 %
# This is global 223 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 66.800000 %
# This is global 224 epoch
#  Average loss 0.871
# Accuracy of the network on the 10000 test images: 66.770000 %
# This is global 225 epoch
#  Average loss 0.929
# Accuracy of the network on the 10000 test images: 66.700000 %
# This is global 226 epoch
#  Average loss 0.943
# Accuracy of the network on the 10000 test images: 66.080000 %
# This is global 227 epoch
#  Average loss 0.901
# Accuracy of the network on the 10000 test images: 67.240000 %
# This is global 228 epoch
#  Average loss 0.942
# Accuracy of the network on the 10000 test images: 66.230000 %
# This is global 229 epoch
#  Average loss 0.903
# Accuracy of the network on the 10000 test images: 66.490000 %
# This is global 230 epoch
#  Average loss 0.890
# Accuracy of the network on the 10000 test images: 67.360000 %
# This is global 231 epoch
#  Average loss 0.955
# Accuracy of the network on the 10000 test images: 67.520000 %
# This is global 232 epoch
#  Average loss 0.884
# Accuracy of the network on the 10000 test images: 66.010000 %
# This is global 233 epoch
#  Average loss 0.865
# Accuracy of the network on the 10000 test images: 67.480000 %
# This is global 234 epoch
#  Average loss 0.846
# Accuracy of the network on the 10000 test images: 66.950000 %
# This is global 235 epoch
#  Average loss 0.880
# Accuracy of the network on the 10000 test images: 67.880000 %
# This is global 236 epoch
#  Average loss 0.935
# Accuracy of the network on the 10000 test images: 65.930000 %
# This is global 237 epoch
#  Average loss 0.880
# Accuracy of the network on the 10000 test images: 67.040000 %
# This is global 238 epoch
#  Average loss 0.858
# Accuracy of the network on the 10000 test images: 67.380000 %
# This is global 239 epoch
#  Average loss 0.932
# Accuracy of the network on the 10000 test images: 67.440000 %
# This is global 240 epoch
#  Average loss 0.902
# Accuracy of the network on the 10000 test images: 67.280000 %
# This is global 241 epoch
#  Average loss 0.905
# Accuracy of the network on the 10000 test images: 66.790000 %
# This is global 242 epoch
#  Average loss 0.866
# Accuracy of the network on the 10000 test images: 67.250000 %
# This is global 243 epoch
#  Average loss 0.878
# Accuracy of the network on the 10000 test images: 67.450000 %
# This is global 244 epoch
#  Average loss 0.892
# Accuracy of the network on the 10000 test images: 67.460000 %
# This is global 245 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 67.070000 %
# This is global 246 epoch
#  Average loss 0.806
# Accuracy of the network on the 10000 test images: 67.480000 %
# This is global 247 epoch
#  Average loss 0.929
# Accuracy of the network on the 10000 test images: 67.020000 %
# This is global 248 epoch
#  Average loss 0.902
# Accuracy of the network on the 10000 test images: 67.730000 %
# This is global 249 epoch
#  Average loss 0.842
# Accuracy of the network on the 10000 test images: 67.540000 %
# This is global 250 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 67.610000 %
# This is global 251 epoch
#  Average loss 0.834
# Accuracy of the network on the 10000 test images: 66.520000 %
# This is global 252 epoch
#  Average loss 0.874
# Accuracy of the network on the 10000 test images: 67.960000 %
# This is global 253 epoch
#  Average loss 0.900
# Accuracy of the network on the 10000 test images: 67.610000 %
# This is global 254 epoch
#  Average loss 0.852
# Accuracy of the network on the 10000 test images: 67.870000 %
# This is global 255 epoch
#  Average loss 0.845
# Accuracy of the network on the 10000 test images: 68.200000 %
# This is global 256 epoch
#  Average loss 0.911
# Accuracy of the network on the 10000 test images: 68.140000 %
# This is global 257 epoch
#  Average loss 0.808
# Accuracy of the network on the 10000 test images: 68.770000 %
# This is global 258 epoch
#  Average loss 0.850
# Accuracy of the network on the 10000 test images: 67.990000 %
# This is global 259 epoch
#  Average loss 0.853
# Accuracy of the network on the 10000 test images: 68.610000 %
# This is global 260 epoch
#  Average loss 0.826
# Accuracy of the network on the 10000 test images: 68.310000 %
# This is global 261 epoch
#  Average loss 0.799
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 262 epoch
#  Average loss 0.892
# Accuracy of the network on the 10000 test images: 67.320000 %
# This is global 263 epoch
#  Average loss 0.783
# Accuracy of the network on the 10000 test images: 68.530000 %
# This is global 264 epoch
#  Average loss 0.878
# Accuracy of the network on the 10000 test images: 68.970000 %
# This is global 265 epoch
#  Average loss 0.779
# Accuracy of the network on the 10000 test images: 68.280000 %
# This is global 266 epoch
#  Average loss 0.829
# Accuracy of the network on the 10000 test images: 67.520000 %
# This is global 267 epoch
#  Average loss 0.791
# Accuracy of the network on the 10000 test images: 68.390000 %
# This is global 268 epoch
#  Average loss 0.861
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 269 epoch
#  Average loss 0.864
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 270 epoch
#  Average loss 0.802
# Accuracy of the network on the 10000 test images: 67.780000 %
# This is global 271 epoch
#  Average loss 0.834
# Accuracy of the network on the 10000 test images: 68.790000 %
# This is global 272 epoch
#  Average loss 0.772
# Accuracy of the network on the 10000 test images: 69.130000 %
# This is global 273 epoch
#  Average loss 0.870
# Accuracy of the network on the 10000 test images: 66.720000 %
# This is global 274 epoch
#  Average loss 0.838
# Accuracy of the network on the 10000 test images: 68.500000 %
# This is global 275 epoch
#  Average loss 0.831
# Accuracy of the network on the 10000 test images: 66.540000 %
# This is global 276 epoch
#  Average loss 0.819
# Accuracy of the network on the 10000 test images: 68.560000 %
# This is global 277 epoch
#  Average loss 0.850
# Accuracy of the network on the 10000 test images: 67.510000 %
# This is global 278 epoch
#  Average loss 0.758
# Accuracy of the network on the 10000 test images: 68.700000 %
# This is global 279 epoch
#  Average loss 0.780
# Accuracy of the network on the 10000 test images: 68.840000 %
# This is global 280 epoch
#  Average loss 0.737
# Accuracy of the network on the 10000 test images: 69.410000 %
# This is global 281 epoch
#  Average loss 0.767
# Accuracy of the network on the 10000 test images: 69.520000 %
# This is global 282 epoch
#  Average loss 0.726
# Accuracy of the network on the 10000 test images: 68.470000 %
# This is global 283 epoch
#  Average loss 0.782
# Accuracy of the network on the 10000 test images: 68.580000 %
# This is global 284 epoch
#  Average loss 0.764
# Accuracy of the network on the 10000 test images: 69.390000 %
# This is global 285 epoch
#  Average loss 0.835
# Accuracy of the network on the 10000 test images: 68.360000 %
# This is global 286 epoch
#  Average loss 0.745
# Accuracy of the network on the 10000 test images: 69.680000 %
# This is global 287 epoch
#  Average loss 0.796
# Accuracy of the network on the 10000 test images: 68.630000 %
# This is global 288 epoch
#  Average loss 0.815
# Accuracy of the network on the 10000 test images: 68.770000 %
# This is global 289 epoch
#  Average loss 0.824
# Accuracy of the network on the 10000 test images: 67.710000 %
# This is global 290 epoch
#  Average loss 0.790
# Accuracy of the network on the 10000 test images: 68.870000 %
# This is global 291 epoch
#  Average loss 0.747
# Accuracy of the network on the 10000 test images: 69.470000 %
# This is global 292 epoch
#  Average loss 0.776
# Accuracy of the network on the 10000 test images: 68.720000 %
# This is global 293 epoch
#  Average loss 0.813
# Accuracy of the network on the 10000 test images: 69.210000 %
# This is global 294 epoch
#  Average loss 0.727
# Accuracy of the network on the 10000 test images: 69.060000 %
# This is global 295 epoch
#  Average loss 0.756
# Accuracy of the network on the 10000 test images: 70.070000 %
# This is global 296 epoch
#  Average loss 0.729
# Accuracy of the network on the 10000 test images: 69.140000 %
# This is global 297 epoch
#  Average loss 0.795
# Accuracy of the network on the 10000 test images: 68.610000 %
# This is global 298 epoch
#  Average loss 0.706
# Accuracy of the network on the 10000 test images: 69.910000 %
# This is global 299 epoch
#  Average loss 0.822
# Accuracy of the network on the 10000 test images: 68.660000 %
# This is global 300 epoch
#  Average loss 0.734
# Accuracy of the network on the 10000 test images: 69.980000 %
# This is global 301 epoch
#  Average loss 0.725
# Accuracy of the network on the 10000 test images: 68.650000 %
# This is global 302 epoch
#  Average loss 0.773
# Accuracy of the network on the 10000 test images: 69.500000 %
# This is global 303 epoch
#  Average loss 0.782
# Accuracy of the network on the 10000 test images: 69.060000 %
# This is global 304 epoch
#  Average loss 0.665
# Accuracy of the network on the 10000 test images: 69.820000 %
# This is global 305 epoch
#  Average loss 0.733
# Accuracy of the network on the 10000 test images: 69.780000 %
# This is global 306 epoch
#  Average loss 0.751
# Accuracy of the network on the 10000 test images: 69.980000 %
# This is global 307 epoch
#  Average loss 0.747
# Accuracy of the network on the 10000 test images: 68.970000 %
# This is global 308 epoch
#  Average loss 0.771
# Accuracy of the network on the 10000 test images: 69.270000 %
# This is global 309 epoch
#  Average loss 0.682
# Accuracy of the network on the 10000 test images: 68.440000 %
# This is global 310 epoch
#  Average loss 0.848
# Accuracy of the network on the 10000 test images: 69.590000 %
# This is global 311 epoch
#  Average loss 0.790
# Accuracy of the network on the 10000 test images: 69.520000 %
# This is global 312 epoch
#  Average loss 0.790
# Accuracy of the network on the 10000 test images: 69.900000 %
# This is global 313 epoch
#  Average loss 0.759
# Accuracy of the network on the 10000 test images: 69.800000 %
# This is global 314 epoch
#  Average loss 0.705
# Accuracy of the network on the 10000 test images: 69.460000 %
# This is global 315 epoch
#  Average loss 0.748
# Accuracy of the network on the 10000 test images: 70.070000 %
# This is global 316 epoch
#  Average loss 0.696
# Accuracy of the network on the 10000 test images: 68.940000 %
# This is global 317 epoch
#  Average loss 0.755
# Accuracy of the network on the 10000 test images: 69.620000 %
# This is global 318 epoch
#  Average loss 0.692
# Accuracy of the network on the 10000 test images: 69.310000 %
# This is global 319 epoch
#  Average loss 0.707
# Accuracy of the network on the 10000 test images: 68.380000 %
# This is global 320 epoch
#  Average loss 0.770
# Accuracy of the network on the 10000 test images: 69.320000 %
# This is global 321 epoch
#  Average loss 0.794
# Accuracy of the network on the 10000 test images: 69.840000 %
# This is global 322 epoch
#  Average loss 0.672
# Accuracy of the network on the 10000 test images: 69.580000 %
# This is global 323 epoch
#  Average loss 0.706
# Accuracy of the network on the 10000 test images: 69.220000 %
# This is global 324 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 70.190000 %
# This is global 325 epoch
#  Average loss 0.752
# Accuracy of the network on the 10000 test images: 70.410000 %
# This is global 326 epoch
#  Average loss 0.798
# Accuracy of the network on the 10000 test images: 69.780000 %
# This is global 327 epoch
#  Average loss 0.748
# Accuracy of the network on the 10000 test images: 69.260000 %
# This is global 328 epoch
#  Average loss 0.776
# Accuracy of the network on the 10000 test images: 69.680000 %
# This is global 329 epoch
#  Average loss 0.683
# Accuracy of the network on the 10000 test images: 69.530000 %
# This is global 330 epoch
#  Average loss 0.727
# Accuracy of the network on the 10000 test images: 70.800000 %
# This is global 331 epoch
#  Average loss 0.668
# Accuracy of the network on the 10000 test images: 69.100000 %
# This is global 332 epoch
#  Average loss 0.677
# Accuracy of the network on the 10000 test images: 70.590000 %
# This is global 333 epoch
#  Average loss 0.675
# Accuracy of the network on the 10000 test images: 70.530000 %
# This is global 334 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 69.450000 %
# This is global 335 epoch
#  Average loss 0.691
# Accuracy of the network on the 10000 test images: 69.920000 %
# This is global 336 epoch
#  Average loss 0.739
# Accuracy of the network on the 10000 test images: 70.270000 %
# This is global 337 epoch
#  Average loss 0.688
# Accuracy of the network on the 10000 test images: 69.090000 %
# This is global 338 epoch
#  Average loss 0.646
# Accuracy of the network on the 10000 test images: 70.620000 %
# This is global 339 epoch
#  Average loss 0.676
# Accuracy of the network on the 10000 test images: 70.130000 %
# This is global 340 epoch
#  Average loss 0.705
# Accuracy of the network on the 10000 test images: 69.540000 %
# This is global 341 epoch
#  Average loss 0.696
# Accuracy of the network on the 10000 test images: 70.250000 %
# This is global 342 epoch
#  Average loss 0.664
# Accuracy of the network on the 10000 test images: 70.690000 %
# This is global 343 epoch
#  Average loss 0.666
# Accuracy of the network on the 10000 test images: 70.240000 %
# This is global 344 epoch
#  Average loss 0.707
# Accuracy of the network on the 10000 test images: 70.970000 %
# This is global 345 epoch
#  Average loss 0.724
# Accuracy of the network on the 10000 test images: 70.880000 %
# This is global 346 epoch
#  Average loss 0.704
# Accuracy of the network on the 10000 test images: 70.280000 %
# This is global 347 epoch
#  Average loss 0.692
# Accuracy of the network on the 10000 test images: 70.200000 %
# This is global 348 epoch
#  Average loss 0.711
# Accuracy of the network on the 10000 test images: 70.410000 %
# This is global 349 epoch
#  Average loss 0.679
# Accuracy of the network on the 10000 test images: 70.320000 %
# This is global 350 epoch
#  Average loss 0.658
# Accuracy of the network on the 10000 test images: 70.940000 %
# This is global 351 epoch
#  Average loss 0.758
# Accuracy of the network on the 10000 test images: 70.440000 %
# This is global 352 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 353 epoch
#  Average loss 0.672
# Accuracy of the network on the 10000 test images: 70.670000 %
# This is global 354 epoch
#  Average loss 0.775
# Accuracy of the network on the 10000 test images: 69.760000 %
# This is global 355 epoch
#  Average loss 0.689
# Accuracy of the network on the 10000 test images: 69.330000 %
# This is global 356 epoch
#  Average loss 0.673
# Accuracy of the network on the 10000 test images: 69.780000 %
# This is global 357 epoch
#  Average loss 0.707
# Accuracy of the network on the 10000 test images: 70.190000 %
# This is global 358 epoch
#  Average loss 0.739
# Accuracy of the network on the 10000 test images: 70.380000 %
# This is global 359 epoch
#  Average loss 0.716
# Accuracy of the network on the 10000 test images: 70.120000 %
# This is global 360 epoch
#  Average loss 0.683
# Accuracy of the network on the 10000 test images: 70.220000 %
# This is global 361 epoch
#  Average loss 0.673
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 362 epoch
#  Average loss 0.682
# Accuracy of the network on the 10000 test images: 68.530000 %
# This is global 363 epoch
#  Average loss 0.619
# Accuracy of the network on the 10000 test images: 71.060000 %
# This is global 364 epoch
#  Average loss 0.648
# Accuracy of the network on the 10000 test images: 70.850000 %
# This is global 365 epoch
#  Average loss 0.720
# Accuracy of the network on the 10000 test images: 70.320000 %
# This is global 366 epoch
#  Average loss 0.665
# Accuracy of the network on the 10000 test images: 69.770000 %
# This is global 367 epoch
#  Average loss 0.618
# Accuracy of the network on the 10000 test images: 70.080000 %
# This is global 368 epoch
#  Average loss 0.582
# Accuracy of the network on the 10000 test images: 70.850000 %
# This is global 369 epoch
#  Average loss 0.671
# Accuracy of the network on the 10000 test images: 70.210000 %
# This is global 370 epoch
#  Average loss 0.648
# Accuracy of the network on the 10000 test images: 70.910000 %
# This is global 371 epoch
#  Average loss 0.641
# Accuracy of the network on the 10000 test images: 71.260000 %
# This is global 372 epoch
#  Average loss 0.537
# Accuracy of the network on the 10000 test images: 70.810000 %
# This is global 373 epoch
#  Average loss 0.674
# Accuracy of the network on the 10000 test images: 70.980000 %
# This is global 374 epoch
#  Average loss 0.623
# Accuracy of the network on the 10000 test images: 70.360000 %
# This is global 375 epoch
#  Average loss 0.613
# Accuracy of the network on the 10000 test images: 70.380000 %
# This is global 376 epoch
#  Average loss 0.586
# Accuracy of the network on the 10000 test images: 70.540000 %
# This is global 377 epoch
#  Average loss 0.548
# Accuracy of the network on the 10000 test images: 70.630000 %
# This is global 378 epoch
#  Average loss 0.725
# Accuracy of the network on the 10000 test images: 69.880000 %
# This is global 379 epoch
#  Average loss 0.625
# Accuracy of the network on the 10000 test images: 70.480000 %
# This is global 380 epoch
#  Average loss 0.678
# Accuracy of the network on the 10000 test images: 70.050000 %
# This is global 381 epoch
#  Average loss 0.561
# Accuracy of the network on the 10000 test images: 70.330000 %
# This is global 382 epoch
#  Average loss 0.578
# Accuracy of the network on the 10000 test images: 69.930000 %
# This is global 383 epoch
#  Average loss 0.686
# Accuracy of the network on the 10000 test images: 71.280000 %
# This is global 384 epoch
#  Average loss 0.674
# Accuracy of the network on the 10000 test images: 71.110000 %
# This is global 385 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 70.440000 %
# This is global 386 epoch
#  Average loss 0.626
# Accuracy of the network on the 10000 test images: 69.450000 %
# This is global 387 epoch
#  Average loss 0.652
# Accuracy of the network on the 10000 test images: 71.430000 %
# This is global 388 epoch
#  Average loss 0.581
# Accuracy of the network on the 10000 test images: 69.530000 %
# This is global 389 epoch
#  Average loss 0.643
# Accuracy of the network on the 10000 test images: 69.830000 %
# This is global 390 epoch
#  Average loss 0.666
# Accuracy of the network on the 10000 test images: 70.110000 %
# This is global 391 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 71.310000 %
# This is global 392 epoch
#  Average loss 0.590
# Accuracy of the network on the 10000 test images: 70.070000 %
# This is global 393 epoch
#  Average loss 0.594
# Accuracy of the network on the 10000 test images: 70.980000 %
# This is global 394 epoch
#  Average loss 0.632
# Accuracy of the network on the 10000 test images: 70.370000 %
# This is global 395 epoch
#  Average loss 0.648
# Accuracy of the network on the 10000 test images: 69.290000 %
# This is global 396 epoch
#  Average loss 0.671
# Accuracy of the network on the 10000 test images: 69.300000 %
# This is global 397 epoch
#  Average loss 0.596
# Accuracy of the network on the 10000 test images: 71.510000 %
# This is global 398 epoch
#  Average loss 0.640
# Accuracy of the network on the 10000 test images: 70.480000 %
# This is global 399 epoch
#  Average loss 0.593
# Accuracy of the network on the 10000 test images: 71.200000 %
# This is global 400 epoch
#  Average loss 0.512
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 401 epoch
#  Average loss 0.548
# Accuracy of the network on the 10000 test images: 70.740000 %
# This is global 402 epoch
#  Average loss 0.562
# Accuracy of the network on the 10000 test images: 70.200000 %
# This is global 403 epoch
#  Average loss 0.626
# Accuracy of the network on the 10000 test images: 69.570000 %
# This is global 404 epoch
#  Average loss 0.628
# Accuracy of the network on the 10000 test images: 70.590000 %
# This is global 405 epoch
#  Average loss 0.538
# Accuracy of the network on the 10000 test images: 70.340000 %
# This is global 406 epoch
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 70.080000 %
# This is global 407 epoch
#  Average loss 0.701
# Accuracy of the network on the 10000 test images: 69.200000 %
# This is global 408 epoch
#  Average loss 0.567
# Accuracy of the network on the 10000 test images: 71.010000 %
# This is global 409 epoch
#  Average loss 0.584
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 410 epoch
#  Average loss 0.587
# Accuracy of the network on the 10000 test images: 70.500000 %
# This is global 411 epoch
#  Average loss 0.547
# Accuracy of the network on the 10000 test images: 70.470000 %
# This is global 412 epoch
#  Average loss 0.574
# Accuracy of the network on the 10000 test images: 71.600000 %
# This is global 413 epoch
#  Average loss 0.576
# Accuracy of the network on the 10000 test images: 70.970000 %
# This is global 414 epoch
#  Average loss 0.564
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 415 epoch
#  Average loss 0.516
# Accuracy of the network on the 10000 test images: 70.110000 %
# This is global 416 epoch
#  Average loss 0.658
# Accuracy of the network on the 10000 test images: 69.820000 %
# This is global 417 epoch
#  Average loss 0.559
# Accuracy of the network on the 10000 test images: 70.960000 %
# This is global 418 epoch
#  Average loss 0.543
# Accuracy of the network on the 10000 test images: 70.420000 %
# This is global 419 epoch
#  Average loss 0.657
# Accuracy of the network on the 10000 test images: 70.160000 %
# This is global 420 epoch
#  Average loss 0.631
# Accuracy of the network on the 10000 test images: 70.760000 %
# This is global 421 epoch
#  Average loss 0.632
# Accuracy of the network on the 10000 test images: 70.000000 %
# This is global 422 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 70.610000 %
# This is global 423 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 71.430000 %
# This is global 424 epoch
#  Average loss 0.621
# Accuracy of the network on the 10000 test images: 70.340000 %
# This is global 425 epoch
#  Average loss 0.577
# Accuracy of the network on the 10000 test images: 70.000000 %
# This is global 426 epoch
#  Average loss 0.605
# Accuracy of the network on the 10000 test images: 70.550000 %
# This is global 427 epoch
#  Average loss 0.523
# Accuracy of the network on the 10000 test images: 70.860000 %
# This is global 428 epoch
#  Average loss 0.589
# Accuracy of the network on the 10000 test images: 70.840000 %
# This is global 429 epoch
#  Average loss 0.595
# Accuracy of the network on the 10000 test images: 70.180000 %
# This is global 430 epoch
#  Average loss 0.531
# Accuracy of the network on the 10000 test images: 70.850000 %
# This is global 431 epoch
#  Average loss 0.570
# Accuracy of the network on the 10000 test images: 70.440000 %
# This is global 432 epoch
#  Average loss 0.538
# Accuracy of the network on the 10000 test images: 70.160000 %
# This is global 433 epoch
#  Average loss 0.509
# Accuracy of the network on the 10000 test images: 71.300000 %
# This is global 434 epoch
#  Average loss 0.544
# Accuracy of the network on the 10000 test images: 70.780000 %
# This is global 435 epoch
#  Average loss 0.517
# Accuracy of the network on the 10000 test images: 70.830000 %
# This is global 436 epoch
#  Average loss 0.645
# Accuracy of the network on the 10000 test images: 69.690000 %
# This is global 437 epoch
#  Average loss 0.541
# Accuracy of the network on the 10000 test images: 70.930000 %
# This is global 438 epoch
#  Average loss 0.557
# Accuracy of the network on the 10000 test images: 70.220000 %
# This is global 439 epoch
#  Average loss 0.554
# Accuracy of the network on the 10000 test images: 70.540000 %
# This is global 440 epoch
#  Average loss 0.557
# Accuracy of the network on the 10000 test images: 71.470000 %
# This is global 441 epoch
#  Average loss 0.554
# Accuracy of the network on the 10000 test images: 70.420000 %
# This is global 442 epoch
#  Average loss 0.509
# Accuracy of the network on the 10000 test images: 70.360000 %
# This is global 443 epoch
#  Average loss 0.462
# Accuracy of the network on the 10000 test images: 70.410000 %
# This is global 444 epoch
#  Average loss 0.546
# Accuracy of the network on the 10000 test images: 70.220000 %
# This is global 445 epoch
#  Average loss 0.455
# Accuracy of the network on the 10000 test images: 71.220000 %
# This is global 446 epoch
#  Average loss 0.574
# Accuracy of the network on the 10000 test images: 70.460000 %
# This is global 447 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 70.810000 %
# This is global 448 epoch
#  Average loss 0.483
# Accuracy of the network on the 10000 test images: 70.370000 %
# This is global 449 epoch
#  Average loss 0.668
# Accuracy of the network on the 10000 test images: 70.890000 %
# This is global 450 epoch
#  Average loss 0.518
# Accuracy of the network on the 10000 test images: 70.470000 %
# This is global 451 epoch
#  Average loss 0.529
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 452 epoch
#  Average loss 0.535
# Accuracy of the network on the 10000 test images: 70.930000 %
# This is global 453 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 70.590000 %
# This is global 454 epoch
#  Average loss 0.446
# Accuracy of the network on the 10000 test images: 71.560000 %
# This is global 455 epoch
#  Average loss 0.634
# Accuracy of the network on the 10000 test images: 70.630000 %
# This is global 456 epoch
#  Average loss 0.539
# Accuracy of the network on the 10000 test images: 71.160000 %
# This is global 457 epoch
#  Average loss 0.437
# Accuracy of the network on the 10000 test images: 71.880000 %
# This is global 458 epoch
#  Average loss 0.454
# Accuracy of the network on the 10000 test images: 70.920000 %
# This is global 459 epoch
#  Average loss 0.572
# Accuracy of the network on the 10000 test images: 70.300000 %
# This is global 460 epoch
#  Average loss 0.450
# Accuracy of the network on the 10000 test images: 71.070000 %
# This is global 461 epoch
#  Average loss 0.539
# Accuracy of the network on the 10000 test images: 70.350000 %
# This is global 462 epoch
#  Average loss 0.488
# Accuracy of the network on the 10000 test images: 70.750000 %
# This is global 463 epoch
#  Average loss 0.565
# Accuracy of the network on the 10000 test images: 70.010000 %
# This is global 464 epoch
#  Average loss 0.466
# Accuracy of the network on the 10000 test images: 70.370000 %
# This is global 465 epoch
#  Average loss 0.512
# Accuracy of the network on the 10000 test images: 70.560000 %
# This is global 466 epoch
#  Average loss 0.576
# Accuracy of the network on the 10000 test images: 70.750000 %
# This is global 467 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 70.630000 %
# This is global 468 epoch
#  Average loss 0.511
# Accuracy of the network on the 10000 test images: 70.960000 %
# This is global 469 epoch
#  Average loss 0.572
# Accuracy of the network on the 10000 test images: 70.820000 %
# This is global 470 epoch
#  Average loss 0.545
# Accuracy of the network on the 10000 test images: 70.850000 %
# This is global 471 epoch
#  Average loss 0.501
# Accuracy of the network on the 10000 test images: 70.540000 %
# This is global 472 epoch
#  Average loss 0.511
# Accuracy of the network on the 10000 test images: 71.030000 %
# This is global 473 epoch
#  Average loss 0.446
# Accuracy of the network on the 10000 test images: 71.270000 %
# This is global 474 epoch
#  Average loss 0.479
# Accuracy of the network on the 10000 test images: 69.820000 %
# This is global 475 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 69.440000 %
# This is global 476 epoch
#  Average loss 0.424
# Accuracy of the network on the 10000 test images: 70.420000 %
# This is global 477 epoch
#  Average loss 0.477
# Accuracy of the network on the 10000 test images: 69.980000 %
# This is global 478 epoch
#  Average loss 0.561
# Accuracy of the network on the 10000 test images: 71.190000 %
# This is global 479 epoch
#  Average loss 0.479
# Accuracy of the network on the 10000 test images: 70.770000 %
# This is global 480 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 70.760000 %
# This is global 481 epoch
#  Average loss 0.442
# Accuracy of the network on the 10000 test images: 70.730000 %
# This is global 482 epoch
#  Average loss 0.472
# Accuracy of the network on the 10000 test images: 70.590000 %
# This is global 483 epoch
#  Average loss 0.452
# Accuracy of the network on the 10000 test images: 71.270000 %
# This is global 484 epoch
#  Average loss 0.346
# Accuracy of the network on the 10000 test images: 70.920000 %
# This is global 485 epoch
#  Average loss 0.663
# Accuracy of the network on the 10000 test images: 70.250000 %
# This is global 486 epoch
#  Average loss 0.491
# Accuracy of the network on the 10000 test images: 70.890000 %
# This is global 487 epoch
#  Average loss 0.430
# Accuracy of the network on the 10000 test images: 70.200000 %
# This is global 488 epoch
#  Average loss 0.380
# Accuracy of the network on the 10000 test images: 71.440000 %
# This is global 489 epoch
#  Average loss 0.481
# Accuracy of the network on the 10000 test images: 70.970000 %
# This is global 490 epoch
#  Average loss 0.500
# Accuracy of the network on the 10000 test images: 70.640000 %
# This is global 491 epoch
#  Average loss 0.507
# Accuracy of the network on the 10000 test images: 69.860000 %
# This is global 492 epoch
#  Average loss 0.479
# Accuracy of the network on the 10000 test images: 70.290000 %
# This is global 493 epoch
#  Average loss 0.389
# Accuracy of the network on the 10000 test images: 70.950000 %
# This is global 494 epoch
#  Average loss 0.539
# Accuracy of the network on the 10000 test images: 71.040000 %
# This is global 495 epoch
#  Average loss 0.532
# Accuracy of the network on the 10000 test images: 70.920000 %
# This is global 496 epoch
#  Average loss 0.451
# Accuracy of the network on the 10000 test images: 71.140000 %
# This is global 497 epoch
#  Average loss 0.529
# Accuracy of the network on the 10000 test images: 70.720000 %
# This is global 498 epoch
#  Average loss 0.451
# Accuracy of the network on the 10000 test images: 70.580000 %
# This is global 499 epoch
#  Average loss 0.391
# Accuracy of the network on the 10000 test images: 70.500000 %
# This is global 500 epoch
#  Average loss 0.520
# Accuracy of the network on the 10000 test images: 70.780000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_iid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %% [markdown]
# cifar10 FedAvg Non-iid로 학습

# %%
device=torch.device('cuda')
FedAvg_model=Net().cuda()
criterion= nn.CrossEntropyLoss().to(device)
FedAvg_model.train()
epoch_loss = []

# Set optimizer for the local updates

optimizer = torch.optim.SGD(FedAvg_model.parameters(), lr=0.001,
                                momentum=0.9)
global_epoch=5001
# Out:
# ==> No gradient to conv1_global.weight
# ==> No gradient to conv1_global.bias
# ==> No gradient to conv2_global.weight
# ==> No gradient to conv2_global.bias
# ==> No gradient to conv3_global.weight
# ==> No gradient to conv3_global.bias
# ==> No gradient to fc1_global.weight
# ==> No gradient to fc1_global.bias
# ==> No gradient to fc2_global.weight
# ==> No gradient to fc2_global.bias

# %%
weight_saved=FedAvg_model.state_dict()

# %%
C=0.05
num_clients=100
CIFAR_noniid_dataset=cifar_noniid(trainset, num_clients)
#CIFAR_iid_dataset=cifar_iid(trainset, num_clients)
loss_train = []
acc_train=[]

# %%
for epoch in range(global_epoch):
    local_weight=[]
    local_loss=[]
    m=max(int(C*num_clients),1)
    selected_user=np.random.choice(range(num_clients),m,replace=False)
    print(f"This is global {epoch} epoch")
    for user in selected_user:
        local_setting=LocalUpdate(lr=0.1,local_epoch=1,device=device,batch_size=40,dataset=trainset, idxs=CIFAR_noniid_dataset[user])
        weight,loss=local_setting.train(net=copy.deepcopy(FedAvg_model).to(device))
        local_weight.append(copy.deepcopy(weight))
        #print(local_weight[0].keys())
        local_loss.append(copy.deepcopy(loss))
    FedAvg_weight=copy.deepcopy(local_weight[0])
    for key in FedAvg_weight.keys():
        for i in range(1,len(local_weight)):
            FedAvg_weight[key]+=local_weight[i][key]
        FedAvg_weight[key]/=len(local_weight)
    FedAvg_model.load_state_dict(FedAvg_weight)
    loss_avg = sum(local_loss) / len(local_loss)
    print(' Average loss {:.3f}'.format( loss_avg))
    loss_train.append(loss_avg)
    if epoch%1==0:
        for j in range(1):
            FedAvg_model.eval()         
            correct = 0
            total = 0
            with torch.no_grad():
                for data in testloader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = FedAvg_model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the 10000 test images: %f %%' % (
                100 * correct / float(total)))
        acc_train.append(100 * correct / float(total))
 
    FedAvg_model.train()
# Out:
# This is global 0 epoch
# /home/dana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#  Average loss 0.719
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 1 epoch
#  Average loss 0.492
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 2 epoch
#  Average loss 0.552
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 3 epoch
#  Average loss 0.556
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 4 epoch
#  Average loss 0.312
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 5 epoch
#  Average loss 0.419
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 6 epoch
#  Average loss 0.318
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 7 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 8 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 9 epoch
#  Average loss 0.255
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 10 epoch
#  Average loss 0.142
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 11 epoch
#  Average loss 0.254
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 12 epoch
#  Average loss 0.337
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 13 epoch
#  Average loss 0.249
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 14 epoch
#  Average loss 0.268
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 15 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 16 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 17 epoch
#  Average loss 0.379
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 18 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 19 epoch
#  Average loss 0.304
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 20 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 21 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 22 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 23 epoch
#  Average loss 0.184
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 24 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 25 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 26 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 27 epoch
#  Average loss 0.303
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 28 epoch
#  Average loss 0.349
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 29 epoch
#  Average loss 0.204
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 30 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 31 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 32 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 33 epoch
#  Average loss 0.143
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 34 epoch
#  Average loss 0.569
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 35 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 36 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 37 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 38 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 39 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 40 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 41 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 42 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 43 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 44 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 45 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 46 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 47 epoch
#  Average loss 0.243
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 48 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 49 epoch
#  Average loss 0.296
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 50 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 51 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 52 epoch
#  Average loss 0.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 53 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 54 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 55 epoch
#  Average loss 0.396
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 56 epoch
#  Average loss 0.335
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 57 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 58 epoch
#  Average loss 0.207
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 59 epoch
#  Average loss 0.182
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 60 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 61 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 62 epoch
#  Average loss 0.167
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 63 epoch
#  Average loss 0.270
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 64 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 65 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 66 epoch
#  Average loss 0.329
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 67 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 68 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 69 epoch
#  Average loss 0.364
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 70 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 71 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 72 epoch
#  Average loss 0.211
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 73 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 74 epoch
#  Average loss 0.269
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 75 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 76 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 77 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 78 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 79 epoch
#  Average loss 0.349
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 80 epoch
#  Average loss 0.348
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 81 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 82 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 83 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 84 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 85 epoch
#  Average loss 0.188
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 86 epoch
#  Average loss 0.363
# Accuracy of the network on the 10000 test images: 10.020000 %
# This is global 87 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 88 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 89 epoch
#  Average loss 0.323
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 90 epoch
#  Average loss 0.281
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 91 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 92 epoch
#  Average loss 0.330
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 93 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 94 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 95 epoch
#  Average loss 0.214
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 96 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 97 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 98 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 99 epoch
#  Average loss 0.370
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 100 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 101 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 102 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 103 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 104 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 105 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 106 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 107 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 108 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 109 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 110 epoch
#  Average loss 0.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 111 epoch
#  Average loss 0.255
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 112 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 113 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 114 epoch
#  Average loss 0.172
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 115 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 116 epoch
#  Average loss 0.196
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 117 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 118 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 119 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 120 epoch
#  Average loss 0.179
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 121 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 122 epoch
#  Average loss 0.357
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 123 epoch
#  Average loss 0.288
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 124 epoch
#  Average loss 0.344
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 125 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 126 epoch
#  Average loss 0.176
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 127 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 128 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 129 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 130 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 131 epoch
#  Average loss 0.179
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 132 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 133 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 134 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 135 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 136 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 137 epoch
#  Average loss 0.315
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 138 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 139 epoch
#  Average loss 0.283
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 140 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 141 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 142 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 143 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 144 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 145 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 146 epoch
#  Average loss 0.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 147 epoch
#  Average loss 0.212
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 148 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 149 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 150 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 151 epoch
#  Average loss 0.370
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 152 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 153 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 154 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 155 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 156 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 157 epoch
#  Average loss 0.355
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 158 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 159 epoch
#  Average loss 0.126
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 160 epoch
#  Average loss 0.416
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 161 epoch
#  Average loss 0.282
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 162 epoch
#  Average loss 0.229
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 163 epoch
#  Average loss 0.219
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 164 epoch
#  Average loss 0.291
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 165 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 166 epoch
#  Average loss 0.351
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 167 epoch
#  Average loss 0.313
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 168 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 169 epoch
#  Average loss 0.234
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 170 epoch
#  Average loss 0.208
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 171 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 172 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 173 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 174 epoch
#  Average loss 0.258
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 175 epoch
#  Average loss 0.134
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 176 epoch
#  Average loss 0.344
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 177 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 178 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 179 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 180 epoch
#  Average loss 0.273
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 181 epoch
#  Average loss 0.322
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 182 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 9.990000 %
# This is global 183 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 184 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 185 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 186 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 187 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 188 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 189 epoch
#  Average loss 0.322
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 190 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 191 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 192 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 193 epoch
#  Average loss 0.315
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 194 epoch
#  Average loss 0.251
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 195 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 196 epoch
#  Average loss 0.286
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 197 epoch
#  Average loss 0.278
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 198 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 199 epoch
#  Average loss 0.257
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 200 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 201 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 202 epoch
#  Average loss 0.320
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 203 epoch
#  Average loss 0.288
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 204 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 205 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 206 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 207 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 208 epoch
#  Average loss 0.289
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 209 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 210 epoch
#  Average loss 0.155
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 211 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 212 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 213 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 214 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 215 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 216 epoch
#  Average loss 0.169
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 217 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 218 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 219 epoch
#  Average loss 0.313
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 220 epoch
#  Average loss 0.232
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 221 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 222 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 223 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 224 epoch
#  Average loss 0.176
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 225 epoch
#  Average loss 0.316
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 226 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 227 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 228 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 229 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 230 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 231 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 232 epoch
#  Average loss 0.416
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 233 epoch
#  Average loss 0.350
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 234 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 235 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 236 epoch
#  Average loss 0.307
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 237 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 238 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 239 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 240 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 241 epoch
#  Average loss 0.233
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 242 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 243 epoch
#  Average loss 0.253
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 244 epoch
#  Average loss 0.165
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 245 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 246 epoch
#  Average loss 0.366
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 247 epoch
#  Average loss 0.295
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 248 epoch
#  Average loss 0.224
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 249 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 250 epoch
#  Average loss 0.212
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 251 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 252 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 253 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 254 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 255 epoch
#  Average loss 0.200
# Accuracy of the network on the 10000 test images: 10.530000 %
# This is global 256 epoch
#  Average loss 0.205
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 257 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 258 epoch
#  Average loss 0.193
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 259 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 260 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 261 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 262 epoch
#  Average loss 0.220
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 263 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 264 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 265 epoch
#  Average loss 0.251
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 266 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 267 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 268 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 269 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 270 epoch
#  Average loss 0.169
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 271 epoch
#  Average loss 0.370
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 272 epoch
#  Average loss 0.372
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 273 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 274 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 275 epoch
#  Average loss 0.168
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 276 epoch
#  Average loss 0.270
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 277 epoch
#  Average loss 0.270
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 278 epoch
#  Average loss 0.308
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 279 epoch
#  Average loss 0.258
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 280 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 281 epoch
#  Average loss 0.349
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 282 epoch
#  Average loss 0.259
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 283 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 284 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 285 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 286 epoch
#  Average loss 0.244
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 287 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 288 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 289 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 290 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 291 epoch
#  Average loss 0.284
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 292 epoch
#  Average loss 0.239
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 293 epoch
#  Average loss 0.153
# Accuracy of the network on the 10000 test images: 12.820000 %
# This is global 294 epoch
#  Average loss 0.292
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 295 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 296 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 297 epoch
#  Average loss 0.266
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 298 epoch
#  Average loss 0.352
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 299 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 300 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 301 epoch
#  Average loss 0.289
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 302 epoch
#  Average loss 0.181
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 303 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 304 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 305 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 13.570000 %
# This is global 306 epoch
#  Average loss 0.156
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 307 epoch
#  Average loss 0.280
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 308 epoch
#  Average loss 0.215
# Accuracy of the network on the 10000 test images: 10.970000 %
# This is global 309 epoch
#  Average loss 0.153
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 310 epoch
#  Average loss 0.341
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 311 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 312 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 313 epoch
#  Average loss 0.293
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 314 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 12.290000 %
# This is global 315 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 13.560000 %
# This is global 316 epoch
#  Average loss 0.169
# Accuracy of the network on the 10000 test images: 14.250000 %
# This is global 317 epoch
#  Average loss 0.254
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 318 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 17.570000 %
# This is global 319 epoch
#  Average loss 0.250
# Accuracy of the network on the 10000 test images: 12.620000 %
# This is global 320 epoch
#  Average loss 0.255
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 321 epoch
#  Average loss 0.314
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 322 epoch
#  Average loss 0.261
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 323 epoch
#  Average loss 0.300
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 324 epoch
#  Average loss 0.329
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 325 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 326 epoch
#  Average loss 0.168
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 327 epoch
#  Average loss 0.364
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 328 epoch
#  Average loss 0.397
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 329 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 330 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 14.410000 %
# This is global 331 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 332 epoch
#  Average loss 0.277
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 333 epoch
#  Average loss 0.189
# Accuracy of the network on the 10000 test images: 13.030000 %
# This is global 334 epoch
#  Average loss 0.227
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 335 epoch
#  Average loss 0.201
# Accuracy of the network on the 10000 test images: 13.590000 %
# This is global 336 epoch
#  Average loss 0.188
# Accuracy of the network on the 10000 test images: 13.950000 %
# This is global 337 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 10.440000 %
# This is global 338 epoch
#  Average loss 0.168
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 339 epoch
#  Average loss 0.180
# Accuracy of the network on the 10000 test images: 10.010000 %
# This is global 340 epoch
#  Average loss 0.188
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 341 epoch
#  Average loss 0.225
# Accuracy of the network on the 10000 test images: 11.800000 %
# This is global 342 epoch
#  Average loss 0.223
# Accuracy of the network on the 10000 test images: 15.880000 %
# This is global 343 epoch
#  Average loss 0.206
# Accuracy of the network on the 10000 test images: 18.520000 %
# This is global 344 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 13.320000 %
# This is global 345 epoch
#  Average loss 0.211
# Accuracy of the network on the 10000 test images: 14.100000 %
# This is global 346 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 12.590000 %
# This is global 347 epoch
#  Average loss 0.305
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 348 epoch
#  Average loss 0.267
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 349 epoch
#  Average loss 0.249
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 350 epoch
#  Average loss 0.245
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 351 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 14.890000 %
# This is global 352 epoch
#  Average loss 0.186
# Accuracy of the network on the 10000 test images: 11.800000 %
# This is global 353 epoch
#  Average loss 0.218
# Accuracy of the network on the 10000 test images: 10.300000 %
# This is global 354 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 355 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 356 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 357 epoch
#  Average loss 0.202
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 358 epoch
#  Average loss 0.262
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 359 epoch
#  Average loss 0.312
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 360 epoch
#  Average loss 0.338
# Accuracy of the network on the 10000 test images: 15.970000 %
# This is global 361 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 362 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 12.020000 %
# This is global 363 epoch
#  Average loss 0.168
# Accuracy of the network on the 10000 test images: 11.050000 %
# This is global 364 epoch
#  Average loss 0.418
# Accuracy of the network on the 10000 test images: 15.730000 %
# This is global 365 epoch
#  Average loss 0.189
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 366 epoch
#  Average loss 0.268
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 367 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 368 epoch
#  Average loss 0.218
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 369 epoch
#  Average loss 0.172
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 370 epoch
#  Average loss 0.274
# Accuracy of the network on the 10000 test images: 13.290000 %
# This is global 371 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 372 epoch
#  Average loss 0.287
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 373 epoch
#  Average loss 0.177
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 374 epoch
#  Average loss 0.448
# Accuracy of the network on the 10000 test images: 10.140000 %
# This is global 375 epoch
#  Average loss 0.285
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 376 epoch
#  Average loss 0.343
# Accuracy of the network on the 10000 test images: 14.900000 %
# This is global 377 epoch
#  Average loss 0.271
# Accuracy of the network on the 10000 test images: 15.040000 %
# This is global 378 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 13.750000 %
# This is global 379 epoch
#  Average loss 0.310
# Accuracy of the network on the 10000 test images: 12.190000 %
# This is global 380 epoch
#  Average loss 0.211
# Accuracy of the network on the 10000 test images: 16.020000 %
# This is global 381 epoch
#  Average loss 0.154
# Accuracy of the network on the 10000 test images: 12.690000 %
# This is global 382 epoch
#  Average loss 0.263
# Accuracy of the network on the 10000 test images: 13.250000 %
# This is global 383 epoch
#  Average loss 0.230
# Accuracy of the network on the 10000 test images: 10.120000 %
# This is global 384 epoch
#  Average loss 0.301
# Accuracy of the network on the 10000 test images: 10.070000 %
# This is global 385 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 11.670000 %
# This is global 386 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 17.040000 %
# This is global 387 epoch
#  Average loss 0.213
# Accuracy of the network on the 10000 test images: 16.440000 %
# This is global 388 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 12.810000 %
# This is global 389 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 390 epoch
#  Average loss 0.286
# Accuracy of the network on the 10000 test images: 10.570000 %
# This is global 391 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 17.190000 %
# This is global 392 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 16.030000 %
# This is global 393 epoch
#  Average loss 0.258
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 394 epoch
#  Average loss 0.209
# Accuracy of the network on the 10000 test images: 11.830000 %
# This is global 395 epoch
#  Average loss 0.341
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 396 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 15.600000 %
# This is global 397 epoch
#  Average loss 0.197
# Accuracy of the network on the 10000 test images: 18.230000 %
# This is global 398 epoch
#  Average loss 0.189
# Accuracy of the network on the 10000 test images: 15.860000 %
# This is global 399 epoch
#  Average loss 0.195
# Accuracy of the network on the 10000 test images: 16.880000 %
# This is global 400 epoch
#  Average loss 0.198
# Accuracy of the network on the 10000 test images: 11.050000 %
# This is global 401 epoch
#  Average loss 0.276
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 402 epoch
#  Average loss 0.212
# Accuracy of the network on the 10000 test images: 16.750000 %
# This is global 403 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 17.340000 %
# This is global 404 epoch
#  Average loss 0.240
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 405 epoch
#  Average loss 0.226
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 406 epoch
#  Average loss 0.222
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 407 epoch
#  Average loss 0.252
# Accuracy of the network on the 10000 test images: 21.490000 %
# This is global 408 epoch
#  Average loss 0.191
# Accuracy of the network on the 10000 test images: 13.900000 %
# This is global 409 epoch
#  Average loss 0.221
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 410 epoch
#  Average loss 0.199
# Accuracy of the network on the 10000 test images: 17.240000 %
# This is global 411 epoch
#  Average loss 0.191
# Accuracy of the network on the 10000 test images: 19.350000 %
# This is global 412 epoch
#  Average loss 0.279
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 413 epoch
#  Average loss 0.205
# Accuracy of the network on the 10000 test images: 15.060000 %
# This is global 414 epoch
#  Average loss 0.241
# Accuracy of the network on the 10000 test images: 17.720000 %
# This is global 415 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 13.230000 %
# This is global 416 epoch
#  Average loss 0.361
# Accuracy of the network on the 10000 test images: 10.810000 %
# This is global 417 epoch
#  Average loss 0.235
# Accuracy of the network on the 10000 test images: 10.840000 %
# This is global 418 epoch
#  Average loss 0.325
# Accuracy of the network on the 10000 test images: 14.900000 %
# This is global 419 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 420 epoch
#  Average loss 0.183
# Accuracy of the network on the 10000 test images: 10.520000 %
# This is global 421 epoch
#  Average loss 0.289
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 422 epoch
#  Average loss 0.185
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 423 epoch
#  Average loss 0.217
# Accuracy of the network on the 10000 test images: 10.270000 %
# This is global 424 epoch
#  Average loss 0.206
# Accuracy of the network on the 10000 test images: 10.260000 %
# This is global 425 epoch
#  Average loss 0.256
# Accuracy of the network on the 10000 test images: 11.980000 %
# This is global 426 epoch
#  Average loss 0.248
# Accuracy of the network on the 10000 test images: 11.220000 %
# This is global 427 epoch
#  Average loss 0.302
# Accuracy of the network on the 10000 test images: 17.220000 %
# This is global 428 epoch
#  Average loss 0.168
# Accuracy of the network on the 10000 test images: 17.380000 %
# This is global 429 epoch
#  Average loss 0.238
# Accuracy of the network on the 10000 test images: 10.290000 %
# This is global 430 epoch
#  Average loss 0.247
# Accuracy of the network on the 10000 test images: 11.800000 %
# This is global 431 epoch
#  Average loss 0.194
# Accuracy of the network on the 10000 test images: 15.730000 %
# This is global 432 epoch
#  Average loss 0.242
# Accuracy of the network on the 10000 test images: 10.000000 %
# This is global 433 epoch
#  Average loss 0.254
# Accuracy of the network on the 10000 test images: 12.820000 %
# This is global 434 epoch
#  Average loss 0.178
# Accuracy of the network on the 10000 test images: 12.950000 %
# This is global 435 epoch
#  Average loss 0.187
# Accuracy of the network on the 10000 test images: 10.690000 %
# This is global 436 epoch
#  Average loss 0.264
# Accuracy of the network on the 10000 test images: 10.030000 %
# This is global 437 epoch
#  Average loss 0.289
# Accuracy of the network on the 10000 test images: 19.840000 %
# This is global 438 epoch
#  Average loss 0.172
# Accuracy of the network on the 10000 test images: 10.090000 %
# This is global 439 epoch
#  Average loss 0.203
# Accuracy of the network on the 10000 test images: 11.430000 %
# This is global 440 epoch
#  Average loss 0.210
# Accuracy of the network on the 10000 test images: 15.520000 %
# This is global 441 epoch
#  Average loss 0.246
# Accuracy of the network on the 10000 test images: 13.670000 %
# This is global 442 epoch
#  Average loss 0.216
# Accuracy of the network on the 10000 test images: 10.820000 %
# This is global 443 epoch
#  Average loss 0.290
# Accuracy of the network on the 10000 test images: 10.590000 %
# This is global 444 epoch
#  Average loss 0.236
# Accuracy of the network on the 10000 test images: 13.790000 %
# This is global 445 epoch
#  Average loss 0.228
# Accuracy of the network on the 10000 test images: 17.250000 %
# This is global 446 epoch
#  Average loss 0.231
# Accuracy of the network on the 10000 test images: 16.250000 %
# ...
# This is global 4853 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 68.060000 %
# This is global 4854 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 67.530000 %
# This is global 4855 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 65.110000 %
# This is global 4856 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 64.610000 %
# This is global 4857 epoch
#  Average loss 0.094
# Accuracy of the network on the 10000 test images: 43.130000 %
# This is global 4858 epoch
#  Average loss 0.174
# Accuracy of the network on the 10000 test images: 55.350000 %
# This is global 4859 epoch
#  Average loss 0.122
# Accuracy of the network on the 10000 test images: 64.180000 %
# This is global 4860 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 65.280000 %
# This is global 4861 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 58.340000 %
# This is global 4862 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 59.350000 %
# This is global 4863 epoch
#  Average loss 0.106
# Accuracy of the network on the 10000 test images: 66.460000 %
# This is global 4864 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 64.500000 %
# This is global 4865 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 65.730000 %
# This is global 4866 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 67.370000 %
# This is global 4867 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 63.400000 %
# This is global 4868 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 65.830000 %
# This is global 4869 epoch
#  Average loss 0.066
# Accuracy of the network on the 10000 test images: 64.310000 %
# This is global 4870 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 66.160000 %
# This is global 4871 epoch
#  Average loss 0.114
# Accuracy of the network on the 10000 test images: 64.010000 %
# This is global 4872 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 66.950000 %
# This is global 4873 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 67.240000 %
# This is global 4874 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 65.850000 %
# This is global 4875 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 56.380000 %
# This is global 4876 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 65.690000 %
# This is global 4877 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 65.530000 %
# This is global 4878 epoch
#  Average loss 0.091
# Accuracy of the network on the 10000 test images: 68.260000 %
# This is global 4879 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 64.190000 %
# This is global 4880 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 66.830000 %
# This is global 4881 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 68.030000 %
# This is global 4882 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 67.480000 %
# This is global 4883 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 62.860000 %
# This is global 4884 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 66.150000 %
# This is global 4885 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 66.850000 %
# This is global 4886 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 66.860000 %
# This is global 4887 epoch
#  Average loss 0.099
# Accuracy of the network on the 10000 test images: 63.210000 %
# This is global 4888 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 66.570000 %
# This is global 4889 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 60.740000 %
# This is global 4890 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 63.500000 %
# This is global 4891 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 4892 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 67.550000 %
# This is global 4893 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 66.590000 %
# This is global 4894 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 69.570000 %
# This is global 4895 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 64.510000 %
# This is global 4896 epoch
#  Average loss 0.049
# Accuracy of the network on the 10000 test images: 62.620000 %
# This is global 4897 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 69.190000 %
# This is global 4898 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 65.330000 %
# This is global 4899 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 60.910000 %
# This is global 4900 epoch
#  Average loss 0.079
# Accuracy of the network on the 10000 test images: 66.480000 %
# This is global 4901 epoch
#  Average loss 0.068
# Accuracy of the network on the 10000 test images: 68.420000 %
# This is global 4902 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 64.610000 %
# This is global 4903 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 68.160000 %
# This is global 4904 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 64.920000 %
# This is global 4905 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 64.050000 %
# This is global 4906 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 64.330000 %
# This is global 4907 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 67.860000 %
# This is global 4908 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 68.860000 %
# This is global 4909 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 62.290000 %
# This is global 4910 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 67.230000 %
# This is global 4911 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 65.600000 %
# This is global 4912 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 64.140000 %
# This is global 4913 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 64.390000 %
# This is global 4914 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 68.640000 %
# This is global 4915 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 67.180000 %
# This is global 4916 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 63.010000 %
# This is global 4917 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 65.100000 %
# This is global 4918 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 65.710000 %
# This is global 4919 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 66.360000 %
# This is global 4920 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 63.430000 %
# This is global 4921 epoch
#  Average loss 0.084
# Accuracy of the network on the 10000 test images: 68.310000 %
# This is global 4922 epoch
#  Average loss 0.043
# Accuracy of the network on the 10000 test images: 65.560000 %
# This is global 4923 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 66.320000 %
# This is global 4924 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 69.110000 %
# This is global 4925 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 69.800000 %
# This is global 4926 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 69.250000 %
# This is global 4927 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 67.800000 %
# This is global 4928 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 69.490000 %
# This is global 4929 epoch
#  Average loss 0.051
# Accuracy of the network on the 10000 test images: 68.580000 %
# This is global 4930 epoch
#  Average loss 0.092
# Accuracy of the network on the 10000 test images: 67.190000 %
# This is global 4931 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 68.380000 %
# This is global 4932 epoch
#  Average loss 0.063
# Accuracy of the network on the 10000 test images: 67.110000 %
# This is global 4933 epoch
#  Average loss 0.041
# Accuracy of the network on the 10000 test images: 63.590000 %
# This is global 4934 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 64.580000 %
# This is global 4935 epoch
#  Average loss 0.044
# Accuracy of the network on the 10000 test images: 64.980000 %
# This is global 4936 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 63.750000 %
# This is global 4937 epoch
#  Average loss 0.101
# Accuracy of the network on the 10000 test images: 65.760000 %
# This is global 4938 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 65.210000 %
# This is global 4939 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 64.740000 %
# This is global 4940 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 61.700000 %
# This is global 4941 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 63.190000 %
# This is global 4942 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 65.240000 %
# This is global 4943 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 67.810000 %
# This is global 4944 epoch
#  Average loss 0.038
# Accuracy of the network on the 10000 test images: 62.790000 %
# This is global 4945 epoch
#  Average loss 0.053
# Accuracy of the network on the 10000 test images: 67.190000 %
# This is global 4946 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 66.060000 %
# This is global 4947 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 68.300000 %
# This is global 4948 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 67.830000 %
# This is global 4949 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 64.450000 %
# This is global 4950 epoch
#  Average loss 0.050
# Accuracy of the network on the 10000 test images: 63.200000 %
# This is global 4951 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 65.570000 %
# This is global 4952 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 66.260000 %
# This is global 4953 epoch
#  Average loss 0.086
# Accuracy of the network on the 10000 test images: 63.810000 %
# This is global 4954 epoch
#  Average loss 0.047
# Accuracy of the network on the 10000 test images: 65.050000 %
# This is global 4955 epoch
#  Average loss 0.089
# Accuracy of the network on the 10000 test images: 66.640000 %
# This is global 4956 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 67.470000 %
# This is global 4957 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 67.850000 %
# This is global 4958 epoch
#  Average loss 0.036
# Accuracy of the network on the 10000 test images: 65.420000 %
# This is global 4959 epoch
#  Average loss 0.061
# Accuracy of the network on the 10000 test images: 65.120000 %
# This is global 4960 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 62.310000 %
# This is global 4961 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 61.130000 %
# This is global 4962 epoch
#  Average loss 0.111
# Accuracy of the network on the 10000 test images: 69.240000 %
# This is global 4963 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 69.390000 %
# This is global 4964 epoch
#  Average loss 0.069
# Accuracy of the network on the 10000 test images: 66.540000 %
# This is global 4965 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 67.930000 %
# This is global 4966 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 64.530000 %
# This is global 4967 epoch
#  Average loss 0.046
# Accuracy of the network on the 10000 test images: 63.700000 %
# This is global 4968 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 66.090000 %
# This is global 4969 epoch
#  Average loss 0.070
# Accuracy of the network on the 10000 test images: 67.620000 %
# This is global 4970 epoch
#  Average loss 0.062
# Accuracy of the network on the 10000 test images: 64.710000 %
# This is global 4971 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 66.140000 %
# This is global 4972 epoch
#  Average loss 0.104
# Accuracy of the network on the 10000 test images: 61.540000 %
# This is global 4973 epoch
#  Average loss 0.072
# Accuracy of the network on the 10000 test images: 66.290000 %
# This is global 4974 epoch
#  Average loss 0.071
# Accuracy of the network on the 10000 test images: 66.820000 %
# This is global 4975 epoch
#  Average loss 0.040
# Accuracy of the network on the 10000 test images: 66.310000 %
# This is global 4976 epoch
#  Average loss 0.052
# Accuracy of the network on the 10000 test images: 66.890000 %
# This is global 4977 epoch
#  Average loss 0.045
# Accuracy of the network on the 10000 test images: 65.550000 %
# This is global 4978 epoch
#  Average loss 0.088
# Accuracy of the network on the 10000 test images: 66.530000 %
# This is global 4979 epoch
#  Average loss 0.073
# Accuracy of the network on the 10000 test images: 67.310000 %
# This is global 4980 epoch
#  Average loss 0.067
# Accuracy of the network on the 10000 test images: 64.040000 %
# This is global 4981 epoch
#  Average loss 0.060
# Accuracy of the network on the 10000 test images: 62.500000 %
# This is global 4982 epoch
#  Average loss 0.093
# Accuracy of the network on the 10000 test images: 60.360000 %
# This is global 4983 epoch
#  Average loss 0.080
# Accuracy of the network on the 10000 test images: 62.600000 %
# This is global 4984 epoch
#  Average loss 0.055
# Accuracy of the network on the 10000 test images: 66.520000 %
# This is global 4985 epoch
#  Average loss 0.039
# Accuracy of the network on the 10000 test images: 63.680000 %
# This is global 4986 epoch
#  Average loss 0.056
# Accuracy of the network on the 10000 test images: 66.010000 %
# This is global 4987 epoch
#  Average loss 0.076
# Accuracy of the network on the 10000 test images: 64.680000 %
# This is global 4988 epoch
#  Average loss 0.075
# Accuracy of the network on the 10000 test images: 69.110000 %
# This is global 4989 epoch
#  Average loss 0.065
# Accuracy of the network on the 10000 test images: 65.300000 %
# This is global 4990 epoch
#  Average loss 0.077
# Accuracy of the network on the 10000 test images: 63.510000 %
# This is global 4991 epoch
#  Average loss 0.057
# Accuracy of the network on the 10000 test images: 63.620000 %
# This is global 4992 epoch
#  Average loss 0.078
# Accuracy of the network on the 10000 test images: 68.180000 %
# This is global 4993 epoch
#  Average loss 0.054
# Accuracy of the network on the 10000 test images: 67.750000 %
# This is global 4994 epoch
#  Average loss 0.058
# Accuracy of the network on the 10000 test images: 67.730000 %
# This is global 4995 epoch
#  Average loss 0.031
# Accuracy of the network on the 10000 test images: 63.530000 %
# This is global 4996 epoch
#  Average loss 0.109
# Accuracy of the network on the 10000 test images: 61.250000 %
# This is global 4997 epoch
#  Average loss 0.059
# Accuracy of the network on the 10000 test images: 64.560000 %
# This is global 4998 epoch
#  Average loss 0.048
# Accuracy of the network on the 10000 test images: 66.210000 %
# This is global 4999 epoch
#  Average loss 0.085
# Accuracy of the network on the 10000 test images: 65.190000 %
# This is global 5000 epoch
#  Average loss 0.090
# Accuracy of the network on the 10000 test images: 64.150000 %

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
line1=ax1.plot(np.array(loss_train),color='g',label='loss_train')
line2=ax2.plot([i*1 for i in range(len(acc_train))],acc_train,label='acc_train')
lines=line1+line2
ax1.set_ylabel("loss")
ax2.set_ylabel("accuracy")
plt.xlabel('Epoch')
plt.title('Experiment Result')
plt.legend(lines,['loss_train','acc_train'])
plt.show()

# %%
PATH = './data/CIFAR_noniid_net_moreparam.pth'
torch.save( FedAvg_model.state_dict(), PATH)

# %%
print(max(acc_train))
# Out:
# 70.05
